# %% [markdown]
# # Experiment: Compare N prev Trial Not started (scaled)
#
# **Goal**: See adding stimulus interaction terms improves model fit compared to models without interaction terms as measured by bits/trial and delta log likelihood
#
# **Summary**: The binary encoding of previous timeout history appears to fit best.
#
# Related notebooks:
#
#
# * `2024_02_20_dev_trial_not_started.ipynb`
# * `2024_02_20_EXP_fit_prev_trial_not_started.ipynb`
# * `2024_02_20_EXP_fit_n_prev_trial_not_started.ipynb`
# * `2024_02_20_EXP_fit_prev_disengaged_scaled.ipynb`
#
# > Written by Jess Breda

# %% [markdown]
# ## Imports

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd

from multiglm.experiments.experiment import load_experiment
from multiglm.experiments.experiment_compare_models import ExperimentCompareModels
from multiglm.features.design_matrix_generator import DesignMatrixGeneratorInteractions, DesignMatrixGeneratorFilteredHistory
from multiglm.models.multiclass_logistic_regression import MultiClassLogisticRegression
from multiglm.visualizations.model_visualizer import ModelVisualizerCompare
from multiglm.utils.fitting_utils import create_violation_interaction_pairs
from multiglm.data import ANIMAL_IDS

sns.set_context("talk")
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# ## Model Configs

# %%
model_config = {
    "psytrack_features": {  # MODEL 1- pystrack multi base
        "model_class": MultiClassLogisticRegression,
        "model_type": "multi",
        "design_matrix_generator": DesignMatrixGeneratorFilteredHistory,
        "filter_implementation": {"prev_violation": -1},  # no filter & drop column
    },
    "filter_prev_violation_stim_itrx": {  # MODEL 2- with filt prev violation history and stim interactions
        "model_class": MultiClassLogisticRegression,
        "model_type": "multi",
        "design_matrix_generator": DesignMatrixGeneratorInteractions,
        "filter_implementation": {
            "prev_violation": 1
        },  # filter column with animals tau,
        "design_matrix_generator_args": {
            "interaction_pairs": create_violation_interaction_pairs(["s_a", "s_b"])
        },
    },
    "prev_not_started": {  # MODEL 3- with filt prev history and n prev not started
        "model_class": MultiClassLogisticRegression,
        "model_type": "multi",
        "design_matrix_generator": DesignMatrixGeneratorFilteredHistory,
        "filter_implementation": {
            "prev_violation": 1
        },  # filter column with animals tau,
        "design_matrix_generator_args": {
            "trial_not_started": "prev",
            "interaction_pairs": create_violation_interaction_pairs(["s_a", "s_b"]),
        },
    },
    "n_prev_not_started": {  # MODEL 4- with filt prev history and n prev not started
        "model_class": MultiClassLogisticRegression,
        "model_type": "multi",
        "design_matrix_generator": DesignMatrixGeneratorFilteredHistory,
        "filter_implementation": {
            "prev_violation": 1
        },  # filter column with animals tau,
        "design_matrix_generator_args": {
            "trial_not_started": "n_prev",
            "interaction_pairs": create_violation_interaction_pairs(["s_a", "s_b"]),
        },
    },
    "n_prev_not_started_scaled": {  # MODEL 5- with filt prev history and n prev not started
        "model_class": MultiClassLogisticRegression,
        "model_type": "multi",
        "design_matrix_generator": DesignMatrixGeneratorFilteredHistory,
        "filter_implementation": {
            "prev_violation": 1
        },  # filter column with animals tau,
        "design_matrix_generator_args": {
            "trial_not_started": "scaled_n_prev",
            "interaction_pairs": create_violation_interaction_pairs(["s_a", "s_b"]),
        },
    },
}

params = {
    "animals": ANIMAL_IDS,
    "data_type": "new_trained",
    "sigmas": [0.07, 0.13, 0.25, 0.5, 1, 2, 4, 8, 16],
    "random_state": 47,
    "null_mode": "multi",
    "eval_train": True,
    "tau_columns": ["prev_violation"],
    "model_config": model_config,
}


save_name = "2024_02_20_compare_n_prev_trial_not_started.pkl"
ORDER = [
    "psytrack_features",
    "filter_prev_violation_stim_itrx",
    "prev_not_started",
    "n_prev_not_started",
    "n_prev_not_started_scaled",
]

# %% [markdown]
# ## Run

# %%
experiment = ExperimentCompareModels(params)
experiment.run()
experiment.save(save_name)
# Out:
# Loading dataset type : new_trained
# Loading data for animal ids:  ['W051', 'W060', 'W065', 'W066', 'W068', 'W072', 'W073', 'W074', 'W075', 'W078', 'W080', 'W081', 'W082', 'W083', 'W088', 'W089', 'W094']
#
#  >>>> evaluating animal W051 <<<<
#
#  ***** evaluating model psytrack_features w/ sigma 0.07 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 64995.381417
#          Iterations: 24
#          Function evaluations: 103
#          Gradient evaluations: 91
#
#  ***** evaluating model psytrack_features w/ sigma 0.13 *****
# Optimization terminated successfully.
#          Current function value: 64759.621627
#          Iterations: 25
#          Function evaluations: 38
#          Gradient evaluations: 38
#
#  ***** evaluating model psytrack_features w/ sigma 0.25 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 64687.335386
#          Iterations: 24
#          Function evaluations: 103
#          Gradient evaluations: 90
#
#  ***** evaluating model psytrack_features w/ sigma 0.5 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 64667.068595
#          Iterations: 23
#          Function evaluations: 68
#          Gradient evaluations: 57
#
#  ***** evaluating model psytrack_features w/ sigma 1 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 64661.989920
#          Iterations: 22
#          Function evaluations: 71
#          Gradient evaluations: 59
#
#  ***** evaluating model psytrack_features w/ sigma 2 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 64660.719500
#          Iterations: 22
#          Function evaluations: 57
#          Gradient evaluations: 46
#
#  ***** evaluating model psytrack_features w/ sigma 4 *****
# Optimization terminated successfully.
#          Current function value: 64660.401848
#          Iterations: 23
#          Function evaluations: 34
#          Gradient evaluations: 34
#
#  ***** evaluating model psytrack_features w/ sigma 8 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 64660.322432
#          Iterations: 22
#          Function evaluations: 71
#          Gradient evaluations: 60
#
#  ***** evaluating model psytrack_features w/ sigma 16 *****
# Optimization terminated successfully.
#          Current function value: 64660.302577
#          Iterations: 23
#          Function evaluations: 34
#          Gradient evaluations: 34
#
#  ***** evaluating model filter_prev_violation_stim_itrx w/ sigma 0.07 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 64737.946312
#          Iterations: 33
#          Function evaluations: 127
#          Gradient evaluations: 109
#
#  ***** evaluating model filter_prev_violation_stim_itrx w/ sigma 0.13 *****
# Optimization terminated successfully.
#          Current function value: 64420.545519
#          Iterations: 32
#          Function evaluations: 79
#          Gradient evaluations: 78
#
#  ***** evaluating model filter_prev_violation_stim_itrx w/ sigma 0.25 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 64312.632101
#          Iterations: 30
#          Function evaluations: 118
#          Gradient evaluations: 104
#
#  ***** evaluating model filter_prev_violation_stim_itrx w/ sigma 0.5 *****
# Optimization terminated successfully.
#          Current function value: 64280.954699
#          Iterations: 30
#          Function evaluations: 40
#          Gradient evaluations: 40
#
#  ***** evaluating model filter_prev_violation_stim_itrx w/ sigma 1 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 64272.899782
#          Iterations: 28
#          Function evaluations: 38
#          Gradient evaluations: 38
#
#  ***** evaluating model filter_prev_violation_stim_itrx w/ sigma 2 *****
# Optimization terminated successfully.
#          Current function value: 64270.877129
#          Iterations: 29
#          Function evaluations: 39
#          Gradient evaluations: 39
#
#  ***** evaluating model filter_prev_violation_stim_itrx w/ sigma 4 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 64270.370901
#          Iterations: 27
#          Function evaluations: 82
#          Gradient evaluations: 70
#
#  ***** evaluating model filter_prev_violation_stim_itrx w/ sigma 8 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 64270.244308
#          Iterations: 27
#          Function evaluations: 76
#          Gradient evaluations: 65
#
#  ***** evaluating model filter_prev_violation_stim_itrx w/ sigma 16 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 64270.212658
#          Iterations: 28
#          Function evaluations: 38
#          Gradient evaluations: 38
# Evaluating trial_not_started prev
#
#  ***** evaluating model prev_not_started w/ sigma 0.07 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 64714.292229
#          Iterations: 33
#          Function evaluations: 87
#          Gradient evaluations: 82
#
#  ***** evaluating model prev_not_started w/ sigma 0.13 *****
# Optimization terminated successfully.
#          Current function value: 64364.494303
#          Iterations: 34
#          Function evaluations: 94
#          Gradient evaluations: 88
#
#  ***** evaluating model prev_not_started w/ sigma 0.25 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 64219.555860
#          Iterations: 33
#          Function evaluations: 76
#          Gradient evaluations: 65
#
#  ***** evaluating model prev_not_started w/ sigma 0.5 *****
# Optimization terminated successfully.
#          Current function value: 64166.740897
#          Iterations: 34
#          Function evaluations: 77
#          Gradient evaluations: 74
#
#  ***** evaluating model prev_not_started w/ sigma 1 *****
# Optimization terminated successfully.
#          Current function value: 64151.461384
#          Iterations: 33
#          Function evaluations: 41
#          Gradient evaluations: 41
#
#  ***** evaluating model prev_not_started w/ sigma 2 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 64147.427369
#          Iterations: 31
#          Function evaluations: 64
#          Gradient evaluations: 53
#
#  ***** evaluating model prev_not_started w/ sigma 4 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 64146.402455
#          Iterations: 32
#          Function evaluations: 101
#          Gradient evaluations: 89
#
#  ***** evaluating model prev_not_started w/ sigma 8 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 64146.145134
#          Iterations: 32
#          Function evaluations: 74
#          Gradient evaluations: 63
#
#  ***** evaluating model prev_not_started w/ sigma 16 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 64146.080735
#          Iterations: 32
#          Function evaluations: 40
#          Gradient evaluations: 40
# Evaluating trial_not_started n_prev
#
#  ***** evaluating model n_prev_not_started w/ sigma 0.07 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 64689.461201
#          Iterations: 34
#          Function evaluations: 86
#          Gradient evaluations: 74
#
#  ***** evaluating model n_prev_not_started w/ sigma 0.13 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 64349.280321
#          Iterations: 36
#          Function evaluations: 50
#          Gradient evaluations: 50
#
#  ***** evaluating model n_prev_not_started w/ sigma 0.25 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 64222.690654
#          Iterations: 40
#          Function evaluations: 52
#          Gradient evaluations: 52
#
#  ***** evaluating model n_prev_not_started w/ sigma 0.5 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 64181.234801
#          Iterations: 38
#          Function evaluations: 100
#          Gradient evaluations: 89
#
#  ***** evaluating model n_prev_not_started w/ sigma 1 *****
# Optimization terminated successfully.
#          Current function value: 64169.865469
#          Iterations: 39
#          Function evaluations: 52
#          Gradient evaluations: 52
#
#  ***** evaluating model n_prev_not_started w/ sigma 2 *****
# Optimization terminated successfully.
#          Current function value: 64166.922550
#          Iterations: 39
#          Function evaluations: 94
#          Gradient evaluations: 91
#
#  ***** evaluating model n_prev_not_started w/ sigma 4 *****
# Optimization terminated successfully.
#          Current function value: 64166.179344
#          Iterations: 38
#          Function evaluations: 48
#          Gradient evaluations: 48
#
#  ***** evaluating model n_prev_not_started w/ sigma 8 *****
# Optimization terminated successfully.
#          Current function value: 64165.993052
#          Iterations: 38
#          Function evaluations: 48
#          Gradient evaluations: 48
#
#  ***** evaluating model n_prev_not_started w/ sigma 16 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 64165.946447
#          Iterations: 36
#          Function evaluations: 97
#          Gradient evaluations: 85
# Evaluating trial_not_started scaled_n_prev
#
#  ***** evaluating model n_prev_not_started_scaled w/ sigma 0.07 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 64737.832337
#          Iterations: 31
#          Function evaluations: 73
#          Gradient evaluations: 61
#
#  ***** evaluating model n_prev_not_started_scaled w/ sigma 0.13 *****
# Optimization terminated successfully.
#          Current function value: 64420.166670
#          Iterations: 34
#          Function evaluations: 47
#          Gradient evaluations: 47
#
#  ***** evaluating model n_prev_not_started_scaled w/ sigma 0.25 *****
# Optimization terminated successfully.
#          Current function value: 64311.280479
#          Iterations: 31
#          Function evaluations: 43
#          Gradient evaluations: 43
#
#  ***** evaluating model n_prev_not_started_scaled w/ sigma 0.5 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 64276.110195
#          Iterations: 30
#          Function evaluations: 41
#          Gradient evaluations: 41
#
#  ***** evaluating model n_prev_not_started_scaled w/ sigma 1 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 64258.626992
#          Iterations: 27
#          Function evaluations: 88
#          Gradient evaluations: 77
#
#  ***** evaluating model n_prev_not_started_scaled w/ sigma 2 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 64238.298385
#          Iterations: 31
#          Function evaluations: 41
#          Gradient evaluations: 41
#
#  ***** evaluating model n_prev_not_started_scaled w/ sigma 4 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 64212.061080
#          Iterations: 34
#          Function evaluations: 97
#          Gradient evaluations: 85
#
#  ***** evaluating model n_prev_not_started_scaled w/ sigma 8 *****
# Optimization terminated successfully.
#          Current function value: 64187.496974
#          Iterations: 37
#          Function evaluations: 47
#          Gradient evaluations: 47
#
#  ***** evaluating model n_prev_not_started_scaled w/ sigma 16 *****
# Optimization terminated successfully.
#          Current function value: 64173.421260
#          Iterations: 40
#          Function evaluations: 50
#          Gradient evaluations: 50
#
#  >>>> evaluating animal W060 <<<<
#
#  ***** evaluating model psytrack_features w/ sigma 0.07 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 52210.844362
#          Iterations: 29
#          Function evaluations: 139
#          Gradient evaluations: 127
#
#  ***** evaluating model psytrack_features w/ sigma 0.13 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 51927.370332
#          Iterations: 26
#          Function evaluations: 79
#          Gradient evaluations: 68
#
#  ***** evaluating model psytrack_features w/ sigma 0.25 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 51839.613929
#          Iterations: 25
#          Function evaluations: 40
#          Gradient evaluations: 40
#
#  ***** evaluating model psytrack_features w/ sigma 0.5 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 51814.935713
#          Iterations: 25
#          Function evaluations: 72
#          Gradient evaluations: 60
#
#  ***** evaluating model psytrack_features w/ sigma 1 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 51808.746419
#          Iterations: 25
#          Function evaluations: 39
#          Gradient evaluations: 39
#
#  ***** evaluating model psytrack_features w/ sigma 2 *****
# Optimization terminated successfully.
#          Current function value: 51807.197856
#          Iterations: 26
#          Function evaluations: 40
#          Gradient evaluations: 40
#
#  ***** evaluating model psytrack_features w/ sigma 4 *****
# Optimization terminated successfully.
#          Current function value: 51806.810638
#          Iterations: 26
#          Function evaluations: 40
#          Gradient evaluations: 40
#
#  ***** evaluating model psytrack_features w/ sigma 8 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 51806
#          Iterations: 36
#          Function evaluations: 45
#          Gradient evaluations: 45
#
#  ***** evaluating model n_prev_not_started w/ sigma 0.25 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 84807.363452
#          Iterations: 32
#          Function evaluations: 80
#          Gradient evaluations: 69
#
#  ***** evaluating model n_prev_not_started w/ sigma 0.5 *****
# Optimization terminated successfully.
#          Current function value: 84757.567162
#          Iterations: 37
#          Function evaluations: 71
#          Gradient evaluations: 70
#
#  ***** evaluating model n_prev_not_started w/ sigma 1 *****
# Optimization terminated successfully.
#          Current function value: 84742.666067
#          Iterations: 37
#          Function evaluations: 44
#          Gradient evaluations: 44
#
#  ***** evaluating model n_prev_not_started w/ sigma 2 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 84738.475210
#          Iterations: 35
#          Function evaluations: 43
#          Gradient evaluations: 43
#
#  ***** evaluating model n_prev_not_started w/ sigma 4 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 84737.373645
#          Iterations: 35
#          Function evaluations: 88
#          Gradient evaluations: 77
#
#  ***** evaluating model n_prev_not_started w/ sigma 8 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 84737.093972
#          Iterations: 35
#          Function evaluations: 115
#          Gradient evaluations: 102
#
#  ***** evaluating model n_prev_not_started w/ sigma 16 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 84737.023766
#          Iterations: 34
#          Function evaluations: 80
#          Gradient evaluations: 68
# Evaluating trial_not_started scaled_n_prev
#
#  ***** evaluating model n_prev_not_started_scaled w/ sigma 0.07 *****
# Optimization terminated successfully.
#          Current function value: 85375.960074
#          Iterations: 33
#          Function evaluations: 45
#          Gradient evaluations: 45
#
#  ***** evaluating model n_prev_not_started_scaled w/ sigma 0.13 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 84996.615112
#          Iterations: 31
#          Function evaluations: 85
#          Gradient evaluations: 73
#
#  ***** evaluating model n_prev_not_started_scaled w/ sigma 0.25 *****
# Optimization terminated successfully.
#          Current function value: 84867.467500
#          Iterations: 33
#          Function evaluations: 43
#          Gradient evaluations: 43
#
#  ***** evaluating model n_prev_not_started_scaled w/ sigma 0.5 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 84825.835727
#          Iterations: 31
#          Function evaluations: 40
#          Gradient evaluations: 40
#
#  ***** evaluating model n_prev_not_started_scaled w/ sigma 1 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 84805.453446
#          Iterations: 28
#          Function evaluations: 83
#          Gradient evaluations: 71
#
#  ***** evaluating model n_prev_not_started_scaled w/ sigma 2 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 84783.818706
#          Iterations: 31
#          Function evaluations: 39
#          Gradient evaluations: 39
#
#  ***** evaluating model n_prev_not_started_scaled w/ sigma 4 *****
# Optimization terminated successfully.
#          Current function value: 84761.842934
#          Iterations: 34
#          Function evaluations: 42
#          Gradient evaluations: 42
#
#  ***** evaluating model n_prev_not_started_scaled w/ sigma 8 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 84747.212593
#          Iterations: 35
#          Function evaluations: 47
#          Gradient evaluations: 47
#
#  ***** evaluating model n_prev_not_started_scaled w/ sigma 16 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 84740.372404
#          Iterations: 36
#          Function evaluations: 91
#          Gradient evaluations: 79
#
#  >>>> evaluating animal W068 <<<<
#
#  ***** evaluating model psytrack_features w/ sigma 0.07 *****
# Optimization terminated successfully.
# ...
#          Iterations: 34
#          Function evaluations: 77
#          Gradient evaluations: 66
#
#  ***** evaluating model n_prev_not_started w/ sigma 0.5 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 91446.661940
#          Iterations: 34
#          Function evaluations: 86
#          Gradient evaluations: 75
#
#  ***** evaluating model n_prev_not_started w/ sigma 1 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 91434.125753
#          Iterations: 33
#          Function evaluations: 71
#          Gradient evaluations: 60
#
#  ***** evaluating model n_prev_not_started w/ sigma 2 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 91430.981426
#          Iterations: 34
#          Function evaluations: 91
#          Gradient evaluations: 79
#
#  ***** evaluating model n_prev_not_started w/ sigma 4 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 91430.194697
#          Iterations: 34
#          Function evaluations: 42
#          Gradient evaluations: 42
#
#  ***** evaluating model n_prev_not_started w/ sigma 8 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 91429.997974
#          Iterations: 33
#          Function evaluations: 75
#          Gradient evaluations: 64
#
#  ***** evaluating model n_prev_not_started w/ sigma 16 *****
# Optimization terminated successfully.
#          Current function value: 91429.948790
#          Iterations: 36
#          Function evaluations: 44
#          Gradient evaluations: 44
# Evaluating trial_not_started scaled_n_prev
#
#  ***** evaluating model n_prev_not_started_scaled w/ sigma 0.07 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 92516.931202
#          Iterations: 36
#          Function evaluations: 94
#          Gradient evaluations: 82
#
#  ***** evaluating model n_prev_not_started_scaled w/ sigma 0.13 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 91963.234609
#          Iterations: 35
#          Function evaluations: 90
#          Gradient evaluations: 78
#
#  ***** evaluating model n_prev_not_started_scaled w/ sigma 0.25 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 91696.170184
#          Iterations: 35
#          Function evaluations: 49
#          Gradient evaluations: 49
#
#  ***** evaluating model n_prev_not_started_scaled w/ sigma 0.5 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 91538.872741
#          Iterations: 36
#          Function evaluations: 123
#          Gradient evaluations: 110
#
#  ***** evaluating model n_prev_not_started_scaled w/ sigma 1 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 91465.388395
#          Iterations: 35
#          Function evaluations: 105
#          Gradient evaluations: 93
#
#  ***** evaluating model n_prev_not_started_scaled w/ sigma 2 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 91439.746662
#          Iterations: 35
#          Function evaluations: 87
#          Gradient evaluations: 75
#
#  ***** evaluating model n_prev_not_started_scaled w/ sigma 4 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 91432.461628
#          Iterations: 36
#          Function evaluations: 107
#          Gradient evaluations: 95
#
#  ***** evaluating model n_prev_not_started_scaled w/ sigma 8 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 91430.569790
#          Iterations: 37
#          Function evaluations: 49
#          Gradient evaluations: 49
#
#  ***** evaluating model n_prev_not_started_scaled w/ sigma 16 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 91430.092068
#          Iterations: 36
#          Function evaluations: 46
#          Gradient evaluations: 46
#
#  >>>> evaluating animal W094 <<<<
#
#  ***** evaluating model psytrack_features w/ sigma 0.07 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 46181.052893
#          Iterations: 21
#          Function evaluations: 61
#          Gradient evaluations: 49
#
#  ***** evaluating model psytrack_features w/ sigma 0.13 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 45920.160201
#          Iterations: 21
#          Function evaluations: 67
#          Gradient evaluations: 55
#
#  ***** evaluating model psytrack_features w/ sigma 0.25 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 45838.411439
#          Iterations: 21
#          Function evaluations: 74
#          Gradient evaluations: 62
#
#  ***** evaluating model psytrack_features w/ sigma 0.5 *****
# Optimization terminated successfully.
#          Current function value: 45815.334405
#          Iterations: 21
#          Function evaluations: 33
#          Gradient evaluations: 33
#
#  ***** evaluating model psytrack_features w/ sigma 1 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 45809.540510
#          Iterations: 20
#          Function evaluations: 79
#          Gradient evaluations: 68
#
#  ***** evaluating model psytrack_features w/ sigma 2 *****
# Optimization terminated successfully.
#          Current function value: 45808.090487
#          Iterations: 21
#          Function evaluations: 33
#          Gradient evaluations: 33
#
#  ***** evaluating model psytrack_features w/ sigma 4 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 45807.727884
#          Iterations: 21
#          Function evaluations: 71
#          Gradient evaluations: 60
#
#  ***** evaluating model psytrack_features w/ sigma 8 *****
# Optimization terminated successfully.
#          Current function value: 45807.637227
#          Iterations: 21
#          Function evaluations: 33
#          Gradient evaluations: 33
#
#  ***** evaluating model psytrack_features w/ sigma 16 *****
# Optimization terminated successfully.
#          Current function value: 45807.614562
#          Iterations: 21
#          Function evaluations: 33
#          Gradient evaluations: 33
#
#  ***** evaluating model filter_prev_violation_stim_itrx w/ sigma 0.07 *****
# Optimization terminated successfully.
#          Current function value: 45582.510569
#          Iterations: 31
#          Function evaluations: 47
#          Gradient evaluations: 47
#
#  ***** evaluating model filter_prev_violation_stim_itrx w/ sigma 0.13 *****
# Optimization terminated successfully.
#          Current function value: 45057.061490
#          Iterations: 31
#          Function evaluations: 40
#          Gradient evaluations: 40
#
#  ***** evaluating model filter_prev_violation_stim_itrx w/ sigma 0.25 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 44842.079913
#          Iterations: 28
#          Function evaluations: 75
#          Gradient evaluations: 64
#
#  ***** evaluating model filter_prev_violation_stim_itrx w/ sigma 0.5 *****
# Optimization terminated successfully.
#          Current function value: 44772.599851
#          Iterations: 28
#          Function evaluations: 37
#          Gradient evaluations: 37
#
#  ***** evaluating model filter_prev_violation_stim_itrx w/ sigma 1 *****
# Optimization terminated successfully.
#          Current function value: 44754.278119
#          Iterations: 28
#          Function evaluations: 37
#          Gradient evaluations: 37
#
#  ***** evaluating model filter_prev_violation_stim_itrx w/ sigma 2 *****
# Optimization terminated successfully.
#          Current function value: 44749.629789
#          Iterations: 28
#          Function evaluations: 37
#          Gradient evaluations: 37
#
#  ***** evaluating model filter_prev_violation_stim_itrx w/ sigma 4 *****
# Optimization terminated successfully.
#          Current function value: 44748.463304
#          Iterations: 28
#          Function evaluations: 37
#          Gradient evaluations: 37
#
#  ***** evaluating model filter_prev_violation_stim_itrx w/ sigma 8 *****
# Optimization terminated successfully.
#          Current function value: 44748.171405
#          Iterations: 28
#          Function evaluations: 37
#          Gradient evaluations: 37
#
#  ***** evaluating model filter_prev_violation_stim_itrx w/ sigma 16 *****
# Optimization terminated successfully.
#          Current function value: 44748.098413
#          Iterations: 28
#          Function evaluations: 37
#          Gradient evaluations: 37
# Evaluating trial_not_started prev
#
#  ***** evaluating model prev_not_started w/ sigma 0.07 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 45508.355973
#          Iterations: 30
#          Function evaluations: 98
#          Gradient evaluations: 86
#
#  ***** evaluating model prev_not_started w/ sigma 0.13 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 44925.340844
#          Iterations: 32
#          Function evaluations: 112
#          Gradient evaluations: 98
#
#  ***** evaluating model prev_not_started w/ sigma 0.25 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 44665.717947
#          Iterations: 32
#          Function evaluations: 85
#          Gradient evaluations: 74
#
#  ***** evaluating model prev_not_started w/ sigma 0.5 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 44576.082234
#          Iterations: 34
#          Function evaluations: 135
#          Gradient evaluations: 121
#
#  ***** evaluating model prev_not_started w/ sigma 1 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 44551.704129
#          Iterations: 32
#          Function evaluations: 86
#          Gradient evaluations: 74
#
#  ***** evaluating model prev_not_started w/ sigma 2 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 44545.458720
#          Iterations: 33
#          Function evaluations: 39
#          Gradient evaluations: 39
#
#  ***** evaluating model prev_not_started w/ sigma 4 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 44543.887344
#          Iterations: 33
#          Function evaluations: 39
#          Gradient evaluations: 39
#
#  ***** evaluating model prev_not_started w/ sigma 8 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 44543.493863
#          Iterations: 32
#          Function evaluations: 82
#          Gradient evaluations: 71
#
#  ***** evaluating model prev_not_started w/ sigma 16 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 44543.395453
#          Iterations: 33
#          Function evaluations: 39
#          Gradient evaluations: 39
# Evaluating trial_not_started n_prev
#
#  ***** evaluating model n_prev_not_started w/ sigma 0.07 *****
# Optimization terminated successfully.
#          Current function value: 45474.167187
#          Iterations: 32
#          Function evaluations: 48
#          Gradient evaluations: 48
#
#  ***** evaluating model n_prev_not_started w/ sigma 0.13 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 44936.658909
#          Iterations: 32
#          Function evaluations: 136
#          Gradient evaluations: 121
#
#  ***** evaluating model n_prev_not_started w/ sigma 0.25 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 44715.658927
#          Iterations: 33
#          Function evaluations: 87
#          Gradient evaluations: 76
#
#  ***** evaluating model n_prev_not_started w/ sigma 0.5 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 44643.937329
#          Iterations: 35
#          Function evaluations: 100
#          Gradient evaluations: 89
#
#  ***** evaluating model n_prev_not_started w/ sigma 1 *****
# Optimization terminated successfully.
#          Current function value: 44624.991385
#          Iterations: 34
#          Function evaluations: 42
#          Gradient evaluations: 42
#
#  ***** evaluating model n_prev_not_started w/ sigma 2 *****
# Optimization terminated successfully.
#          Current function value: 44620.182241
#          Iterations: 34
#          Function evaluations: 42
#          Gradient evaluations: 42
#
#  ***** evaluating model n_prev_not_started w/ sigma 4 *****
# Optimization terminated successfully.
#          Current function value: 44618.975241
#          Iterations: 34
#          Function evaluations: 42
#          Gradient evaluations: 42
#
#  ***** evaluating model n_prev_not_started w/ sigma 8 *****
# Optimization terminated successfully.
#          Current function value: 44618.673193
#          Iterations: 34
#          Function evaluations: 42
#          Gradient evaluations: 42
#
#  ***** evaluating model n_prev_not_started w/ sigma 16 *****
# Optimization terminated successfully.
#          Current function value: 44618.597662
#          Iterations: 34
#          Function evaluations: 42
#          Gradient evaluations: 42
# Evaluating trial_not_started scaled_n_prev
#
#  ***** evaluating model n_prev_not_started_scaled w/ sigma 0.07 *****
# Optimization terminated successfully.
#          Current function value: 45580.852500
#          Iterations: 33
#          Function evaluations: 51
#          Gradient evaluations: 51
#
#  ***** evaluating model n_prev_not_started_scaled w/ sigma 0.13 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 45052.071653
#          Iterations: 32
#          Function evaluations: 42
#          Gradient evaluations: 42
#
#  ***** evaluating model n_prev_not_started_scaled w/ sigma 0.25 *****
# Optimization terminated successfully.
#          Current function value: 44826.713880
#          Iterations: 31
#          Function evaluations: 41
#          Gradient evaluations: 41
#
#  ***** evaluating model n_prev_not_started_scaled w/ sigma 0.5 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 44732.499641
#          Iterations: 29
#          Function evaluations: 88
#          Gradient evaluations: 76
#
#  ***** evaluating model n_prev_not_started_scaled w/ sigma 1 *****
# Optimization terminated successfully.
#          Current function value: 44680.309339
#          Iterations: 31
#          Function evaluations: 38
#          Gradient evaluations: 38
#
#  ***** evaluating model n_prev_not_started_scaled w/ sigma 2 *****
# Optimization terminated successfully.
#          Current function value: 44645.793920
#          Iterations: 33
#          Function evaluations: 40
#          Gradient evaluations: 40
#
#  ***** evaluating model n_prev_not_started_scaled w/ sigma 4 *****
# Optimization terminated successfully.
#          Current function value: 44627.727168
#          Iterations: 35
#          Function evaluations: 42
#          Gradient evaluations: 42
#
#  ***** evaluating model n_prev_not_started_scaled w/ sigma 8 *****
# Optimization terminated successfully.
#          Current function value: 44621.128968
#          Iterations: 35
#          Function evaluations: 42
#          Gradient evaluations: 42
#
#  ***** evaluating model n_prev_not_started_scaled w/ sigma 16 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 44619.232701
#          Iterations: 34
#          Function evaluations: 85
#          Gradient evaluations: 73

# %% [markdown]
# ## Visualize

# %%
experiment = load_experiment(save_name)
mvc = ModelVisualizerCompare(experiment)

# %%
df = mvc.find_best_fit(group="model_name")
df["model_name"] = pd.Categorical(df["model_name"], categories=ORDER, ordered=True)
for model_name, model_df in df.groupby("model_name"):
    mvc.plot_sigma_summary(model_df, title=f"{model_name} fit sigma summary")

# %%
fig, ax = plt.subplots(
    len(ORDER), 1, figsize=(10, len(ORDER) * 6), constrained_layout=True, sharey=False
)

best_fit_by_model = mvc.find_best_fit(group=["animal_id", "model_name"])
best_fit_by_model["model_name"] = pd.Categorical(
    best_fit_by_model["model_name"], categories=ORDER, ordered=True
)

for ii, (model_name, model_df) in enumerate(best_fit_by_model.groupby("model_name")):
    unpacked = mvc.unpack_features_and_weights(model_df)

    mvc.plot_weights_summary(
        df=unpacked,
        ax=ax[ii],
        palette="Set2",
        title=f"{model_name} weights summary",
    )

# %%
fig, ax = plt.subplots(1, 1, figsize=(8, 5))
mvc.plot_model_comparison(
    hue=None,
    ax=ax,
    order=ORDER,
    errorbar=None,
)

# %%
fig, ax = plt.subplots(1, 1, figsize=(8, 5))
mvc.plot_model_comparison(
    hue=None,
    ax=ax,
    order=ORDER[0:3],
    errorbar=None,
)

# %%
fig, ax = plt.subplots(1, 1, figsize=(8, 5))
mvc.plot_model_comparison(
    hue=None,
    ax=ax,
    order=ORDER[2:4],
    errorbar=None,
)

# %%
fig, ax = plt.subplots(1, 1, figsize=(8, 5))
mvc.plot_model_comparison(
    hue=None,
    ax=ax,
    order=[ORDER[0], ORDER[4]],
    errorbar=None,
)

# %%
mvc.plot_train_and_test_ll(
    order=ORDER,
    errorbar=None,
)

# %%
mvc.plot_ll_delta_by_animal(
    base_model_name=ORDER[1],
    new_model_name=ORDER[2],
    type="test",
)
# Out:
# <Axes: title={'center': 'Model Improvement- mu: 131.17 std: 123.91 \n filter_prev_violation_stim_itrx -> prev_not_started'}, xlabel='animal_id', ylabel='Delta test LL (new - base)'>

# %%
mvc.plot_ll_delta_by_animal(
    base_model_name=ORDER[0],
    new_model_name=ORDER[2],
    type="test",
)
# Out:
# <Axes: title={'center': 'Model Improvement- mu: 517.85 std: 427.46 \n psytrack_features -> prev_not_started'}, xlabel='animal_id', ylabel='Delta test LL (new - base)'>

# %%
mvc.plot_ll_delta_by_animal(
    base_model_name=ORDER[2],
    new_model_name=ORDER[3],
    type="test",
)
# Out:
# <Axes: title={'center': 'Model Improvement- mu: -42.08 std: 51.87 \n prev_not_started -> n_prev_not_started'}, xlabel='animal_id', ylabel='Delta test LL (new - base)'>

# %%
mvc.plot_ll_delta_by_animal(
    base_model_name=ORDER[3],
    new_model_name=ORDER[4],
    type="test",
)
# Out:
# <Axes: title={'center': 'Model Improvement- mu: 1.15 std: 5.03 \n n_prev_not_started -> n_prev_not_started_scaled'}, xlabel='animal_id', ylabel='Delta test LL (new - base)'>

# %%
mvc.plot_ll_delta_by_animal(
    base_model_name=ORDER[0],
    new_model_name=ORDER[4],
    type="test",
)
# Out:
# <Axes: title={'center': 'Model Improvement- mu: 476.91 std: 400.72 \n psytrack_features -> n_prev_not_started_scaled'}, xlabel='animal_id', ylabel='Delta test LL (new - base)'>

# %%
for i in range(len(ORDER)):
    for j in range(i + 1, len(ORDER)):
        mvc.plot_delta_ll_by_violation_rate(ORDER[i], ORDER[j])

# %%
for i in range(len(ORDER)):
    for j in range(i + 1, len(ORDER)):
        mvc.plot_delta_ll_by_train_test_size(ORDER[i], ORDER[j])

# %%
# TODO- bits per trial vs violation rate?

# %%
# TODO- bits per trial vs violation rate?
