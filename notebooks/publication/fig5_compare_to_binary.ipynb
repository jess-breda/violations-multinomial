# %% [markdown]
# # Fig: Dev Experiment Compare Interaction Terms
#
# Compare interaction terms with binary prev violation history vs. filtered prev violation history

# %%
import seaborn as sns
import matplotlib.pyplot as plt

from violmulti.experiments.experiment import load_experiment
from violmulti.experiments.experiment_compare_models import ExperimentCompareModels
from violmulti.models.multiclass_logistic_regression import MultiClassLogisticRegression
from violmulti.models.binary_logistic_regression import BinaryLogisticRegression
from violmulti.visualizations.model_visualizer import ModelVisualizer
from violmulti.features.design_matrix_generator_PWM import *

from violmulti.visualizations.model_visualizer import *

from violmulti.data import ANIMAL_IDS
from violmulti.experiments import STANDARD_SIGMAS
import config as c

sns.set_context("talk")
# %load_ext autoreload
# %autoreload 2

# %%
shared_cols = {
    "session": lambda df: (copy(df.session)),
    "bias": lambda df: (add_bias_column(df)),
    "s_a": lambda df: (standardize(df.s_a)),
    "s_b": lambda df: (standardize(df.s_b)),
    "prev_avg_stim": lambda df: prev_avg_stim(df, mask_prev_violation=True),
    "prev_correct": lambda df: (prev_correct_side(df)),
    "prev_choice": lambda df: (prev_choice(df)),
}

models_config = {
    "base" : {
        "model_class": BinaryLogisticRegression,
        "dmg_config": {
            **shared_cols,
            "labels" : binary_choice_labels(),
        },
    },
    "prev_viol_binary" : {
        "model_class": MultiClassLogisticRegression,
        "dmg_config": {
            **shared_cols,
            "prev_violation": lambda df: prev_violation(df),
            "labels": multi_choice_labels(),
        },
        "lr_only_eval": True,
    },
    "prev_viol_filtered" : {
        "model_class": MultiClassLogisticRegression,
        "dmg_config": {
            **shared_cols,
            "filt_prev_violation": lambda df: (
                filtered_prev_viol(df, get_animals_tau(df, "prev_violation", save_path=c.MODEL_FITS_PATH + "/taus_df.csv"))
            ),
            "labels": multi_choice_labels(),
        },
        "lr_only_eval": True,
    },
    "prev_viol_binary_itrx" : {
        "model_class": MultiClassLogisticRegression,
        "dmg_config": {
            **shared_cols,
            "prev_violation": lambda df: prev_violation(df),
            "sa_x_prev_viol": lambda df: stim_filt_binary_intrx(df, "s_a"),
            "sb_x_prev_viol": lambda df: stim_filt_binary_intrx(df, "s_b"),
            "labels": multi_choice_labels(),
        },
        "lr_only_eval": True,
    },
    "prev_viol_filtered_itrx" : {
        "model_class": MultiClassLogisticRegression,
        "dmg_config": {
            **shared_cols,
            "filt_prev_violation": lambda df: (
                filtered_prev_viol(df, get_animals_tau(df, "prev_violation", save_path=c.MODEL_FITS_PATH + "/taus_df.csv"))
            ),
            "sa_x_prev_viol": lambda df: (
                stim_filt_viol_intrx(df, "s_a", get_animals_tau(df, "prev_violation", save_path=c.MODEL_FITS_PATH + "/taus_df.csv"))
            ),
            "sb_x_prev_viol": lambda df: (
            stim_filt_viol_intrx(df, "s_b", get_animals_tau(df, "prev_violation", save_path=c.MODEL_FITS_PATH + "/taus_df.csv"))
             ),
            "labels": multi_choice_labels(),
        },
        "lr_only_eval":True,
    },
}
params = {
    "animals": ANIMAL_IDS,
    "data_type": "new_trained_cleaned",
    "sigmas": STANDARD_SIGMAS,
    "random_state": 47,
    "eval_train": True,
    "null_mode": "binary",
    "model_config": models_config,
}

save_name = "2025_07_22_fig5_compare_to_binary_rs47.pkl"

ORDER = [
    "base",
    "prev_viol_binary",
    "prev_viol_binary_itrx",
    "prev_viol_filtered",
    "prev_viol_filtered_itrx",
]

# %% [markdown]
# ## Run

# %%
experiment = ExperimentCompareModels(params)
experiment.run()
experiment.save(save_name, file_path=c.MODEL_FITS_PATH)
# Out:
# Loading dataset type : new_trained_cleaned
# DataLoader: Loading data type:  new_trained_cleaned  for animal ids:  ['W051', 'W060', 'W065', 'W066', 'W068', 'W072', 'W073', 'W074', 'W075', 'W078', 'W080', 'W081', 'W083', 'W088', 'W089', 'W094']
#
#  >>>> evaluating animal W051 <<<<
#
#  ***** evaluating model base w/ sigma 0.07 *****
#          Current function value: 31996.010443
#          Iterations: 13
#          Function evaluations: 69
#          Gradient evaluations: 57
#
#  ***** evaluating model base w/ sigma 0.13 *****
#          Current function value: 32387.580144
#          Iterations: 13
#          Function evaluations: 59
#          Gradient evaluations: 47
#
#  ***** evaluating model base w/ sigma 0.25 *****
#          Current function value: 32527.683346
#          Iterations: 13
#          Function evaluations: 57
#          Gradient evaluations: 45
#
#  ***** evaluating model base w/ sigma 0.5 *****
#          Current function value: 32568.830990
#          Iterations: 13
#          Function evaluations: 61
#          Gradient evaluations: 49
#
#  ***** evaluating model base w/ sigma 1 *****
#          Current function value: 32579.274913
#          Iterations: 13
#          Function evaluations: 75
#          Gradient evaluations: 63
#
#  ***** evaluating model base w/ sigma 2 *****
#          Current function value: 32581.895840
#          Iterations: 13
#          Function evaluations: 57
#          Gradient evaluations: 45
#
#  ***** evaluating model base w/ sigma 4 *****
#          Current function value: 32582.551693
#          Iterations: 13
#          Function evaluations: 69
#          Gradient evaluations: 57
#
#  ***** evaluating model base w/ sigma 8 *****
#          Current function value: 32582.715695
#          Iterations: 13
#          Function evaluations: 79
#          Gradient evaluations: 68
#
#  ***** evaluating model base w/ sigma 16 *****
#          Current function value: 32582.756698
#          Iterations: 14
#          Function evaluations: 64
#          Gradient evaluations: 52
#
#  ***** evaluating model prev_viol_binary w/ sigma 0.07 *****
# Optimization terminated successfully.
#          Current function value: 64606.137646
#          Iterations: 27
#          Function evaluations: 44
#          Gradient evaluations: 44
#
#  ***** evaluating model prev_viol_binary w/ sigma 0.13 *****
#          Current function value: 64357.132928
#          Iterations: 26
#          Function evaluations: 41
#          Gradient evaluations: 41
#
#  ***** evaluating model prev_viol_binary w/ sigma 0.25 *****
#          Current function value: 64280.548024
#          Iterations: 25
#          Function evaluations: 66
#          Gradient evaluations: 55
#
#  ***** evaluating model prev_viol_binary w/ sigma 0.5 *****
#          Current function value: 64259.054955
#          Iterations: 25
#          Function evaluations: 75
#          Gradient evaluations: 64
#
#  ***** evaluating model prev_viol_binary w/ sigma 1 *****
# Optimization terminated successfully.
#          Current function value: 64253.667517
#          Iterations: 25
#          Function evaluations: 38
#          Gradient evaluations: 38
#
#  ***** evaluating model prev_viol_binary w/ sigma 2 *****
#          Current function value: 64252.319768
#          Iterations: 24
#          Function evaluations: 73
#          Gradient evaluations: 61
#
#  ***** evaluating model prev_viol_binary w/ sigma 4 *****
# Optimization terminated successfully.
#          Current function value: 64251.982775
#          Iterations: 25
#          Function evaluations: 38
#          Gradient evaluations: 38
#
#  ***** evaluating model prev_viol_binary w/ sigma 8 *****
# Optimization terminated successfully.
#          Current function value: 64251.898524
#          Iterations: 25
#          Function evaluations: 38
#          Gradient evaluations: 38
#
#  ***** evaluating model prev_viol_binary w/ sigma 16 *****
# Optimization terminated successfully.
#          Current function value: 64251.877461
#          Iterations: 25
#          Function evaluations: 38
#          Gradient evaluations: 38
#
#  ***** evaluating model prev_viol_filtered w/ sigma 0.07 *****
#          Current function value: 64562.167041
#          Iterations: 28
#          Function evaluations: 85
#          Gradient evaluations: 73
#
#  ***** evaluating model prev_viol_filtered w/ sigma 0.13 *****
#          Current function value: 64294.481841
#          Iterations: 27
#          Function evaluations: 111
#          Gradient evaluations: 97
#
#  ***** evaluating model prev_viol_filtered w/ sigma 0.25 *****
#          Current function value: 64210.979301
#          Iterations: 27
#          Function evaluations: 83
#          Gradient evaluations: 71
#
#  ***** evaluating model prev_viol_filtered w/ sigma 0.5 *****
#          Current function value: 64187.430396
#          Iterations: 25
#          Function evaluations: 89
#          Gradient evaluations: 79
#
#  ***** evaluating model prev_viol_filtered w/ sigma 1 *****
#          Current function value: 64181.519426
#          Iterations: 25
#          Function evaluations: 35
#          Gradient evaluations: 35
#
#  ***** evaluating model prev_viol_filtered w/ sigma 2 *****
#          Current function value: 64180.040186
#          Iterations: 24
#          Function evaluations: 73
#          Gradient evaluations: 61
#
#  ***** evaluating model prev_viol_filtered w/ sigma 4 *****
# Optimization terminated successfully.
#          Current function value: 64179.670283
#          Iterations: 26
#          Function evaluations: 36
#          Gradient evaluations: 36
#
#  ***** evaluating model prev_viol_filtered w/ sigma 8 *****
#          Current function value: 64179.577801
#          Iterations: 25
#          Function evaluations: 85
#          Gradient evaluations: 74
#
#  ***** evaluating model prev_viol_filtered w/ sigma 16 *****
# Optimization terminated successfully.
#          Current function value: 64179.554680
#          Iterations: 26
#          Function evaluations: 36
#          Gradient evaluations: 36
#
#  ***** evaluating model prev_viol_binary_itrx w/ sigma 0.07 *****
#          Current function value: 64572.381169
#          Iterations: 31
#          Function evaluations: 66
#          Gradient evaluations: 54
#
#  ***** evaluating model prev_viol_binary_itrx w/ sigma 0.13 *****
# Optimization terminated successfully.
#          Current function value: 64310.538963
#          Iterations: 31
#          Function evaluations: 50
#          Gradient evaluations: 50
#
#  ***** evaluating model prev_viol_binary_itrx w/ sigma 0.25 *****
#          Current function value: 64228.982988
#          Iterations: 30
#          Function evaluations: 102
#          Gradient evaluations: 88
#
#  ***** evaluating model prev_viol_binary_itrx w/ sigma 0.5 *****
#          Current function value: 64205.988158
#          Iterations: 29
#          Function evaluations: 47
#          Gradient evaluations: 47
#
#  ***** evaluating model prev_viol_binary_itrx w/ sigma 1 *****
#          Current function value: 64200.216451
#          Iterations: 28
#          Function evaluations: 90
#          Gradient evaluations: 78
#
#  ***** evaluating model prev_viol_binary_itrx w/ sigma 2 *****
# Optimization terminated successfully.
#          Current function value: 64198.772071
#          Iterations: 29
#          Function evaluations: 46
#          Gradient evaluations: 46
#
#  ***** evaluating model prev_viol_binary_itrx w/ sigma 4 *****
# Optimization terminated successfully.
#          Current function value: 64198.410885
#          Iterations: 29
#          Function evaluations: 46
#          Gradient evaluations: 46
#
#  ***** evaluating model prev_viol_binary_itrx w/ sigma 8 *****
#          Current function value: 64198.320583
#          Iterations: 29
#          Function evaluations: 48
#          Gradient evaluations: 48
#
#  ***** evaluating model prev_viol_binary_itrx w/ sigma 16 *****
# Optimization terminated successfully.
#          Current function value: 64198.298007
#          Iterations: 30
#          Function evaluations: 63
#          Gradient evaluations: 61
#
#  ***** evaluating model prev_viol_filtered_itrx w/ sigma 0.07 *****
#          Current function value: 64525.919854
#          Iterations: 31
#          Function evaluations: 67
#          Gradient evaluations: 60
#
#  ***** evaluating model prev_viol_filtered_itrx w/ sigma 0.13 *****
# Optimization terminated successfully.
#          Current function value: 64238.142960
#          Iterations: 32
#          Function evaluations: 45
#          Gradient evaluations: 45
#
#  ***** evaluating model prev_viol_filtered_itrx w/ sigma 0.25 *****
# Optimization terminated successfully.
#          Current function value: 64145.763529
#          Iterations: 30
#          Function evaluations: 44
#          Gradient evaluations: 44
#
#  ***** evaluating model prev_viol_filtered_itrx w/ sigma 0.5 *****
#          Current function value: 64119.388843
#          Iterations: 27
#          Function evaluations: 85
#          Gradient evaluations: 73
#
#  ***** evaluating model prev_viol_filtered_itrx w/ sigma 1 *****
#          Current function value: 64112.743322
#          Iterations: 27
#          Function evaluations: 85
#          Gradient evaluations: 74
#
#  ***** evaluating model prev_viol_filtered_itrx w/ sigma 2 *****
#          Current function value: 64111.078614
#          Iterations: 28
#          Function evaluations: 118
#          Gradient evaluations: 104
#
#  ***** evaluating model prev_viol_filtered_itrx w/ sigma 4 *****
#          Current function value: 64110.662228
#          Iterations: 29
#          Function evaluations: 124
#          Gradient evaluations: 109
#
#  ***** evaluating model prev_viol_filtered_itrx w/ sigma 8 *****
#          Current function value: 64110.558119
#          Iterations: 28
#          Function evaluations: 38
#          Gradient evaluations: 38
#
#  ***** evaluating model prev_viol_filtered_itrx w/ sigma 16 *****
# Optimization terminated successfully.
#          Current function value: 64110.532090
#          Iterations: 29
#          Function evaluations: 37
#          Gradient evaluations: 37
#
#  >>>> evaluating animal W060 <<<<
#
#  ***** evaluating model base w/ sigma 0.07 *****
#          Current function value:
#
#  ***** evaluating model prev_viol_binary w/ sigma 1 *****
#          Current function value: 85843.954278
#          Iterations: 25
#          Function evaluations: 80
#          Gradient evaluations: 69
#
#  ***** evaluating model prev_viol_binary w/ sigma 2 *****
#          Current function value: 85842.240539
#          Iterations: 26
#          Function evaluations: 78
#          Gradient evaluations: 66
#
#  ***** evaluating model prev_viol_binary w/ sigma 4 *****
# Optimization terminated successfully.
#          Current function value: 85841.812020
#          Iterations: 27
#          Function evaluations: 65
#          Gradient evaluations: 64
#
#  ***** evaluating model prev_viol_binary w/ sigma 8 *****
#          Current function value: 85841.704885
#          Iterations: 26
#          Function evaluations: 37
#          Gradient evaluations: 37
#
#  ***** evaluating model prev_viol_binary w/ sigma 16 *****
#          Current function value: 85841.678101
#          Iterations: 25
#          Function evaluations: 71
#          Gradient evaluations: 59
#
#  ***** evaluating model prev_viol_filtered w/ sigma 0.07 *****
#          Current function value: 86156.764635
#          Iterations: 26
#          Function evaluations: 83
#          Gradient evaluations: 72
#
#  ***** evaluating model prev_viol_filtered w/ sigma 0.13 *****
#          Current function value: 85756.711599
#          Iterations: 25
#          Function evaluations: 36
#          Gradient evaluations: 36
#
#  ***** evaluating model prev_viol_filtered w/ sigma 0.25 *****
#          Current function value: 85623.453811
#          Iterations: 25
#          Function evaluations: 37
#          Gradient evaluations: 37
#
#  ***** evaluating model prev_viol_filtered w/ sigma 0.5 *****
#          Current function value: 85584.890046
#          Iterations: 26
#          Function evaluations: 107
#          Gradient evaluations: 91
#
#  ***** evaluating model prev_viol_filtered w/ sigma 1 *****
# Optimization terminated successfully.
#          Current function value: 85575.135040
#          Iterations: 25
#          Function evaluations: 34
#          Gradient evaluations: 34
#
#  ***** evaluating model prev_viol_filtered w/ sigma 2 *****
# Optimization terminated successfully.
#          Current function value: 85572.688959
#          Iterations: 25
#          Function evaluations: 34
#          Gradient evaluations: 34
#
#  ***** evaluating model prev_viol_filtered w/ sigma 4 *****
# Optimization terminated successfully.
#          Current function value: 85572.076978
#          Iterations: 25
#          Function evaluations: 34
#          Gradient evaluations: 34
#
#  ***** evaluating model prev_viol_filtered w/ sigma 8 *****
# Optimization terminated successfully.
#          Current function value: 85571.923954
#          Iterations: 25
#          Function evaluations: 34
#          Gradient evaluations: 34
#
#  ***** evaluating model prev_viol_filtered w/ sigma 16 *****
#          Current function value: 85571.885696
#          Iterations: 24
#          Function evaluations: 88
#          Gradient evaluations: 78
#
#  ***** evaluating model prev_viol_binary_itrx w/ sigma 0.07 *****
#          Current function value: 86276.935600
#          Iterations: 33
#          Function evaluations: 128
#          Gradient evaluations: 108
#
#  ***** evaluating model prev_viol_binary_itrx w/ sigma 0.13 *****
#          Current function value: 85965.687995
#          Iterations: 32
#          Function evaluations: 92
#          Gradient evaluations: 80
#
#  ***** evaluating model prev_viol_binary_itrx w/ sigma 0.25 *****
#          Current function value: 85868.677691
#          Iterations: 32
#          Function evaluations: 47
#          Gradient evaluations: 47
#
#  ***** evaluating model prev_viol_binary_itrx w/ sigma 0.5 *****
# Optimization terminated successfully.
#          Current function value: 85841.326914
#          Iterations: 30
#          Function evaluations: 43
#          Gradient evaluations: 43
#
#  ***** evaluating model prev_viol_binary_itrx w/ sigma 1 *****
# Optimization terminated successfully.
#          Current function value: 85834.462134
#          Iterations: 31
#          Function evaluations: 77
#          Gradient evaluations: 76
#
#  ***** evaluating model prev_viol_binary_itrx w/ sigma 2 *****
# Optimization terminated successfully.
#          Current function value: 85832.744231
#          Iterations: 32
#          Function evaluations: 70
#          Gradient evaluations: 69
#
#  ***** evaluating model prev_viol_binary_itrx w/ sigma 4 *****
#          Current function value: 85832.314648
#          Iterations: 30
#          Function evaluations: 85
#          Gradient evaluations: 73
#
#  ***** evaluating model prev_viol_binary_itrx w/ sigma 8 *****
#          Current function value: 85832.207246
#          Iterations: 30
#          Function evaluations: 43
#          Gradient evaluations: 43
#
#  ***** evaluating model prev_viol_binary_itrx w/ sigma 16 *****
# Optimization terminated successfully.
#          Current function value: 85832.180395
#          Iterations: 31
#          Function evaluations: 45
#          Gradient evaluations: 45
#
#  ***** evaluating model prev_viol_filtered_itrx w/ sigma 0.07 *****
# Optimization terminated successfully.
#          Current function value: 86126.295704
#          Iterations: 32
#          Function evaluations: 46
#          Gradient evaluations: 46
#
#  ***** evaluating model prev_viol_filtered_itrx w/ sigma 0.13 *****
#          Current function value: 85733.415747
#          Iterations: 29
#          Function evaluations: 77
#          Gradient evaluations: 65
#
#  ***** evaluating model prev_viol_filtered_itrx w/ sigma 0.25 *****
#          Current function value: 85600.616679
#          Iterations: 30
#          Function evaluations: 40
#          Gradient evaluations: 40
#
#  ***** evaluating model prev_viol_filtered_itrx w/ sigma 0.5 *****
#          Current function value: 85561.850158
#          Iterations: 30
#          Function evaluations: 38
#          Gradient evaluations: 38
#
#  ***** evaluating model prev_viol_filtered_itrx w/ sigma 1 *****
# Optimization terminated successfully.
#          Current function value: 85552.010186
#          Iterations: 30
#          Function evaluations: 38
#          Gradient evaluations: 38
#
#  ***** evaluating model prev_viol_filtered_itrx w/ sigma 2 *****
#          Current function value: 85549.540389
#          Iterations: 29
#          Function evaluations: 82
#          Gradient evaluations: 70
#
#  ***** evaluating model prev_viol_filtered_itrx w/ sigma 4 *****
# Optimization terminated successfully.
#          Current function value: 85548.922317
#          Iterations: 30
#          Function evaluations: 38
#          Gradient evaluations: 38
#
#  ***** evaluating model prev_viol_filtered_itrx w/ sigma 8 *****
# Optimization terminated successfully.
#          Current function value: 85548.767760
#          Iterations: 30
#          Function evaluations: 38
#          Gradient evaluations: 38
#
#  ***** evaluating model prev_viol_filtered_itrx w/ sigma 16 *****
# Optimization terminated successfully.
#          Current function value: 85548.729119
#          Iterations: 30
#          Function evaluations: 38
#          Gradient evaluations: 38
#
#  >>>> evaluating animal W068 <<<<
#
#  ***** evaluating model base w/ sigma 0.07 *****
#          Current function value: 36740.483443
#          Iterations: 13
#          Function evaluations: 56
#          Gradient evaluations: 44
#
#  ***** evaluating model base w/ sigma 0.13 *****
#          Current function value: 37139.965720
#          Iterations: 13
#          Function evaluations: 82
#          Gradient evaluations: 70
#
#  ***** evaluating model base w/ sigma 0.25 *****
#          Current function value: 37281.127444
#          Iterations: 14
#          Function evaluations: 79
#          Gradient evaluations: 67
#
#  ***** evaluating model base w/ sigma 0.5 *****
#          Current function value: 37322.439879
#          Iterations: 13
#          Function evaluations: 73
#          Gradient evaluations: 61
#
#  ***** evaluating model base w/ sigma 1 *****
#          Current function value: 37332.914991
#          Iterations: 12
#          Function evaluations: 69
#          Gradient evaluations: 57
#
#  ***** evaluating model base w/ sigma 2 *****
#          Current function value: 37335.543463
#          Iterations: 13
#          Function evaluations: 85
#          Gradient evaluations: 73
#
#  ***** evaluating model base w/ sigma 4 *****
#          Current function value: 37336.201118
#          Iterations: 14
#          Function evaluations: 73
#          Gradient evaluations: 61
#
#  ***** evaluating model base w/ sigma 8 *****
#          Current function value: 37336.365564
#          Iterations: 13
#          Function evaluations: 57
#          Gradient evaluations: 45
#
#  ***** evaluating model base w/ sigma 16 *****
#          Current function value: 37336.406678
#          Iterations: 13
#          Function evaluations: 77
#          Gradient evaluations: 65
#
#  ***** evaluating model prev_viol_binary w/ sigma 0.07 *****
#          Current function value: 78062.871856
#          Iterations: 24
#          Function evaluations: 73
#          Gradient evaluations: 62
#
#  ***** evaluating model prev_viol_binary w/ sigma 0.13 *****
#          Current function value: 77820.852799
#          Iterations: 25
#          Function evaluations: 39
#          Gradient evaluations: 39
#
#  ***** evaluating model prev_viol_binary w/ sigma 0.25 *****
# Optimization terminated successfully.
#          Current function value: 77746.744295
#          Iterations: 25
#          Function evaluations: 37
#          Gradient evaluations: 37
#
#  ***** evaluating model prev_viol_binary w/ sigma 0.5 *****
#          Current function value: 77725.974677
#          Iterations: 23
#          Function evaluations: 35
#          Gradient evaluations: 35
#
#  ***** evaluating model prev_viol_binary w/ sigma 1 *****
#          Current function value: 77720.770551
#          Iterations: 23
#          Function evaluations: 35
#          Gradient evaluations: 35
#
#  ***** evaluating model prev_viol_binary w/ sigma 2 *****
#          Current function value: 77719.468785
#          Iterations: 23
#          Function evaluations: 35
#          Gradient evaluations: 35
#
#  ***** evaluating model prev_viol_binary w/ sigma 4 *****
# Optimization terminated successfully.
#          Current function value: 77719.143297
#          Iterations: 24
#          Function evaluations: 36
#          Gradient evaluations: 36
#
#  ***** evaluating model prev_viol_binary w/ sigma 8 *****
# Optimization terminated successfully.
#          Current function value: 77719.061922
#          Iterations: 24
#          Function evaluations: 39
#          Gradient evaluations: 39
#
#  ***** evaluating model prev_viol_binary w/ sigma 16 *****
# Optimization terminated successfully.
#          Current function value: 77719.041578
#          Iterations: 24
#          Function evaluations: 36
#          Gradient evaluations: 36
#
#  ***** evaluating model prev_viol_filtered w/ sigma 0.07 *****
#          Current function value: 78128.764268
#          Iterations: 28
#          Function evaluations: 43
#          Gradient evaluations: 43
#
#  ***** evaluating model prev_viol_filtered w/ sigma 0.13 *****
# Optimization terminated successfully.
#          Current function value: 77844.296709
#          Iterations: 24
#          Function evaluations: 39
#          Gradient evaluations: 39
#
#  ***** evaluating model prev_viol_filtered w/ sigma 0.25 *****
# Optimization terminated successfully.
#          Current function value: 77750.196828
#          Iterations: 25
#          Function evaluations: 39
#          Gradient evaluations: 39
#
#  ***** evaluating model prev_viol_filtered w/ sigma 0.5 *****
#          Current function value: 77722.958779
#          Iterations: 23
#          Function evaluations: 36
#          Gradient evaluations: 36
#
#  ***** evaluating model prev_viol_filtered w/ sigma 1 *****
#          Current function value: 77716.066191
#          Iterations: 23
#          Function evaluations: 85
#          Gradient evaluations: 73
#
#  ***** evaluating model prev_viol_filtered w/ sigma 2 *****
# Optimization terminated successfully.
#          Current function value: 77714.337667
#          Iterations: 24
#          Function evaluations: 37
#          Gradient evaluations: 37
#
#  ***** evaluating model prev_viol_filtered w/ sigma 4 *****
#          Current function value: 77713.905196
#          Iterations: 22
#          Function evaluations: 66
#          Gradient evaluations: 54
#
#  ***** evaluating model prev_viol_filtered w/ sigma 8 *****
# Optimization terminated successfully.
#          Current function value: 77713.797057
#          Iterations: 24
#          Function evaluations: 39
#          Gradient evaluations: 39
#
#  ***** evaluating model prev_viol_filtered w/ sigma 16 *****
#          Current function value: 77713.770021
#          Iterations: 23
#          Function evaluations: 79
#          Gradient evaluations: 67
#
#  ***** evaluating model prev_viol_binary_itrx w/ sigma 0.07 *****
#          Current function value: 78047.411997
#          Iterations: 29
#          Function evaluations: 145
#          Gradient evaluations: 133
#
#  ***** evaluating model prev_viol_binary_itrx w/ sigma 0.13 *****
#          Current function value: 77800.456367
#          Iterations: 28
#          Function evaluations: 97
#          Gradient evaluations: 85
#
#  ***** evaluating model prev_viol_binary_itrx w/ sigma 0.25 *****
# Optimization terminated successfully.
#          Current function value: 77724.413972
#          Iterations: 30
#          Function evaluations: 45
#          Gradient evaluations: 45
#
#  ***** evaluating model prev_viol_binary_itrx w/ sigma 0.5 *****
# Optimization terminated successfully.
#          Current function value: 77703.060504
#          Iterations: 30
#          Function evaluations: 45
#          Gradient evaluations: 45
#
#  ***** evaluating model prev_viol_binary_itrx w/ sigma 1 *****
# Optimization terminated successfully.
#          Current function value: 77697.707062
#          Iterations: 29
#          Function evaluations: 43
#          Gradient evaluations: 43
#
#  ***** evaluating model prev_viol_binary_itrx w/ sigma 2 *****
#          Current function value: 77696.367753
#          Iterations: 27
#          Function evaluations: 71
#          Gradient evaluations: 59
#
#  ***** evaluating model prev_viol_binary_itrx w/ sigma 4 *****
#          Current function value: 77696.032867
#          Iterations: 27
#          Function evaluations: 81
#          Gradient evaluations: 69
#
#  ***** evaluating model prev_viol_binary_itrx w/ sigma 8 *****
#          Current function value: 77695.949141
#          Iterations: 28
#          Function evaluations: 62
#          Gradient evaluations: 50
#
#  ***** evaluating model prev_viol_binary_itrx w/ sigma 16 *****
#          Current function value: 77695.928210
#          Iterations: 28
#          Function evaluations: 94
#          Gradient evaluations: 82
#
#  ***** evaluating model prev_viol_filtered_itrx w/ sigma 0.07 *****
#          Current function value: 78123.584431
#          Iterations: 30
#          Function evaluations: 49
#          Gradient evaluations: 49
#
#  ***** evaluating model prev_viol_filtered_itrx w/ sigma 0.13 *****
#          Current function value: 77844.008757
#          Iterations: 29
#          Function evaluations: 82
#          Gradient evaluations: 70
#
#  ***** evaluating model prev_viol_filtered_itrx w/ sigma 0.25 *****
# Optimization terminated successfully.
#          Current function value: 77749.453204
#          Iterations: 29
#          Function evaluations: 44
#          Gradient evaluations: 44
#
#  ***** evaluating model prev_viol_filtered_itrx w/ sigma 0.5 *****
#          Current function value: 77721.788499
#          Iterations: 28
#          Function evaluations: 42
#          Gradient evaluations: 42
#
#  ***** evaluating model prev_viol_filtered_itrx w/ sigma 1 *****
#          Current function value: 77714.762504
#          Iterations: 27
#          Function evaluations: 90
#          Gradient evaluations: 78
#
#  ***** evaluating model prev_viol_filtered_itrx w/ sigma 2 *****
#          Current function value: 77712.998806
#          Iterations: 28
#          Function evaluations: 42
#          Gradient evaluations: 42
#
#  ***** evaluating model prev_viol_filtered_itrx w/ sigma 4 *****
#          Current function value: 77712.557426
#          Iterations: 28
#          Function evaluations: 75
#          Gradient evaluations: 63
#
#  ***** evaluating model prev_viol_filtered_itrx w/ sigma 8 *****
#          Current function value: 77712.447053
#          Iterations: 29
#          Function evaluations: 46
#          Gradient evaluations: 46
#
# ...
#
#  ***** evaluating model prev_viol_binary w/ sigma 4 *****
#          Current function value: 92487.432676
#          Iterations: 28
#          Function evaluations: 38
#          Gradient evaluations: 38
#
#  ***** evaluating model prev_viol_binary w/ sigma 8 *****
#          Current function value: 92487.325456
#          Iterations: 28
#          Function evaluations: 139
#          Gradient evaluations: 127
#
#  ***** evaluating model prev_viol_binary w/ sigma 16 *****
#          Current function value: 92487.298651
#          Iterations: 28
#          Function evaluations: 38
#          Gradient evaluations: 38
#
#  ***** evaluating model prev_viol_filtered w/ sigma 0.07 *****
#          Current function value: 92691.373341
#          Iterations: 30
#          Function evaluations: 104
#          Gradient evaluations: 92
#
#  ***** evaluating model prev_viol_filtered w/ sigma 0.13 *****
#          Current function value: 92218.108919
#          Iterations: 30
#          Function evaluations: 41
#          Gradient evaluations: 41
#
#  ***** evaluating model prev_viol_filtered w/ sigma 0.25 *****
#          Current function value: 92062.765272
#          Iterations: 28
#          Function evaluations: 91
#          Gradient evaluations: 79
#
#  ***** evaluating model prev_viol_filtered w/ sigma 0.5 *****
# Optimization terminated successfully.
#          Current function value: 92018.196596
#          Iterations: 31
#          Function evaluations: 75
#          Gradient evaluations: 72
#
#  ***** evaluating model prev_viol_filtered w/ sigma 1 *****
#          Current function value: 92006.954772
#          Iterations: 28
#          Function evaluations: 38
#          Gradient evaluations: 38
#
#  ***** evaluating model prev_viol_filtered w/ sigma 2 *****
#          Current function value: 92004.137993
#          Iterations: 27
#          Function evaluations: 37
#          Gradient evaluations: 37
#
#  ***** evaluating model prev_viol_filtered w/ sigma 4 *****
#          Current function value: 92003.433402
#          Iterations: 28
#          Function evaluations: 38
#          Gradient evaluations: 38
#
#  ***** evaluating model prev_viol_filtered w/ sigma 8 *****
#          Current function value: 92003.257229
#          Iterations: 28
#          Function evaluations: 83
#          Gradient evaluations: 71
#
#  ***** evaluating model prev_viol_filtered w/ sigma 16 *****
#          Current function value: 92003.213185
#          Iterations: 27
#          Function evaluations: 90
#          Gradient evaluations: 79
#
#  ***** evaluating model prev_viol_binary_itrx w/ sigma 0.07 *****
#          Current function value: 92785.023923
#          Iterations: 34
#          Function evaluations: 79
#          Gradient evaluations: 71
#
#  ***** evaluating model prev_viol_binary_itrx w/ sigma 0.13 *****
#          Current function value: 92443.914931
#          Iterations: 34
#          Function evaluations: 45
#          Gradient evaluations: 45
#
#  ***** evaluating model prev_viol_binary_itrx w/ sigma 0.25 *****
#          Current function value: 92338.433779
#          Iterations: 32
#          Function evaluations: 83
#          Gradient evaluations: 71
#
#  ***** evaluating model prev_viol_binary_itrx w/ sigma 0.5 *****
#          Current function value: 92308.769390
#          Iterations: 33
#          Function evaluations: 44
#          Gradient evaluations: 44
#
#  ***** evaluating model prev_viol_binary_itrx w/ sigma 1 *****
# Optimization terminated successfully.
#          Current function value: 92301.329160
#          Iterations: 33
#          Function evaluations: 43
#          Gradient evaluations: 43
#
#  ***** evaluating model prev_viol_binary_itrx w/ sigma 2 *****
# Optimization terminated successfully.
#          Current function value: 92299.467582
#          Iterations: 33
#          Function evaluations: 43
#          Gradient evaluations: 43
#
#  ***** evaluating model prev_viol_binary_itrx w/ sigma 4 *****
#          Current function value: 92299.002092
#          Iterations: 31
#          Function evaluations: 93
#          Gradient evaluations: 82
#
#  ***** evaluating model prev_viol_binary_itrx w/ sigma 8 *****
#          Current function value: 92298.885714
#          Iterations: 33
#          Function evaluations: 46
#          Gradient evaluations: 46
#
#  ***** evaluating model prev_viol_binary_itrx w/ sigma 16 *****
#          Current function value: 92298.856619
#          Iterations: 31
#          Function evaluations: 91
#          Gradient evaluations: 79
#
#  ***** evaluating model prev_viol_filtered_itrx w/ sigma 0.07 *****
#          Current function value: 92490.688838
#          Iterations: 35
#          Function evaluations: 98
#          Gradient evaluations: 87
#
#  ***** evaluating model prev_viol_filtered_itrx w/ sigma 0.13 *****
#          Current function value: 91964.952264
#          Iterations: 33
#          Function evaluations: 86
#          Gradient evaluations: 74
#
#  ***** evaluating model prev_viol_filtered_itrx w/ sigma 0.25 *****
#          Current function value: 91787.376596
#          Iterations: 32
#          Function evaluations: 69
#          Gradient evaluations: 64
#
#  ***** evaluating model prev_viol_filtered_itrx w/ sigma 0.5 *****
#          Current function value: 91735.757217
#          Iterations: 33
#          Function evaluations: 46
#          Gradient evaluations: 46
#
#  ***** evaluating model prev_viol_filtered_itrx w/ sigma 1 *****
#          Current function value: 91722.682441
#          Iterations: 31
#          Function evaluations: 41
#          Gradient evaluations: 41
#
#  ***** evaluating model prev_viol_filtered_itrx w/ sigma 2 *****
#          Current function value: 91719.402808
#          Iterations: 32
#          Function evaluations: 120
#          Gradient evaluations: 107
#
#  ***** evaluating model prev_viol_filtered_itrx w/ sigma 4 *****
#          Current function value: 91718.582211
#          Iterations: 30
#          Function evaluations: 102
#          Gradient evaluations: 91
#
#  ***** evaluating model prev_viol_filtered_itrx w/ sigma 8 *****
#          Current function value: 91718.377018
#          Iterations: 30
#          Function evaluations: 78
#          Gradient evaluations: 67
#
#  ***** evaluating model prev_viol_filtered_itrx w/ sigma 16 *****
#          Current function value: 91718.325718
#          Iterations: 31
#          Function evaluations: 41
#          Gradient evaluations: 41
#
#  >>>> evaluating animal W094 <<<<
#
#  ***** evaluating model base w/ sigma 0.07 *****
#          Current function value: 19026.416396
#          Iterations: 14
#          Function evaluations: 90
#          Gradient evaluations: 78
#
#  ***** evaluating model base w/ sigma 0.13 *****
#          Current function value: 19398.469405
#          Iterations: 12
#          Function evaluations: 59
#          Gradient evaluations: 47
#
#  ***** evaluating model base w/ sigma 0.25 *****
#          Current function value: 19553.076902
#          Iterations: 12
#          Function evaluations: 92
#          Gradient evaluations: 80
#
#  ***** evaluating model base w/ sigma 0.5 *****
#          Current function value: 19600.725010
#          Iterations: 13
#          Function evaluations: 76
#          Gradient evaluations: 64
#
#  ***** evaluating model base w/ sigma 1 *****
#          Current function value: 19612.983981
#          Iterations: 13
#          Function evaluations: 74
#          Gradient evaluations: 62
#
#  ***** evaluating model base w/ sigma 2 *****
#          Current function value: 19616.071513
#          Iterations: 12
#          Function evaluations: 64
#          Gradient evaluations: 52
#
#  ***** evaluating model base w/ sigma 4 *****
#          Current function value: 19616.844676
#          Iterations: 13
#          Function evaluations: 66
#          Gradient evaluations: 54
#
#  ***** evaluating model base w/ sigma 8 *****
#          Current function value: 19617.038056
#          Iterations: 13
#          Function evaluations: 50
#          Gradient evaluations: 38
#
#  ***** evaluating model base w/ sigma 16 *****
#          Current function value: 19617.086406
#          Iterations: 14
#          Function evaluations: 60
#          Gradient evaluations: 49
#
#  ***** evaluating model prev_viol_binary w/ sigma 0.07 *****
#          Current function value: 46145.992161
#          Iterations: 24
#          Function evaluations: 40
#          Gradient evaluations: 40
#
#  ***** evaluating model prev_viol_binary w/ sigma 0.13 *****
# Optimization terminated successfully.
#          Current function value: 45855.657504
#          Iterations: 24
#          Function evaluations: 37
#          Gradient evaluations: 37
#
#  ***** evaluating model prev_viol_binary w/ sigma 0.25 *****
# Optimization terminated successfully.
#          Current function value: 45764.400844
#          Iterations: 25
#          Function evaluations: 74
#          Gradient evaluations: 72
#
#  ***** evaluating model prev_viol_binary w/ sigma 0.5 *****
#          Current function value: 45738.615083
#          Iterations: 22
#          Function evaluations: 35
#          Gradient evaluations: 35
#
#  ***** evaluating model prev_viol_binary w/ sigma 1 *****
#          Current function value: 45732.139398
#          Iterations: 23
#          Function evaluations: 66
#          Gradient evaluations: 54
#
#  ***** evaluating model prev_viol_binary w/ sigma 2 *****
# Optimization terminated successfully.
#          Current function value: 45730.518637
#          Iterations: 23
#          Function evaluations: 34
#          Gradient evaluations: 34
#
#  ***** evaluating model prev_viol_binary w/ sigma 4 *****
#          Current function value: 45730.113331
#          Iterations: 22
#          Function evaluations: 73
#          Gradient evaluations: 62
#
#  ***** evaluating model prev_viol_binary w/ sigma 8 *****
# Optimization terminated successfully.
#          Current function value: 45730.011997
#          Iterations: 23
#          Function evaluations: 34
#          Gradient evaluations: 34
#
#  ***** evaluating model prev_viol_binary w/ sigma 16 *****
# Optimization terminated successfully.
#          Current function value: 45729.986664
#          Iterations: 23
#          Function evaluations: 34
#          Gradient evaluations: 34
#
#  ***** evaluating model prev_viol_filtered w/ sigma 0.07 *****
#          Current function value: 45952.864794
#          Iterations: 25
#          Function evaluations: 77
#          Gradient evaluations: 68
#
#  ***** evaluating model prev_viol_filtered w/ sigma 0.13 *****
#          Current function value: 45483.577233
#          Iterations: 26
#          Function evaluations: 142
#          Gradient evaluations: 126
#
#  ***** evaluating model prev_viol_filtered w/ sigma 0.25 *****
#          Current function value: 45310.096482
#          Iterations: 25
#          Function evaluations: 36
#          Gradient evaluations: 36
#
#  ***** evaluating model prev_viol_filtered w/ sigma 0.5 *****
#          Current function value: 45257.808044
#          Iterations: 23
#          Function evaluations: 94
#          Gradient evaluations: 83
#
#  ***** evaluating model prev_viol_filtered w/ sigma 1 *****
#          Current function value: 45244.418436
#          Iterations: 25
#          Function evaluations: 148
#          Gradient evaluations: 133
#
#  ***** evaluating model prev_viol_filtered w/ sigma 2 *****
#          Current function value: 45241.050378
#          Iterations: 23
#          Function evaluations: 97
#          Gradient evaluations: 85
#
#  ***** evaluating model prev_viol_filtered w/ sigma 4 *****
#          Current function value: 45240.207059
#          Iterations: 24
#          Function evaluations: 87
#          Gradient evaluations: 75
#
#  ***** evaluating model prev_viol_filtered w/ sigma 8 *****
#          Current function value: 45239.996147
#          Iterations: 24
#          Function evaluations: 82
#          Gradient evaluations: 70
#
#  ***** evaluating model prev_viol_filtered w/ sigma 16 *****
#          Current function value: 45239.943414
#          Iterations: 23
#          Function evaluations: 92
#          Gradient evaluations: 81
#
#  ***** evaluating model prev_viol_binary_itrx w/ sigma 0.07 *****
# Optimization terminated successfully.
#          Current function value: 46101.297900
#          Iterations: 31
#          Function evaluations: 49
#          Gradient evaluations: 49
#
#  ***** evaluating model prev_viol_binary_itrx w/ sigma 0.13 *****
# Optimization terminated successfully.
#          Current function value: 45792.808484
#          Iterations: 28
#          Function evaluations: 46
#          Gradient evaluations: 46
#
#  ***** evaluating model prev_viol_binary_itrx w/ sigma 0.25 *****
# Optimization terminated successfully.
#          Current function value: 45693.923997
#          Iterations: 28
#          Function evaluations: 46
#          Gradient evaluations: 46
#
#  ***** evaluating model prev_viol_binary_itrx w/ sigma 0.5 *****
#          Current function value: 45665.762245
#          Iterations: 28
#          Function evaluations: 61
#          Gradient evaluations: 56
#
#  ***** evaluating model prev_viol_binary_itrx w/ sigma 1 *****
# Optimization terminated successfully.
#          Current function value: 45658.673065
#          Iterations: 27
#          Function evaluations: 43
#          Gradient evaluations: 43
#
#  ***** evaluating model prev_viol_binary_itrx w/ sigma 2 *****
# Optimization terminated successfully.
#          Current function value: 45656.897672
#          Iterations: 27
#          Function evaluations: 43
#          Gradient evaluations: 43
#
#  ***** evaluating model prev_viol_binary_itrx w/ sigma 4 *****
# Optimization terminated successfully.
#          Current function value: 45656.453629
#          Iterations: 27
#          Function evaluations: 43
#          Gradient evaluations: 43
#
#  ***** evaluating model prev_viol_binary_itrx w/ sigma 8 *****
# Optimization terminated successfully.
#          Current function value: 45656.342606
#          Iterations: 27
#          Function evaluations: 43
#          Gradient evaluations: 43
#
#  ***** evaluating model prev_viol_binary_itrx w/ sigma 16 *****
# Optimization terminated successfully.
#          Current function value: 45656.314850
#          Iterations: 27
#          Function evaluations: 43
#          Gradient evaluations: 43
#
#  ***** evaluating model prev_viol_filtered_itrx w/ sigma 0.07 *****
# Optimization terminated successfully.
#          Current function value: 45926.175977
#          Iterations: 30
#          Function evaluations: 46
#          Gradient evaluations: 46
#
#  ***** evaluating model prev_viol_filtered_itrx w/ sigma 0.13 *****
# Optimization terminated successfully.
#          Current function value: 45422.422044
#          Iterations: 31
#          Function evaluations: 40
#          Gradient evaluations: 40
#
#  ***** evaluating model prev_viol_filtered_itrx w/ sigma 0.25 *****
# Optimization terminated successfully.
#          Current function value: 45225.609070
#          Iterations: 30
#          Function evaluations: 37
#          Gradient evaluations: 37
#
#  ***** evaluating model prev_viol_filtered_itrx w/ sigma 0.5 *****
# Optimization terminated successfully.
#          Current function value: 45163.688267
#          Iterations: 29
#          Function evaluations: 107
#          Gradient evaluations: 105
#
#  ***** evaluating model prev_viol_filtered_itrx w/ sigma 1 *****
# Optimization terminated successfully.
#          Current function value: 45147.537886
#          Iterations: 28
#          Function evaluations: 35
#          Gradient evaluations: 35
#
#  ***** evaluating model prev_viol_filtered_itrx w/ sigma 2 *****
# Optimization terminated successfully.
#          Current function value: 45143.453586
#          Iterations: 28
#          Function evaluations: 35
#          Gradient evaluations: 35
#
#  ***** evaluating model prev_viol_filtered_itrx w/ sigma 4 *****
#          Current function value: 45142.429504
#          Iterations: 29
#          Function evaluations: 130
#          Gradient evaluations: 113
#
#  ***** evaluating model prev_viol_filtered_itrx w/ sigma 8 *****
# Optimization terminated successfully.
#          Current function value: 45142.173295
#          Iterations: 28
#          Function evaluations: 35
#          Gradient evaluations: 35
#
#  ***** evaluating model prev_viol_filtered_itrx w/ sigma 16 *****
# Optimization terminated successfully.
#          Current function value: 45142.109230
#          Iterations: 28
#          Function evaluations: 35
#          Gradient evaluations: 35

# %% [markdown]
# ## Visualize

# %%
experiment = load_experiment(save_name, save_path=c.MODEL_FITS_PATH)
mvc = ModelVisualizerCompare(experiment)

# %%
df = mvc.find_best_fit(group="model_name")
df["model_name"] = pd.Categorical(df["model_name"], categories=ORDER, ordered=True)
for model_name, model_df in df.groupby("model_name"):
    mvc.plot_sigma_summary(model_df, title=f"{model_name} fit sigma summary")
# Out:
# /var/folders/__/8jn6qz211155h1xb451s5zcr0000gn/T/ipykernel_30649/2431235986.py:3: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   for model_name, model_df in df.groupby("model_name"):

# %%
fig, ax = plt.subplots(
    len(ORDER), 1, figsize=(10, len(ORDER) * 6), constrained_layout=True, sharey=False
)

best_fit_by_model = mvc.find_best_fit(group=["animal_id", "model_name"])
best_fit_by_model["model_name"] = pd.Categorical(
    best_fit_by_model["model_name"], categories=ORDER, ordered=True
)

for ii, (model_name, model_df) in enumerate(best_fit_by_model.groupby("model_name")):
    unpacked = mvc.unpack_features_and_weights(model_df)

    mvc.plot_weights_summary(
        df=unpacked,
        ax=ax[ii],
        palette=c.MULTI_CHOICE_PAL,
        title=f"{model_name} weights summary",
    )
# Out:
# /var/folders/__/8jn6qz211155h1xb451s5zcr0000gn/T/ipykernel_30649/3658154948.py:10: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   for ii, (model_name, model_df) in enumerate(best_fit_by_model.groupby("model_name")):
# /Users/jessbreda/Desktop/github/violations-multinomial/src/violmulti/visualizations/model_visualizer.py:347: UserWarning: The palette list has more values (3) than needed (1), which may not be intended.
#   sns.barplot(

# %%
fig, ax = plt.subplots(figsize=(8, 5))
mvc.plot_model_comparison(
    ax=ax,
    order=ORDER,
    color="purple",
    errorbar=None,
)
ax.legend().remove()
# Out:
# /var/folders/__/8jn6qz211155h1xb451s5zcr0000gn/T/ipykernel_30649/2177012689.py:8: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   ax.legend().remove()

# %%
fig, ax = plt.subplots(figsize=(8, 7))
sns.despine()
mvc.plot_model_comparison(
    hue="animal_id",
    ax=ax,
    order=ORDER,
    palette=["gray"] * 16,
    alpha = 0.5,
    y="bits_per_trial_relative_to_base"
)
mvc.plot_model_comparison(
    ax=ax,
    order=ORDER,
    color=c.MODEL_COMPARE_COLOR,
    errorbar=None,
    y="bits_per_trial_relative_to_base",
    ylabel="$\Delta$ test LL (bits per trial)",
)
# ax.set_xticks(range(len(LABELS)))
# ax.set_xticklabels(LABELS, rotation=0)
ax.legend().remove()
ax.set(xlabel="", title="Model Comparison")

# save fig
plt.tight_layout()

# %%
bpt = mvc.compute_bits_per_trial_df()

bpt.groupby("model_name").bits_per_trial_relative_to_base.agg(["mean", "std"])
# Out:
#                              mean       std
# model_name
# base                     0.000000  0.000000
# null                    -1.369610  0.084161
# prev_viol_binary        -0.000692  0.001592
# prev_viol_binary_itrx    0.000133  0.001961
# prev_viol_filtered      -0.000690  0.001753
# prev_viol_filtered_itrx  0.000502  0.002340
