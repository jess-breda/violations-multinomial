# %% [markdown]
# # Fig Experiment: Compare Previous Violation Regressors
#
# Compare models with non prev viol regressor, binary prev viol regressor and filtered prev viol regressor

# %%
import seaborn as sns
import matplotlib.pyplot as plt

from violmulti.experiments.experiment import load_experiment
from violmulti.experiments.experiment_compare_models import ExperimentCompareModels
from violmulti.models.multiclass_logistic_regression import MultiClassLogisticRegression
from violmulti.visualizations.model_visualizer import ModelVisualizer
from violmulti.features.design_matrix_generator_PWM import *

from violmulti.visualizations.model_visualizer import *

from violmulti.data import ANIMAL_IDS
from violmulti.experiments import STANDARD_SIGMAS
import config as c

sns.set_context("talk")
# %load_ext autoreload
# %autoreload 2

# %%
shared_cols = {
    "session": lambda df: (copy(df.session)),
    "bias": lambda df: (add_bias_column(df)),
    "s_a": lambda df: (standardize(df.s_a)),
    "s_b": lambda df: (standardize(df.s_b)),
    "prev_avg_stim": lambda df: prev_avg_stim(df, mask_prev_violation=True),
    "prev_correct": lambda df: (prev_correct_side(df)),
    "prev_choice": lambda df: (prev_choice(df)),
    "labels": multi_choice_labels(),
}

models_config = {
    "base" : {
        "model_class": MultiClassLogisticRegression,
        "dmg_config": {
            **shared_cols,
        },
    },
    "prev_viol_binary" : {
        "model_class": MultiClassLogisticRegression,
        "dmg_config": {
            **shared_cols,
            "prev_violation": lambda df: prev_violation(df),
        },
    },
    "prev_viol_filtered" : {
        "model_class": MultiClassLogisticRegression,
        "dmg_config": {
            **shared_cols,
            "filt_prev_violation": lambda df: (
                filtered_prev_viol(df, get_animals_tau(df, "prev_violation", save_path = c.MODEL_FITS_PATH + "/taus_df.csv"))
            ),
        },
    },
}
params = {
    "animals": ANIMAL_IDS,
    "data_type": "new_trained_cleaned",
    "sigmas": STANDARD_SIGMAS,
    "random_state": 47,
    "eval_train": True,
    "null_mode": "multi",
    "model_config": models_config,
}


save_name = "2025_07_19_fig3_compare_prev_viol_rs47.pkl"

ORDER = [
    "base",
    "prev_viol_binary",
    "prev_viol_filtered",
]

# %% [markdown]
# ## Run

# %%
experiment = ExperimentCompareModels(params)
experiment.run()
experiment.save(save_name, file_path=c.MODEL_FITS_PATH)
# Out:
# Loading dataset type : new_trained_cleaned
# DataLoader: Loading data type:  new_trained_cleaned  for animal ids:  ['W051', 'W060', 'W065', 'W066', 'W068', 'W072', 'W073', 'W074', 'W075', 'W078', 'W080', 'W081', 'W083', 'W088', 'W089', 'W094']
#
#  >>>> evaluating animal W051 <<<<
#
#  ***** evaluating model base w/ sigma 0.07 *****
#          Current function value: 64786.225261
#          Iterations: 26
#          Function evaluations: 44
#          Gradient evaluations: 44
#
#  ***** evaluating model base w/ sigma 0.13 *****
#          Current function value: 64550.403897
#          Iterations: 25
#          Function evaluations: 42
#          Gradient evaluations: 42
#
#  ***** evaluating model base w/ sigma 0.25 *****
#          Current function value: 64478.105527
#          Iterations: 24
#          Function evaluations: 38
#          Gradient evaluations: 38
#
#  ***** evaluating model base w/ sigma 0.5 *****
# Optimization terminated successfully.
#          Current function value: 64457.835923
#          Iterations: 23
#          Function evaluations: 36
#          Gradient evaluations: 36
#
#  ***** evaluating model base w/ sigma 1 *****
# Optimization terminated successfully.
#          Current function value: 64452.756584
#          Iterations: 23
#          Function evaluations: 36
#          Gradient evaluations: 36
#
#  ***** evaluating model base w/ sigma 2 *****
# Optimization terminated successfully.
#          Current function value: 64451.486000
#          Iterations: 24
#          Function evaluations: 59
#          Gradient evaluations: 56
#
#  ***** evaluating model base w/ sigma 4 *****
#          Current function value: 64451.168308
#          Iterations: 23
#          Function evaluations: 97
#          Gradient evaluations: 83
#
#  ***** evaluating model base w/ sigma 8 *****
# Optimization terminated successfully.
#          Current function value: 64451.088882
#          Iterations: 23
#          Function evaluations: 36
#          Gradient evaluations: 36
#
#  ***** evaluating model base w/ sigma 16 *****
# Optimization terminated successfully.
#          Current function value: 64451.069025
#          Iterations: 23
#          Function evaluations: 36
#          Gradient evaluations: 36
#
#  ***** evaluating model prev_viol_binary w/ sigma 0.07 *****
# Optimization terminated successfully.
#          Current function value: 64606.137646
#          Iterations: 27
#          Function evaluations: 44
#          Gradient evaluations: 44
#
#  ***** evaluating model prev_viol_binary w/ sigma 0.13 *****
#          Current function value: 64357.132928
#          Iterations: 26
#          Function evaluations: 41
#          Gradient evaluations: 41
#
#  ***** evaluating model prev_viol_binary w/ sigma 0.25 *****
#          Current function value: 64280.548024
#          Iterations: 25
#          Function evaluations: 66
#          Gradient evaluations: 55
#
#  ***** evaluating model prev_viol_binary w/ sigma 0.5 *****
#          Current function value: 64259.054955
#          Iterations: 25
#          Function evaluations: 75
#          Gradient evaluations: 64
#
#  ***** evaluating model prev_viol_binary w/ sigma 1 *****
# Optimization terminated successfully.
#          Current function value: 64253.667517
#          Iterations: 25
#          Function evaluations: 38
#          Gradient evaluations: 38
#
#  ***** evaluating model prev_viol_binary w/ sigma 2 *****
#          Current function value: 64252.319768
#          Iterations: 24
#          Function evaluations: 73
#          Gradient evaluations: 61
#
#  ***** evaluating model prev_viol_binary w/ sigma 4 *****
# Optimization terminated successfully.
#          Current function value: 64251.982775
#          Iterations: 25
#          Function evaluations: 38
#          Gradient evaluations: 38
#
#  ***** evaluating model prev_viol_binary w/ sigma 8 *****
# Optimization terminated successfully.
#          Current function value: 64251.898524
#          Iterations: 25
#          Function evaluations: 38
#          Gradient evaluations: 38
#
#  ***** evaluating model prev_viol_binary w/ sigma 16 *****
# Optimization terminated successfully.
#          Current function value: 64251.877461
#          Iterations: 25
#          Function evaluations: 38
#          Gradient evaluations: 38
#
#  ***** evaluating model prev_viol_filtered w/ sigma 0.07 *****
#          Current function value: 64562.167041
#          Iterations: 28
#          Function evaluations: 85
#          Gradient evaluations: 73
#
#  ***** evaluating model prev_viol_filtered w/ sigma 0.13 *****
#          Current function value: 64294.481841
#          Iterations: 27
#          Function evaluations: 111
#          Gradient evaluations: 97
#
#  ***** evaluating model prev_viol_filtered w/ sigma 0.25 *****
#          Current function value: 64210.979301
#          Iterations: 27
#          Function evaluations: 83
#          Gradient evaluations: 71
#
#  ***** evaluating model prev_viol_filtered w/ sigma 0.5 *****
#          Current function value: 64187.430396
#          Iterations: 25
#          Function evaluations: 89
#          Gradient evaluations: 79
#
#  ***** evaluating model prev_viol_filtered w/ sigma 1 *****
#          Current function value: 64181.519426
#          Iterations: 25
#          Function evaluations: 35
#          Gradient evaluations: 35
#
#  ***** evaluating model prev_viol_filtered w/ sigma 2 *****
#          Current function value: 64180.040186
#          Iterations: 24
#          Function evaluations: 73
#          Gradient evaluations: 61
#
#  ***** evaluating model prev_viol_filtered w/ sigma 4 *****
# Optimization terminated successfully.
#          Current function value: 64179.670283
#          Iterations: 26
#          Function evaluations: 36
#          Gradient evaluations: 36
#
#  ***** evaluating model prev_viol_filtered w/ sigma 8 *****
#          Current function value: 64179.577801
#          Iterations: 25
#          Function evaluations: 85
#          Gradient evaluations: 74
#
#  ***** evaluating model prev_viol_filtered w/ sigma 16 *****
# Optimization terminated successfully.
#          Current function value: 64179.554680
#          Iterations: 26
#          Function evaluations: 36
#          Gradient evaluations: 36
#
#  >>>> evaluating animal W060 <<<<
#
#  ***** evaluating model base w/ sigma 0.07 *****
#          Current function value: 51054.619483
#          Iterations: 26
#          Function evaluations: 100
#          Gradient evaluations: 88
#
#  ***** evaluating model base w/ sigma 0.13 *****
#          Current function value: 50771.039028
#          Iterations: 27
#          Function evaluations: 89
#          Gradient evaluations: 77
#
#  ***** evaluating model base w/ sigma 0.25 *****
# Optimization terminated successfully.
#          Current function value: 50683.202601
#          Iterations: 25
#          Function evaluations: 42
#          Gradient evaluations: 42
#
#  ***** evaluating model base w/ sigma 0.5 *****
#          Current function value: 50658.497739
#          Iterations: 25
#          Function evaluations: 111
#          Gradient evaluations: 97
#
#  ***** evaluating model base w/ sigma 1 *****
# Optimization terminated successfully.
#          Current function value: 50652.301474
#          Iterations: 25
#          Function evaluations: 41
#          Gradient evaluations: 41
#
#  ***** evaluating model base w/ sigma 2 *****
#          Current function value: 50650.751149
#          Iterations: 24
#          Function evaluations: 40
#          Gradient evaluations: 40
#
#  ***** evaluating model base w/ sigma 4 *****
# Optimization terminated successfully.
#          Current function value: 50650.363489
#          Iterations: 25
#          Function evaluations: 41
#          Gradient evaluations: 41
#
#  ***** evaluating model base w/ sigma 8 *****
#          Current function value: 50650.266569
#          Iterations: 24
#          Function evaluations: 88
#          Gradient evaluations: 76
#
#  ***** evaluating model base w/ sigma 16 *****
#          Current function value: 50650.242338
#          Iterations: 25
#          Function evaluations: 93
#          Gradient evaluations: 79
#
#  ***** evaluating model prev_viol_binary w/ sigma 0.07 *****
#          Current function value: 50702.169599
#          Iterations: 28
#          Function evaluations: 41
#          Gradient evaluations: 41
#
#  ***** evaluating model prev_viol_binary w/ sigma 0.13 *****
#          Current function value: 50389.779141
#          Iterations: 26
#          Function evaluations: 40
#          Gradient evaluations: 40
#
#  ***** evaluating model prev_viol_binary w/ sigma 0.25 *****
# Optimization terminated successfully.
#          Current function value: 50292.498856
#          Iterations: 28
#          Function evaluations: 41
#          Gradient evaluations: 41
#
#  ***** evaluating model prev_viol_binary w/ sigma 0.5 *****
#          Current function value: 50265.091769
#          Iterations: 29
#          Function evaluations: 129
#          Gradient evaluations: 115
#
#  ***** evaluating model prev_viol_binary w/ sigma 1 *****
# Optimization terminated successfully.
#          Current function value: 50258.214548
#          Iterations: 28
#          Function evaluations: 40
#          Gradient evaluations: 40
#
#  ***** evaluating model prev_viol_binary w/ sigma 2 *****
#          Current function value: 50256.493644
#          Iterations: 26
#          Function evaluations: 87
#          Gradient evaluations: 76
#
#  ***** evaluating model prev_viol_binary w/ sigma 4 *****
# Optimization terminated successfully.
#          Current function value: 50256.063318
#          Iterations: 27
#          Function evaluations: 40
#          Gradient evaluations: 40
#
#  ***** evaluating model prev_viol_binary w/ sigma 8 *****
# Optimization terminated successfully.
#          Current function value: 50255.955730
#          Iterations: 27
#          Function evaluations: 70
#          Gradient evaluations: 69
#
#  ***** evaluating model prev_viol_binary w/ sigma 16 *****
#          Current function value: 50255.928833
#          Iterations: 26
#          Function evaluations: 63
#          Gradient evaluations: 52
#
#  ***** evaluating model prev_viol_filtered w/ sigma 0.07 *****
#          Current function value: 50709.891893
#          Iterations: 27
#          Function evaluations: 84
#          Gradient evaluations: 72
#
#  ***** evaluating model prev_viol_filtered w/ sigma 0.13 *****
#          Current function value: 50371.902019
#          Iterations: 29
#          Function evaluations: 41
#          Gradient evaluations: 41
#
#  ***** evaluating model prev_viol_filtered w/ sigma 0.25 *****
# Optimization terminated successfully.
#          Current function value: 50264.627028
#          Iterations: 28
#          Function evaluations: 40
#          Gradient evaluations: 40
#
#  ***** evaluating model prev_viol_filtered w/ sigma 0.5 *****
#          Current function value: 50234.203047
#          Iterations: 27
#          Function evaluations: 40
#          Gradient evaluations: 40
#
#  ***** evaluating model prev_viol_filtered w/ sigma 1 *****
#          Current function value: 50226.554285
#          Iterations: 26
#          Function evaluations: 79
#          Gradient evaluations: 69
#
#  ***** evaluating model prev_viol_filtered w/ sigma 2 *****
#          Current function value: 50224.639393
#          Iterations: 27
#          Function evaluations: 38
#          Gradient evaluations: 38
#
#  ***** evaluating model prev_viol_filtered w/ sigma 4 *****
#          Current function value: 50224.160501
#          Iterations: 27
#          Function evaluations: 116
#          Gradient evaluations: 104
#
#  ***** evaluating model prev_viol_filtered w/ sigma 8 *****
# Optimization terminated successfully.
#          Current function value: 50224.040768
#          Iterations: 28
#          Function evaluations: 42
#          Gradient evaluations: 42
#
#  ***** evaluating model prev_viol_filtered w/ sigma 16 *****
#          Current function value: 50224.010834
#          Iterations: 27
#          Function evaluations: 88
#          Gradient evaluations: 76
#
#  >>>> evaluating animal W065 <<<<
#
#  ***** evaluating model base w/ sigma 0.07 *****
# Optimization terminated successfully.
#          Current function value: 58393.725231
#          Iterations: 25
#          Function evaluations: 34
#          Gradient evaluations: 34
#
#  ***** evaluating model base w/ sigma 0.13 *****
#          Current function value: 58156.406564
#          Iterations: 25
#          Function evaluations: 85
#          Gradient evaluations: 74
#
#  ***** evaluating model base w/ sigma 0.25 *****
# Optimization terminated successfully.
#          Current function value: 58082.416564
#          Iterations: 25
#          Function evaluations: 33
#          Gradient evaluations: 33
#
#  ***** evaluating model base w/ sigma 0.5 *****
#          Current function value: 58061.562942
#          Iterations: 23
#          Function evaluations: 79
#          Gradient evaluations: 67
#
#  ***** evaluating model base w/ sigma 1 *****
# Optimization terminated successfully.
#          Current function value: 58056.329592
#          Iterations: 24
#          Function evaluations: 31
#          Gradient evaluations: 31
#
#  ***** evaluating model base w/ sigma 2 *****
#          Current function value: 58055.020000
#          Iterations: 23
#          Function evaluations: 70
#          Gradient evaluations: 59
#
#  ***** evaluating model base w/ sigma 4 *****
#          Current function value: 58054.692524
#          Iterations: 24
#          Function evaluations: 104
#          Gradient evaluations: 92
#
#  ***** evaluating model base w/ sigma 8 *****
#          Current function value: 58054.610650
#          Iterations: 23
#          Function evaluations: 62
#          Gradient evaluations: 50
#
#  ***** evaluating model base w/ sigma 16 *****
# Optimization terminated successfully.
#          Current function value: 58054.590181
#          Iterations: 24
#          Function evaluations: 31
#          Gradient evaluations: 31
#
#  ***** evaluating model prev_viol_binary w/ sigma 0.07 *****
# Optimization terminated successfully.
#          Current function value: 57958.057820
#          Iterations: 28
#          Function evaluations: 43
#          Gradient evaluations: 43
#
#  ***** evaluating model prev_viol_binary w/ sigma 0.13 *****
# Optimization terminated successfully.
#          Current function value: 57702.449669
#          Iterations: 29
#          Function evaluations: 43
#          Gradient evaluations: 43
#
#  ***** evaluating model prev_viol_binary w/ sigma 0.25 *****
# Optimization terminated successfully.
#          Current function value: 57622.698020
#          Iterations: 27
#          Function evaluations: 40
#          Gradient evaluations: 40
#
#  ***** evaluating model prev_viol_binary w/ sigma 0.5 *****
#          Current function value: 57600.215655
#          Iterations: 25
#          Function evaluations: 56
#          Gradient evaluations: 48
#
#  ***** evaluating model prev_viol_binary w/ sigma 1 *****
# Optimization terminated successfully.
#          Current function value: 57594.573231
#          Iterations: 26
#          Function evaluations: 38
#          Gradient evaluations: 38
#
#  ***** evaluating model prev_viol_binary w/ sigma 2 *****
# Optimization terminated successfully.
#          Current function value: 57593.161252
#          Iterations: 26
#          Function evaluations: 38
#          Gradient evaluations: 38
#
#  ***** evaluating model prev_viol_binary w/ sigma 4 *****
# Optimization terminated successfully.
#          Current function value: 57592.808171
#          Iterations: 26
#          Function evaluations: 38
#          Gradient evaluations: 38
#
#  ***** evaluating model prev_viol_binary w/ sigma 8 *****
# Optimization terminated successfully.
#          Current function value: 57592.719896
#          Iterations: 26
#          Function evaluations: 38
#          Gradient evaluations: 38
#
#  ***** evaluating model prev_viol_binary w/ sigma 16 *****
# Optimization terminated successfully.
#          Current function value: 57592.697827
#          Iterations: 26
#          Function evaluations: 38
#          Gradient evaluations: 38
#
#  ***** evaluating model prev_viol_filtered w/ sigma 0.07 *****
#          Current function value: 57551.188445
#          Iterations: 27
#          Function evaluations: 114
#          Gradient evaluations: 100
#
#  ***** evaluating model prev_viol_filtered w/ sigma 0.13 *****
#          Current function value: 57174.998446
#          Iterations: 26
#          Function evaluations: 78
#          Gradient evaluations: 66
#
#  ***** evaluating model prev_viol_filtered w/ sigma 0.25 *****
# Optimization terminated successfully.
#          Current function value: 57050.233396
#          Iterations: 26
#          Function evaluations: 39
#          Gradient evaluations: 39
#
#  ***** evaluating model prev_viol_filtered w/ sigma 0.5 *****
#          Current function value: 57014.305702
#          Iterations: 24
#          Function evaluations: 114
#          Gradient evaluations: 101
#
#  ***** evaluating model prev_viol_filtered w/ sigma 1 *****
# Optimization terminated successfully.
#          Current function value: 57005.233670
#          Iterations: 25
#          Function evaluations: 34
#          Gradient evaluations: 34
#
#  ***** evaluating model prev_viol_filtered w/ sigma 2 *****
# Optimization terminated successfully.
#          Current function value: 57002.959933
#          Iterations: 25
#          Function evaluations: 34
#          Gradient evaluations: 34
#
#  ***** evaluating model prev_viol_filtered w/ sigma 4 *****
#          Current function value: 57002.391140
#          Iterations: 24
#          Function evaluations: 93
#          Gradient evaluations: 81
#
#  ***** evaluating model prev_viol_filtered w/ sigma 8 *****
# Optimization terminated successfully.
#          Current function value: 57002.248919
#          Iterations: 25
#          Function evaluations: 34
#          Gradient evaluations: 34
#
#  ***** evaluating model prev_viol_filtered w/ sigma 16 *****
# Optimization terminated successfully.
#          Current function value: 57002.213362
#          Iterations: 25
#          Function evaluations: 34
#          Gradient evaluations: 34
#
#  >>>> evaluating animal W066 <<<<
#
#  ***** evaluating model base w/ sigma 0.07 *****
#          Current function value: 86492.293875
#          Iterations: 22
#          Function evaluations: 95
#          Gradient evaluations: 83
#
#  ***** evaluating model base w/ sigma 0.13 *****
#          Current function value:
#
#  ***** evaluating model prev_viol_filtered w/ sigma 16 *****
# Optimization terminated successfully.
#          Current function value: 72281.992240
#          Iterations: 26
#          Function evaluations: 36
#          Gradient evaluations: 36
#
#  >>>> evaluating animal W074 <<<<
#
#  ***** evaluating model base w/ sigma 0.07 *****
# Optimization terminated successfully.
#          Current function value: 116016.286394
#          Iterations: 32
#          Function evaluations: 48
#          Gradient evaluations: 48
#
#  ***** evaluating model base w/ sigma 0.13 *****
#          Current function value: 115356.063539
#          Iterations: 30
#          Function evaluations: 111
#          Gradient evaluations: 98
#
#  ***** evaluating model base w/ sigma 0.25 *****
#          Current function value: 115152.608782
#          Iterations: 28
#          Function evaluations: 69
#          Gradient evaluations: 57
#
#  ***** evaluating model base w/ sigma 0.5 *****
#          Current function value: 115095.462850
#          Iterations: 30
#          Function evaluations: 40
#          Gradient evaluations: 40
#
#  ***** evaluating model base w/ sigma 1 *****
# Optimization terminated successfully.
#          Current function value: 115081.135093
#          Iterations: 29
#          Function evaluations: 38
#          Gradient evaluations: 38
#
#  ***** evaluating model base w/ sigma 2 *****
#          Current function value: 115077.550558
#          Iterations: 28
#          Function evaluations: 64
#          Gradient evaluations: 52
#
#  ***** evaluating model base w/ sigma 4 *****
#          Current function value: 115076.654261
#          Iterations: 28
#          Function evaluations: 73
#          Gradient evaluations: 62
#
#  ***** evaluating model base w/ sigma 8 *****
#          Current function value: 115076.430177
#          Iterations: 27
#          Function evaluations: 96
#          Gradient evaluations: 84
#
#  ***** evaluating model base w/ sigma 16 *****
# Optimization terminated successfully.
#          Current function value: 115076.374155
#          Iterations: 29
#          Function evaluations: 38
#          Gradient evaluations: 38
#
#  ***** evaluating model prev_viol_binary w/ sigma 0.07 *****
#          Current function value: 113024.399394
#          Iterations: 28
#          Function evaluations: 102
#          Gradient evaluations: 91
#
#  ***** evaluating model prev_viol_binary w/ sigma 0.13 *****
#          Current function value: 112217.014186
#          Iterations: 34
#          Function evaluations: 84
#          Gradient evaluations: 72
#
#  ***** evaluating model prev_viol_binary w/ sigma 0.25 *****
#          Current function value: 111967.007024
#          Iterations: 32
#          Function evaluations: 45
#          Gradient evaluations: 45
#
#  ***** evaluating model prev_viol_binary w/ sigma 0.5 *****
#          Current function value: 111896.684163
#          Iterations: 30
#          Function evaluations: 81
#          Gradient evaluations: 71
#
#  ***** evaluating model prev_viol_binary w/ sigma 1 *****
#          Current function value: 111879.045700
#          Iterations: 29
#          Function evaluations: 102
#          Gradient evaluations: 90
#
#  ***** evaluating model prev_viol_binary w/ sigma 2 *****
#          Current function value: 111874.632452
#          Iterations: 29
#          Function evaluations: 38
#          Gradient evaluations: 38
#
#  ***** evaluating model prev_viol_binary w/ sigma 4 *****
#          Current function value: 111873.528913
#          Iterations: 28
#          Function evaluations: 66
#          Gradient evaluations: 54
#
#  ***** evaluating model prev_viol_binary w/ sigma 8 *****
#          Current function value: 111873.253014
#          Iterations: 28
#          Function evaluations: 90
#          Gradient evaluations: 78
#
#  ***** evaluating model prev_viol_binary w/ sigma 16 *****
#          Current function value: 111873.184038
#          Iterations: 29
#          Function evaluations: 73
#          Gradient evaluations: 62
#
#  ***** evaluating model prev_viol_filtered w/ sigma 0.07 *****
#          Current function value: 112264.947506
#          Iterations: 34
#          Function evaluations: 49
#          Gradient evaluations: 49
#
#  ***** evaluating model prev_viol_filtered w/ sigma 0.13 *****
#          Current function value: 111005.048331
#          Iterations: 32
#          Function evaluations: 81
#          Gradient evaluations: 70
#
#  ***** evaluating model prev_viol_filtered w/ sigma 0.25 *****
#          Current function value: 110585.695442
#          Iterations: 30
#          Function evaluations: 90
#          Gradient evaluations: 80
#
#  ***** evaluating model prev_viol_filtered w/ sigma 0.5 *****
#          Current function value: 110464.763046
#          Iterations: 32
#          Function evaluations: 175
#          Gradient evaluations: 159
#
#  ***** evaluating model prev_viol_filtered w/ sigma 1 *****
#          Current function value: 110434.213226
#          Iterations: 29
#          Function evaluations: 39
#          Gradient evaluations: 39
#
#  ***** evaluating model prev_viol_filtered w/ sigma 2 *****
#          Current function value: 110426.555613
#          Iterations: 28
#          Function evaluations: 76
#          Gradient evaluations: 65
#
#  ***** evaluating model prev_viol_filtered w/ sigma 4 *****
#          Current function value: 110424.639944
#          Iterations: 28
#          Function evaluations: 77
#          Gradient evaluations: 66
#
#  ***** evaluating model prev_viol_filtered w/ sigma 8 *****
# Optimization terminated successfully.
#          Current function value: 110424.160947
#          Iterations: 30
#          Function evaluations: 40
#          Gradient evaluations: 40
#
#  ***** evaluating model prev_viol_filtered w/ sigma 16 *****
# Optimization terminated successfully.
#          Current function value: 110424.041193
#          Iterations: 30
#          Function evaluations: 40
#          Gradient evaluations: 40
#
#  >>>> evaluating animal W075 <<<<
#
#  ***** evaluating model base w/ sigma 0.07 *****
#          Current function value: 133883.801779
#          Iterations: 29
#          Function evaluations: 43
#          Gradient evaluations: 43
#
#  ***** evaluating model base w/ sigma 0.13 *****
#          Current function value: 133293.441286
#          Iterations: 28
#          Function evaluations: 94
#          Gradient evaluations: 82
#
#  ***** evaluating model base w/ sigma 0.25 *****
# Optimization terminated successfully.
#          Current function value: 133113.430993
#          Iterations: 31
#          Function evaluations: 64
#          Gradient evaluations: 63
#
#  ***** evaluating model base w/ sigma 0.5 *****
#          Current function value: 133063.044419
#          Iterations: 30
#          Function evaluations: 158
#          Gradient evaluations: 143
#
#  ***** evaluating model base w/ sigma 1 *****
# Optimization terminated successfully.
#          Current function value: 133050.423637
#          Iterations: 29
#          Function evaluations: 38
#          Gradient evaluations: 38
#
#  ***** evaluating model base w/ sigma 2 *****
#          Current function value: 133047.266927
#          Iterations: 26
#          Function evaluations: 84
#          Gradient evaluations: 72
#
#  ***** evaluating model base w/ sigma 4 *****
#          Current function value: 133046.477655
#          Iterations: 27
#          Function evaluations: 87
#          Gradient evaluations: 77
#
#  ***** evaluating model base w/ sigma 8 *****
#          Current function value: 133046.280332
# ...
#          Function evaluations: 106
#          Gradient evaluations: 92
#
#  ***** evaluating model base w/ sigma 1 *****
# Optimization terminated successfully.
#          Current function value: 77686.429982
#          Iterations: 23
#          Function evaluations: 38
#          Gradient evaluations: 38
#
#  ***** evaluating model base w/ sigma 2 *****
#          Current function value: 77685.009224
#          Iterations: 21
#          Function evaluations: 60
#          Gradient evaluations: 49
#
#  ***** evaluating model base w/ sigma 4 *****
# Optimization terminated successfully.
#          Current function value: 77684.653982
#          Iterations: 22
#          Function evaluations: 34
#          Gradient evaluations: 34
#
#  ***** evaluating model base w/ sigma 8 *****
#          Current function value: 77684.565168
#          Iterations: 22
#          Function evaluations: 146
#          Gradient evaluations: 133
#
#  ***** evaluating model base w/ sigma 16 *****
# Optimization terminated successfully.
#          Current function value: 77684.542964
#          Iterations: 22
#          Function evaluations: 34
#          Gradient evaluations: 34
#
#  ***** evaluating model prev_viol_binary w/ sigma 0.07 *****
#          Current function value: 76991.757845
#          Iterations: 24
#          Function evaluations: 40
#          Gradient evaluations: 40
#
#  ***** evaluating model prev_viol_binary w/ sigma 0.13 *****
#          Current function value: 76686.861418
#          Iterations: 25
#          Function evaluations: 41
#          Gradient evaluations: 41
#
#  ***** evaluating model prev_viol_binary w/ sigma 0.25 *****
#          Current function value: 76593.110056
#          Iterations: 25
#          Function evaluations: 41
#          Gradient evaluations: 41
#
#  ***** evaluating model prev_viol_binary w/ sigma 0.5 *****
# Optimization terminated successfully.
#          Current function value: 76566.802260
#          Iterations: 25
#          Function evaluations: 53
#          Gradient evaluations: 50
#
#  ***** evaluating model prev_viol_binary w/ sigma 1 *****
#          Current function value: 76560.208187
#          Iterations: 23
#          Function evaluations: 99
#          Gradient evaluations: 87
#
#  ***** evaluating model prev_viol_binary w/ sigma 2 *****
# Optimization terminated successfully.
#          Current function value: 76558.558595
#          Iterations: 25
#          Function evaluations: 44
#          Gradient evaluations: 44
#
#  ***** evaluating model prev_viol_binary w/ sigma 4 *****
#          Current function value: 76558.146130
#          Iterations: 24
#          Function evaluations: 39
#          Gradient evaluations: 39
#
#  ***** evaluating model prev_viol_binary w/ sigma 8 *****
#          Current function value: 76558.043009
#          Iterations: 24
#          Function evaluations: 82
#          Gradient evaluations: 70
#
#  ***** evaluating model prev_viol_binary w/ sigma 16 *****
#          Current function value: 76558.017229
#          Iterations: 24
#          Function evaluations: 98
#          Gradient evaluations: 85
#
#  ***** evaluating model prev_viol_filtered w/ sigma 0.07 *****
# Optimization terminated successfully.
#          Current function value: 76657.987537
#          Iterations: 25
#          Function evaluations: 38
#          Gradient evaluations: 38
#
#  ***** evaluating model prev_viol_filtered w/ sigma 0.13 *****
# Optimization terminated successfully.
#          Current function value: 76233.341380
#          Iterations: 24
#          Function evaluations: 36
#          Gradient evaluations: 36
#
#  ***** evaluating model prev_viol_filtered w/ sigma 0.25 *****
#          Current function value: 76097.305950
#          Iterations: 23
#          Function evaluations: 100
#          Gradient evaluations: 88
#
#  ***** evaluating model prev_viol_filtered w/ sigma 0.5 *****
# Optimization terminated successfully.
#          Current function value: 76058.613152
#          Iterations: 24
#          Function evaluations: 37
#          Gradient evaluations: 37
#
#  ***** evaluating model prev_viol_filtered w/ sigma 1 *****
#          Current function value: 76048.877735
#          Iterations: 22
#          Function evaluations: 75
#          Gradient evaluations: 63
#
#  ***** evaluating model prev_viol_filtered w/ sigma 2 *****
#          Current function value: 76046.439950
#          Iterations: 23
#          Function evaluations: 34
#          Gradient evaluations: 34
#
#  ***** evaluating model prev_viol_filtered w/ sigma 4 *****
#          Current function value: 76045.830258
#          Iterations: 23
#          Function evaluations: 34
#          Gradient evaluations: 34
#
#  ***** evaluating model prev_viol_filtered w/ sigma 8 *****
#          Current function value: 76045.677819
#          Iterations: 23
#          Function evaluations: 34
#          Gradient evaluations: 34
#
#  ***** evaluating model prev_viol_filtered w/ sigma 16 *****
#          Current function value: 76045.639709
#          Iterations: 23
#          Function evaluations: 87
#          Gradient evaluations: 74
#
#  >>>> evaluating animal W089 <<<<
#
#  ***** evaluating model base w/ sigma 0.07 *****
#          Current function value: 93948.665143
#          Iterations: 27
#          Function evaluations: 43
#          Gradient evaluations: 43
#
#  ***** evaluating model base w/ sigma 0.13 *****
# Optimization terminated successfully.
#          Current function value: 93683.977911
#          Iterations: 29
#          Function evaluations: 45
#          Gradient evaluations: 45
#
#  ***** evaluating model base w/ sigma 0.25 *****
#          Current function value: 93603.496278
#          Iterations: 26
#          Function evaluations: 85
#          Gradient evaluations: 73
#
#  ***** evaluating model base w/ sigma 0.5 *****
#          Current function value: 93580.988918
#          Iterations: 25
#          Function evaluations: 39
#          Gradient evaluations: 39
#
#  ***** evaluating model base w/ sigma 1 *****
#          Current function value: 93575.352707
#          Iterations: 25
#          Function evaluations: 38
#          Gradient evaluations: 38
#
#  ***** evaluating model base w/ sigma 2 *****
#          Current function value: 93573.943067
#          Iterations: 25
#          Function evaluations: 110
#          Gradient evaluations: 95
#
#  ***** evaluating model base w/ sigma 4 *****
#          Current function value: 93573.590620
#          Iterations: 25
#          Function evaluations: 41
#          Gradient evaluations: 41
#
#  ***** evaluating model base w/ sigma 8 *****
#          Current function value: 93573.502507
#          Iterations: 24
#          Function evaluations: 85
#          Gradient evaluations: 73
#
#  ***** evaluating model base w/ sigma 16 *****
#          Current function value: 93573.480478
#          Iterations: 24
#          Function evaluations: 84
#          Gradient evaluations: 73
#
#  ***** evaluating model prev_viol_binary w/ sigma 0.07 *****
#          Current function value: 92940.332052
#          Iterations: 28
#          Function evaluations: 87
#          Gradient evaluations: 76
#
#  ***** evaluating model prev_viol_binary w/ sigma 0.13 *****
# Optimization terminated successfully.
#          Current function value: 92621.444891
#          Iterations: 32
#          Function evaluations: 45
#          Gradient evaluations: 45
#
#  ***** evaluating model prev_viol_binary w/ sigma 0.25 *****
#          Current function value: 92523.799754
#          Iterations: 29
#          Function evaluations: 42
#          Gradient evaluations: 42
#
#  ***** evaluating model prev_viol_binary w/ sigma 0.5 *****
#          Current function value: 92496.433711
#          Iterations: 29
#          Function evaluations: 40
#          Gradient evaluations: 40
#
#  ***** evaluating model prev_viol_binary w/ sigma 1 *****
# Optimization terminated successfully.
#          Current function value: 92489.576748
#          Iterations: 29
#          Function evaluations: 65
#          Gradient evaluations: 64
#
#  ***** evaluating model prev_viol_binary w/ sigma 2 *****
#          Current function value: 92487.861539
#          Iterations: 27
#          Function evaluations: 69
#          Gradient evaluations: 58
#
#  ***** evaluating model prev_viol_binary w/ sigma 4 *****
#          Current function value: 92487.432676
#          Iterations: 28
#          Function evaluations: 38
#          Gradient evaluations: 38
#
#  ***** evaluating model prev_viol_binary w/ sigma 8 *****
#          Current function value: 92487.325456
#          Iterations: 28
#          Function evaluations: 139
#          Gradient evaluations: 127
#
#  ***** evaluating model prev_viol_binary w/ sigma 16 *****
#          Current function value: 92487.298651
#          Iterations: 28
#          Function evaluations: 38
#          Gradient evaluations: 38
#
#  ***** evaluating model prev_viol_filtered w/ sigma 0.07 *****
#          Current function value: 92691.373341
#          Iterations: 30
#          Function evaluations: 104
#          Gradient evaluations: 92
#
#  ***** evaluating model prev_viol_filtered w/ sigma 0.13 *****
#          Current function value: 92218.108919
#          Iterations: 30
#          Function evaluations: 41
#          Gradient evaluations: 41
#
#  ***** evaluating model prev_viol_filtered w/ sigma 0.25 *****
#          Current function value: 92062.765272
#          Iterations: 28
#          Function evaluations: 91
#          Gradient evaluations: 79
#
#  ***** evaluating model prev_viol_filtered w/ sigma 0.5 *****
# Optimization terminated successfully.
#          Current function value: 92018.196596
#          Iterations: 31
#          Function evaluations: 75
#          Gradient evaluations: 72
#
#  ***** evaluating model prev_viol_filtered w/ sigma 1 *****
#          Current function value: 92006.954772
#          Iterations: 28
#          Function evaluations: 38
#          Gradient evaluations: 38
#
#  ***** evaluating model prev_viol_filtered w/ sigma 2 *****
#          Current function value: 92004.137993
#          Iterations: 27
#          Function evaluations: 37
#          Gradient evaluations: 37
#
#  ***** evaluating model prev_viol_filtered w/ sigma 4 *****
#          Current function value: 92003.433402
#          Iterations: 28
#          Function evaluations: 38
#          Gradient evaluations: 38
#
#  ***** evaluating model prev_viol_filtered w/ sigma 8 *****
#          Current function value: 92003.257229
#          Iterations: 28
#          Function evaluations: 83
#          Gradient evaluations: 71
#
#  ***** evaluating model prev_viol_filtered w/ sigma 16 *****
#          Current function value: 92003.213185
#          Iterations: 27
#          Function evaluations: 90
#          Gradient evaluations: 79
#
#  >>>> evaluating animal W094 <<<<
#
#  ***** evaluating model base w/ sigma 0.07 *****
#          Current function value: 46562.785045
#          Iterations: 22
#          Function evaluations: 36
#          Gradient evaluations: 36
#
#  ***** evaluating model base w/ sigma 0.13 *****
#          Current function value: 46301.071172
#          Iterations: 21
#          Function evaluations: 76
#          Gradient evaluations: 65
#
#  ***** evaluating model base w/ sigma 0.25 *****
# Optimization terminated successfully.
#          Current function value: 46219.115122
#          Iterations: 22
#          Function evaluations: 35
#          Gradient evaluations: 35
#
#  ***** evaluating model base w/ sigma 0.5 *****
#          Current function value: 46195.984104
#          Iterations: 20
#          Function evaluations: 74
#          Gradient evaluations: 62
#
#  ***** evaluating model base w/ sigma 1 *****
# Optimization terminated successfully.
#          Current function value: 46190.176973
#          Iterations: 21
#          Function evaluations: 33
#          Gradient evaluations: 33
#
#  ***** evaluating model base w/ sigma 2 *****
#          Current function value: 46188.723658
#          Iterations: 20
#          Function evaluations: 76
#          Gradient evaluations: 64
#
#  ***** evaluating model base w/ sigma 4 *****
#          Current function value: 46188.360233
#          Iterations: 21
#          Function evaluations: 35
#          Gradient evaluations: 35
#
#  ***** evaluating model base w/ sigma 8 *****
# Optimization terminated successfully.
#          Current function value: 46188.269370
#          Iterations: 21
#          Function evaluations: 33
#          Gradient evaluations: 33
#
#  ***** evaluating model base w/ sigma 16 *****
# Optimization terminated successfully.
#          Current function value: 46188.246655
#          Iterations: 21
#          Function evaluations: 33
#          Gradient evaluations: 33
#
#  ***** evaluating model prev_viol_binary w/ sigma 0.07 *****
#          Current function value: 46145.992161
#          Iterations: 24
#          Function evaluations: 40
#          Gradient evaluations: 40
#
#  ***** evaluating model prev_viol_binary w/ sigma 0.13 *****
# Optimization terminated successfully.
#          Current function value: 45855.657504
#          Iterations: 24
#          Function evaluations: 37
#          Gradient evaluations: 37
#
#  ***** evaluating model prev_viol_binary w/ sigma 0.25 *****
# Optimization terminated successfully.
#          Current function value: 45764.400844
#          Iterations: 25
#          Function evaluations: 74
#          Gradient evaluations: 72
#
#  ***** evaluating model prev_viol_binary w/ sigma 0.5 *****
#          Current function value: 45738.615083
#          Iterations: 22
#          Function evaluations: 35
#          Gradient evaluations: 35
#
#  ***** evaluating model prev_viol_binary w/ sigma 1 *****
#          Current function value: 45732.139398
#          Iterations: 23
#          Function evaluations: 66
#          Gradient evaluations: 54
#
#  ***** evaluating model prev_viol_binary w/ sigma 2 *****
# Optimization terminated successfully.
#          Current function value: 45730.518637
#          Iterations: 23
#          Function evaluations: 34
#          Gradient evaluations: 34
#
#  ***** evaluating model prev_viol_binary w/ sigma 4 *****
#          Current function value: 45730.113331
#          Iterations: 22
#          Function evaluations: 73
#          Gradient evaluations: 62
#
#  ***** evaluating model prev_viol_binary w/ sigma 8 *****
# Optimization terminated successfully.
#          Current function value: 45730.011997
#          Iterations: 23
#          Function evaluations: 34
#          Gradient evaluations: 34
#
#  ***** evaluating model prev_viol_binary w/ sigma 16 *****
# Optimization terminated successfully.
#          Current function value: 45729.986664
#          Iterations: 23
#          Function evaluations: 34
#          Gradient evaluations: 34
#
#  ***** evaluating model prev_viol_filtered w/ sigma 0.07 *****
#          Current function value: 45952.864794
#          Iterations: 25
#          Function evaluations: 77
#          Gradient evaluations: 68
#
#  ***** evaluating model prev_viol_filtered w/ sigma 0.13 *****
#          Current function value: 45483.577233
#          Iterations: 26
#          Function evaluations: 142
#          Gradient evaluations: 126
#
#  ***** evaluating model prev_viol_filtered w/ sigma 0.25 *****
#          Current function value: 45310.096482
#          Iterations: 25
#          Function evaluations: 36
#          Gradient evaluations: 36
#
#  ***** evaluating model prev_viol_filtered w/ sigma 0.5 *****
#          Current function value: 45257.808044
#          Iterations: 23
#          Function evaluations: 94
#          Gradient evaluations: 83
#
#  ***** evaluating model prev_viol_filtered w/ sigma 1 *****
#          Current function value: 45244.418436
#          Iterations: 25
#          Function evaluations: 148
#          Gradient evaluations: 133
#
#  ***** evaluating model prev_viol_filtered w/ sigma 2 *****
#          Current function value: 45241.050378
#          Iterations: 23
#          Function evaluations: 97
#          Gradient evaluations: 85
#
#  ***** evaluating model prev_viol_filtered w/ sigma 4 *****
#          Current function value: 45240.207059
#          Iterations: 24
#          Function evaluations: 87
#          Gradient evaluations: 75
#
#  ***** evaluating model prev_viol_filtered w/ sigma 8 *****
#          Current function value: 45239.996147
#          Iterations: 24
#          Function evaluations: 82
#          Gradient evaluations: 70
#
#  ***** evaluating model prev_viol_filtered w/ sigma 16 *****
#          Current function value: 45239.943414
#          Iterations: 23
#          Function evaluations: 92
#          Gradient evaluations: 81

# %% [markdown]
# ## Visualize

# %%
experiment = load_experiment(save_name, save_path=c.MODEL_FITS_PATH)
mvc = ModelVisualizerCompare(experiment)

# %%
df = mvc.find_best_fit(group="model_name")
df["model_name"] = pd.Categorical(df["model_name"], categories=ORDER, ordered=True)
for model_name, model_df in df.groupby("model_name"):
    mvc.plot_sigma_summary(model_df, title=f"{model_name} fit sigma summary")
# Out:
# /var/folders/__/8jn6qz211155h1xb451s5zcr0000gn/T/ipykernel_82522/2431235986.py:3: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   for model_name, model_df in df.groupby("model_name"):

# %%
fig, ax = plt.subplots(
    len(ORDER), 1, figsize=(10, len(ORDER) * 6), constrained_layout=True, sharey=False
)

best_fit_by_model = mvc.find_best_fit(group=["animal_id", "model_name"])
best_fit_by_model["model_name"] = pd.Categorical(
    best_fit_by_model["model_name"], categories=ORDER, ordered=True
)

for ii, (model_name, model_df) in enumerate(best_fit_by_model.groupby("model_name")):
    unpacked = mvc.unpack_features_and_weights(model_df)

    mvc.plot_weights_summary(
        df=unpacked,
        ax=ax[ii],
        palette=c.MULTI_CHOICE_PAL,
        title=f"{model_name} weights summary",
    )
# Out:
# /var/folders/__/8jn6qz211155h1xb451s5zcr0000gn/T/ipykernel_82522/3658154948.py:10: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   for ii, (model_name, model_df) in enumerate(best_fit_by_model.groupby("model_name")):

# %%
fig, ax = plt.subplots(figsize=(8, 5))
mvc.plot_model_comparison(
    ax=ax,
    order=ORDER,
    color="purple",
    errorbar=None,
)
ax.legend().remove()
# Out:
# /var/folders/__/8jn6qz211155h1xb451s5zcr0000gn/T/ipykernel_82522/2177012689.py:8: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   ax.legend().remove()

# %%
fig, ax = plt.subplots(figsize=(8, 5))
mvc.plot_model_comparison(
    hue="animal_id",
    ax=ax,
    order=ORDER,
    palette=["gray"] * 16,
    alpha = 0.5
)
mvc.plot_model_comparison(
    ax=ax,
    order=ORDER,
    color="purple",
    errorbar=None,
)
ax.legend().remove()
ax.set_ylim(.15, )
# Out:
# (0.15, 0.5351949310943019)

# %%
mvc.plot_ll_delta_by_animal(
    base_model_name=ORDER[0],
    new_model_name=ORDER[1],
    type="test",
)
# Out:
# <Axes: title={'center': 'Model Improvement- mu: 180.79 std: 163.13 \n base -> prev_viol_binary'}, xlabel='animal_id', ylabel='Delta test LL (new - base)'>

# %%
mvc.plot_ll_delta_by_animal(
    base_model_name=ORDER[0],
    new_model_name=ORDER[2],
    type="test",
)
# Out:
# <Axes: title={'center': 'Model Improvement- mu: 314.35 std: 301.07 \n base -> prev_viol_filtered'}, xlabel='animal_id', ylabel='Delta test LL (new - base)'>

# %%
mvc.plot_ll_delta_by_animal(
    base_model_name=ORDER[1],
    new_model_name=ORDER[2],
    type="test",
)
# Out:
# <Axes: title={'center': 'Model Improvement- mu: 133.56 std: 192.98 \n prev_viol_binary -> prev_viol_filtered'}, xlabel='animal_id', ylabel='Delta test LL (new - base)'>

# %%
mvc.plot_delta_ll_by_violation_rate(
    base_model_name=ORDER[0],
    new_model_name=ORDER[1],
)

# %%
mvc.plot_delta_ll_by_violation_rate(
    base_model_name=ORDER[0],
    new_model_name=ORDER[2],
)

# %%
mvc.plot_delta_ll_by_violation_rate(
    base_model_name=ORDER[1],
    new_model_name=ORDER[2],
)
