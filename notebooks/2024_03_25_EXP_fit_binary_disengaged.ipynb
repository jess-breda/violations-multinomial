# %% [markdown]
# # Experiment: Fit Binary Disengaged
#
# **Goal**: Get binary model up and running with visuals and add in disengaged terms to see what their weights look like in a binary setting.
#
# Related notebooks:
#
# * `2024_03_22_EXP_compare_prev_disengageds_filt`
# * `2024_03_23_compare_prev_disengaged_stim_intrxs`
#
# > Written by Jess Breda

# %% [markdown]
# ## Imports

# %%
import seaborn as sns
import matplotlib.pyplot as plt

from multiglm.experiments.experiment import load_experiment

from multiglm.experiments.experiment_sigma_sweep import ExperimentSigmaSweep
from multiglm.experiments.experiment_tau_sweep import ExperimentTauSweep
from multiglm.experiments.experiment_compare_models import ExperimentCompareModels

from multiglm.features.design_matrix_generator import *
from multiglm.features.design_matrix_generator_PWM import *

from multiglm.models.binary_logistic_regression import BinaryLogisticRegression
from multiglm.models.multiclass_logistic_regression import MultiClassLogisticRegression

from multiglm.visualizations.model_visualizer import *

from multiglm.data import ANIMAL_IDS
from multiglm.experiments import STANDARD_SIGMAS


sns.set_context("talk")
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# ## Model Configs

# %% [markdown]
# ### Sigma Sweep

# %%
# design matrix columns
dmg_config = {
    "session": lambda df: (copy(df.session)),
    "bias": lambda df: (add_bias_column(df)),
    "s_a": lambda df: (standardize(df.s_a)),
    "s_a_x_filt_prev_viol": lambda df: (
        stim_filt_viol_intrx(df, "s_a", get_animals_tau(df, "prev_violation"))
    ),
    "s_b": lambda df: (standardize(df.s_b)),
    "s_b_x_filt_prev_viol": lambda df: (
        stim_filt_viol_intrx(df, "s_b", get_animals_tau(df, "prev_violation"))
    ),
    "prev_avg_stim": lambda df: prev_avg_stim(df, mask_prev_violation=True),
    "prev_correct": lambda df: (prev_correct_side(df)),
    "prev_choice": lambda df: (prev_choice(df)),
    "prev_tns": lambda df: (prev_trial_not_started(df)),
    "prev_violation_filt": lambda df: (
        filtered_prev_viol(df, get_animals_tau(df, "prev_violation"))
    ),
    "labels": binary_choice_labels(),
}

model_config = {
    "binary_w_disengaged": {
        "model_class": BinaryLogisticRegression,
        "dmg_config": dmg_config,
    },
}

params = {
    "animals": ANIMAL_IDS,
    "data_type": "new_trained",
    "sigmas": STANDARD_SIGMAS,
    "random_state": 47,
    "eval_train": True,
    "model_config": model_config,
}

save_name = "2024_03_25_fit_binary_disengaged.pkl"

# ORDER = ["feature order here"]

# %% [markdown]
# ## Run

# %%
experiment = ExperimentSigmaSweep(params)
experiment.run()
experiment.save(save_name)
# Out:
# Loading dataset type : new_trained
# Loading data for animal ids:  ['W051', 'W060', 'W065', 'W066', 'W068', 'W072', 'W073', 'W074', 'W075', 'W078', 'W080', 'W081', 'W082', 'W083', 'W088', 'W089', 'W094']
#
#  >>>> evaluating animal W051 <<<<
#
#  ***** evaluating model binary_w_disengaged w/ sigma 0.07 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 31965.137309
#          Iterations: 11
#          Function evaluations: 80
#          Gradient evaluations: 68
#
#  ***** evaluating model binary_w_disengaged w/ sigma 0.13 *****
# Optimization terminated successfully.
#          Current function value: 32341.675726
#          Iterations: 21
#          Function evaluations: 26
#          Gradient evaluations: 26
#
#  ***** evaluating model binary_w_disengaged w/ sigma 0.25 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 32476.884490
#          Iterations: 21
#          Function evaluations: 66
#          Gradient evaluations: 54
#
#  ***** evaluating model binary_w_disengaged w/ sigma 0.5 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 32015.032042
#          Iterations: 11
#          Function evaluations: 83
#          Gradient evaluations: 71
#
#  ***** evaluating model binary_w_disengaged w/ sigma 1 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 32536.808294
#          Iterations: 18
#          Function evaluations: 85
#          Gradient evaluations: 73
#
#  ***** evaluating model binary_w_disengaged w/ sigma 2 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 32540.314678
#          Iterations: 20
#          Function evaluations: 65
#          Gradient evaluations: 53
#
#  ***** evaluating model binary_w_disengaged w/ sigma 4 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 32541.216178
#          Iterations: 16
#          Function evaluations: 81
#          Gradient evaluations: 69
#
#  ***** evaluating model binary_w_disengaged w/ sigma 8 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 32541.444618
#          Iterations: 16
#          Function evaluations: 68
#          Gradient evaluations: 57
#
#  ***** evaluating model binary_w_disengaged w/ sigma 16 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 32541.501649
#          Iterations: 21
#          Function evaluations: 54
#          Gradient evaluations: 42
#
#  >>>> evaluating animal W060 <<<<
#
#  ***** evaluating model binary_w_disengaged w/ sigma 0.07 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 24591.508322
#          Iterations: 16
#          Function evaluations: 99
#          Gradient evaluations: 87
#
#  ***** evaluating model binary_w_disengaged w/ sigma 0.13 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 24979.297550
#          Iterations: 17
#          Function evaluations: 78
#          Gradient evaluations: 66
#
#  ***** evaluating model binary_w_disengaged w/ sigma 0.25 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 25135.171389
#          Iterations: 18
#          Function evaluations: 81
#          Gradient evaluations: 69
#
#  ***** evaluating model binary_w_disengaged w/ sigma 0.5 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 25191.378106
#          Iterations: 25
#          Function evaluations: 74
#          Gradient evaluations: 62
#
#  ***** evaluating model binary_w_disengaged w/ sigma 1 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 25207.386303
#          Iterations: 25
#          Function evaluations: 65
#          Gradient evaluations: 53
#
#  ***** evaluating model binary_w_disengaged w/ sigma 2 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 25211.549919
#          Iterations: 24
#          Function evaluations: 63
#          Gradient evaluations: 51
#
#  ***** evaluating model binary_w_disengaged w/ sigma 4 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 25212.601711
#          Iterations: 22
#          Function evaluations: 73
#          Gradient evaluations: 61
#
#  ***** evaluating model binary_w_disengaged w/ sigma 8 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 25212.865353
#          Iterations: 21
#          Function evaluations: 75
#          Gradient evaluations: 63
#
#  ***** evaluating model binary_w_disengaged w/ sigma 16 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 25212.931307
#          Iterations: 24
#          Function evaluations: 77
#          Gradient evaluations: 65
#
#  >>>> evaluating animal W065 <<<<
#
#  ***** evaluating model binary_w_disengaged w/ sigma 0.07 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 21027.512868
#          Iterations: 16
#          Function evaluations: 64
#          Gradient evaluations: 52
#
#  ***** evaluating model binary_w_disengaged w/ sigma 0.13 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 21363.581514
#          Iterations: 19
#          Function evaluations: 78
#          Gradient evaluations: 66
#
#  ***** evaluating model binary_w_disengaged w/ sigma 0.25 *****
# Optimization terminated successfully.
#          Current function value: 21512.562217
#          Iterations: 20
#          Function evaluations: 26
#          Gradient evaluations: 26
#
#  ***** evaluating model binary_w_disengaged w/ sigma 0.5 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 21564.308749
#          Iterations: 16
#          Function evaluations: 67
#          Gradient evaluations: 55
#
#  ***** evaluating model binary_w_disengaged w/ sigma 1 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 21578.577567
#          Iterations: 17
#          Function evaluations: 82
#          Gradient evaluations: 70
#
#  ***** evaluating model binary_w_disengaged w/ sigma 2 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 21582.251830
#          Iterations: 20
#          Function evaluations: 68
#          Gradient evaluations: 56
#
#  ***** evaluating model binary_w_disengaged w/ sigma 4 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 21583.177686
#          Iterations: 23
#          Function evaluations: 74
#          Gradient evaluations: 62
#
#  ***** evaluating model binary_w_disengaged w/ sigma 8 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 21583.409619
#          Iterations: 20
#          Function evaluations: 70
#          Gradient evaluations: 58
#
#  ***** evaluating model binary_w_disengaged w/ sigma 16 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 21583.467631
#          Iterations: 18
#          Function evaluations: 85
#          Gradient evaluations: 73
#
#  >>>> evaluating animal W066 <<<<
#
#  ***** evaluating model binary_w_disengaged w/ sigma 0.07 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 31998.141806
#          Iterations: 17
#          Function evaluations: 82
#          Gradient evaluations: 70
#
#  ***** evaluating model binary_w_disengaged w/ sigma 0.13 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 32471.329251
#          Iterations: 19
#          Function evaluations: 69
#          Gradient evaluations: 57
#
#  ***** evaluating model binary_w_disengaged w/ sigma 0.25 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 32651.465518
#          Iterations: 18
#          Function evaluations: 79
#          Gradient evaluations: 67
#
#  ***** evaluating model binary_w_disengaged w/ sigma 0.5 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 32705.129979
#          Iterations: 16
#          Function evaluations: 80
#          Gradient evaluations: 68
#
#  ***** evaluating model binary_w_disengaged w/ sigma 1 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 32716.516510
#          Iterations: 12
#          Function evaluations: 77
#          Gradient evaluations: 65
#
#  ***** evaluating model binary_w_disengaged w/ sigma 2 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 32722.029770
#          Iterations: 16
#          Function evaluations: 84
#          Gradient evaluations: 72
#
#  ***** evaluating model binary_w_disengaged w/ sigma 4 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 32722.998385
#          Iterations: 15
#          Function evaluations: 81
#          Gradient evaluations: 69
#
#  ***** evaluating model binary_w_disengaged w/ sigma 8 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 32723.249132
#          Iterations: 16
#          Function evaluations: 76
#          Gradient evaluations: 64
#
#  ***** evaluating model binary_w_disengaged w/ sigma 16 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 32723.312488
#          Iterations: 18
#          Function evaluations: 53
#          Gradient evaluations: 41
#
#  >>>> evaluating animal W068 <<<<
#
#  ***** evaluating model binary_w_disengaged w/ sigma 0.07 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 36777.563564
#          Iterations: 17
#          Function evaluations: 70
#          Gradient evaluations: 58
#
#  ***** evaluating model binary_w_disengaged w/ sigma 0.13 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 37136.663587
#          Iterations: 17
#          Function evaluations: 96
#          Gradient evaluations: 84
#
#  ***** evaluating model binary_w_disengaged w/ sigma 0.25 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 37261.772477
#          Iterations: 16
#          Function evaluations: 75
#          Gradient evaluations: 63
#
#  ***** evaluating model binary_w_disengaged w/ sigma 0.5 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 37301.156825
#          Iterations: 14
#          Function evaluations: 72
#          Gradient evaluations: 60
#
#  ***** evaluating model binary_w_disengaged w/ sigma 1 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 37311.859429
#          Iterations: 19
#          Function evaluations: 67
#          Gradient evaluations: 55
#
#  ***** evaluating model binary_w_disengaged w/ sigma 2 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 37314.616397
#          Iterations: 16
#          Function evaluations: 84
#          Gradient evaluations: 72
#
#  ***** evaluating model binary_w_disengaged w/ sigma 4 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 37315.312275
#          Iterations: 17
#          Function evaluations: 82
#          Gradient evaluations: 70
#
#  ***** evaluating model binary_w_disengaged w/ sigma 8 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 37315.486436
#          Iterations: 17
#          Function evaluations: 65
#          Gradient evaluations: 53
#
#  ***** evaluating model binary_w_disengaged w/ sigma 16 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 37315.530000
#          Iterations: 21
#          Function evaluations: 32
#          Gradient evaluations: 32
#
#  >>>> evaluating animal W072 <<<<
#
#  ***** evaluating model binary_w_disengaged w/ sigma 0.07 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 28438.407859
#          Iterations: 17
#          Function evaluations: 91
#          Gradient evaluations: 79
#
#  ***** evaluating model binary_w_disengaged w/ sigma 0.13 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 28768.433459
#          Iterations: 16
#          Function evaluations: 72
#          Gradient evaluations: 60
#
#  ***** evaluating model binary_w_disengaged w/ sigma 0.25 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 28900.787400
#          Iterations: 16
#          Function evaluations: 96
#          Gradient evaluations: 84
#
#  ***** evaluating model binary_w_disengaged w/ sigma 0.5 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 28949.682567
#          Iterations: 16
#          Function evaluations: 70
#          Gradient evaluations: 58
#
#  ***** evaluating model binary_w_disengaged w/ sigma 1 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 28964.540863
#          Iterations: 15
#          Function evaluations: 55
#          Gradient evaluations: 43
#
#  ***** evaluating model binary_w_disengaged w/ sigma 2 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 28968.534329
#          Iterations: 14
#          Function evaluations: 73
#          Gradient evaluations: 61
#
#  ***** evaluating model binary_w_disengaged w/ sigma 4 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 28969.554002
#          Iterations: 15
#          Function evaluations: 81
#          Gradient evaluations: 69
#
#  ***** evaluating model binary_w_disengaged w/ sigma 8 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 28969.810192
#          Iterations: 16
#          Function evaluations: 73
#          Gradient evaluations: 62
#
#  ***** evaluating model binary_w_disengaged w/ sigma 16 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 28969.874295
#          Iterations: 18
#          Function evaluations: 78
#          Gradient evaluations: 66
#
#  >>>> evaluating animal W073 <<<<
#
#  ***** evaluating model binary_w_disengaged w/ sigma 0.07 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 33025.786844
#          Iterations: 16
#          Function evaluations: 69
#          Gradient evaluations: 57
#
#  ***** evaluating model binary_w_disengaged w/ sigma 0.13 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 33599.696125
#          Iterations: 18
#          Function evaluations: 74
#          Gradient evaluations: 62
#
#  ***** evaluating model binary_w_disengaged w/ sigma 0.25 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 33818.737644
#          Iterations: 17
#          Function evaluations: 81
#          Gradient evaluations: 69
#
#  ***** evaluating model binary_w_disengaged w/ sigma 0.5 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 33892.427310
#          Iterations: 22
#          Function evaluations: 68
#          Gradient evaluations: 56
#
#  ***** evaluating model binary_w_disengaged w/ sigma 1 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 33912.611948
#          Iterations: 22
#          Function evaluations: 87
#          Gradient evaluations: 75
#
#  ***** evaluating model binary_w_disengaged w/ sigma 2 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 33917.801339
#          Iterations: 23
#          Function evaluations: 79
#          Gradient evaluations: 67
#
#  ***** evaluating model binary_w_disengaged w/ sigma 4 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 33919.108270
#          Iterations: 23
#          Function evaluations: 70
#          Gradient evaluations: 58
#
#  ***** evaluating model binary_w_disengaged w/ sigma 8 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 33919.435614
#          Iterations: 21
#          Function evaluations: 83
#          Gradient evaluations: 71
#
#  ***** evaluating model binary_w_disengaged w/ sigma 16 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 33919.517488
#          Iterations: 21
#          Function evaluations: 65
#          Gradient evaluations: 54
#
#  >>>> evaluating animal W074 <<<<
#
#  ***** evaluating model binary_w_disengaged w/ sigma 0.07 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 54262.699872
#          Iterations: 16
#          Function evaluations: 74
#          Gradient evaluations: 62
#
#  ***** evaluating model binary_w_disengaged w/ sigma 0.13 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 55255.804605
#          Iterations: 16
#          Function evaluations: 80
#          Gradient evaluations: 68
#
#  ***** evaluating model binary_w_disengaged w/ sigma 0.25 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 55643.111098
#          Iterations: 17
#          Function evaluations: 75
#          Gradient evaluations: 63
#
#  ***** evaluating model binary_w_disengaged w/ sigma 0.5 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 55778.106498
#          Iterations: 17
#          Function evaluations: 73
#          Gradient evaluations: 61
#
#  ***** evaluating model binary_w_disengaged w/ sigma 1 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 55817.974361
#          Iterations: 17
#          Function evaluations: 65
#          Gradient evaluations: 53
#
#  ***** evaluating model binary_w_disengaged w/ sigma 2 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 55828.646604
#          Iterations: 20
#          Function evaluations: 63
#          Gradient evaluations: 52
#
#  ***** evaluating model binary_w_disengaged w/ sigma 4 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 55831.364985
#          Iterations: 21
#          Function evaluations: 71
#          Gradient evaluations: 59
#
#  ***** evaluating model binary_w_disengaged w/ sigma 8 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 55832.047868
#          Iterations: 22
#          Function evaluations: 69
#          Gradient evaluations: 57
#
#  ***** evaluating model binary_w_disengaged w/ sigma 16 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 55832.218765
#          Iterations: 28
#          Function evaluations: 39
#          Gradient evaluations: 39
#
#  >>>> evaluating animal W075 <<<<
#
#  ***** evaluating model binary_w_disengaged w/ sigma 0.07 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 46400.809095
#          Iterations: 17
#          Function evaluations: 79
#          Gradient evaluations: 67
#
#  ***** evaluating model binary_w_disengaged w/ sigma 0.13 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 47279.914039
#          Iterations: 17
#          Function evaluations: 88
#          Gradient evaluations: 76
#
#  ***** evaluating model binary_w_disengaged w/ sigma 0.25 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 47580.840069
#          Iterations: 18
#          Function evaluations: 62
#          Gradient evaluations: 50
#
#  ***** evaluating model binary_w_disengaged w/ sigma 0.5 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 47693.260410
#          Iterations: 17
#          Function evaluations: 73
#          Gradient evaluations: 61
#
#  ***** evaluating model binary_w_disengaged w/ sigma 1 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 47729.178335
#          Iterations: 23
#          Function evaluations: 64
#          Gradient evaluations: 52
#
#  ***** evaluating model binary_w_disengaged w/ sigma 2 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 47738.852194
#          Iterations: 24
#          Function evaluations: 72
#          Gradient evaluations: 60
#
#  ***** evaluating model binary_w_disengaged w/ sigma 4 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 47741.324597
#          Iterations: 24
#          Function evaluations: 72
#          Gradient evaluations: 61
#
#  ***** evaluating model binary_w_disengaged w/ sigma 8 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 47741.946178
#          Iterations: 24
#          Function evaluations: 80
#          Gradient evaluations: 68
#
#  ***** evaluating model binary_w_disengaged w/ sigma 16 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 47742.101794
#          Iterations: 23
#          Function evaluations: 73
#          Gradient evaluations: 61
#
#  >>>> evaluating animal W078 <<<<
#
#  ***** evaluating model binary_w_disengaged w/ sigma 0.07 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 21607.231339
#          Iterations: 17
#          Function evaluations: 72
#          Gradient evaluations: 60
#
#  ***** evaluating model binary_w_disengaged w/ sigma 0.13 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 22136.890376
#          Iterations: 15
#          Function evaluations: 77
#          Gradient evaluations: 65
#
#  ***** evaluating model binary_w_disengaged w/ sigma 0.25 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 22357.093556
#          Iterations: 15
#          Function evaluations: 80
#          Gradient evaluations: 68
#
#  ***** evaluating model binary_w_disengaged w/ sigma 0.5 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 22429.794975
#          Iterations: 23
#          Function evaluations: 114
#          Gradient evaluations: 102
#
#  ***** evaluating model binary_w_disengaged w/ sigma 1 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 22449.576945
#          Iterations: 16
#          Function evaluations: 76
#          Gradient evaluations: 65
#
#  ***** evaluating model binary_w_disengaged w/ sigma 2 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 22454.660030
#          Iterations: 24
#          Function evaluations: 102
#          Gradient evaluations: 90
#
#  ***** evaluating model binary_w_disengaged w/ sigma 4 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 22455.939820
#          Iterations: 18
#          Function evaluations: 74
#          Gradient evaluations: 62
#
#  ***** evaluating model binary_w_disengaged w/ sigma 8 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 22456.260434
#          Iterations: 21
#          Function evaluations: 76
#          Gradient evaluations: 65
#
#  ***** evaluating model binary_w_disengaged w/ sigma 16 *****
# Optimization terminated successfully.
#          Current function value: 22456.340611
#          Iterations: 24
#          Function evaluations: 28
#          Gradient evaluations: 28
#
#  >>>> evaluating animal W080 <<<<
#
#  ***** evaluating model binary_w_disengaged w/ sigma 0.07 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 15326.939321
#          Iterations: 18
#          Function evaluations: 102
#          Gradient evaluations: 90
#
#  ***** evaluating model binary_w_disengaged w/ sigma 0.13 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 15520.747855
#          Iterations: 16
#          Function evaluations: 89
#          Gradient evaluations: 77
#
#  ***** evaluating model binary_w_disengaged w/ sigma 0.25 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 15608.314996
#          Iterations: 17
#          Function evaluations: 83
#          Gradient evaluations: 71
#
#  ***** evaluating model binary_w_disengaged w/ sigma 0.5 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 15639.161098
#          Iterations: 17
#          Function evaluations: 95
#          Gradient evaluations: 83
#
#  ***** evaluating model binary_w_disengaged w/ sigma 1 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 15647.738721
#          Iterations: 17
#          Function evaluations: 64
#          Gradient evaluations: 52
#
#  ***** evaluating model binary_w_disengaged w/ sigma 2 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 15649.954672
#          Iterations: 18
#          Function evaluations: 74
#          Gradient evaluations: 62
#
#  ***** evaluating model binary_w_disengaged w/ sigma 4 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 15650.513523
#          Iterations: 16
#          Function evaluations: 81
#          Gradient evaluations: 69
#
#  ***** evaluating model binary_w_disengaged w/ sigma 8 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 15650.653543
#          Iterations: 17
#          Function evaluations: 71
#          Gradient evaluations: 59
#
#  ***** evaluating model binary_w_disengaged w/ sigma 16 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 15650.688573
#          Iterations: 19
#          Function evaluations: 82
#          Gradient evaluations: 71
#
#  >>>> evaluating animal W081 <<<<
#
#  ***** evaluating model binary_w_disengaged w/ sigma 0.07 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 12522.282222
#          Iterations: 16
#          Function evaluations: 87
#          Gradient evaluations: 75
#
#  ***** evaluating model binary_w_disengaged w/ sigma 0.13 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 12703.926931
#          Iterations: 19
#          Function evaluations: 93
#          Gradient evaluations: 81
#
#  ***** evaluating model binary_w_disengaged w/ sigma 0.25 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 12790.240409
#          Iterations: 17
#          Function evaluations: 93
#          Gradient evaluations: 81
#
#  ***** evaluating model binary_w_disengaged w/ sigma 0.5 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 12820.876458
#          Iterations: 17
#          Function evaluations: 76
#          Gradient evaluations: 64
#
#  ***** evaluating model binary_w_disengaged w/ sigma 1 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 12829.680829
#          Iterations: 13
#          Function evaluations: 79
#          Gradient evaluations: 67
#
#  ***** evaluating model binary_w_disengaged w/ sigma 2 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 12832.161833
#          Iterations: 18
#          Function evaluations: 83
#          Gradient evaluations: 71
#
#  ***** evaluating model binary_w_disengaged w/ sigma 4 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 12832.787518
#          Iterations: 16
#          Function evaluations: 66
#          Gradient evaluations: 54
#
#  ***** evaluating model binary_w_disengaged w/ sigma 8 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 12832.945541
#          Iterations: 15
#          Function evaluations: 63
#          Gradient evaluations: 51
#
#  ***** evaluating model binary_w_disengaged w/ sigma 16 *****
# Optimization terminated successfully.
#          Current function value: 12832.985159
#          Iterations: 21
#          Function evaluations: 28
#          Gradient evaluations: 28
#
#  >>>> evaluating animal W082 <<<<
#
#  ***** evaluating model binary_w_disengaged w/ sigma 0.07 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 51842.631511
#          Iterations: 18
#          Function evaluations: 72
#          Gradient evaluations: 60
#
#  ***** evaluating model binary_w_disengaged w/ sigma 0.13 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 52303.330699
#          Iterations: 17
#          Function evaluations: 101
#          Gradient evaluations: 89
#
#  ***** evaluating model binary_w_disengaged w/ sigma 0.25 *****
# Optimization terminated successfully.
#          Current function value: 52460.105654
#          Iterations: 25
#          Function evaluations: 33
#          Gradient evaluations: 33
#
#  ***** evaluating model binary_w_disengaged w/ sigma 0.5 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 52507.657333
#          Iterations: 17
#          Function evaluations: 75
#          Gradient evaluations: 63
#
#  ***** evaluating model binary_w_disengaged w/ sigma 1 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 52520.096288
#          Iterations: 15
#          Function evaluations: 77
#          Gradient evaluations: 66
#
#  ***** evaluating model binary_w_disengaged w/ sigma 2 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 52523.253675
#          Iterations: 18
#          Function evaluations: 63
#          Gradient evaluations: 51
#
#  ***** evaluating model binary_w_disengaged w/ sigma 4 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 52524.045763
#          Iterations: 20
#          Function evaluations: 74
#          Gradient evaluations: 63
#
#  ***** evaluating model binary_w_disengaged w/ sigma 8 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 52524.243981
#          Iterations: 22
#          Function evaluations: 67
#          Gradient evaluations: 55
#
#  ***** evaluating model binary_w_disengaged w/ sigma 16 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 52524.293548
#          Iterations: 23
#          Function evaluations: 74
#          Gradient evaluations: 62
#
#  >>>> evaluating animal W083 <<<<
#
#  ***** evaluating model binary_w_disengaged w/ sigma 0.07 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 43046.763812
#          Iterations: 17
#          Function evaluations: 68
#          Gradient evaluations: 56
#
#  ***** evaluating model binary_w_disengaged w/ sigma 0.13 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 43509.291426
#          Iterations: 17
#          Function evaluations: 73
#          Gradient evaluations: 61
#
#  ***** evaluating model binary_w_disengaged w/ sigma 0.25 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 43671.872107
#          Iterations: 18
#          Function evaluations: 90
#          Gradient evaluations: 78
#
#  ***** evaluating model binary_w_disengaged w/ sigma 0.5 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 43721.343753
#          Iterations: 19
#          Function evaluations: 96
#          Gradient evaluations: 84
#
#  ***** evaluating model binary_w_disengaged w/ sigma 1 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 43734.201604
#          Iterations: 22
#          Function evaluations: 63
#          Gradient evaluations: 51
#
#  ***** evaluating model binary_w_disengaged w/ sigma 2 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 43737.453087
#          Iterations: 18
#          Function evaluations: 88
#          Gradient evaluations: 76
#
#  ***** evaluating model binary_w_disengaged w/ sigma 4 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 43738.268460
#          Iterations: 20
#          Function evaluations: 77
#          Gradient evaluations: 65
#
#  ***** evaluating model binary_w_disengaged w/ sigma 8 *****
# Optimization terminated successfully.
#          Current function value: 43738.472464
#          Iterations: 25
#          Function evaluations: 33
#          Gradient evaluations: 33
#
#  ***** evaluating model binary_w_disengaged w/ sigma 16 *****
# Optimization terminated successfully.
#          Current function value: 43738.523471
#          Iterations: 22
#          Function evaluations: 66
#          Gradient evaluations: 63
#
#  >>>> evaluating animal W088 <<<<
#
#  ***** evaluating model binary_w_disengaged w/ sigma 0.07 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 33203.589266
#          Iterations: 19
#          Function evaluations: 71
#          Gradient evaluations: 59
#
#  ***** evaluating model binary_w_disengaged w/ sigma 0.13 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 33612.337475
#          Iterations: 16
#          Function evaluations: 79
#          Gradient evaluations: 67
#
#  ***** evaluating model binary_w_disengaged w/ sigma 0.25 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 33771.269250
#          Iterations: 15
#          Function evaluations: 84
#          Gradient evaluations: 72
#
#  ***** evaluating model binary_w_disengaged w/ sigma 0.5 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 33826.148762
#          Iterations: 17
#          Function evaluations: 55
#          Gradient evaluations: 43
#
#  ***** evaluating model binary_w_disengaged w/ sigma 1 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 33841.326420
#          Iterations: 16
#          Function evaluations: 84
#          Gradient evaluations: 72
#
#  ***** evaluating model binary_w_disengaged w/ sigma 2 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 33845.245578
#          Iterations: 18
#          Function evaluations: 67
#          Gradient evaluations: 55
#
#  ***** evaluating model binary_w_disengaged w/ sigma 4 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 33846.231764
#          Iterations: 18
#          Function evaluations: 76
#          Gradient evaluations: 64
#
#  ***** evaluating model binary_w_disengaged w/ sigma 8 *****
# Optimization terminated successfully.
#          Current function value: 33846.478816
#          Iterations: 19
#          Function evaluations: 23
#          Gradient evaluations: 23
#
#  ***** evaluating model binary_w_disengaged w/ sigma 16 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 33846.540608
#          Iterations: 19
#          Function evaluations: 90
#          Gradient evaluations: 78
#
#  >>>> evaluating animal W089 <<<<
#
#  ***** evaluating model binary_w_disengaged w/ sigma 0.07 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 49136.945475
#          Iterations: 18
#          Function evaluations: 75
#          Gradient evaluations: 63
#
#  ***** evaluating model binary_w_disengaged w/ sigma 0.13 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 51944.079921
#          Iterations: 10
#          Function evaluations: 46
#          Gradient evaluations: 35
#
#  ***** evaluating model binary_w_disengaged w/ sigma 0.25 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 49710.811957
#          Iterations: 15
#          Function evaluations: 85
#          Gradient evaluations: 73
#
#  ***** evaluating model binary_w_disengaged w/ sigma 0.5 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 49774.060701
#          Iterations: 20
#          Function evaluations: 73
#          Gradient evaluations: 61
#
#  ***** evaluating model binary_w_disengaged w/ sigma 1 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 49791.078020
#          Iterations: 17
#          Function evaluations: 76
#          Gradient evaluations: 64
#
#  ***** evaluating model binary_w_disengaged w/ sigma 2 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 49795.454794
#          Iterations: 18
#          Function evaluations: 89
#          Gradient evaluations: 77
#
#  ***** evaluating model binary_w_disengaged w/ sigma 4 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 49796.555349
#          Iterations: 19
#          Function evaluations: 77
#          Gradient evaluations: 65
#
#  ***** evaluating model binary_w_disengaged w/ sigma 8 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 49796.830963
#          Iterations: 22
#          Function evaluations: 77
#          Gradient evaluations: 66
#
#  ***** evaluating model binary_w_disengaged w/ sigma 16 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 49796.899896
#          Iterations: 20
#          Function evaluations: 82
#          Gradient evaluations: 70
#
#  >>>> evaluating animal W094 <<<<
#
#  ***** evaluating model binary_w_disengaged w/ sigma 0.07 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 18794.931984
#          Iterations: 17
#          Function evaluations: 65
#          Gradient evaluations: 53
#
#  ***** evaluating model binary_w_disengaged w/ sigma 0.13 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 19099.483576
#          Iterations: 17
#          Function evaluations: 84
#          Gradient evaluations: 72
#
#  ***** evaluating model binary_w_disengaged w/ sigma 0.25 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 19207.827699
#          Iterations: 13
#          Function evaluations: 84
#          Gradient evaluations: 72
#
#  ***** evaluating model binary_w_disengaged w/ sigma 0.5 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 19260.344112
#          Iterations: 18
#          Function evaluations: 76
#          Gradient evaluations: 64
#
#  ***** evaluating model binary_w_disengaged w/ sigma 1 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 19279.897213
#          Iterations: 16
#          Function evaluations: 68
#          Gradient evaluations: 56
#
#  ***** evaluating model binary_w_disengaged w/ sigma 2 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 19285.709308
#          Iterations: 18
#          Function evaluations: 74
#          Gradient evaluations: 62
#
#  ***** evaluating model binary_w_disengaged w/ sigma 4 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 19287.225277
#          Iterations: 18
#          Function evaluations: 78
#          Gradient evaluations: 66
#
#  ***** evaluating model binary_w_disengaged w/ sigma 8 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 19287.608660
#          Iterations: 22
#          Function evaluations: 81
#          Gradient evaluations: 70
#
#  ***** evaluating model binary_w_disengaged w/ sigma 16 *****
# Optimization terminated successfully.
#          Current function value: 19287.704780
#          Iterations: 22
#          Function evaluations: 27
#          Gradient evaluations: 27

# %% [markdown]
# ## Visualize

# %%
# experiment = load_experiment(save_name)
palette = "rocket"
mv = ModelVisualizer(experiment)

# %%
mv.plot_sigma_summary()
# Out:
# /Users/jessbreda/anaconda3/envs/an_lrn/lib/python3.10/site-packages/seaborn/categorical.py:641: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   grouped_vals = vals.groupby(grouper)

# %%
mv.plot_weights_summary(palette=palette)

# %%
mv.plot_nll_over_sigmas_by_animal()
# Out:
# /Users/jessbreda/Desktop/github/animal-learning/src/multiglm/visualizations/model_visualizer.py:206: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   df["is_min"] = df.groupby("animal_id")["nll"].transform(lambda x: x == x.min())
# /Users/jessbreda/Desktop/github/animal-learning/src/multiglm/visualizations/model_visualizer.py:211: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   for idx, (animal_id, sub_df) in enumerate(df.groupby("animal_id")):
# /Users/jessbreda/anaconda3/envs/an_lrn/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /Users/jessbreda/anaconda3/envs/an_lrn/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /Users/jessbreda/anaconda3/envs/an_lrn/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /Users/jessbreda/anaconda3/envs/an_lrn/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /Users/jessbreda/anaconda3/envs/an_lrn/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /Users/jessbreda/anaconda3/envs/an_lrn/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /Users/jessbreda/anaconda3/envs/an_lrn/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /Users/jessbreda/anaconda3/envs/an_lrn/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /Users/jessbreda/anaconda3/envs/an_lrn/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /Users/jessbreda/anaconda3/envs/an_lrn/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /Users/jessbreda/anaconda3/envs/an_lrn/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /Users/jessbreda/anaconda3/envs/an_lrn/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /Users/jessbreda/anaconda3/envs/an_lrn/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /Users/jessbreda/anaconda3/envs/an_lrn/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /Users/jessbreda/anaconda3/envs/an_lrn/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /Users/jessbreda/anaconda3/envs/an_lrn/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /Users/jessbreda/anaconda3/envs/an_lrn/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /Users/jessbreda/anaconda3/envs/an_lrn/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /Users/jessbreda/anaconda3/envs/an_lrn/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /Users/jessbreda/anaconda3/envs/an_lrn/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /Users/jessbreda/anaconda3/envs/an_lrn/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /Users/jessbreda/anaconda3/envs/an_lrn/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /Users/jessbreda/anaconda3/envs/an_lrn/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /Users/jessbreda/anaconda3/envs/an_lrn/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /Users/jessbreda/anaconda3/envs/an_lrn/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /Users/jessbreda/anaconda3/envs/an_lrn/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /Users/jessbreda/anaconda3/envs/an_lrn/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /Users/jessbreda/anaconda3/envs/an_lrn/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /Users/jessbreda/anaconda3/envs/an_lrn/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /Users/jessbreda/anaconda3/envs/an_lrn/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /Users/jessbreda/anaconda3/envs/an_lrn/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /Users/jessbreda/anaconda3/envs/an_lrn/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /Users/jessbreda/anaconda3/envs/an_lrn/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /Users/jessbreda/anaconda3/envs/an_lrn/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
mv.plot_weights_by_animal(palette=palette)
