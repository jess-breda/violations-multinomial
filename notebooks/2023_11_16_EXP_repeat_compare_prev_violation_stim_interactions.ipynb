# %% [markdown]
# # Compare Previous Violations History With Stim Interactions
#
# **Goal**: Given the validation of the model comparison with the `2023_11_10_EXP_compare_prev_violation_history.ipynb` notebook. Re-implement the model comparison using the model with and without stimulus interaction terms. Then, compare on for binary and multi
#
# The goal of this is to ensure the model comparison code is working as expected and the interaction comparison results are still valid.

# %%
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt
import pathlib
import sys
[
    sys.path.append(str(folder))
    for folder in pathlib.Path("../src/").iterdir()
    if folder.is_dir()
]
from fitting_utils import create_violation_interaction_pairs
from experiment_compare_models import ExperimentCompareModels
from multiclass_logistic_regression import MultiClassLogisticRegression
from model_visualizer import ModelVisualizerCompare
from design_matrix_generator import DesignMatrixGeneratorFilteredHistory, DesignMatrixGeneratorInteractions
sns.set_context("talk")
# %load_ext autoreload
# %autoreload 2

# %%
model_config = {
    "psytrack_features": {  # MODEL 1- pysrack base
        "model_class": MultiClassLogisticRegression,
        "model_type": "multi",
        "design_matrix_generator": DesignMatrixGeneratorFilteredHistory,
        "filter_implementation": {"prev_violation": -1},  # no filter & drop column
    },
    "filter_prev_violation": {  # MODEL 2- with filt prev violation history
        "model_class": MultiClassLogisticRegression,
        "model_type": "mutli",
        "design_matrix_generator": DesignMatrixGeneratorFilteredHistory,
        "filter_implementation": {
            "prev_violation": 1
        },  # filter column with animals tau
    },
    "filter_prev_violation_stim_itrx": {  # MODEL 3- with filt prev violation history and interactions
        "model_class": MultiClassLogisticRegression,
        "model_type": "mutli",
        "design_matrix_generator": DesignMatrixGeneratorInteractions,
        "filter_implementation": {
            "prev_violation": 1
        },  # filter column with animals tau,
        "design_matrix_generator_args": {
            "interaction_pairs": create_violation_interaction_pairs(["s_a", "s_b"])
        },
    },
}
params = {
    "animals": None,
    "sigmas": [0.07, 0.13, 0.25, 0.5, 1, 2, 4, 8, 16],
    "random_state": 47,
    "null_mode": "multi",
    "eval_train": True,
    "tau_columns": ["prev_violation"],
    "model_config": model_config,
}

# %%
experiment = ExperimentCompareModels(params)
experiment.run()
experiment.save(
    file_name="2023_11_16_repeat_compare_prev_violation_stim_interactions.pkl"
)
# Out:
# returning viol dataset for all animals
#
#  >>>> evaluating animal W051 <<<<
#
#  ***** evaluating model psytrack_features w/ sigma 0.07 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 41950.303150
#          Iterations: 20
#          Function evaluations: 88
#          Gradient evaluations: 76
#
#  ***** evaluating model psytrack_features w/ sigma 0.13 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 41893.656506
#          Iterations: 21
#          Function evaluations: 85
#          Gradient evaluations: 74
#
#  ***** evaluating model psytrack_features w/ sigma 0.25 *****
# Optimization terminated successfully.
#          Current function value: 41876.171967
#          Iterations: 21
#          Function evaluations: 35
#          Gradient evaluations: 35
#
#  ***** evaluating model psytrack_features w/ sigma 0.5 *****
# Optimization terminated successfully.
#          Current function value: 41871.260132
#          Iterations: 20
#          Function evaluations: 33
#          Gradient evaluations: 33
#
#  ***** evaluating model psytrack_features w/ sigma 1 *****
# Optimization terminated successfully.
#          Current function value: 41870.028605
#          Iterations: 20
#          Function evaluations: 33
#          Gradient evaluations: 33
#
#  ***** evaluating model psytrack_features w/ sigma 2 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 41869.720499
#          Iterations: 19
#          Function evaluations: 95
#          Gradient evaluations: 83
#
#  ***** evaluating model psytrack_features w/ sigma 4 *****
# Optimization terminated successfully.
#          Current function value: 41869.643459
#          Iterations: 20
#          Function evaluations: 33
#          Gradient evaluations: 33
#
#  ***** evaluating model psytrack_features w/ sigma 8 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 41869.624198
#          Iterations: 19
#          Function evaluations: 62
#          Gradient evaluations: 51
#
#  ***** evaluating model psytrack_features w/ sigma 16 *****
# Optimization terminated successfully.
#          Current function value: 41869.619382
#          Iterations: 20
#          Function evaluations: 33
#          Gradient evaluations: 33
#
#  ***** evaluating model filter_prev_violation w/ sigma 0.07 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 41208.619621
#          Iterations: 23
#          Function evaluations: 36
#          Gradient evaluations: 36
#
#  ***** evaluating model filter_prev_violation w/ sigma 0.13 *****
# Optimization terminated successfully.
#          Current function value: 40814.204222
#          Iterations: 25
#          Function evaluations: 35
#          Gradient evaluations: 35
#
#  ***** evaluating model filter_prev_violation w/ sigma 0.25 *****
# Optimization terminated successfully.
#          Current function value: 40627.904023
#          Iterations: 25
#          Function evaluations: 39
#          Gradient evaluations: 39
#
#  ***** evaluating model filter_prev_violation w/ sigma 0.5 *****
# Optimization terminated successfully.
#          Current function value: 40565.943728
#          Iterations: 24
#          Function evaluations: 35
#          Gradient evaluations: 35
#
#  ***** evaluating model filter_prev_violation w/ sigma 1 *****
# Optimization terminated successfully.
#          Current function value: 40549.584035
#          Iterations: 23
#          Function evaluations: 34
#          Gradient evaluations: 34
#
#  ***** evaluating model filter_prev_violation w/ sigma 2 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 40545.435837
#          Iterations: 23
#          Function evaluations: 136
#          Gradient evaluations: 123
#
#  ***** evaluating model filter_prev_violation w/ sigma 4 *****
# Optimization terminated successfully.
#          Current function value: 40544.395078
#          Iterations: 23
#          Function evaluations: 34
#          Gradient evaluations: 34
#
#  ***** evaluating model filter_prev_violation w/ sigma 8 *****
# Optimization terminated successfully.
#          Current function value: 40544.134656
#          Iterations: 23
#          Function evaluations: 34
#          Gradient evaluations: 34
#
#  ***** evaluating model filter_prev_violation w/ sigma 16 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 40544.069536
#          Iterations: 22
#          Function evaluations: 77
#          Gradient evaluations: 65
#
#  ***** evaluating model filter_prev_violation_stim_itrx w/ sigma 0.07 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 41163.808690
#          Iterations: 27
#          Function evaluations: 78
#          Gradient evaluations: 66
#
#  ***** evaluating model filter_prev_violation_stim_itrx w/ sigma 0.13 *****
# Optimization terminated successfully.
#          Current function value: 40733.110147
#          Iterations: 29
#          Function evaluations: 39
#          Gradient evaluations: 39
#
#  ***** evaluating model filter_prev_violation_stim_itrx w/ sigma 0.25 *****
# Optimization terminated successfully.
#          Current function value: 40520.737100
#          Iterations: 31
#          Function evaluations: 40
#          Gradient evaluations: 40
#
#  ***** evaluating model filter_prev_violation_stim_itrx w/ sigma 0.5 *****
# Optimization terminated successfully.
#          Current function value: 40447.561549
#          Iterations: 29
#          Function evaluations: 40
#          Gradient evaluations: 40
#
#  ***** evaluating model filter_prev_violation_stim_itrx w/ sigma 1 *****
# Optimization terminated successfully.
#          Current function value: 40427.938482
#          Iterations: 29
#          Function evaluations: 39
#          Gradient evaluations: 39
#
#  ***** evaluating model filter_prev_violation_stim_itrx w/ sigma 2 *****
# Optimization terminated successfully.
#          Current function value: 40422.940074
#          Iterations: 29
#          Function evaluations: 39
#          Gradient evaluations: 39
#
#  ***** evaluating model filter_prev_violation_stim_itrx w/ sigma 4 *****
# Optimization terminated successfully.
#          Current function value: 40421.684509
#          Iterations: 29
#          Function evaluations: 39
#          Gradient evaluations: 39
#
#  ***** evaluating model filter_prev_violation_stim_itrx w/ sigma 8 *****
# Optimization terminated successfully.
#          Current function value: 40421.370243
#          Iterations: 29
#          Function evaluations: 39
#          Gradient evaluations: 39
#
#  ***** evaluating model filter_prev_violation_stim_itrx w/ sigma 16 *****
# Optimization terminated successfully.
#          Current function value: 40421.291653
#          Iterations: 29
#          Function evaluations: 39
#          Gradient evaluations: 39
#
#  >>>> evaluating animal W060 <<<<
#
#  ***** evaluating model psytrack_features w/ sigma 0.07 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 30703.331899
#          Iterations: 22
#          Function evaluations: 39
#          Gradient evaluations: 39
#
#  ***** evaluating model psytrack_features w/ sigma 0.13 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 30580.883259
#          Iterations: 21
#          Function evaluations: 99
#          Gradient evaluations: 87
#
#  ***** evaluating model psytrack_features w/ sigma 0.25 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 30542.531549
#          Iterations: 22
#          Function evaluations: 39
#          Gradient evaluations: 39
#
#  ***** evaluating model psytrack_features w/ sigma 0.5 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 30531.708242
#          Iterations: 19
#          Function evaluations: 80
#          Gradient evaluations: 68
#
#  ***** evaluating model psytrack_features w/ sigma 1 *****
# Optimization terminated successfully.
#          Current function value: 30528.991110
#          Iterations: 20
#          Function evaluations: 33
#          Gradient evaluations: 33
#
#  ***** evaluating model psytrack_features w/ sigma 2 *****
# Optimization terminated successfully.
#          Current function value: 30528.311117
#          Iterations: 20
#          Function evaluations: 33
#          Gradient evaluations: 33
#
#  ***** evaluating model psytrack_features w/ sigma 4 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 30528.141074
#          Iterations: 19
#          Function evaluations: 62
#          Gradient evaluations: 51
#
#  ***** evaluating model psytrack_features w/ sigma 8 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 30528.098561
#          Iterations: 19
#          Function evaluations: 79
#          Gradient evaluations: 68
#
#  ***** evaluating model psytrack_features w/ sigma 16 *****
# Optimization terminated successfully.
#          Current function value: 30528.087932
#          Iterations: 20
#          Function evaluations: 33
#          Gradient evaluations: 33
#
#  ***** evaluating model filter_prev_violation w/ sigma 0.07 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 30056.784009
#          Iterations: 25
#          Function evaluations: 76
#          Gradient evaluations: 64
#
#  ***** evaluating model filter_prev_violation w/ sigma 0.13 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 29611.577228
#          Iterations: 25
#          Function evaluations: 96
#          Gradient evaluations: 80
#
#  ***** evaluating model filter_prev_violation w/ sigma 0.25 *****
# Optimization terminated successfully.
#          Current function value: 29407.377907
#          Iterations: 26
#          Function evaluations: 36
#          Gradient evaluations: 36
#
#  ***** evaluating model filter_prev_violation w/ sigma 0.5 *****
# Optimization terminated successfully.
#          Current function value: 29339.750457
#          Iterations: 26
#          Function evaluations: 36
#          Gradient evaluations: 36
#
#  ***** evaluating model filter_prev_violation w/ sigma 1 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 29321.896893
#          Iterations: 25
#          Function evaluations: 34
#          Gradient evaluations: 34
#
#  ***** evaluating model filter_prev_violation w/ sigma 2 *****
# Optimization terminated successfully.
#          Current function value: 29317.369581
#          Iterations: 26
#          Function evaluations: 35
#          Gradient evaluations: 35
#
#  ***** evaluating model filter_prev_violation w/ sigma 4 *****
# Optimization terminated successfully.
#          Current function value: 29316.233676
#          Iterations: 26
#          Function evaluations: 35
#          Gradient evaluations: 35
#
#  ***** evaluating model filter_prev_violation w/ sigma 8 *****
# Optimization terminated successfully.
#          Current function value: 29315.949444
#          Iterations: 26
#          Function evaluations: 35
#          Gradient evaluations: 35
#
#  ***** evaluating model filter_prev_violation w/ sigma 16 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 29315.878369
#          Iterations: 25
#          Function evaluations: 79
#          Gradient evaluations: 67
#
#  ***** evaluating model filter_prev_violation_stim_itrx w/ sigma 0.07 *****
# Optimization terminated successfully.
#          Current function value: 30028.087337
#          Iterations: 30
#          Function evaluations: 43
#          Gradient evaluations: 43
#
#  ***** evaluating model filter_prev_violation_stim_itrx w/ sigma 0.13 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 29561.152100
#          Iterations: 30
#          Function evaluations: 86
#          Gradient evaluations: 74
#
#  ***** evaluating model filter_prev_violation_stim_itrx w/ sigma 0.25 *****
# Optimization terminated successfully.
#          Current function value: 29342.030672
#          Iterations: 30
#          Function evaluations: 42
#          Gradient evaluations: 42
#
#  ***** evaluating model filter_prev_violation_stim_itrx w/ sigma 0.5 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 29267.723513
#          Iterations: 29
#          Function evaluations: 77
#          Gradient evaluations: 64
#
#  ***** evaluating model filter_prev_violation_stim_itrx w/ sigma 1 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 29247.875413
#          Iterations: 28
#          Function evaluations: 77
#          Gradient evaluations: 65
#
#  ***** evaluating model filter_prev_violation_stim_itrx w/ sigma 2 *****
# Optimization terminated successfully.
#          Current function value: 29242.824161
#          Iterations: 29
#          Function evaluations: 42
#          Gradient evaluations: 42
#
#  ***** evaluating model filter_prev_violation_stim_itrx w/ sigma 4 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 29241.555591
#          Iterations: 28
#          Function evaluations: 39
#          Gradient evaluations: 39
#
#  ***** evaluating model filter_prev_violation_stim_itrx w/ sigma 8 *****
# Optimization terminated successfully.
#          Current function value: 29241.238086
#          Iterations: 29
#          Function evaluations: 40
#          Gradient evaluations: 40
#
#  ***** evaluating model filter_prev_violation_stim_itrx w/ sigma 16 *****
# Optimization terminated successfully.
#          Current function value: 29241.158687
#          Iterations: 29
#          Function evaluations: 40
#          Gradient evaluations: 40
#
#  >>>> evaluating animal W061 <<<<
#
#  ***** evaluating model psytrack_features w/ sigma 0.07 *****
# Optimization terminated successfully.
#          Current function value: 26305.283070
#          Iterations: 24
#          Function evaluations: 38
#          Gradient evaluations: 38
#
#  ***** evaluating model psytrack_features w/ sigma 0.13 *****
# Optimization terminated successfully.
#          Current function value: 26255.012492
#          Iterations: 23
#          Function evaluations: 35
#          Gradient evaluations: 35
#
#  ***** evaluating model psytrack_features w/ sigma 0.25 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 26239.315022
#          Iterations: 23
#          Function evaluations: 36
#          Gradient evaluations: 36
#
#  ***** evaluating model psytrack_features w/ sigma 0.5 *****
# Optimization terminated successfully.
#          Current function value: 26234.888860
#          Iterations: 22
#          Function evaluations: 34
#          Gradient evaluations: 34
#
#  ***** evaluating model psytrack_features w/ sigma 1 *****
# Optimization terminated successfully.
#          Current function value: 26233.777957
#          Iterations: 22
#          Function evaluations: 34
#          Gradient evaluations: 34
#
#  ***** evaluating model psytrack_features w/ sigma 2 *****
# Optimization terminated successfully.
#          Current function value: 26233.499957
#          Iterations: 22
#          Function evaluations: 34
#          Gradient evaluations: 34
#
#  ***** evaluating model psytrack_features w/ sigma 4 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 26233.430440
#          Iterations: 22
#          Function evaluations: 127
#          Gradient evaluations: 112
#
#  ***** evaluating model psytrack_features w/ sigma 8 *****
# Optimization terminated successfully.
#          Current function value: 26233.413060
#          Iterations: 22
#          Function evaluations: 34
#          Gradient evaluations: 34
#
#  ***** evaluating model psytrack_features w/ sigma 16 *****
# Optimization terminated successfully.
#          Current function value: 26233.408714
#          Iterations: 22
#          Function evaluations: 34
#          Gradient evaluations: 34
#
#  ***** evaluating model filter_prev_violation w/ sigma 0.07 *****
# Optimization terminated successfully.
#          Current function value: 25464.766350
#          Iterations: 27
#          Function evaluations: 37
#          Gradient evaluations: 37
#
#  ***** evaluating model filter_prev_violation w/ sigma 0.13 *****
# Optimization terminated successfully.
#          Current function value: 25177.980342
#          Iterations: 24
#          Function evaluations: 32
#          Gradient evaluations: 32
#
#  ***** evaluating model filter_prev_violation w/ sigma 0.25 *****
# Optimization terminated successfully.
#          Current function value: 25061.863652
#          Iterations: 26
#          Function evaluations: 34
#          Gradient evaluations: 34
#
#  ***** evaluating model filter_prev_violation w/ sigma 0.5 *****
# Optimization terminated successfully.
#          Current function value: 25025.806353
#          Iterations: 24
#          Function evaluations: 32
#          Gradient evaluations: 32
#
#  ***** evaluating model filter_prev_violation w/ sigma 1 *****
# Optimization terminated successfully.
#          Current function value: 25016.494105
#          Iterations: 24
#          Function evaluations: 34
#          Gradient evaluations: 34
#
#  ***** evaluating model filter_prev_violation w/ sigma 2 *****
# Optimization terminated successfully.
#          Current function value: 25014.146599
#          Iterations: 24
#          Function evaluations: 32
#          Gradient evaluations: 32
#
#  ***** evaluating model filter_prev_violation w/ sigma 4 *****
# Optimization terminated successfully.
#          Current function value: 25013.558494
#          Iterations: 24
#          Function evaluations: 32
#          Gradient evaluations: 32
#
#  ***** evaluating model filter_prev_violation w/ sigma 8 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 
#          Function evaluations: 44
#          Gradient evaluations: 44
#
#  ***** evaluating model filter_prev_violation_stim_itrx w/ sigma 0.25 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 17875.457275
#          Iterations: 34
#          Function evaluations: 87
#          Gradient evaluations: 75
#
#  ***** evaluating model filter_prev_violation_stim_itrx w/ sigma 0.5 *****
# Optimization terminated successfully.
#          Current function value: 17767.953139
#          Iterations: 35
#          Function evaluations: 47
#          Gradient evaluations: 47
#
#  ***** evaluating model filter_prev_violation_stim_itrx w/ sigma 1 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 17740.109942
#          Iterations: 33
#          Function evaluations: 43
#          Gradient evaluations: 43
#
#  ***** evaluating model filter_prev_violation_stim_itrx w/ sigma 2 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 17733.084056
#          Iterations: 34
#          Function evaluations: 136
#          Gradient evaluations: 121
#
#  ***** evaluating model filter_prev_violation_stim_itrx w/ sigma 4 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 17731.323435
#          Iterations: 34
#          Function evaluations: 47
#          Gradient evaluations: 47
#
#  ***** evaluating model filter_prev_violation_stim_itrx w/ sigma 8 *****
# Optimization terminated successfully.
#          Current function value: 17730.883019
#          Iterations: 34
#          Function evaluations: 44
#          Gradient evaluations: 44
#
#  ***** evaluating model filter_prev_violation_stim_itrx w/ sigma 16 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 17730.772899
#          Iterations: 34
#          Function evaluations: 132
#          Gradient evaluations: 119
#
#  >>>> evaluating animal W089 <<<<
#
#  ***** evaluating model psytrack_features w/ sigma 0.07 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 34299.775261
#          Iterations: 22
#          Function evaluations: 38
#          Gradient evaluations: 38
#
#  ***** evaluating model psytrack_features w/ sigma 0.13 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 34201.523569
#          Iterations: 23
#          Function evaluations: 40
#          Gradient evaluations: 40
#
#  ***** evaluating model psytrack_features w/ sigma 0.25 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 34170.529797
#          Iterations: 22
#          Function evaluations: 108
#          Gradient evaluations: 95
#
#  ***** evaluating model psytrack_features w/ sigma 0.5 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 34161.763363
#          Iterations: 20
#          Function evaluations: 69
#          Gradient evaluations: 57
#
#  ***** evaluating model psytrack_features w/ sigma 1 *****
# Optimization terminated successfully.
#          Current function value: 34159.561229
#          Iterations: 21
#          Function evaluations: 35
#          Gradient evaluations: 35
#
#  ***** evaluating model psytrack_features w/ sigma 2 *****
# Optimization terminated successfully.
#          Current function value: 34159.010033
#          Iterations: 21
#          Function evaluations: 35
#          Gradient evaluations: 35
#
#  ***** evaluating model psytrack_features w/ sigma 4 *****
# Optimization terminated successfully.
#          Current function value: 34158.872193
#          Iterations: 21
#          Function evaluations: 35
#          Gradient evaluations: 35
#
#  ***** evaluating model psytrack_features w/ sigma 8 *****
# Optimization terminated successfully.
#          Current function value: 34158.837730
#          Iterations: 21
#          Function evaluations: 35
#          Gradient evaluations: 35
#
#  ***** evaluating model psytrack_features w/ sigma 16 *****
# Optimization terminated successfully.
#          Current function value: 34158.829114
#          Iterations: 21
#          Function evaluations: 35
#          Gradient evaluations: 35
#
#  ***** evaluating model filter_prev_violation w/ sigma 0.07 *****
# Optimization terminated successfully.
#          Current function value: 27704.730214
#          Iterations: 26
#          Function evaluations: 39
#          Gradient evaluations: 39
#
#  ***** evaluating model filter_prev_violation w/ sigma 0.13 *****
# Optimization terminated successfully.
#          Current function value: 26783.443316
#          Iterations: 28
#          Function evaluations: 38
#          Gradient evaluations: 38
#
#  ***** evaluating model filter_prev_violation w/ sigma 0.25 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 26441.556148
#          Iterations: 27
#          Function evaluations: 102
#          Gradient evaluations: 88
#
#  ***** evaluating model filter_prev_violation w/ sigma 0.5 *****
# Optimization terminated successfully.
#          Current function value: 26338.463648
#          Iterations: 25
#          Function evaluations: 35
#          Gradient evaluations: 35
#
#  ***** evaluating model filter_prev_violation w/ sigma 1 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 26312.057304
#          Iterations: 25
#          Function evaluations: 36
#          Gradient evaluations: 36
#
#  ***** evaluating model filter_prev_violation w/ sigma 2 *****
# Optimization terminated successfully.
#          Current function value: 26305.414386
#          Iterations: 26
#          Function evaluations: 35
#          Gradient evaluations: 35
#
#  ***** evaluating model filter_prev_violation w/ sigma 4 *****
# Optimization terminated successfully.
#          Current function value: 26303.751044
#          Iterations: 26
#          Function evaluations: 40
#          Gradient evaluations: 39
#
#  ***** evaluating model filter_prev_violation w/ sigma 8 *****
# Optimization terminated successfully.
#          Current function value: 26303.335044
#          Iterations: 26
#          Function evaluations: 32
#          Gradient evaluations: 32
#
#  ***** evaluating model filter_prev_violation w/ sigma 16 *****
# Optimization terminated successfully.
#          Current function value: 26303.231034
#          Iterations: 26
#          Function evaluations: 32
#          Gradient evaluations: 32
#
#  ***** evaluating model filter_prev_violation_stim_itrx w/ sigma 0.07 *****
# Optimization terminated successfully.
#          Current function value: 27666.939528
#          Iterations: 30
#          Function evaluations: 45
#          Gradient evaluations: 45
#
#  ***** evaluating model filter_prev_violation_stim_itrx w/ sigma 0.13 *****
# Optimization terminated successfully.
#          Current function value: 26742.468161
#          Iterations: 35
#          Function evaluations: 43
#          Gradient evaluations: 43
#
#  ***** evaluating model filter_prev_violation_stim_itrx w/ sigma 0.25 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 26398.527256
#          Iterations: 31
#          Function evaluations: 79
#          Gradient evaluations: 69
#
#  ***** evaluating model filter_prev_violation_stim_itrx w/ sigma 0.5 *****
# Optimization terminated successfully.
#          Current function value: 26294.523716
#          Iterations: 33
#          Function evaluations: 42
#          Gradient evaluations: 42
#
#  ***** evaluating model filter_prev_violation_stim_itrx w/ sigma 1 *****
# Optimization terminated successfully.
#          Current function value: 26267.850218
#          Iterations: 31
#          Function evaluations: 39
#          Gradient evaluations: 39
#
#  ***** evaluating model filter_prev_violation_stim_itrx w/ sigma 2 *****
# Optimization terminated successfully.
#          Current function value: 26261.137596
#          Iterations: 32
#          Function evaluations: 40
#          Gradient evaluations: 40
#
#  ***** evaluating model filter_prev_violation_stim_itrx w/ sigma 4 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 26259.456638
#          Iterations: 31
#          Function evaluations: 132
#          Gradient evaluations: 120
#
#  ***** evaluating model filter_prev_violation_stim_itrx w/ sigma 8 *****
# Optimization terminated successfully.
#          Current function value: 26259.036222
#          Iterations: 32
#          Function evaluations: 54
#          Gradient evaluations: 52
#
#  ***** evaluating model filter_prev_violation_stim_itrx w/ sigma 16 *****
# Optimization terminated successfully.
#          Current function value: 26258.931107
#          Iterations: 32
#          Function evaluations: 40
#          Gradient evaluations: 40
#
#  >>>> evaluating animal W094 <<<<
#
#  ***** evaluating model psytrack_features w/ sigma 0.07 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 20540.344652
#          Iterations: 21
#          Function evaluations: 85
#          Gradient evaluations: 73
#
#  ***** evaluating model psytrack_features w/ sigma 0.13 *****
# Optimization terminated successfully.
#          Current function value: 20462.145037
#          Iterations: 23
#          Function evaluations: 40
#          Gradient evaluations: 40
#
#  ***** evaluating model psytrack_features w/ sigma 0.25 *****
# Optimization terminated successfully.
#          Current function value: 20436.966057
#          Iterations: 23
#          Function evaluations: 41
#          Gradient evaluations: 41
#
#  ***** evaluating model psytrack_features w/ sigma 0.5 *****
# Optimization terminated successfully.
#          Current function value: 20429.795104
#          Iterations: 22
#          Function evaluations: 37
#          Gradient evaluations: 37
#
#  ***** evaluating model psytrack_features w/ sigma 1 *****
# Optimization terminated successfully.
#          Current function value: 20427.990236
#          Iterations: 22
#          Function evaluations: 37
#          Gradient evaluations: 37
#
#  ***** evaluating model psytrack_features w/ sigma 2 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 20427.538253
#          Iterations: 22
#          Function evaluations: 112
#          Gradient evaluations: 100
#
#  ***** evaluating model psytrack_features w/ sigma 4 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 20427.425209
#          Iterations: 21
#          Function evaluations: 88
#          Gradient evaluations: 76
#
#  ***** evaluating model psytrack_features w/ sigma 8 *****
# Optimization terminated successfully.
#          Current function value: 20427.396946
#          Iterations: 22
#          Function evaluations: 37
#          Gradient evaluations: 37
#
#  ***** evaluating model psytrack_features w/ sigma 16 *****
# Optimization terminated successfully.
#          Current function value: 20427.389879
#          Iterations: 22
#          Function evaluations: 37
#          Gradient evaluations: 37
#
#  ***** evaluating model filter_prev_violation w/ sigma 0.07 *****
# Optimization terminated successfully.
#          Current function value: 19776.959134
#          Iterations: 26
#          Function evaluations: 42
#          Gradient evaluations: 42
#
#  ***** evaluating model filter_prev_violation w/ sigma 0.13 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 19419.710195
#          Iterations: 25
#          Function evaluations: 67
#          Gradient evaluations: 55
#
#  ***** evaluating model filter_prev_violation w/ sigma 0.25 *****
# Optimization terminated successfully.
#          Current function value: 19261.175316
#          Iterations: 24
#          Function evaluations: 32
#          Gradient evaluations: 32
#
#  ***** evaluating model filter_prev_violation w/ sigma 0.5 *****
# Optimization terminated successfully.
#          Current function value: 19209.617645
#          Iterations: 24
#          Function evaluations: 32
#          Gradient evaluations: 32
#
#  ***** evaluating model filter_prev_violation w/ sigma 1 *****
# Optimization terminated successfully.
#          Current function value: 19196.093754
#          Iterations: 24
#          Function evaluations: 34
#          Gradient evaluations: 34
#
#  ***** evaluating model filter_prev_violation w/ sigma 2 *****
# Optimization terminated successfully.
#          Current function value: 19192.670370
#          Iterations: 24
#          Function evaluations: 57
#          Gradient evaluations: 56
#
#  ***** evaluating model filter_prev_violation w/ sigma 4 *****
# Optimization terminated successfully.
#          Current function value: 19191.811827
#          Iterations: 24
#          Function evaluations: 36
#          Gradient evaluations: 36
#
#  ***** evaluating model filter_prev_violation w/ sigma 8 *****
# Optimization terminated successfully.
#          Current function value: 19191.597022
#          Iterations: 24
#          Function evaluations: 32
#          Gradient evaluations: 32
#
#  ***** evaluating model filter_prev_violation w/ sigma 16 *****
# Optimization terminated successfully.
#          Current function value: 19191.543310
#          Iterations: 24
#          Function evaluations: 32
#          Gradient evaluations: 32
#
#  ***** evaluating model filter_prev_violation_stim_itrx w/ sigma 0.07 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 19774.072466
#          Iterations: 29
#          Function evaluations: 42
#          Gradient evaluations: 42
#
#  ***** evaluating model filter_prev_violation_stim_itrx w/ sigma 0.13 *****
# Optimization terminated successfully.
#          Current function value: 19415.388308
#          Iterations: 33
#          Function evaluations: 44
#          Gradient evaluations: 44
#
#  ***** evaluating model filter_prev_violation_stim_itrx w/ sigma 0.25 *****
# Optimization terminated successfully.
#          Current function value: 19255.006176
#          Iterations: 32
#          Function evaluations: 40
#          Gradient evaluations: 40
#
#  ***** evaluating model filter_prev_violation_stim_itrx w/ sigma 0.5 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 19202.391200
#          Iterations: 31
#          Function evaluations: 96
#          Gradient evaluations: 84
#
#  ***** evaluating model filter_prev_violation_stim_itrx w/ sigma 1 *****
# Optimization terminated successfully.
#          Current function value: 19188.529665
#          Iterations: 32
#          Function evaluations: 38
#          Gradient evaluations: 38
#
#  ***** evaluating model filter_prev_violation_stim_itrx w/ sigma 2 *****
# Optimization terminated successfully.
#          Current function value: 19185.016065
#          Iterations: 32
#          Function evaluations: 38
#          Gradient evaluations: 38
#
#  ***** evaluating model filter_prev_violation_stim_itrx w/ sigma 4 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 19184.134580
#          Iterations: 31
#          Function evaluations: 73
#          Gradient evaluations: 61
#
#  ***** evaluating model filter_prev_violation_stim_itrx w/ sigma 8 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 19183.914015
#          Iterations: 31
#          Function evaluations: 73
#          Gradient evaluations: 62
#
#  ***** evaluating model filter_prev_violation_stim_itrx w/ sigma 16 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 19183.858861
#          Iterations: 31
#          Function evaluations: 75
#          Gradient evaluations: 64

# %%
ORDER = [
    "psytrack_features",
    "filter_prev_violation",
    "filter_prev_violation_stim_itrx",
]

# %%
df.sort_values

# %%
mvc = ModelVisualizerCompare(experiment)
df = mvc.find_best_fit(group="model_name")
df["model_name"] = pd.Categorical(df["model_name"], categories=ORDER, ordered=True)

# Sort the DataFrame
df = df.sort_values("model_name")

# %%
for model_name, model_df in df.groupby("model_name"):
    mvc.plot_sigma_summary(model_df, title=f"{model_name} fit sigma summary")

# %%
fig, ax = plt.subplots(1, 1, figsize=(8, 5))
mvc.plot_model_comparison(
    hue=None,
    ax=ax,
    order=ORDER,
    ylim=(0, 0.6),
)

# %%
fig, ax = plt.subplots(1, 1, figsize=(8, 5))
mvc.plot_model_comparison(
    hue="animal_id",
    ax=ax,
    order=ORDER,
    ylim=(0, 0.6),
)

# %%
fig, ax = plt.subplots(1, 1, figsize=(8, 5))
mvc.plot_model_comparison(
    hue="prev_violation_tau",
    ax=ax,
    order=ORDER,
    ylim=(0, 0.6),
)

# %%
mvc.plot_train_and_test_nll(
    order=ORDER,
)

# %%
fig, ax = plt.subplots(3, 1, figsize=(10, 20), constrained_layout=True, sharey=True)

best_fit_by_model = mvc.find_best_fit(group=["animal_id", "model_name"])
# best_fit_by_model["model_name"] = pd.Categorical(
#     df["model_name"], categories=ORDER, ordered=True
# )
# best_fit_by_model = best_fit_by_model.sort_values("model_name")
for ii, (model_name, model_df) in enumerate(best_fit_by_model.groupby("model_name")):
    unpacked = mvc.unpack_features_and_weights(model_df)

    mvc.plot_weights_summary(
        df=unpacked,
        ax=ax[ii],
        palette="Set2",
        title=f"{model_name} weights summary",
    )

# %% [markdown]
# Based on these results- it appears that the previous findings hold. Adding in the prev_violation regressor is so significantly better that adding in interactions only improves the model slightly. Could assess doing prev_violation (no filtered history) with an interactions but it doesn't seem like it would be very worthwhile to keep slicing and dicing.
