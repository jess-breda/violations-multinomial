# %% [markdown]
# # Experiment: Compare Previous Disengaged with Stim Interactions
#
# **Goal**: See if interaction terms with both violation and trial not started history fits better than just single one of each or a combined version of them.
#
# Additional Notes
#
# Related notebooks:
#
# * `2024_03_23_compare_prev_disengaged_stim_intrxs.ipynb`
# * `2024_02_19_fit_filtered_prev_violation_stim_intrx.ipynb`
#
# > Written by Jess Breda
#
# Models being compared.
#
# 1. base model (psy track features)
# 2. base + prev tns + filt viol
# 3. base + prev tns + filt voil + prev tns x stim
# 4. base + prev tns + filt viol + filt viol x stim
# 5. base + prev tns + filt voil + prev tns x stim

# %% [markdown]
# ## Imports

# %%
import seaborn as sns
import matplotlib.pyplot as plt

from multiglm.experiments.experiment import load_experiment

from multiglm.experiments.experiment_compare_models import ExperimentCompareModels

from multiglm.features.design_matrix_generator import *
from multiglm.features.design_matrix_generator_PWM import *

from multiglm.models.multiclass_logistic_regression import MultiClassLogisticRegression

from multiglm.visualizations.model_visualizer import *

from multiglm.data import ANIMAL_IDS
from multiglm.experiments import STANDARD_SIGMAS


sns.set_context("talk")
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# ## Model Configs

# %% [markdown]
# ### Compare

# %%
# design matrix columns shared between all models being fit
shared_cols = {
    "session": lambda df: (copy(df.session)),
    "bias": lambda df: (add_bias_column(df)),
    "s_a": lambda df: (standardize(df.s_a)),
    "s_b": lambda df: (standardize(df.s_b)),
    "prev_avg_stim": lambda df: (prev_avg_stim(df, mask_prev_violation=True)),
    "prev_correct": lambda df: (prev_correct_side(df)),
    "prev_choice": lambda df: (prev_choice(df)),
    "labels": {"column_name": "choice"},
}


models_config = {
    "base": {
        "model_class": MultiClassLogisticRegression,
        "dmg_config": {
            **shared_cols,
        },
    },
    "disengaged_terms": {
        "model_class": MultiClassLogisticRegression,
        "dmg_config": {
            **shared_cols,
            "prev_tns": lambda df: (prev_trial_not_started(df)),
            "filt_prev_viol": lambda df: (
                filtered_prev_viol(df, get_animals_tau(df, var_name="prev_violation"))
            ),
        },
    },
    "disengaged_tns_stim_intrx": {
        "model_class": MultiClassLogisticRegression,
        "dmg_config": {
            **shared_cols,
            "prev_tns": lambda df: (prev_trial_not_started(df)),
            "filt_prev_viol": lambda df: (
                filtered_prev_viol(df, get_animals_tau(df, var_name="prev_violation"))
            ),
            "sa_tns_intrx": lambda df: combine_two_cols(
                standardize(df.s_a), prev_trial_not_started(df), operator.mul
            ),
            "sb_tns_intrx": lambda df: combine_two_cols(
                standardize(df.s_b), prev_trial_not_started(df), operator.mul
            ),
        },
    },
    "disengaged_viol_stim_intrx": {
        "model_class": MultiClassLogisticRegression,
        "dmg_config": {
            **shared_cols,
            "prev_tns": lambda df: (prev_trial_not_started(df)),
            "filt_prev_viol": lambda df: (
                filtered_prev_viol(df, get_animals_tau(df, var_name="prev_violation"))
            ),
            "sa_viol_intrx": lambda df: combine_two_cols(
                standardize(df.s_a),
                filtered_prev_viol(df, get_animals_tau(df, var_name="prev_violation")),
                operator.mul,
            ),
            "sb_viol_intrx": lambda df: combine_two_cols(
                standardize(df.s_b),
                filtered_prev_viol(df, get_animals_tau(df, var_name="prev_violation")),
                operator.mul,
            ),
        },
    },
}

params = {
    "animals": ANIMAL_IDS,
    "data_type": "new_trained",
    "sigmas": STANDARD_SIGMAS,
    "random_state": 47,
    "eval_train": True,
    "null_mode": "multi",
    "model_config": models_config,
}

save_name = "2024_03_23_compare_prev_disengaged_stim_intrxs.pkl"

ORDER = [
    "base",
    "disengaged_terms",
    "disengaged_tns_stim_intrx",
    "disengaged_viol_stim_intrx",
]

# %% [markdown]
# ## Run

# %%
experiment = ExperimentCompareModels(params)
experiment.run()
experiment.save(save_name)
# Out:
# Loading dataset type : new_trained
# Loading data for animal ids:  ['W051', 'W060', 'W065', 'W066', 'W068', 'W072', 'W073', 'W074', 'W075', 'W078', 'W080', 'W081', 'W082', 'W083', 'W088', 'W089', 'W094']
#
#  >>>> evaluating animal W051 <<<<
#
#  ***** evaluating model base w/ sigma 0.07 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 64995.381251
#          Iterations: 25
#          Function evaluations: 116
#          Gradient evaluations: 103
#
#  ***** evaluating model base w/ sigma 0.13 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 64759.621472
#          Iterations: 25
#          Function evaluations: 107
#          Gradient evaluations: 94
#
#  ***** evaluating model base w/ sigma 0.25 *****
# Optimization terminated successfully.
#          Current function value: 64687.335235
#          Iterations: 24
#          Function evaluations: 36
#          Gradient evaluations: 36
#
#  ***** evaluating model base w/ sigma 0.5 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 64667.068445
#          Iterations: 22
#          Function evaluations: 44
#          Gradient evaluations: 39
#
#  ***** evaluating model base w/ sigma 1 *****
# Optimization terminated successfully.
#          Current function value: 64661.989770
#          Iterations: 24
#          Function evaluations: 62
#          Gradient evaluations: 61
#
#  ***** evaluating model base w/ sigma 2 *****
# Optimization terminated successfully.
#          Current function value: 64660.719350
#          Iterations: 23
#          Function evaluations: 34
#          Gradient evaluations: 34
#
#  ***** evaluating model base w/ sigma 4 *****
# Optimization terminated successfully.
#          Current function value: 64660.401698
#          Iterations: 23
#          Function evaluations: 34
#          Gradient evaluations: 34
#
#  ***** evaluating model base w/ sigma 8 *****
# Optimization terminated successfully.
#          Current function value: 64660.322282
#          Iterations: 23
#          Function evaluations: 34
#          Gradient evaluations: 34
#
#  ***** evaluating model base w/ sigma 16 *****
# Optimization terminated successfully.
#          Current function value: 64660.302428
#          Iterations: 23
#          Function evaluations: 34
#          Gradient evaluations: 34
#
#  ***** evaluating model disengaged_terms w/ sigma 0.07 *****
# Optimization terminated successfully.
#          Current function value: 64748.713786
#          Iterations: 28
#          Function evaluations: 43
#          Gradient evaluations: 43
#
#  ***** evaluating model disengaged_terms w/ sigma 0.13 *****
# Optimization terminated successfully.
#          Current function value: 64426.218070
#          Iterations: 30
#          Function evaluations: 45
#          Gradient evaluations: 45
#
#  ***** evaluating model disengaged_terms w/ sigma 0.25 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 64295.523682
#          Iterations: 27
#          Function evaluations: 94
#          Gradient evaluations: 82
#
#  ***** evaluating model disengaged_terms w/ sigma 0.5 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 64247.626692
#          Iterations: 27
#          Function evaluations: 90
#          Gradient evaluations: 79
#
#  ***** evaluating model disengaged_terms w/ sigma 1 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 64233.660550
#          Iterations: 27
#          Function evaluations: 73
#          Gradient evaluations: 62
#
#  ***** evaluating model disengaged_terms w/ sigma 2 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 64229.960317
#          Iterations: 28
#          Function evaluations: 39
#          Gradient evaluations: 39
#
#  ***** evaluating model disengaged_terms w/ sigma 4 *****
# Optimization terminated successfully.
#          Current function value: 64229.019180
#          Iterations: 29
#          Function evaluations: 40
#          Gradient evaluations: 40
#
#  ***** evaluating model disengaged_terms w/ sigma 8 *****
# Optimization terminated successfully.
#          Current function value: 64228.782824
#          Iterations: 29
#          Function evaluations: 40
#          Gradient evaluations: 40
#
#  ***** evaluating model disengaged_terms w/ sigma 16 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 64228.723667
#          Iterations: 30
#          Function evaluations: 167
#          Gradient evaluations: 149
#
#  ***** evaluating model disengaged_tns_stim_intrx w/ sigma 0.07 *****
# Optimization terminated successfully.
#          Current function value: 64747.039233
#          Iterations: 35
#          Function evaluations: 53
#          Gradient evaluations: 53
#
#  ***** evaluating model disengaged_tns_stim_intrx w/ sigma 0.13 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 64423.097141
#          Iterations: 33
#          Function evaluations: 96
#          Gradient evaluations: 84
#
#  ***** evaluating model disengaged_tns_stim_intrx w/ sigma 0.25 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 64291.399977
#          Iterations: 35
#          Function evaluations: 131
#          Gradient evaluations: 118
#
#  ***** evaluating model disengaged_tns_stim_intrx w/ sigma 0.5 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 64242.007978
#          Iterations: 36
#          Function evaluations: 50
#          Gradient evaluations: 50
#
#  ***** evaluating model disengaged_tns_stim_intrx w/ sigma 1 *****
# Optimization terminated successfully.
#          Current function value: 64226.487812
#          Iterations: 35
#          Function evaluations: 46
#          Gradient evaluations: 46
#
#  ***** evaluating model disengaged_tns_stim_intrx w/ sigma 2 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 64222.029063
#          Iterations: 36
#          Function evaluations: 99
#          Gradient evaluations: 87
#
#  ***** evaluating model disengaged_tns_stim_intrx w/ sigma 4 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 64220.848638
#          Iterations: 37
#          Function evaluations: 82
#          Gradient evaluations: 71
#
#  ***** evaluating model disengaged_tns_stim_intrx w/ sigma 8 *****
# Optimization terminated successfully.
#          Current function value: 64220.548376
#          Iterations: 38
#          Function evaluations: 103
#          Gradient evaluations: 102
#
#  ***** evaluating model disengaged_tns_stim_intrx w/ sigma 16 *****
# Optimization terminated successfully.
#          Current function value: 64220.472966
#          Iterations: 38
#          Function evaluations: 50
#          Gradient evaluations: 50
#
#  ***** evaluating model disengaged_viol_stim_intrx w/ sigma 0.07 *****
# Optimization terminated successfully.
#          Current function value: 64714.292158
#          Iterations: 35
#          Function evaluations: 104
#          Gradient evaluations: 97
#
#  ***** evaluating model disengaged_viol_stim_intrx w/ sigma 0.13 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 64364.494265
#          Iterations: 32
#          Function evaluations: 104
#          Gradient evaluations: 92
#
#  ***** evaluating model disengaged_viol_stim_intrx w/ sigma 0.25 *****
# Optimization terminated successfully.
#          Current function value: 64219.555834
#          Iterations: 34
#          Function evaluations: 42
#          Gradient evaluations: 42
#
#  ***** evaluating model disengaged_viol_stim_intrx w/ sigma 0.5 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 64166.740875
#          Iterations: 31
#          Function evaluations: 84
#          Gradient evaluations: 72
#
#  ***** evaluating model disengaged_viol_stim_intrx w/ sigma 1 *****
# Optimization terminated successfully.
#          Current function value: 64151.461363
#          Iterations: 33
#          Function evaluations: 41
#          Gradient evaluations: 41
#
#  ***** evaluating model disengaged_viol_stim_intrx w/ sigma 2 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 64147.427349
#          Iterations: 32
#          Function evaluations: 64
#          Gradient evaluations: 54
#
#  ***** evaluating model disengaged_viol_stim_intrx w/ sigma 4 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 64146.402435
#          Iterations: 31
#          Function evaluations: 83
#          Gradient evaluations: 71
#
#  ***** evaluating model disengaged_viol_stim_intrx w/ sigma 8 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 64146.145114
#          Iterations: 33
#          Function evaluations: 99
#          Gradient evaluations: 87
#
#  ***** evaluating model disengaged_viol_stim_intrx w/ sigma 16 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 64146.080714
#          Iterations: 33
#          Function evaluations: 90
#          Gradient evaluations: 76
#
#  >>>> evaluating animal W060 <<<<
#
#  ***** evaluating model base w/ sigma 0.07 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 52210.844301
#          Iterations: 26
#          Function evaluations: 95
#          Gradient evaluations: 84
#
#  ***** evaluating model base w/ sigma 0.13 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 51927.370292
#          Iterations: 24
#          Function evaluations: 41
#          Gradient evaluations: 41
#
#  ***** evaluating model base w/ sigma 0.25 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 51839.613896
#          Iterations: 26
#          Function evaluations: 41
#          Gradient evaluations: 41
#
#  ***** evaluating model base w/ sigma 0.5 *****
# Optimization terminated successfully.
#          Current function value: 51814.935682
#          Iterations: 27
#          Function evaluations: 42
#          Gradient evaluations: 42
#
#  ***** evaluating model base w/ sigma 1 *****
# Optimization terminated successfully.
#          Current function value: 51808.746389
#          Iterations: 26
#          Function evaluations: 40
#          Gradient evaluations: 40
#
#  ***** evaluating model base w/ sigma 2 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 51807.197826
#          Iterations: 24
#          Function evaluations: 87
#          Gradient evaluations: 75
#
#  ***** evaluating model base w/ sigma 4 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 51806.810608
#          Iterations: 25
#          Function evaluations: 39
#          Gradient evaluations: 39
#
#  ***** evaluating model base w/ sigma 8 *****
# Optimization terminated successfully.
#          Current function value: 51806.713799
#          Iterations: 26
#          Function evaluations: 40
#          Gradient evaluations: 40
#
#  ***** evaluating model base w/ sigma 16 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 51806.689596
#          Iterations: 25
#          Function evaluations: 127
#          Gradient evaluations: 113
#
#  ***** evaluating model disengaged_terms w/ sigma 0.07 *****
# Optimization terminated successfully.
#          Current function value: 51799.751171
#          Iterations: 33
#          Function evaluations: 49
#          Gradient evaluations: 49
#
#  ***** evaluating model disengaged_terms w/ sigma 0.13 *****
# Optimization terminated successfully.
#          Current function value: 51381.337104
#          Iterations: 32
#          Function evaluations: 79
#          Gradient evaluations: 75
#
#  ***** evaluating model disengaged_terms w/ sigma 0.25 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 51232.348873
#          Iterations: 29
#          Function evaluations: 39
#          Gradient evaluations: 39
#
#  ***** evaluating model disengaged_terms w/ sigma 0.5 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 
#          Iterations: 25
#          Function evaluations: 80
#          Gradient evaluations: 68
#
#  ***** evaluating model disengaged_terms w/ sigma 1 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 77030.035779
#          Iterations: 26
#          Function evaluations: 74
#          Gradient evaluations: 63
#
#  ***** evaluating model disengaged_terms w/ sigma 2 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 77026.651291
#          Iterations: 27
#          Function evaluations: 80
#          Gradient evaluations: 69
#
#  ***** evaluating model disengaged_terms w/ sigma 4 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 77025.803140
#          Iterations: 26
#          Function evaluations: 78
#          Gradient evaluations: 67
#
#  ***** evaluating model disengaged_terms w/ sigma 8 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 77025.590975
#          Iterations: 26
#          Function evaluations: 77
#          Gradient evaluations: 65
#
#  ***** evaluating model disengaged_terms w/ sigma 16 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 77025.537925
#          Iterations: 27
#          Function evaluations: 82
#          Gradient evaluations: 71
#
#  ***** evaluating model disengaged_tns_stim_intrx w/ sigma 0.07 *****
# Optimization terminated successfully.
#          Current function value: 77684.403857
#          Iterations: 33
#          Function evaluations: 51
#          Gradient evaluations: 51
#
#  ***** evaluating model disengaged_tns_stim_intrx w/ sigma 0.13 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 77249.299171
#          Iterations: 31
#          Function evaluations: 65
#          Gradient evaluations: 54
#
#  ***** evaluating model disengaged_tns_stim_intrx w/ sigma 0.25 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 77081.232251
#          Iterations: 34
#          Function evaluations: 78
#          Gradient evaluations: 66
#
#  ***** evaluating model disengaged_tns_stim_intrx w/ sigma 0.5 *****
# Optimization terminated successfully.
#          Current function value: 77028.498605
#          Iterations: 35
#          Function evaluations: 47
#          Gradient evaluations: 47
#
#  ***** evaluating model disengaged_tns_stim_intrx w/ sigma 1 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 77014.739944
#          Iterations: 33
#          Function evaluations: 44
#          Gradient evaluations: 44
#
#  ***** evaluating model disengaged_tns_stim_intrx w/ sigma 2 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 77011.259285
#          Iterations: 33
#          Function evaluations: 44
#          Gradient evaluations: 44
#
#  ***** evaluating model disengaged_tns_stim_intrx w/ sigma 4 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 77010.386460
#          Iterations: 33
#          Function evaluations: 45
#          Gradient evaluations: 45
#
#  ***** evaluating model disengaged_tns_stim_intrx w/ sigma 8 *****
# Optimization terminated successfully.
#          Current function value: 77010.168086
#          Iterations: 34
#          Function evaluations: 45
#          Gradient evaluations: 45
#
#  ***** evaluating model disengaged_tns_stim_intrx w/ sigma 16 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 77010.113481
#          Iterations: 34
#          Function evaluations: 146
#          Gradient evaluations: 134
#
#  ***** evaluating model disengaged_viol_stim_intrx w/ sigma 0.07 *****
# Optimization terminated successfully.
#          Current function value: 77688.996174
#          Iterations: 33
#          Function evaluations: 48
#          Gradient evaluations: 48
#
#  ***** evaluating model disengaged_viol_stim_intrx w/ sigma 0.13 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 77261.016886
#          Iterations: 32
#          Function evaluations: 156
#          Gradient evaluations: 140
#
#  ***** evaluating model disengaged_viol_stim_intrx w/ sigma 0.25 *****
# Optimization terminated successfully.
#          Current function value: 77093.958165
#          Iterations: 33
#          Function evaluations: 45
#          Gradient evaluations: 45
#
#  ***** evaluating model disengaged_viol_stim_intrx w/ sigma 0.5 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 77041.817975
#          Iterations: 32
#          Function evaluations: 46
#          Gradient evaluations: 46
#
#  ***** evaluating model disengaged_viol_stim_intrx w/ sigma 1 *****
# Optimization terminated successfully.
#          Current function value: 77028.286923
#          Iterations: 33
#          Function evaluations: 45
#          Gradient evaluations: 45
#
#  ***** evaluating model disengaged_viol_stim_intrx w/ sigma 2 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 77024.870508
#          Iterations: 31
#          Function evaluations: 138
#          Gradient evaluations: 125
#
#  ***** evaluating model disengaged_viol_stim_intrx w/ sigma 4 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 77024.014254
#          Iterations: 31
#          Function evaluations: 42
#          Gradient evaluations: 42
#
#  ***** evaluating model disengaged_viol_stim_intrx w/ sigma 8 *****
# Optimization terminated successfully.
#          Current function value: 77023.800056
#          Iterations: 32
#          Function evaluations: 43
#          Gradient evaluations: 43
#
#  ***** evaluating model disengaged_viol_stim_intrx w/ sigma 16 *****
# Optimization terminated successfully.
#          Current function value: 77023.746498
#          Iterations: 32
#          Function evaluations: 43
#          Gradient evaluations: 43
#
#  >>>> evaluating animal W072 <<<<
#
#  ***** evaluating model base w/ sigma 0.07 *****
# Optimization terminated successfully.
#          Current function value: 61425.060327
#          Iterations: 23
#          Function evaluations: 36
#          Gradient evaluations: 36
#
#  ***** evaluating model base w/ sigma 0.13 *****
# Optimization terminated successfully.
#          Current function value: 61187.277675
#          Iterations: 23
#          Function evaluations: 38
#          Gradient evaluations: 38
#
#  ***** evaluating model base w/ sigma 0.25 *****
# Optimization terminated successfully.
#          Current function value: 61113.966316
#          Iterations: 23
#          Function evaluations: 35
#          Gradient evaluations: 35
#
#  ***** evaluating model base w/ sigma 0.5 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 61093.376716
#          Iterations: 20
#          Function evaluations: 81
#          Gradient evaluations: 68
#
#  ***** evaluating model base w/ sigma 1 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 61088.214690
#          Iterations: 19
#          Function evaluations: 77
#          Gradient evaluations: 65
#
# ...
#          Current function value: 91537.860810
#          Iterations: 32
#          Function evaluations: 104
#          Gradient evaluations: 92
#
#  ***** evaluating model disengaged_terms w/ sigma 0.5 *****
# Optimization terminated successfully.
#          Current function value: 91481.523858
#          Iterations: 32
#          Function evaluations: 43
#          Gradient evaluations: 43
#
#  ***** evaluating model disengaged_terms w/ sigma 1 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 91467.248033
#          Iterations: 29
#          Function evaluations: 79
#          Gradient evaluations: 70
#
#  ***** evaluating model disengaged_terms w/ sigma 2 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 91463.666799
#          Iterations: 29
#          Function evaluations: 91
#          Gradient evaluations: 79
#
#  ***** evaluating model disengaged_terms w/ sigma 4 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 91462.770719
#          Iterations: 30
#          Function evaluations: 41
#          Gradient evaluations: 41
#
#  ***** evaluating model disengaged_terms w/ sigma 8 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 91462.546650
#          Iterations: 30
#          Function evaluations: 56
#          Gradient evaluations: 46
#
#  ***** evaluating model disengaged_terms w/ sigma 16 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 91462.490630
#          Iterations: 31
#          Function evaluations: 41
#          Gradient evaluations: 41
#
#  ***** evaluating model disengaged_tns_stim_intrx w/ sigma 0.07 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 92253.373413
#          Iterations: 36
#          Function evaluations: 119
#          Gradient evaluations: 107
#
#  ***** evaluating model disengaged_tns_stim_intrx w/ sigma 0.13 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 91671.934220
#          Iterations: 36
#          Function evaluations: 95
#          Gradient evaluations: 83
#
#  ***** evaluating model disengaged_tns_stim_intrx w/ sigma 0.25 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 91469.233137
#          Iterations: 34
#          Function evaluations: 46
#          Gradient evaluations: 46
#
#  ***** evaluating model disengaged_tns_stim_intrx w/ sigma 0.5 *****
# Optimization terminated successfully.
#          Current function value: 91409.238475
#          Iterations: 37
#          Function evaluations: 48
#          Gradient evaluations: 48
#
#  ***** evaluating model disengaged_tns_stim_intrx w/ sigma 1 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 91393.938010
#          Iterations: 35
#          Function evaluations: 102
#          Gradient evaluations: 90
#
#  ***** evaluating model disengaged_tns_stim_intrx w/ sigma 2 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 91390.092745
#          Iterations: 34
#          Function evaluations: 87
#          Gradient evaluations: 75
#
#  ***** evaluating model disengaged_tns_stim_intrx w/ sigma 4 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 91389.130148
#          Iterations: 35
#          Function evaluations: 45
#          Gradient evaluations: 45
#
#  ***** evaluating model disengaged_tns_stim_intrx w/ sigma 8 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 91388.889418
#          Iterations: 34
#          Function evaluations: 90
#          Gradient evaluations: 79
#
#  ***** evaluating model disengaged_tns_stim_intrx w/ sigma 16 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 91388.829230
#          Iterations: 34
#          Function evaluations: 84
#          Gradient evaluations: 72
#
#  ***** evaluating model disengaged_viol_stim_intrx w/ sigma 0.07 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 92116.373955
#          Iterations: 38
#          Function evaluations: 62
#          Gradient evaluations: 59
#
#  ***** evaluating model disengaged_viol_stim_intrx w/ sigma 0.13 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 91501.454627
#          Iterations: 36
#          Function evaluations: 47
#          Gradient evaluations: 47
#
#  ***** evaluating model disengaged_viol_stim_intrx w/ sigma 0.25 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 91287.509771
#          Iterations: 35
#          Function evaluations: 91
#          Gradient evaluations: 80
#
#  ***** evaluating model disengaged_viol_stim_intrx w/ sigma 0.5 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 91224.656439
#          Iterations: 36
#          Function evaluations: 46
#          Gradient evaluations: 46
#
#  ***** evaluating model disengaged_viol_stim_intrx w/ sigma 1 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 91208.687151
#          Iterations: 34
#          Function evaluations: 44
#          Gradient evaluations: 44
#
#  ***** evaluating model disengaged_viol_stim_intrx w/ sigma 2 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 91204.678326
#          Iterations: 35
#          Function evaluations: 104
#          Gradient evaluations: 92
#
#  ***** evaluating model disengaged_viol_stim_intrx w/ sigma 4 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 91203.675081
#          Iterations: 33
#          Function evaluations: 91
#          Gradient evaluations: 79
#
#  ***** evaluating model disengaged_viol_stim_intrx w/ sigma 8 *****
# Optimization terminated successfully.
#          Current function value: 91203.424204
#          Iterations: 36
#          Function evaluations: 45
#          Gradient evaluations: 45
#
#  ***** evaluating model disengaged_viol_stim_intrx w/ sigma 16 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 91203.361481
#          Iterations: 34
#          Function evaluations: 43
#          Gradient evaluations: 43
#
#  >>>> evaluating animal W094 <<<<
#
#  ***** evaluating model base w/ sigma 0.07 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 46181.052794
#          Iterations: 22
#          Function evaluations: 36
#          Gradient evaluations: 36
#
#  ***** evaluating model base w/ sigma 0.13 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 45920.160099
#          Iterations: 21
#          Function evaluations: 84
#          Gradient evaluations: 73
#
#  ***** evaluating model base w/ sigma 0.25 *****
# Optimization terminated successfully.
#          Current function value: 45838.411336
#          Iterations: 22
#          Function evaluations: 35
#          Gradient evaluations: 35
#
#  ***** evaluating model base w/ sigma 0.5 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 45815.334302
#          Iterations: 20
#          Function evaluations: 72
#          Gradient evaluations: 60
#
#  ***** evaluating model base w/ sigma 1 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 45809.540407
#          Iterations: 20
#          Function evaluations: 62
#          Gradient evaluations: 50
#
#  ***** evaluating model base w/ sigma 2 *****
# Optimization terminated successfully.
#          Current function value: 45808.090384
#          Iterations: 22
#          Function evaluations: 58
#          Gradient evaluations: 57
#
#  ***** evaluating model base w/ sigma 4 *****
# Optimization terminated successfully.
#          Current function value: 45807.727781
#          Iterations: 21
#          Function evaluations: 33
#          Gradient evaluations: 33
#
#  ***** evaluating model base w/ sigma 8 *****
# Optimization terminated successfully.
#          Current function value: 45807.637124
#          Iterations: 21
#          Function evaluations: 33
#          Gradient evaluations: 33
#
#  ***** evaluating model base w/ sigma 16 *****
# Optimization terminated successfully.
#          Current function value: 45807.614460
#          Iterations: 21
#          Function evaluations: 33
#          Gradient evaluations: 33
#
#  ***** evaluating model disengaged_terms w/ sigma 0.07 *****
# Optimization terminated successfully.
#          Current function value: 45529.280175
#          Iterations: 29
#          Function evaluations: 44
#          Gradient evaluations: 44
#
#  ***** evaluating model disengaged_terms w/ sigma 0.13 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 44979.610109
#          Iterations: 26
#          Function evaluations: 92
#          Gradient evaluations: 80
#
#  ***** evaluating model disengaged_terms w/ sigma 0.25 *****
# Optimization terminated successfully.
#          Current function value: 44744.936734
#          Iterations: 27
#          Function evaluations: 37
#          Gradient evaluations: 37
#
#  ***** evaluating model disengaged_terms w/ sigma 0.5 *****
# Optimization terminated successfully.
#          Current function value: 44666.430286
#          Iterations: 26
#          Function evaluations: 35
#          Gradient evaluations: 35
#
#  ***** evaluating model disengaged_terms w/ sigma 1 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 44645.355504
#          Iterations: 26
#          Function evaluations: 35
#          Gradient evaluations: 35
#
#  ***** evaluating model disengaged_terms w/ sigma 2 *****
# Optimization terminated successfully.
#          Current function value: 44639.976199
#          Iterations: 27
#          Function evaluations: 36
#          Gradient evaluations: 36
#
#  ***** evaluating model disengaged_terms w/ sigma 4 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 44638.624019
#          Iterations: 26
#          Function evaluations: 98
#          Gradient evaluations: 86
#
#  ***** evaluating model disengaged_terms w/ sigma 8 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 44638.285507
#          Iterations: 26
#          Function evaluations: 35
#          Gradient evaluations: 35
#
#  ***** evaluating model disengaged_terms w/ sigma 16 *****
# Optimization terminated successfully.
#          Current function value: 44638.200850
#          Iterations: 27
#          Function evaluations: 36
#          Gradient evaluations: 36
#
#  ***** evaluating model disengaged_tns_stim_intrx w/ sigma 0.07 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 45524.069853
#          Iterations: 32
#          Function evaluations: 103
#          Gradient evaluations: 91
#
#  ***** evaluating model disengaged_tns_stim_intrx w/ sigma 0.13 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 44972.717924
#          Iterations: 32
#          Function evaluations: 121
#          Gradient evaluations: 101
#
#  ***** evaluating model disengaged_tns_stim_intrx w/ sigma 0.25 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 44737.818214
#          Iterations: 33
#          Function evaluations: 97
#          Gradient evaluations: 81
#
#  ***** evaluating model disengaged_tns_stim_intrx w/ sigma 0.5 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 44658.783174
#          Iterations: 32
#          Function evaluations: 42
#          Gradient evaluations: 42
#
#  ***** evaluating model disengaged_tns_stim_intrx w/ sigma 1 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 44637.264595
#          Iterations: 32
#          Function evaluations: 41
#          Gradient evaluations: 41
#
#  ***** evaluating model disengaged_tns_stim_intrx w/ sigma 2 *****
# Optimization terminated successfully.
#          Current function value: 44631.719422
#          Iterations: 33
#          Function evaluations: 42
#          Gradient evaluations: 42
#
#  ***** evaluating model disengaged_tns_stim_intrx w/ sigma 4 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 44630.320742
#          Iterations: 33
#          Function evaluations: 128
#          Gradient evaluations: 114
#
#  ***** evaluating model disengaged_tns_stim_intrx w/ sigma 8 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 44629.970252
#          Iterations: 34
#          Function evaluations: 153
#          Gradient evaluations: 136
#
#  ***** evaluating model disengaged_tns_stim_intrx w/ sigma 16 *****
# Optimization terminated successfully.
#          Current function value: 44629.882578
#          Iterations: 33
#          Function evaluations: 42
#          Gradient evaluations: 42
#
#  ***** evaluating model disengaged_viol_stim_intrx w/ sigma 0.07 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 45508.356000
#          Iterations: 31
#          Function evaluations: 74
#          Gradient evaluations: 62
#
#  ***** evaluating model disengaged_viol_stim_intrx w/ sigma 0.13 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 44925.340959
#          Iterations: 33
#          Function evaluations: 146
#          Gradient evaluations: 133
#
#  ***** evaluating model disengaged_viol_stim_intrx w/ sigma 0.25 *****
# Optimization terminated successfully.
#          Current function value: 44665.718113
#          Iterations: 33
#          Function evaluations: 39
#          Gradient evaluations: 39
#
#  ***** evaluating model disengaged_viol_stim_intrx w/ sigma 0.5 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 44576.082421
#          Iterations: 32
#          Function evaluations: 78
#          Gradient evaluations: 66
#
#  ***** evaluating model disengaged_viol_stim_intrx w/ sigma 1 *****
# Optimization terminated successfully.
#          Current function value: 44551.704321
#          Iterations: 33
#          Function evaluations: 39
#          Gradient evaluations: 39
#
#  ***** evaluating model disengaged_viol_stim_intrx w/ sigma 2 *****
# Optimization terminated successfully.
#          Current function value: 44545.458913
#          Iterations: 34
#          Function evaluations: 42
#          Gradient evaluations: 42
#
#  ***** evaluating model disengaged_viol_stim_intrx w/ sigma 4 *****
# Optimization terminated successfully.
#          Current function value: 44543.887537
#          Iterations: 34
#          Function evaluations: 40
#          Gradient evaluations: 40
#
#  ***** evaluating model disengaged_viol_stim_intrx w/ sigma 8 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 44543.494057
#          Iterations: 33
#          Function evaluations: 108
#          Gradient evaluations: 95
#
#  ***** evaluating model disengaged_viol_stim_intrx w/ sigma 16 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 44543.395647
#          Iterations: 33
#          Function evaluations: 81
#          Gradient evaluations: 69

# %% [markdown]
# ## Visualize

# %%
experiment = load_experiment(save_name)
mvc = ModelVisualizerCompare(experiment)

# %%
df = mvc.find_best_fit(group="model_name")
df["model_name"] = pd.Categorical(df["model_name"], categories=ORDER, ordered=True)
for model_name, model_df in df.groupby("model_name"):
    mvc.plot_sigma_summary(model_df, title=f"{model_name} fit sigma summary")
# Out:
# /var/folders/__/8jn6qz211155h1xb451s5zcr0000gn/T/ipykernel_50264/2431235986.py:3: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   for model_name, model_df in df.groupby("model_name"):
# /Users/jessbreda/anaconda3/envs/an_lrn/lib/python3.10/site-packages/seaborn/categorical.py:641: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   grouped_vals = vals.groupby(grouper)
# /Users/jessbreda/anaconda3/envs/an_lrn/lib/python3.10/site-packages/seaborn/categorical.py:641: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   grouped_vals = vals.groupby(grouper)
# /Users/jessbreda/anaconda3/envs/an_lrn/lib/python3.10/site-packages/seaborn/categorical.py:641: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   grouped_vals = vals.groupby(grouper)
# /Users/jessbreda/anaconda3/envs/an_lrn/lib/python3.10/site-packages/seaborn/categorical.py:641: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   grouped_vals = vals.groupby(grouper)

# %%
fig, ax = plt.subplots(
    len(ORDER), 1, figsize=(10, len(ORDER) * 6), constrained_layout=True, sharey=False
)

best_fit_by_model = mvc.find_best_fit(group=["animal_id", "model_name"])
best_fit_by_model["model_name"] = pd.Categorical(
    best_fit_by_model["model_name"], categories=ORDER, ordered=True
)

for ii, (model_name, model_df) in enumerate(best_fit_by_model.groupby("model_name")):
    unpacked = mvc.unpack_features_and_weights(model_df)

    mvc.plot_weights_summary(
        df=unpacked,
        ax=ax[ii],
        palette="Set2",
        title=f"{model_name} weights summary",
    )
# Out:
# /var/folders/__/8jn6qz211155h1xb451s5zcr0000gn/T/ipykernel_50264/2667047998.py:10: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   for ii, (model_name, model_df) in enumerate(best_fit_by_model.groupby("model_name")):

# %%
fig, ax = plt.subplots(1, 1, figsize=(8, 5))
mvc.plot_model_comparison(
    hue=None,
    ax=ax,
    order=ORDER,
    errorbar=None,
)

# %%
fig, ax = plt.subplots(1, 1, figsize=(8, 5))
mvc.plot_model_comparison(
    hue=None,
    ax=ax,
    order=ORDER[1:],
    errorbar=None,
)

# %%
mvc.plot_train_and_test_ll(
    order=ORDER,
    errorbar=None,
)
# Out:
# /Users/jessbreda/anaconda3/envs/an_lrn/lib/python3.10/site-packages/seaborn/categorical.py:641: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   grouped_vals = vals.groupby(grouper)
# /Users/jessbreda/anaconda3/envs/an_lrn/lib/python3.10/site-packages/seaborn/categorical.py:641: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   grouped_vals = vals.groupby(grouper)

# %%
mvc.plot_ll_delta_by_animal(
    base_model_name=ORDER[1],
    new_model_name=ORDER[3],
    type="test",
)
# Out:
# <Axes: title={'center': 'Model Improvement- mu: 23.7 std: 29.96 \n disengaged_terms -> disengaged_viol_stim_intrx'}, xlabel='animal_id', ylabel='Delta test LL (new - base)'>
