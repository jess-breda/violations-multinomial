# %% [markdown]
# # Compare Previous Violations History Experiment
#
# **Goal**: Reproduce the results from the previous violation comparison experiment using base regressors (psytrack), one trial back previous history or filtered previous history
#
# The goal of this is to ensure the model comparison code is working as expected and the interaction comparison results are still valid.

# %%
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt
import pathlib
import sys
[
    sys.path.append(str(folder))
    for folder in pathlib.Path("../src/").iterdir()
    if folder.is_dir()
]

from experiment_compare_models import ExperimentCompareModels
from multiclass_logistic_regression import MultiClassLogisticRegression
from model_visualizer import ModelVisualizerCompare
from design_matrix_generator import DesignMatrixGeneratorFilteredHistory
sns.set_context("talk")
# %load_ext autoreload
# %autoreload 2

# %%
model_config = {
    "psytrack_features": {  # MODEL 1
        "model_class": MultiClassLogisticRegression,
        "model_type": "multi",
        "design_matrix_generator": DesignMatrixGeneratorFilteredHistory,
        "filter_implementation": {"prev_violation": -1},  # no filter & drop column
    },
    "prev_violation": {  # MODEL 2
        "model_class": MultiClassLogisticRegression,
        "model_type": "mutli",
        "design_matrix_generator": DesignMatrixGeneratorFilteredHistory,
        "filter_implementation": {"prev_violation": 0},  # no filter
    },
    "filter_prev_violation": {  # MODEL 3
        "model_class": MultiClassLogisticRegression,
        "model_type": "mutli",
        "design_matrix_generator": DesignMatrixGeneratorFilteredHistory,
        "filter_implementation": {
            "prev_violation": 1
        },  # filter column with animals tau
    },
}
params = {
    "animals": None,
    "sigmas": [0.07, 0.13, 0.25, 0.5, 1, 2, 4, 8, 16],
    "random_state": 47,
    "null_mode": "multi",
    "eval_train": True,
    "tau_columns": ["prev_violation"],
    "model_config": model_config,
}

# %%
experiment = ExperimentCompareModels(params)
experiment.run()
experiment.save(file_name="2023_11_10_compare_prev_violation_history.pkl")
# Out:
# returning viol dataset for all animals
#
#  >>>> evaluating animal W051 <<<<
#
#  ***** evaluating model psytrack_features w/ sigma 0.07 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 41950.303150
#          Iterations: 20
#          Function evaluations: 88
#          Gradient evaluations: 76
#
#  ***** evaluating model psytrack_features w/ sigma 0.13 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 41893.656506
#          Iterations: 21
#          Function evaluations: 85
#          Gradient evaluations: 74
#
#  ***** evaluating model psytrack_features w/ sigma 0.25 *****
# Optimization terminated successfully.
#          Current function value: 41876.171967
#          Iterations: 21
#          Function evaluations: 35
#          Gradient evaluations: 35
#
#  ***** evaluating model psytrack_features w/ sigma 0.5 *****
# Optimization terminated successfully.
#          Current function value: 41871.260132
#          Iterations: 20
#          Function evaluations: 33
#          Gradient evaluations: 33
#
#  ***** evaluating model psytrack_features w/ sigma 1 *****
# Optimization terminated successfully.
#          Current function value: 41870.028605
#          Iterations: 20
#          Function evaluations: 33
#          Gradient evaluations: 33
#
#  ***** evaluating model psytrack_features w/ sigma 2 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 41869.720499
#          Iterations: 19
#          Function evaluations: 95
#          Gradient evaluations: 83
#
#  ***** evaluating model psytrack_features w/ sigma 4 *****
# Optimization terminated successfully.
#          Current function value: 41869.643459
#          Iterations: 20
#          Function evaluations: 33
#          Gradient evaluations: 33
#
#  ***** evaluating model psytrack_features w/ sigma 8 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 41869.624198
#          Iterations: 19
#          Function evaluations: 62
#          Gradient evaluations: 51
#
#  ***** evaluating model psytrack_features w/ sigma 16 *****
# Optimization terminated successfully.
#          Current function value: 41869.619382
#          Iterations: 20
#          Function evaluations: 33
#          Gradient evaluations: 33
#
#  ***** evaluating model prev_violation w/ sigma 0.07 *****
# Optimization terminated successfully.
#          Current function value: 41313.379945
#          Iterations: 26
#          Function evaluations: 41
#          Gradient evaluations: 41
#
#  ***** evaluating model prev_violation w/ sigma 0.13 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 41196.477788
#          Iterations: 24
#          Function evaluations: 89
#          Gradient evaluations: 77
#
#  ***** evaluating model prev_violation w/ sigma 0.25 *****
# Optimization terminated successfully.
#          Current function value: 41158.933152
#          Iterations: 24
#          Function evaluations: 38
#          Gradient evaluations: 38
#
#  ***** evaluating model prev_violation w/ sigma 0.5 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 41148.252742
#          Iterations: 23
#          Function evaluations: 83
#          Gradient evaluations: 71
#
#  ***** evaluating model prev_violation w/ sigma 1 *****
# Optimization terminated successfully.
#          Current function value: 41145.565517
#          Iterations: 23
#          Function evaluations: 36
#          Gradient evaluations: 36
#
#  ***** evaluating model prev_violation w/ sigma 2 *****
# Optimization terminated successfully.
#          Current function value: 41144.892632
#          Iterations: 23
#          Function evaluations: 36
#          Gradient evaluations: 36
#
#  ***** evaluating model prev_violation w/ sigma 4 *****
# Optimization terminated successfully.
#          Current function value: 41144.724343
#          Iterations: 23
#          Function evaluations: 36
#          Gradient evaluations: 36
#
#  ***** evaluating model prev_violation w/ sigma 8 *****
# Optimization terminated successfully.
#          Current function value: 41144.682266
#          Iterations: 23
#          Function evaluations: 36
#          Gradient evaluations: 36
#
#  ***** evaluating model prev_violation w/ sigma 16 *****
# Optimization terminated successfully.
#          Current function value: 41144.671747
#          Iterations: 23
#          Function evaluations: 36
#          Gradient evaluations: 36
#
#  ***** evaluating model filter_prev_violation w/ sigma 0.07 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 41208.619621
#          Iterations: 23
#          Function evaluations: 36
#          Gradient evaluations: 36
#
#  ***** evaluating model filter_prev_violation w/ sigma 0.13 *****
# Optimization terminated successfully.
#          Current function value: 40814.204222
#          Iterations: 25
#          Function evaluations: 35
#          Gradient evaluations: 35
#
#  ***** evaluating model filter_prev_violation w/ sigma 0.25 *****
# Optimization terminated successfully.
#          Current function value: 40627.904023
#          Iterations: 25
#          Function evaluations: 39
#          Gradient evaluations: 39
#
#  ***** evaluating model filter_prev_violation w/ sigma 0.5 *****
# Optimization terminated successfully.
#          Current function value: 40565.943728
#          Iterations: 24
#          Function evaluations: 35
#          Gradient evaluations: 35
#
#  ***** evaluating model filter_prev_violation w/ sigma 1 *****
# Optimization terminated successfully.
#          Current function value: 40549.584035
#          Iterations: 23
#          Function evaluations: 34
#          Gradient evaluations: 34
#
#  ***** evaluating model filter_prev_violation w/ sigma 2 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 40545.435837
#          Iterations: 23
#          Function evaluations: 136
#          Gradient evaluations: 123
#
#  ***** evaluating model filter_prev_violation w/ sigma 4 *****
# Optimization terminated successfully.
#          Current function value: 40544.395078
#          Iterations: 23
#          Function evaluations: 34
#          Gradient evaluations: 34
#
#  ***** evaluating model filter_prev_violation w/ sigma 8 *****
# Optimization terminated successfully.
#          Current function value: 40544.134656
#          Iterations: 23
#          Function evaluations: 34
#          Gradient evaluations: 34
#
#  ***** evaluating model filter_prev_violation w/ sigma 16 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 40544.069536
#          Iterations: 22
#          Function evaluations: 77
#          Gradient evaluations: 65
#
#  >>>> evaluating animal W060 <<<<
#
#  ***** evaluating model psytrack_features w/ sigma 0.07 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 30703.331899
#          Iterations: 22
#          Function evaluations: 39
#          Gradient evaluations: 39
#
#  ***** evaluating model psytrack_features w/ sigma 0.13 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 30580.883259
#          Iterations: 21
#          Function evaluations: 99
#          Gradient evaluations: 87
#
#  ***** evaluating model psytrack_features w/ sigma 0.25 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 30542.531549
#          Iterations: 22
#          Function evaluations: 39
#          Gradient evaluations: 39
#
#  ***** evaluating model psytrack_features w/ sigma 0.5 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 30531.708242
#          Iterations: 19
#          Function evaluations: 80
#          Gradient evaluations: 68
#
#  ***** evaluating model psytrack_features w/ sigma 1 *****
# Optimization terminated successfully.
#          Current function value: 30528.991110
#          Iterations: 20
#          Function evaluations: 33
#          Gradient evaluations: 33
#
#  ***** evaluating model psytrack_features w/ sigma 2 *****
# Optimization terminated successfully.
#          Current function value: 30528.311117
#          Iterations: 20
#          Function evaluations: 33
#          Gradient evaluations: 33
#
#  ***** evaluating model psytrack_features w/ sigma 4 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 30528.141074
#          Iterations: 19
#          Function evaluations: 62
#          Gradient evaluations: 51
#
#  ***** evaluating model psytrack_features w/ sigma 8 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 30528.098561
#          Iterations: 19
#          Function evaluations: 79
#          Gradient evaluations: 68
#
#  ***** evaluating model psytrack_features w/ sigma 16 *****
# Optimization terminated successfully.
#          Current function value: 30528.087932
#          Iterations: 20
#          Function evaluations: 33
#          Gradient evaluations: 33
#
#  ***** evaluating model prev_violation w/ sigma 0.07 *****
# Optimization terminated successfully.
#          Current function value: 30028.523711
#          Iterations: 25
#          Function evaluations: 93
#          Gradient evaluations: 90
#
#  ***** evaluating model prev_violation w/ sigma 0.13 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 29812.824226
#          Iterations: 24
#          Function evaluations: 86
#          Gradient evaluations: 74
#
#  ***** evaluating model prev_violation w/ sigma 0.25 *****
# Optimization terminated successfully.
#          Current function value: 29742.003273
#          Iterations: 24
#          Function evaluations: 33
#          Gradient evaluations: 33
#
#  ***** evaluating model prev_violation w/ sigma 0.5 *****
# Optimization terminated successfully.
#          Current function value: 29721.706955
#          Iterations: 23
#          Function evaluations: 31
#          Gradient evaluations: 31
#
#  ***** evaluating model prev_violation w/ sigma 1 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 29716.589606
#          Iterations: 22
#          Function evaluations: 70
#          Gradient evaluations: 58
#
#  ***** evaluating model prev_violation w/ sigma 2 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 29715.307534
#          Iterations: 23
#          Function evaluations: 102
#          Gradient evaluations: 89
#
#  ***** evaluating model prev_violation w/ sigma 4 *****
# Optimization terminated successfully.
#          Current function value: 29714.986844
#          Iterations: 23
#          Function evaluations: 31
#          Gradient evaluations: 31
#
#  ***** evaluating model prev_violation w/ sigma 8 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 29714.906661
#          Iterations: 23
#          Function evaluations: 107
#          Gradient evaluations: 94
#
#  ***** evaluating model prev_violation w/ sigma 16 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 29714.886615
#          Iterations: 23
#          Function evaluations: 86
#          Gradient evaluations: 71
#
#  ***** evaluating model filter_prev_violation w/ sigma 0.07 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 30056.784009
#          Iterations: 25
#          Function evaluations: 76
#          Gradient evaluations: 64
#
#  ***** evaluating model filter_prev_violation w/ sigma 0.13 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 29611.577228
#          Iterations: 25
#          Function evaluations: 96
#          Gradient evaluations: 80
#
#  ***** evaluating model filter_prev_violation w/ sigma 0.25 *****
# Optimization terminated successfully.
#          Current function value: 29407.377907
#          Iterations: 26
#          Function evaluations: 36
#          Gradient evaluations: 36
#
#  ***** evaluating model filter_prev_violation w/ sigma 0.5 *****
# Optimization terminated successfully.
#          Current function value: 29339.750457
#          Iterations: 26
#          Function evaluations: 36
#          Gradient evaluations: 36
#
#  ***** evaluating model filter_prev_violation w/ sigma 1 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 29321.896893
#          Iterations: 25
#          Function evaluations: 34
#          Gradient evaluations: 34
#
#  ***** evaluating model filter_prev_violation w/ sigma 2 *****
# Optimization terminated successfully.
#          Current function value: 29317.369581
#          Iterations: 26
#          Function evaluations: 35
#          Gradient evaluations: 35
#
#  ***** evaluating model filter_prev_violation w/ sigma 4 *****
# Optimization terminated successfully.
#          Current function value: 29316.233676
#          Iterations: 26
#          Function evaluations: 35
#          Gradient evaluations: 35
#
#  ***** evaluating model filter_prev_violation w/ sigma 8 *****
# Optimization terminated successfully.
#          Current function value: 29315.949444
#          Iterations: 26
#          Function evaluations: 35
#          Gradient evaluations: 35
#
#  ***** evaluating model filter_prev_violation w/ sigma 16 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 29315.878369
#          Iterations: 25
#          Function evaluations: 79
#          Gradient evaluations: 67
#
#  >>>> evaluating animal W061 <<<<
#
#  ***** evaluating model psytrack_features w/ sigma 0.07 *****
# Optimization terminated successfully.
#          Current function value: 26305.283070
#          Iterations: 24
#          Function evaluations: 38
#          Gradient evaluations: 38
#
#  ***** evaluating model psytrack_features w/ sigma 0.13 *****
# Optimization terminated successfully.
#          Current function value: 26255.012492
#          Iterations: 23
#          Function evaluations: 35
#          Gradient evaluations: 35
#
#  ***** evaluating model psytrack_features w/ sigma 0.25 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 26239.315022
#          Iterations: 23
#          Function evaluations: 36
#          Gradient evaluations: 36
#
#  ***** evaluating model psytrack_features w/ sigma 0.5 *****
# Optimization terminated successfully.
#          Current function value: 26234.888860
#          Iterations: 22
#          Function evaluations: 34
#          Gradient evaluations: 34
#
#  ***** evaluating model psytrack_features w/ sigma 1 *****
# Optimization terminated successfully.
#          Current function value: 26233.777957
#          Iterations: 22
#          Function evaluations: 34
#          Gradient evaluations: 34
#
#  ***** evaluating model psytrack_features w/ sigma 2 *****
# Optimization terminated successfully.
#          Current function value: 26233.499957
#          Iterations: 22
#          Function evaluations: 34
#          Gradient evaluations: 34
#
#  ***** evaluating model psytrack_features w/ sigma 4 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 
#          Iterations: 25
#          Function evaluations: 33
#          Gradient evaluations: 33
#
#  ***** evaluating model filter_prev_violation w/ sigma 4 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 23213.529493
#          Iterations: 24
#          Function evaluations: 65
#          Gradient evaluations: 53
#
#  ***** evaluating model filter_prev_violation w/ sigma 8 *****
# Optimization terminated successfully.
#          Current function value: 23213.322505
#          Iterations: 25
#          Function evaluations: 33
#          Gradient evaluations: 33
#
#  ***** evaluating model filter_prev_violation w/ sigma 16 *****
# Optimization terminated successfully.
#          Current function value: 23213.270750
#          Iterations: 25
#          Function evaluations: 33
#          Gradient evaluations: 33
#
#  >>>> evaluating animal W072 <<<<
#
#  ***** evaluating model psytrack_features w/ sigma 0.07 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 20530.685188
#          Iterations: 24
#          Function evaluations: 75
#          Gradient evaluations: 63
#
#  ***** evaluating model psytrack_features w/ sigma 0.13 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 20446.835896
#          Iterations: 25
#          Function evaluations: 39
#          Gradient evaluations: 39
#
#  ***** evaluating model psytrack_features w/ sigma 0.25 *****
# Optimization terminated successfully.
#          Current function value: 20419.648742
#          Iterations: 25
#          Function evaluations: 36
#          Gradient evaluations: 36
#
#  ***** evaluating model psytrack_features w/ sigma 0.5 *****
# Optimization terminated successfully.
#          Current function value: 20411.889624
# ...
#          Iterations: 24
#          Function evaluations: 90
#          Gradient evaluations: 78
#
#  ***** evaluating model prev_violation w/ sigma 16 *****
# Optimization terminated successfully.
#          Current function value: 19525.880192
#          Iterations: 25
#          Function evaluations: 40
#          Gradient evaluations: 40
#
#  ***** evaluating model filter_prev_violation w/ sigma 0.07 *****
# Optimization terminated successfully.
#          Current function value: 19135.899573
#          Iterations: 29
#          Function evaluations: 38
#          Gradient evaluations: 38
#
#  ***** evaluating model filter_prev_violation w/ sigma 0.13 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 18247.427837
#          Iterations: 27
#          Function evaluations: 77
#          Gradient evaluations: 65
#
#  ***** evaluating model filter_prev_violation w/ sigma 0.25 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 17899.230905
#          Iterations: 28
#          Function evaluations: 84
#          Gradient evaluations: 72
#
#  ***** evaluating model filter_prev_violation w/ sigma 0.5 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 17791.449601
#          Iterations: 26
#          Function evaluations: 56
#          Gradient evaluations: 52
#
#  ***** evaluating model filter_prev_violation w/ sigma 1 *****
# Optimization terminated successfully.
#          Current function value: 17763.598064
#          Iterations: 27
#          Function evaluations: 33
#          Gradient evaluations: 33
#
#  ***** evaluating model filter_prev_violation w/ sigma 2 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 17756.575051
#          Iterations: 26
#          Function evaluations: 92
#          Gradient evaluations: 80
#
#  ***** evaluating model filter_prev_violation w/ sigma 4 *****
# Optimization terminated successfully.
#          Current function value: 17754.815480
#          Iterations: 27
#          Function evaluations: 33
#          Gradient evaluations: 33
#
#  ***** evaluating model filter_prev_violation w/ sigma 8 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 17754.375348
#          Iterations: 26
#          Function evaluations: 91
#          Gradient evaluations: 79
#
#  ***** evaluating model filter_prev_violation w/ sigma 16 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 17754.265300
#          Iterations: 26
#          Function evaluations: 64
#          Gradient evaluations: 53
#
#  >>>> evaluating animal W089 <<<<
#
#  ***** evaluating model psytrack_features w/ sigma 0.07 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 34299.775261
#          Iterations: 22
#          Function evaluations: 38
#          Gradient evaluations: 38
#
#  ***** evaluating model psytrack_features w/ sigma 0.13 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 34201.523569
#          Iterations: 23
#          Function evaluations: 40
#          Gradient evaluations: 40
#
#  ***** evaluating model psytrack_features w/ sigma 0.25 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 34170.529797
#          Iterations: 22
#          Function evaluations: 108
#          Gradient evaluations: 95
#
#  ***** evaluating model psytrack_features w/ sigma 0.5 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 34161.763363
#          Iterations: 20
#          Function evaluations: 69
#          Gradient evaluations: 57
#
#  ***** evaluating model psytrack_features w/ sigma 1 *****
# Optimization terminated successfully.
#          Current function value: 34159.561229
#          Iterations: 21
#          Function evaluations: 35
#          Gradient evaluations: 35
#
#  ***** evaluating model psytrack_features w/ sigma 2 *****
# Optimization terminated successfully.
#          Current function value: 34159.010033
#          Iterations: 21
#          Function evaluations: 35
#          Gradient evaluations: 35
#
#  ***** evaluating model psytrack_features w/ sigma 4 *****
# Optimization terminated successfully.
#          Current function value: 34158.872193
#          Iterations: 21
#          Function evaluations: 35
#          Gradient evaluations: 35
#
#  ***** evaluating model psytrack_features w/ sigma 8 *****
# Optimization terminated successfully.
#          Current function value: 34158.837730
#          Iterations: 21
#          Function evaluations: 35
#          Gradient evaluations: 35
#
#  ***** evaluating model psytrack_features w/ sigma 16 *****
# Optimization terminated successfully.
#          Current function value: 34158.829114
#          Iterations: 21
#          Function evaluations: 35
#          Gradient evaluations: 35
#
#  ***** evaluating model prev_violation w/ sigma 0.07 *****
# Optimization terminated successfully.
#          Current function value: 28888.565013
#          Iterations: 32
#          Function evaluations: 46
#          Gradient evaluations: 46
#
#  ***** evaluating model prev_violation w/ sigma 0.13 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 28438.875830
#          Iterations: 25
#          Function evaluations: 67
#          Gradient evaluations: 59
#
#  ***** evaluating model prev_violation w/ sigma 0.25 *****
# Optimization terminated successfully.
#          Current function value: 28292.026497
#          Iterations: 27
#          Function evaluations: 40
#          Gradient evaluations: 40
#
#  ***** evaluating model prev_violation w/ sigma 0.5 *****
# Optimization terminated successfully.
#          Current function value: 28250.013287
#          Iterations: 26
#          Function evaluations: 40
#          Gradient evaluations: 40
#
#  ***** evaluating model prev_violation w/ sigma 1 *****
# Optimization terminated successfully.
#          Current function value: 28239.425389
#          Iterations: 27
#          Function evaluations: 38
#          Gradient evaluations: 38
#
#  ***** evaluating model prev_violation w/ sigma 2 *****
# Optimization terminated successfully.
#          Current function value: 28236.773067
#          Iterations: 25
#          Function evaluations: 35
#          Gradient evaluations: 35
#
#  ***** evaluating model prev_violation w/ sigma 4 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 28236.109651
#          Iterations: 25
#          Function evaluations: 35
#          Gradient evaluations: 35
#
#  ***** evaluating model prev_violation w/ sigma 8 *****
# Optimization terminated successfully.
#          Current function value: 28235.943776
#          Iterations: 27
#          Function evaluations: 35
#          Gradient evaluations: 35
#
#  ***** evaluating model prev_violation w/ sigma 16 *****
# Optimization terminated successfully.
#          Current function value: 28235.902306
#          Iterations: 27
#          Function evaluations: 35
#          Gradient evaluations: 35
#
#  ***** evaluating model filter_prev_violation w/ sigma 0.07 *****
# Optimization terminated successfully.
#          Current function value: 27704.730214
#          Iterations: 26
#          Function evaluations: 39
#          Gradient evaluations: 39
#
#  ***** evaluating model filter_prev_violation w/ sigma 0.13 *****
# Optimization terminated successfully.
#          Current function value: 26783.443316
#          Iterations: 28
#          Function evaluations: 38
#          Gradient evaluations: 38
#
#  ***** evaluating model filter_prev_violation w/ sigma 0.25 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 26441.556148
#          Iterations: 27
#          Function evaluations: 102
#          Gradient evaluations: 88
#
#  ***** evaluating model filter_prev_violation w/ sigma 0.5 *****
# Optimization terminated successfully.
#          Current function value: 26338.463648
#          Iterations: 25
#          Function evaluations: 35
#          Gradient evaluations: 35
#
#  ***** evaluating model filter_prev_violation w/ sigma 1 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 26312.057304
#          Iterations: 25
#          Function evaluations: 36
#          Gradient evaluations: 36
#
#  ***** evaluating model filter_prev_violation w/ sigma 2 *****
# Optimization terminated successfully.
#          Current function value: 26305.414386
#          Iterations: 26
#          Function evaluations: 35
#          Gradient evaluations: 35
#
#  ***** evaluating model filter_prev_violation w/ sigma 4 *****
# Optimization terminated successfully.
#          Current function value: 26303.751044
#          Iterations: 26
#          Function evaluations: 40
#          Gradient evaluations: 39
#
#  ***** evaluating model filter_prev_violation w/ sigma 8 *****
# Optimization terminated successfully.
#          Current function value: 26303.335044
#          Iterations: 26
#          Function evaluations: 32
#          Gradient evaluations: 32
#
#  ***** evaluating model filter_prev_violation w/ sigma 16 *****
# Optimization terminated successfully.
#          Current function value: 26303.231034
#          Iterations: 26
#          Function evaluations: 32
#          Gradient evaluations: 32
#
#  >>>> evaluating animal W094 <<<<
#
#  ***** evaluating model psytrack_features w/ sigma 0.07 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 20540.344652
#          Iterations: 21
#          Function evaluations: 85
#          Gradient evaluations: 73
#
#  ***** evaluating model psytrack_features w/ sigma 0.13 *****
# Optimization terminated successfully.
#          Current function value: 20462.145037
#          Iterations: 23
#          Function evaluations: 40
#          Gradient evaluations: 40
#
#  ***** evaluating model psytrack_features w/ sigma 0.25 *****
# Optimization terminated successfully.
#          Current function value: 20436.966057
#          Iterations: 23
#          Function evaluations: 41
#          Gradient evaluations: 41
#
#  ***** evaluating model psytrack_features w/ sigma 0.5 *****
# Optimization terminated successfully.
#          Current function value: 20429.795104
#          Iterations: 22
#          Function evaluations: 37
#          Gradient evaluations: 37
#
#  ***** evaluating model psytrack_features w/ sigma 1 *****
# Optimization terminated successfully.
#          Current function value: 20427.990236
#          Iterations: 22
#          Function evaluations: 37
#          Gradient evaluations: 37
#
#  ***** evaluating model psytrack_features w/ sigma 2 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 20427.538253
#          Iterations: 22
#          Function evaluations: 112
#          Gradient evaluations: 100
#
#  ***** evaluating model psytrack_features w/ sigma 4 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 20427.425209
#          Iterations: 21
#          Function evaluations: 88
#          Gradient evaluations: 76
#
#  ***** evaluating model psytrack_features w/ sigma 8 *****
# Optimization terminated successfully.
#          Current function value: 20427.396946
#          Iterations: 22
#          Function evaluations: 37
#          Gradient evaluations: 37
#
#  ***** evaluating model psytrack_features w/ sigma 16 *****
# Optimization terminated successfully.
#          Current function value: 20427.389879
#          Iterations: 22
#          Function evaluations: 37
#          Gradient evaluations: 37
#
#  ***** evaluating model prev_violation w/ sigma 0.07 *****
# Optimization terminated successfully.
#          Current function value: 20124.544585
#          Iterations: 26
#          Function evaluations: 46
#          Gradient evaluations: 46
#
#  ***** evaluating model prev_violation w/ sigma 0.13 *****
# Optimization terminated successfully.
#          Current function value: 20013.146357
#          Iterations: 24
#          Function evaluations: 41
#          Gradient evaluations: 41
#
#  ***** evaluating model prev_violation w/ sigma 0.25 *****
# Optimization terminated successfully.
#          Current function value: 19976.930828
#          Iterations: 24
#          Function evaluations: 39
#          Gradient evaluations: 39
#
#  ***** evaluating model prev_violation w/ sigma 0.5 *****
# Optimization terminated successfully.
#          Current function value: 19966.586020
#          Iterations: 24
#          Function evaluations: 37
#          Gradient evaluations: 37
#
#  ***** evaluating model prev_violation w/ sigma 1 *****
# Optimization terminated successfully.
#          Current function value: 19963.980186
#          Iterations: 23
#          Function evaluations: 36
#          Gradient evaluations: 36
#
#  ***** evaluating model prev_violation w/ sigma 2 *****
# Optimization terminated successfully.
#          Current function value: 19963.327488
#          Iterations: 23
#          Function evaluations: 36
#          Gradient evaluations: 36
#
#  ***** evaluating model prev_violation w/ sigma 4 *****
# Optimization terminated successfully.
#          Current function value: 19963.164236
#          Iterations: 23
#          Function evaluations: 36
#          Gradient evaluations: 36
#
#  ***** evaluating model prev_violation w/ sigma 8 *****
# Optimization terminated successfully.
#          Current function value: 19963.123418
#          Iterations: 23
#          Function evaluations: 36
#          Gradient evaluations: 36
#
#  ***** evaluating model prev_violation w/ sigma 16 *****
# Optimization terminated successfully.
#          Current function value: 19963.113213
#          Iterations: 23
#          Function evaluations: 36
#          Gradient evaluations: 36
#
#  ***** evaluating model filter_prev_violation w/ sigma 0.07 *****
# Optimization terminated successfully.
#          Current function value: 19776.959134
#          Iterations: 26
#          Function evaluations: 42
#          Gradient evaluations: 42
#
#  ***** evaluating model filter_prev_violation w/ sigma 0.13 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 19419.710195
#          Iterations: 25
#          Function evaluations: 67
#          Gradient evaluations: 55
#
#  ***** evaluating model filter_prev_violation w/ sigma 0.25 *****
# Optimization terminated successfully.
#          Current function value: 19261.175316
#          Iterations: 24
#          Function evaluations: 32
#          Gradient evaluations: 32
#
#  ***** evaluating model filter_prev_violation w/ sigma 0.5 *****
# Optimization terminated successfully.
#          Current function value: 19209.617645
#          Iterations: 24
#          Function evaluations: 32
#          Gradient evaluations: 32
#
#  ***** evaluating model filter_prev_violation w/ sigma 1 *****
# Optimization terminated successfully.
#          Current function value: 19196.093754
#          Iterations: 24
#          Function evaluations: 34
#          Gradient evaluations: 34
#
#  ***** evaluating model filter_prev_violation w/ sigma 2 *****
# Optimization terminated successfully.
#          Current function value: 19192.670370
#          Iterations: 24
#          Function evaluations: 57
#          Gradient evaluations: 56
#
#  ***** evaluating model filter_prev_violation w/ sigma 4 *****
# Optimization terminated successfully.
#          Current function value: 19191.811827
#          Iterations: 24
#          Function evaluations: 36
#          Gradient evaluations: 36
#
#  ***** evaluating model filter_prev_violation w/ sigma 8 *****
# Optimization terminated successfully.
#          Current function value: 19191.597022
#          Iterations: 24
#          Function evaluations: 32
#          Gradient evaluations: 32
#
#  ***** evaluating model filter_prev_violation w/ sigma 16 *****
# Optimization terminated successfully.
#          Current function value: 19191.543310
#          Iterations: 24
#          Function evaluations: 32
#          Gradient evaluations: 32

# %%
mvc = ModelVisualizerCompare(experiment)
df = mvc.find_best_fit(group="model_name")
for model_name, model_df in df.groupby("model_name"):
    mvc.plot_sigma_summary(model_df, title=f"{model_name} fit sigma summary")

# %%
fig, ax = plt.subplots(1, 1, figsize=(8, 5))
mvc.plot_model_comparison(
    hue=None,
    ax=ax,
    order=["psytrack_features", "prev_violation", "filter_prev_violation"],
    ylim=(0, 0.6),
)

# %%
fig, ax = plt.subplots(1, 1, figsize=(8, 5))
mvc.plot_model_comparison(
    hue="animal_id",
    ax=ax,
    order=["psytrack_features", "prev_violation", "filter_prev_violation"],
    ylim=(0, 0.6),
)

# %%
fig, ax = plt.subplots(1, 1, figsize=(8, 5))
mvc.plot_model_comparison(
    hue="prev_violation_tau",
    ax=ax,
    order=["psytrack_features", "prev_violation", "filter_prev_violation"],
    ylim=(0, 0.6),
)

# %%
mvc.plot_train_and_test_nll(
    order=["psytrack_features", "prev_violation", "filter_prev_violation"]
)
