# %% [markdown]
# ## Compare Prev Violation & Psytrack
#
# > Written by Jess Breda September 2023
#
# For this notebook, I am writing based on updated and debugged macro search now that I am no longer accidentally fitting to all animals at once
#
# The goals for this NB are
#
# 1. Write a flexible design matrix generator for either prev_violation (given animal_id, best tau) or psytrack classic regressors.
#
# 2. Iterate over sigmas, models and fit/test for each animal
#
# 3. Compare to a "null" model in bits/trial space.

# %%
import pathlib
import platform
import sys
[
    sys.path.append(str(folder))
    for folder in pathlib.Path("../src/").iterdir()
    if folder.is_dir()
]
import numpy as np
from matplotlib import pyplot as plt
import seaborn as sns
import pandas as pd

sns.set_context("talk")
import pathlib
import platform
import sys
[
    sys.path.append(str(folder))
    for folder in pathlib.Path("../src/").iterdir()
    if folder.is_dir()
]
import numpy as np
from matplotlib import pyplot as plt
import seaborn as sns
import pandas as pd
from collections import Counter

sns.set_context("talk")

from sklearn.model_selection import train_test_split

from generate_design_matrix import ExpFilter
from get_rat_data import *
from multiclass_logistic_regression import MultiClassLogisticRegression
MODE = "local"

# settings
# %load_ext autoreload
# %autoreload 2

# %%
class DesignMatrixGeneratorCompareClassicViolation:
    def __init__(self, animal_id, verbose=True):
        self.animal_id = animal_id
        self.verbose = verbose

    @staticmethod
    def normalize_column(col):
        return (col - col.mean()) / col.std()

    def generate_design_matrix(
        self,
        df,
        feature_mode,
        tau,
        return_labels=True,
        drop_session_column=False,
    ):
        """
        Function to generate flexibledesign matrix given a dataframe
        with violations tracked. In this case "base" means using the
        same regressors as Nick Roy did in Psytrack, but adjusted to
        take into account 3 choice options (L,R, Violation).

        here, we are adding prev_violation fileted given a specific
        tau for each animal that was previously searched

        N = number of trials
        D = number of features
        C = number of classes, in this case 3 (L, R, Violation)

        params
        ------
        df : pd.DataFrame
            dataframe with columns `s_a` `s_b` `session`, `violation`
            `correct_side` and `choice`, likely generated by
            get_rat_viol_data()
        tau : float
            tau for exponential filter for prev_violation column
        feature_mode : str
            model to use for generating design matrix either
            "basic" or "violation" or "violation_filtered"
        return_label : bool (default = True)
            whether to return one-hot encoded choice labels
        drop_session_column : bool (default = False)
            whether to drop 'session' column. should be set to
            false if doing session based train/test split
            following design matrix generation

        returns
        -------
        X : pd.DataFrame, shape (N, D + 1)
            design matrix with regressors for s_a, s_b,
            prev sound avg, correct side and choice info,
            normalized to standard normal with bias column added
        Y : np.ndarray, shape (N, C), where C = 3 if return_labels=True
            one-hot encoded choice labels for each trial as left,
            right or violation
        """
        # Initialize
        X = pd.DataFrame()
        stim_cols = ["s_a", "s_b"]
        X["session"] = df.session

        # Masks- if first trial in a session and/or previous trial
        # was a violation, "prev" variables get set to 0
        session_boundaries_mask = df["session"].diff() == 0
        X["prev_violation"] = (
            df["violation"].shift() * session_boundaries_mask
        ).fillna(0)
        prev_violation_mask = X["prev_violation"] == 0

        # # Violation Exp Filter
        if feature_mode == "violation_filtered":
            self.exp_filter = ExpFilter(
                tau=tau, verbose=self.verbose, column="prev_violation"
            )
            self.exp_filter.apply_filter_to_dataframe(X)
            X.drop(columns=["prev_violation"], inplace=True)

        # Stimuli (s_a, s_b) get normalized
        for col in stim_cols:
            X[stim_cols] = self.normalize_column(df[stim_cols])

        # Average previous stimulus (s_a, s_b) loudness
        X["prev_sound_avg"] = df[stim_cols].shift().mean(axis=1)
        X["prev_sound_avg"] = self.normalize_column(X["prev_sound_avg"])
        X["prev_sound_avg"] *= session_boundaries_mask * prev_violation_mask

        # Prev correct side (L, R) (0, 1) -> (-1, 1),
        X["prev_correct"] = (
            df.correct_side.replace({0: -1}).astype(int).shift()
            * session_boundaries_mask
            * prev_violation_mask
        )

        # prev choice regressors (L, R, V) (0, 1, Nan) -> (-1, 1, 0),
        X["prev_choice"] = (
            df.choice.replace({0: -1}).fillna(0).astype(int).shift()
            * session_boundaries_mask
        )

        if feature_mode == "base":
            X.drop(columns=["prev_violation"], inplace=True)

        X.fillna(0, inplace=True)  # remove nan from shift()
        X.insert(0, "bias", 1)  # add bias column

        if drop_session_column:
            X.drop(columns=["session"], inplace=True)

        if return_labels:
            Y = self.one_hot_encode_labels(df)
            return X, Y
        else:
            return X

    @staticmethod
    def one_hot_encode_labels(df):
        """
        Function to one-hot encode choice labels for each trial as
        left, right or violation (C = 3)

        params
        ------
        df : pd.DataFrame
            dataframe with columns `choice` likely generated by
            get_rat_viol_data()

        returns
        -------
        Y : np.ndarray, shape (N, C), where C = 3
            one-hot encoded choice labels for each trial as left,
            right or violation
        """

        Y = pd.get_dummies(df["choice"], "choice", dummy_na=True).to_numpy(copy=True)
        return Y

    def get_train_test_sessions(self, df, test_size, random_state=45):
        """
        This function will return a list of sessions to use for training
        and testing respectively. To apply, see function
        see apply_session_train_test_split()


        Parameters:
        -----------
        df : pd.DataFrame
            dataframe with `sessions` column
        test_size : float
            Proportion of data to use for test set
        """
        unique_sessions = df["session"].unique()
        train_sessions, test_sessions = train_test_split(
            unique_sessions, test_size=test_size, random_state=random_state
        )

        self.train_sessions = train_sessions
        self.test_sessions = test_sessions
        self.random_state = random_state
        self.test_size = test_size

    def apply_session_train_test_split(self, X, Y):
        """
        train_sessions = np.array
            sessions for the
        test_values = np.array indices for the test values

        """
        # check if train/test sessions have been set
        if not hasattr(self, "train_sessions"):
            raise ValueError(
                "train_sessions and test_sessions have not been set. "
                "Please run get_train_test_sessions() first."
            )

        # Filter rows based on session values for X
        X_train = X[X["session"].isin(self.train_sessions)].copy()
        X_test = X[X["session"].isin(self.test_sessions)].copy()

        # Filter rows based on session values for Y
        # Assuming the index of Y corresponds to that of X
        Y_train = Y[X["session"].isin(self.train_sessions).values]
        Y_test = Y[X["session"].isin(self.test_sessions).values]

        X_train.drop(columns=["session"], inplace=True)
        X_test.drop(columns=["session"], inplace=True)

        self.X_train = X_train
        self.X_test = X_test
        self.Y_train = Y_train
        self.Y_test = Y_test

        return X_train, X_test, Y_train, Y_test

    def fit_null_model(self, animal_df):
        """
        Fits a null model and returns the log likelihood.

        Parameters:
        animal_df: DataFrame with choice and session data.

        Returns:
        float:
        """
        # Convert nan (violation) -> 2, L = 0, R =1
        choice = animal_df.choice.fillna(2)
        test_labels = choice[animal_df["session"].isin(self.test_sessions).values]

        # Count occurrences of each label
        label_counts = Counter(test_labels)

        # Calculate the total number of observations
        total_count = len(test_labels)

        # Calculate observed probabilities
        probabilities = {
            label: count / total_count for label, count in label_counts.items()
        }

        # Calculate the log-likelihood based on the observed probabilities
        log_likelihood = 0
        for label, prob in probabilities.items():
            log_likelihood += label_counts[label] * np.log(prob)
        return {
            "nll": -log_likelihood,
            "p_left": probabilities[0],
            "n_left": label_counts[0],
            "p_right": probabilities[1],
            "n_right": label_counts[1],
            "p_viol": probabilities[2],
            "n_viol": label_counts[2],
            "n_test_trials": total_count,
            "n_train_trials": len(animal_df) - total_count,
        }

    def store_null_info(self, animal_df):
        null_model = self.fit_null_model(animal_df)

        animal_info_df = pd.DataFrame(
            {
                "animal_id": [self.animal_id],
                "nll": [null_model["nll"]],
                "test_size": [self.test_size],
                "random_state": [self.random_state],
                "p_violation": [null_model["p_viol"]],
                "n_violation": [null_model["n_viol"]],
                "p_left": [null_model["p_left"]],
                "n_left": [null_model["n_left"]],
                "p_right": [null_model["p_right"]],
                "n_right": [null_model["n_right"]],
                "n_test_trials": [null_model["n_test_trials"]],
                "test_sessions": [self.test_sessions],
                "n_train_trials": [null_model["n_train_trials"]],
                "train_sessions": [self.train_sessions],
            }
        )
        # will be concat in experiment loop
        return animal_info_df

# %%
animal_id = "W065"
df = get_rat_viol_data(animal_id)
dmg = DesignMatrixGeneratorCompareClassicViolation(animal_id=animal_id)
dmg.get_train_test_sessions(df, test_size=0.2, random_state=45)
dmg.store_null_info(df)
# Out:
# returning viol data for W065
#   animal_id           nll  test_size  random_state  p_violation  n_violation
# 0      W065  10886.977495        0.2            45     0.248734         2505  \
#
#      p_left  n_left   p_right  n_right  n_test_trials
# 0  0.359944    3625  0.391322     3941          10071  \
#
#                                        test_sessions  n_train_trials
# 0  [46, 73, 41, 59, 26, 14, 154, 81, 4, 45, 135, ...           40034  \
#
#                                       train_sessions
# 0  [98, 175, 139, 68, 176, 117, 136, 30, 62, 84, ...

# %%
class SigmaSearchCompareClassicViolation:
    def __init__(self, params):
        self.animals = params["animals"]
        self.sigmas = params["sigmas"]
        self.model_names = params["model_names"]
        self.random_state = params["random_state"]
        self.test_size = params["test_size"]
        self.taus = self.get_taus()
        self.df = get_rat_viol_data(animal_ids=self.animals)
        self.stored_fits = []
        self.null_models = []

        if self.animals is None:
            self.animals = self.df.animal_id.unique()
        self.n_animals = len(self.animals)

    def run(self):
        for animal in self.animals:
            print(f"\n\n !!!!! evaluating animal {animal} !!!!!\n\n")
            if self.df.animal_id.nunique() > 1:
                # Load in data for specific animal
                animal_df = self.df.query("animal_id == @animal and training_stage > 2")
            else:
                animal_df = self.df.query("training_stage > 2")

            # Create a DesignMatrixGenerator object & get train/test sessions for animal
            dmg = DesignMatrixGeneratorCompareClassicViolation(
                verbose=False, animal_id=animal
            )
            dmg.get_train_test_sessions(
                animal_df, test_size=self.test_size, random_state=self.random_state
            )

            # store train/test info and null fit
            self.null_models.append(dmg.store_null_info(animal_df))

            # get tau for this animal
            tau = self.taus.query("animal_id == @animal")["tau"].values[0]

            # Iterate over sigma/tau combinations
            for sigma in self.sigmas:
                for model_name in self.model_names:
                    # Generate design matrix & create train/test splits
                    X, Y = dmg.generate_design_matrix(
                        animal_df,
                        tau=tau,
                        feature_mode=model_name,
                        return_labels=True,
                    )
                    print(
                        f"model : {model_name}, sigma: {sigma}, tau: {tau}, size of X: {X.shape}, Y: {Y.shape}"
                    )
                    (
                        X_train,
                        X_test,
                        Y_train,
                        Y_test,
                    ) = dmg.apply_session_train_test_split(X, Y)

                    # Fit model & evaluate
                    model = MultiClassLogisticRegression(sigma=sigma)
                    W_fit = model.fit(X_train, Y_train)
                    nll = model.eval(X_test, Y_test)

                    # Store model_fits
                    self.store(
                        animal,
                        model_name,
                        nll,
                        sigma,
                        tau,
                        W_fit,
                        dmg,
                    )

        self.model_fits = pd.concat(self.stored_fits, ignore_index=True)
        self.null_fits = pd.concat(self.null_models, ignore_index=True)
        return self.model_fits, self.null_fits

    def store(self, animal, model_name, nll, sigma, tau, W_fit, dmg):
        # Create a DataFrame for this iteration
        iter_df = pd.DataFrame(
            {
                "animal_id": [animal],
                "model_name": [model_name],
                "nll": [nll],
                "sigma": [sigma],
                "tau": [tau],
                "features": [list(dmg.X_test.columns)],
                "weights": [list(W_fit)],  # Convert numpy array to list
            }
        )
        # Append to the list of stored fits
        self.stored_fits.append(iter_df)

    ## WRANGLING ##

    def get_taus(self):
        """Load df with tau values for each animal
        that were found in macro sweep"""
        taus_df = pd.read_csv(
            "/Users/jessbreda/Desktop/github/animal-learning/data/results/prev_violation_tau.csv"
        )
        return taus_df

    def find_best_fit(self, group="model_name"):
        # if group is model name, will find the best sigma for
        # each tau tested.
        # if group is sigma, will find the best model name for
        # each sigma tested.

        best_fit_dfs = []

        for animal_id, sub_df in self.model_fits.groupby(["animal_id"]):
            best_idx = sub_df.groupby(group)["nll"].idxmin()
            best_fit_df = sub_df.loc[best_idx][
                ["animal_id", "model_name", "sigma", "tau", "nll"]
            ]
            best_fit_dfs.append(best_fit_df)

        return pd.concat(best_fit_dfs, ignore_index=True)

    def query_min_nll(self, animal_id, model_name):
        """
        Query the row with the minimum NLL for a given animal_id and model_name
        """
        query = self.model_fits.query(
            "animal_id == @animal_id and model_name == @model_name"
        ).sort_values(by="nll", ascending=True)

        return query.iloc[0]

    def compute_bits_per_trial_df(self):
        """
        Wrapper function to compute the number of bits per trial
        for each animal and model relative to the null model
        and return a dataframe with the results
        """
        combined_df = self._merge_null_and_fit_model_dfs()

        bits_per_trial_df = (
            combined_df.groupby("animal_id")
            .apply(self._calculate_bits_per_trial)
            .reset_index(drop=True)
        )

        self.bits_per_trial_df = bits_per_trial_df
        return bits_per_trial_df

    def _merge_null_and_fit_model_dfs(self):
        """
        Merge the null and model fit dataframes together
        with respect to negative log-like
        """

        # clean up dfs for concating
        self.null_fits["model_name"] = "null"
        best_fits = self.find_best_fit(
            group=["animal_id", "model_name"]
        )  # find best sigma for each animal, model

        # concat nll for null and fit models
        combined_df = pd.concat(
            [
                self.null_fits[["animal_id", "nll", "model_name"]],
                best_fits[["animal_id", "nll", "model_name"]],
            ]
        )

        # add in number of test trials for each animal
        combined_df = pd.merge(
            combined_df,
            self.null_fits[["animal_id", "n_test_trials"]],
            on="animal_id",
            how="left",
        )

        combined_df = pd.merge(
            combined_df, best_fits[["animal_id", "tau"]], on="animal_id", how="left"
        )

        # add in log-like (for easier bit calculation)
        combined_df["log_like"] = combined_df["nll"] * -1

        return combined_df

    def _calculate_bits_per_trial(self, group):
        """
        Calculate the number of bits per trial relative for each model
        relative to the null model (L_0) for each animal (group)

        bit/trial = (log model - log null model) / (n_test_trials * log(2))

        params
        ------
        group : pd.DataFrame
            groupby object with columns `animal_id`, `model_name`,
            `n_test_trials` and `ll` (log-likelihood)
            grouped by animal_id
        """
        bits_per_trial = []

        n_test_trials = group["n_test_trials"].iloc[
            0
        ]  # assumes each animal has same test size

        null_ll = group.query("model_name == 'null'")["log_like"].iloc[0]

        for _, row in group.iterrows():
            if row["model_name"] == "null":
                bits_per_trial.append((null_ll) / (n_test_trials * np.log(2)))
            else:
                bits_per_trial.append(
                    (row["log_like"] - null_ll) / (n_test_trials * np.log(2))
                )

        group["bits_per_trial"] = bits_per_trial
        return group

    ## PLOTTING ##

    def plot_nll_over_sigmas_by_animal(self, df=None):
        if df is None:
            df = self.find_best_fit(group="sigma")

        n_animals = df.animal_id.nunique()
        fig, ax = plt.subplots(
            n_animals, 1, figsize=(15, 5 * n_animals), sharex=True, sharey=True
        )

        df["is_min"] = df.groupby("animal_id")["nll"].transform(lambda x: x == x.min())

        if n_animals == 1:
            ax = [ax]

        for idx, (animal_id, sub_df) in enumerate(df.groupby("animal_id")):
            plt.xticks(rotation=90)

            current_ax = ax[idx] if n_animals > 1 else ax[0]

            sns.scatterplot(
                x="sigma",
                y="nll",
                data=sub_df,
                ax=current_ax,
                hue="is_min",
                palette=["grey", "red"],
            )

            # aesthetics
            plt.xticks(rotation=90)
            sns.despine()
            current_ax.legend().remove()
            current_ax.set(
                ylabel="Test NLL",
                title=f"Animal {animal_id}",
            )
            # if on the last plot, add the x-axis label
            if idx == n_animals - 1:
                current_ax.set(xlabel="Sigma")
            else:
                current_ax.set(xlabel="")

        return None

    def plot_class_weights(self, animal_id, model_name):
        """
        Wrapper function to plot class weights for a given animal and model
        """
        row = self.query_min_nll(animal_id, model_name)
        self._plot_class_weights(
            row["features"], np.array(row["weights"]), title=f"{animal_id} {model_name}"
        )

    def _plot_class_weights(self, feature_names, W_fit, title=""):
        """
        Internal function to plot the weights for each feature and class as bar charts.
        """
        D, C = W_fit.shape
        classes = ["L", "R", "V"]

        weight_data = [
            {"Weight": W_fit[d, c], "Feature": feature_names[d], "Class": classes[c]}
            for c in range(C)
            for d in range(D)
        ]
        df_weights = pd.DataFrame(weight_data)

        fig, ax = plt.subplots(figsize=(15, 6))
        ax.axhline(y=0, color="black")
        sns.barplot(x="Feature", y="Weight", hue="Class", data=df_weights, ax=ax)
        plt.xticks(rotation=45)
        plt.legend(loc="upper left")
        plt.title(title)

    def plot_model_comparison(
        self, type="point", hue=None, ax=None, ylim=None, **kwargs
    ):
        """
        Plot the model comparison for each animal
        """

        if ax is None:
            fig, ax = plt.subplots(figsize=(10, 5))

        if not hasattr(self, "bits_per_trial_df"):
            self.compute_bits_per_trial_df()

        if type == "point":
            sns.pointplot(
                data=self.bits_per_trial_df.query("model_name != 'null'"),
                x="model_name",
                y="bits_per_trial",
                hue=hue,
                ax=ax,
                **kwargs,
            )
        elif type == "bar":
            sns.barplot(
                data=self.bits_per_trial_df.query("model_name != 'null'"),
                x="model_name",
                y="bits_per_trial",
                hue=hue,
                ax=ax,
                **kwargs,
            )

        if hue == "animal_id":
            ax.legend().remove()
        if hue == "tau":
            ax.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.0)
        plt.xlabel("Model")
        plt.ylabel("Bits/Trial")

        if ylim is not None:
            ax.set(ylim=ylim)

        return None

# %%
params = {
    "animals": None,
    "sigmas": [0.13, 0.25, 0.5, 1, 2, 4, 8, 16],
    "model_names": ["base", "violation", "violation_filtered"],
    "random_state": 47,
    "test_size": 0.25,
}

# params = {
#     "animals": ["W065", "W078"],
#     "sigmas": [2, 4],  # [0.13, 0.25, 0.5, 1, 2, 4, 8, 16],
#     "model_names": ["base", "violation", "violation_filtered"],
#     "random_state": 47,
#     "test_size": 0.25,
# }
experiment = SigmaSearchCompareClassicViolation(params)
# Out:
# returning viol dataset for all animals

# %%
model_fits, null_fits = experiment.run()
# Out:
#  !!!!! evaluating animal W051 !!!!!
#
#
# model : base, sigma: 0.13, tau: 6, size of X: (55433, 7), Y: (55433, 3)
# Optimization terminated successfully.
#          Current function value: 39058.881852
#          Iterations: 22
#          Function evaluations: 37
#          Gradient evaluations: 37
# model : violation, sigma: 0.13, tau: 6, size of X: (55433, 8), Y: (55433, 3)
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 38429.109681
#          Iterations: 23
#          Function evaluations: 79
#          Gradient evaluations: 67
# model : violation_filtered, sigma: 0.13, tau: 6, size of X: (55433, 8), Y: (55433, 3)
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 38136.723851
#          Iterations: 24
#          Function evaluations: 71
#          Gradient evaluations: 60
# model : base, sigma: 0.25, tau: 6, size of X: (55433, 7), Y: (55433, 3)
# Optimization terminated successfully.
#          Current function value: 39041.492792
#          Iterations: 22
#          Function evaluations: 37
#          Gradient evaluations: 37
# model : violation, sigma: 0.25, tau: 6, size of X: (55433, 8), Y: (55433, 3)
# Optimization terminated successfully.
#          Current function value: 38392.126952
#          Iterations: 24
#          Function evaluations: 36
#          Gradient evaluations: 36
# model : violation_filtered, sigma: 0.25, tau: 6, size of X: (55433, 8), Y: (55433, 3)
# Optimization terminated successfully.
#          Current function value: 37960.083698
#          Iterations: 25
#          Function evaluations: 35
#          Gradient evaluations: 35
# model : base, sigma: 0.5, tau: 6, size of X: (55433, 7), Y: (55433, 3)
# Optimization terminated successfully.
#          Current function value: 39036.604114
#          Iterations: 20
#          Function evaluations: 35
#          Gradient evaluations: 35
# model : violation, sigma: 0.5, tau: 6, size of X: (55433, 8), Y: (55433, 3)
# Optimization terminated successfully.
#          Current function value: 38381.589435
#          Iterations: 23
#          Function evaluations: 35
#          Gradient evaluations: 35
# model : violation_filtered, sigma: 0.5, tau: 6, size of X: (55433, 8), Y: (55433, 3)
# Optimization terminated successfully.
#          Current function value: 37900.419117
#          Iterations: 24
#          Function evaluations: 34
#          Gradient evaluations: 34
# model : base, sigma: 1, tau: 6, size of X: (55433, 7), Y: (55433, 3)
# Optimization terminated successfully.
#          Current function value: 39035.378140
#          Iterations: 20
#          Function evaluations: 35
#          Gradient evaluations: 35
# model : violation, sigma: 1, tau: 6, size of X: (55433, 8), Y: (55433, 3)
# Optimization terminated successfully.
#          Current function value: 38378.936966
#          Iterations: 23
#          Function evaluations: 35
#          Gradient evaluations: 35
# model : violation_filtered, sigma: 1, tau: 6, size of X: (55433, 8), Y: (55433, 3)
# Optimization terminated successfully.
#          Current function value: 37884.582677
#          Iterations: 24
#          Function evaluations: 34
#          Gradient evaluations: 34
# model : base, sigma: 2, tau: 6, size of X: (55433, 7), Y: (55433, 3)
# Optimization terminated successfully.
#          Current function value: 39035.071408
#          Iterations: 20
#          Function evaluations: 35
#          Gradient evaluations: 35
# model : violation, sigma: 2, tau: 6, size of X: (55433, 8), Y: (55433, 3)
# Optimization terminated successfully.
#          Current function value: 38378.272708
#          Iterations: 23
#          Function evaluations: 35
#          Gradient evaluations: 35
# model : violation_filtered, sigma: 2, tau: 6, size of X: (55433, 8), Y: (55433, 3)
# Optimization terminated successfully.
#          Current function value: 37880.561497
#          Iterations: 24
#          Function evaluations: 34
#          Gradient evaluations: 34
# model : base, sigma: 4, tau: 6, size of X: (55433, 7), Y: (55433, 3)
# Optimization terminated successfully.
#          Current function value: 39034.994710
#          Iterations: 20
#          Function evaluations: 35
#          Gradient evaluations: 35
# model : violation, sigma: 4, tau: 6, size of X: (55433, 8), Y: (55433, 3)
# Optimization terminated successfully.
#          Current function value: 38378.106572
#          Iterations: 23
#          Function evaluations: 35
#          Gradient evaluations: 35
# model : violation_filtered, sigma: 4, tau: 6, size of X: (55433, 8), Y: (55433, 3)
# Optimization terminated successfully.
#          Current function value: 37879.552245
#          Iterations: 24
#          Function evaluations: 34
#          Gradient evaluations: 34
# model : base, sigma: 8, tau: 6, size of X: (55433, 7), Y: (55433, 3)
# Optimization terminated successfully.
#          Current function value: 39034.975535
#          Iterations: 20
#          Function evaluations: 35
#          Gradient evaluations: 35
# model : violation, sigma: 8, tau: 6, size of X: (55433, 8), Y: (55433, 3)
# Optimization terminated successfully.
#          Current function value: 38378.065034
#          Iterations: 23
#          Function evaluations: 35
#          Gradient evaluations: 35
# model : violation_filtered, sigma: 8, tau: 6, size of X: (55433, 8), Y: (55433, 3)
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 37879.299683
#          Iterations: 23
#          Function evaluations: 67
#          Gradient evaluations: 55
# model : base, sigma: 16, tau: 6, size of X: (55433, 7), Y: (55433, 3)
# Optimization terminated successfully.
#          Current function value: 39034.970741
#          Iterations: 20
#          Function evaluations: 35
#          Gradient evaluations: 35
# model : violation, sigma: 16, tau: 6, size of X: (55433, 8), Y: (55433, 3)
# Optimization terminated successfully.
#          Current function value: 38378.054649
#          Iterations: 23
#          Function evaluations: 35
#          Gradient evaluations: 35
# model : violation_filtered, sigma: 16, tau: 6, size of X: (55433, 8), Y: (55433, 3)
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 37879.236527
#          Iterations: 23
#          Function evaluations: 64
#          Gradient evaluations: 52
#
#
#  !!!!! evaluating animal W060 !!!!!
#
#
# model : base, sigma: 0.13, tau: 4, size of X: (43389, 7), Y: (43389, 3)
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 28447.800636
#          Iterations: 21
#          Function evaluations: 35
#          Gradient evaluations: 35
# model : violation, sigma: 0.13, tau: 4, size of X: (43389, 8), Y: (43389, 3)
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 27831.955495
#          Iterations: 25
#          Function evaluations: 39
#          Gradient evaluations: 39
# model : violation_filtered, sigma: 0.13, tau: 4, size of X: (43389, 8), Y: (43389, 3)
# Optimization terminated successfully.
#          Current function value: 27731.293850
#          Iterations: 25
#          Function evaluations: 39
#          Gradient evaluations: 39
# model : base, sigma: 0.25, tau: 4, size of X: (43389, 7), Y: (43389, 3)
# Optimization terminated successfully.
#          Current function value: 28409.252557
#          Iterations: 21
#          Function evaluations: 35
#          Gradient evaluations: 35
# model : violation, sigma: 0.25, tau: 4, size of X: (43389, 8), Y: (43389, 3)
# Optimization terminated successfully.
#          Current function value: 27764.442247
#          Iterations: 26
#          Function evaluations: 39
#          Gradient evaluations: 39
# model : violation_filtered, sigma: 0.25, tau: 4, size of X: (43389, 8), Y: (43389, 3)
# Optimization terminated successfully.
#          Current function value: 27545.868764
#          Iterations: 25
#          Function evaluations: 38
#          Gradient evaluations: 38
# model : base, sigma: 0.5, tau: 4, size of X: (43389, 7), Y: (43389, 3)
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 28398.362346
#          Iterations: 21
#          Function evaluations: 34
#          Gradient evaluations: 34
# model : violation, sigma: 0.5, tau: 4, size of X: (43389, 8), Y: (43389, 3)
# Optimization terminated successfully.
#          Current function value: 27745.059293
#          Iterations: 25
#          Function evaluations: 38
#          Gradient evaluations: 38
# model : violation_filtered, sigma: 0.5, tau: 4, size of X: (43389, 8), Y: (43389, 3)
# Optimization terminated successfully.
#          Current function value: 27483.078976
#          Iterations: 24
#          Function evaluations: 36
#          Gradient evaluations: 36
# model : base, sigma: 1, tau: 4, size of X: (43389, 7), Y: (43389, 3)
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 28395.627616
#          Iterations: 20
#          Function evaluations: 63
#          Gradient evaluations: 51
# model : violation, sigma: 1, tau: 4, size of X: (43389, 8), Y: (43389, 3)
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 27740.169728
#          Iterations: 24
#          Function evaluations: 105
#          Gradient evaluations: 94
# model : violation_filtered, sigma: 1, tau: 4, size of X: (43389, 8), Y: (43389, 3)
# Optimization terminated successfully.
#          Current function value: 27466.376921
#          Iterations: 24
#          Function evaluations: 36
#          Gradient evaluations: 36
# model : base, sigma: 2, tau: 4, size of X: (43389, 7), Y: (43389, 3)
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 28394.943169
#          Iterations: 21
#          Function evaluations: 85
#          Gradient evaluations: 73
# model : violation, sigma: 2, tau: 4, size of X: (43389, 8), Y: (43389, 3)
# Optimization terminated successfully.
#          Current function value: 27738.944564
#          Iterations: 25
#          Function evaluations: 37
#          Gradient evaluations: 37
# model : violation_filtered, sigma: 2, tau: 4, size of X: (43389, 8), Y: (43389, 3)
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 27462.133018
#          Iterations: 23
#          Function evaluations: 84
#          Gradient evaluations: 72
# model : base, sigma: 4, tau: 4, size of X: (43389, 7), Y: (43389, 3)
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 28394.772009
#          Iterations: 21
#          Function evaluations: 78
#          Gradient evaluations: 68
# model : violation, sigma: 4, tau: 4, size of X: (43389, 8), Y: (43389, 3)
# Optimization terminated successfully.
#          Current function value: 27738.638099
#          Iterations: 25
#          Function evaluations: 37
#          Gradient evaluations: 37
# model : violation_filtered, sigma: 4, tau: 4, size of X: (43389, 8), Y: (43389, 3)
# Optimization terminated successfully.
#          Current function value: 27461.067671
#          Iterations: 24
#          Function evaluations: 36
#          Gradient evaluations: 36
# model : base, sigma: 8, tau: 4, size of X: (43389, 7), Y: (43389, 3)
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 28394.729216
#          Iterations: 21
#          Function evaluations: 79
#          Gradient evaluations: 68
# model : violation, sigma: 8, tau: 4, size of X: (43389, 8), Y: (43389, 3)
# Optimization terminated successfully.
#          Current function value: 27738.561472
#          Iterations: 25
#          Function evaluations: 37
#          Gradient evaluations: 37
# model : violation_filtered, sigma: 8, tau: 4, size of X: (43389, 8), Y: (43389, 3)
# Optimization terminated successfully.
#          Current function value: 27460.801059
#          Iterations: 24
#          Function evaluations: 36
#          Gradient evaluations: 36
# model : base, sigma: 16, tau: 4, size of X: (43389, 7), Y: (43389, 3)
# Optimization terminated successfully.
#          Current function value: 28394.718517
#          Iterations: 22
#          Function evaluations: 65
#          Gradient evaluations: 63
# model : violation, sigma: 16, tau: 4, size of X: (43389, 8), Y: (43389, 3)
# Optimization terminated successfully.
#          Current function value: 27738.542314
#          Iterations: 25
#          Function evaluations: 82
#          Gradient evaluations: 81
# model : violation_filtered, sigma: 16, tau: 4, size of X: (43389, 8), Y: (43389, 3)
# Optimization terminated successfully.
#          Current function value: 27460.734389
#          Iterations: 24
#          Function evaluations: 36
#          Gradient evaluations: 36
#
#
#  !!!!! evaluating animal W061 !!!!!
#
#
# model : base, sigma: 0.13, tau: 3, size of X: (32569, 7), Y: (32569, 3)
# Optimization terminated successfully.
#          Current function value: 25019.237897
#          Iterations: 23
#          Function evaluations: 35
#          Gradient evaluations: 35
# model : violation, sigma: 0.13, tau: 3, size of X: (32569, 8), Y: (32569, 3)
# Optimization terminated successfully.
#          Current function value: 24300.612039
#          Iterations: 25
#          Function evaluations: 40
#          Gradient evaluations: 40
# model : violation_filtered, sigma: 0.13, tau: 3, size of X: (32569, 8), Y: (32569, 3)
# Optimization terminated successfully.
#          Current function value: 24027.222887
#          Iterations: 25
#          Function evaluations: 33
#          Gradient evaluations: 33
# model : base, sigma: 0.25, tau: 3, size of X: (32569, 7), Y: (32569, 3)
# Optimization terminated successfully.
#          Current function value: 25003.688771
#          Iterations: 23
#          Function evaluations: 37
#          Gradient evaluations: 37
# model : violation, sigma: 0.25, tau: 3, size of X: (32569, 8), Y: (32569, 3)
# Optimization terminated successfully.
#          Current function value: 24264.359817
#          Iterations: 25
#          Function evaluations: 40
#          Gradient evaluations: 40
# model : violation_filtered, sigma: 0.25, tau: 3, size of X: (32569, 8), Y: (32569, 3)
# Optimization terminated successfully.
#          Current function value: 23913.074200
#          Iterations: 24
#          Function evaluations: 33
#          Gradient evaluations: 33
# model : base, sigma: 0.5, tau: 3, size of X: (32569, 7), Y: (32569, 3)
# Optimization terminated successfully.
#          Current function value: 24999.301609
#          Iterations: 22
#          Function evaluations: 35
#          Gradient evaluations: 35
# model : violation, sigma: 0.5, tau: 3, size of X: (32569, 8), Y: (32569, 3)
# Optimization terminated successfully.
#          Current function value: 24253.998487
#          Iterations: 24
#          Function evaluations: 38
#          Gradient evaluations: 38
# model : violation_filtered, sigma: 0.5, tau: 3, size of X: (32569, 8), Y: (32569, 3)
# Optimization terminated successfully.
#          Current function value: 23877.402780
#          Iterations: 25
#          Function evaluations: 32
#          Gradient evaluations: 32
# model : base, sigma: 1, tau: 3, size of X: (32569, 7), Y: (32569, 3)
# Optimization terminated successfully.
#          Current function value: 24998.200298
#          Iterations: 22
#          Function evaluations: 35
#          Gradient evaluations: 35
# model : violation, sigma: 1, tau: 3, size of X: (32569, 8), Y: (32569, 3)
# Optimization terminated successfully.
#          Current function value: 24251.388091
#          Iterations: 25
#          Function evaluations: 73
#          Gradient evaluations: 72
# model : violation_filtered, sigma: 1, tau: 3, size of X: (32569, 8), Y: (32569, 3)
# Optimization terminated successfully.
#          Current function value: 23868.171862
#          Iterations: 23
#          Function evaluations: 30
#          Gradient evaluations: 30
# model : base, sigma: 2, tau: 3, size of X: (32569, 7), Y: (32569, 3)
# Optimization terminated successfully.
#          Current function value: 24997.924685
#          Iterations: 22
#          Function evaluations: 33
#          Gradient evaluations: 33
# model : violation, sigma: 2, tau: 3, size of X: (32569, 8), Y: (32569, 3)
# Optimization terminated successfully.
#          Current function value: 24250.734225
#          Iterations: 24
#          Function evaluations: 38
#          Gradient evaluations: 38
# model : violation_filtered, sigma: 2, tau: 3, size of X: (32569, 8), Y: (32569, 3)
# Optimization terminated successfully.
#          Current function value: 23865.843650
#          Iterations: 24
#          Function evaluations: 31
#          Gradient evaluations: 31
# model : base, sigma: 4, tau: 3, size of X: (32569, 7), Y: (32569, 3)
# Optimization terminated successfully.
#          Current function value: 24997.855765
#          Iterations: 22
#          Function evaluations: 33
#          Gradient evaluations: 33
# model : violation, sigma: 4, tau: 3, size of X: (32569, 8), Y: (32569, 3)
# Optimization terminated successfully.
#          Current function value: 24250.570680
#          Iterations: 24
#          Function evaluations: 38
#          Gradient evaluations: 38
# model : violation_filtered, sigma: 4, tau: 3, size of X: (32569, 8), Y: (32569, 3)
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 23865.260302
#          Iterations: 24
#          Function evaluations: 106
#          Gradient evaluations: 91
# model : base, sigma: 8, tau: 3, size of X: (32569, 7), Y: (32569, 3)
# Optimization terminated successfully.
#          Current function value: 24997.838533
#          Iterations: 22
#          Function evaluations: 33
#          Gradient evaluations: 33
# model : violation, sigma: 8, tau: 3, size of X: (32569, 8), Y: (32569, 3)
# Optimization terminated successfully.
#          Current function value: 24250.529788
#          Iterations: 24
#          Function evaluations: 38
#          Gradient evaluations: 38
# model : violation_filtered, sigma: 8, tau: 3, size of X: (32569, 8), Y: (32569, 3)
# Optimization terminated successfully.
#          Current function value: 23865.114384
#          Iterations: 24
#          Function evaluations: 31
#          Gradient evaluations: 31
# model : base, sigma: 16, tau: 3, size of X: (32569, 7), Y: (32569, 3)
# Optimization terminated successfully.
#          Current function value: 24997.834225
#          Iterations: 22
#          Function evaluations: 33
#          Gradient evaluations: 33
# model : violation, sigma: 16, tau: 3, size of X: (32569, 8), Y: (32569, 3)
# Optimization terminated successfully.
#          Current function value: 24250.519565
#          Iterations: 24
#          Function evaluations: 38
#          Gradient evaluations: 38
# model : violation_filtered, sigma: 16, tau: 3, size of X: (32569, 8), Y: (32569, 3)
# Optimization terminated successfully.
#          Current function value: 23865.077899
#          Iterations: 24
#          Function evaluations: 31
#          Gradient evaluations: 31
#
#
#  !!!!! evaluating animal W062 !!!!!
#
#
# model : base, sigma: 0.13, tau: 3, size of X: (25635, 7), Y: (25635, 3)
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 20108.147611
#          Iterations: 24
#          Function evaluations: 98
#          Gradient evaluations: 86
# model : violation, sigma: 0.13, tau: 3, size of X: (25635, 8), Y: (25635, 3)
# Optimization terminated successfully.
#          Current function value: 19495.681412
#          Iterations: 28
#          Function evaluations: 41
#          Gradient evaluations: 41
# model : violation_filtered, sigma: 0.13, tau: 3, size of X: (25635, 8), Y: (25635, 3)
# Optimization terminated successfully.
#          Current function value: 19087.470808
#          Iterations: 29
#          Function evaluations: 36
#          Gradient evaluations: 36
# model : base, sigma: 0.25, tau: 3, size of X: (25635, 7), Y: (25635, 3)
# Optimization terminated successfully.
#          Current function value: 20096.162497
#          Iterations: 25
#          Function evaluations: 38
#          Gradient evaluations: 38
# model : violation, sigma: 0.25, tau: 3, size of X: (25635, 8), Y: (25635, 3)
# Optimization terminated successfully.
#          Current function value: 19464.691911
#          Iterations: 27
#          Function evaluations: 39
#          Gradient evaluations: 39
# model : violation_filtered, sigma: 0.25, tau: 3, size of X: (25635, 8), Y: (25635, 3)
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 18972.651400
#          Iterations: 25
#          Function evaluations: 67
#          Gradient evaluations: 55
# model : base, sigma: 0.5, tau: 3, size of X: (25635, 7), Y: (25635, 3)
# Optimization terminated successfully.
#          Current function value: 20092.766641
#          Iterations: 23
#          Function evaluations: 34
#          Gradient evaluations: 34
# model : violation, sigma: 0.5, tau: 3, size of X: (25635, 8), Y: (25635, 3)
# Optimization terminated successfully.
#          Current function value: 19455.791171
#          Iterations: 25
#          Function evaluations: 36
#          Gradient evaluations: 36
# model : violation_filtered, sigma: 0.5, tau: 3, size of X: (25635, 8), Y: (25635, 3)
# Optimization terminated successfully.
#          Current function value: 18936.360103
#          Iterations: 24
#          Function evaluations: 29
#          Gradient evaluations: 29
# model : base, sigma: 1, tau: 3, size of X: (25635, 7), Y: (25635, 3)
# Optimization terminated successfully.
#          Current function value: 20091.913174
#          Iterations: 23
#          Function evaluations: 34
#          Gradient evaluations: 34
# model : violation, sigma: 1, tau: 3, size of X: (25635, 8), Y: (25635, 3)
# Optimization terminated successfully.
#          Current function value: 19453.545651
#          Iterations: 25
#          Function evaluations: 36
#          Gradient evaluations: 36
# model : violation_filtered, sigma: 1, tau: 3, size of X: (25635, 8), Y: (25635, 3)
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 18926.933835
#          Iterations: 24
#          Function evaluations: 68
#          Gradient evaluations: 56
# model : base, sigma: 2, tau: 3, size of X: (25635, 7), Y: (25635, 3)
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 20091.699523
#          Iterations: 22
#          Function evaluations: 83
#          Gradient evaluations: 71
# model : violation, sigma: 2, tau: 3, size of X: (25635, 8), Y: (25635, 3)
# Optimization terminated successfully.
#          Current function value: 19452.982985
#          Iterations: 25
#          Function evaluations: 36
#          Gradient evaluations: 36
# model : violation_filtered, sigma: 2, tau: 3, size of X: (25635, 8), Y: (25635, 3)
# Optimization terminated successfully.
#          Current function value: 18924.554012
#          Iterations: 25
#          Function evaluations: 30
#          Gradient evaluations: 30
# model : base, sigma: 4, tau: 3, size of X: (25635, 7), Y: (25635, 3)
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 20091.646093
#          Iterations: 22
#          Function evaluations: 82
#          Gradient evaluations: 71
# model : violation, sigma: 4, tau: 3, size of X: (25635, 8), Y: (25635, 3)
# Optimization terminated successfully.
#          Current function value: 19452.842238
#          Iterations: 25
#          Function evaluations: 36
#          Gradient evaluations: 36
# model : violation_filtered, sigma: 4, tau: 3, size of X: (25635, 8), Y: (25635, 3)
# Optimization terminated successfully.
#          Current function value: 18923.957583
#          Iterations: 25
#          Function evaluations: 30
#          Gradient evaluations: 30
# model : base, sigma: 8, tau: 3, size of X: (25635, 7), Y: (25635, 3)
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 20091.632734
#          Iterations: 22
#          Function evaluations: 67
#          Gradient evaluations: 56
# model : violation, sigma: 8, tau: 3, size of X: (25635, 8), Y: (25635, 3)
# Optimization terminated successfully.
#          Current function value: 19452.807046
#          Iterations: 25
#          Function evaluations: 36
#          Gradient evaluations: 36
# model : violation_filtered, sigma: 8, tau: 3, size of X: (25635, 8), Y: (25635, 3)
# Optimization terminated successfully.
#          Current function value: 18923.808383
#          Iterations: 25
#          Function evaluations: 30
#          Gradient evaluations: 30
# model : base, sigma: 16, tau: 3, size of X: (25635, 7), Y: (25635, 3)
# Optimization terminated successfully.
#          Current function value: 20091.629394
#          Iterations: 24
#          Function evaluations: 64
#          Gradient evaluations: 63
# model : violation, sigma: 16, tau: 3, size of X: (25635, 8), Y: (25635, 3)
# Optimization terminated successfully.
#          Current function value: 19452.798247
#          Iterations: 25
#          Function evaluations: 36
#          Gradient evaluations: 36
# model : violation_filtered, sigma: 16, tau: 3, size of X: (25635, 8), Y: (25635, 3)
# Optimization terminated successfully.
#          Current function value: 18923.771078
#          Iterations: 25
#          Function evaluations: 30
#          Gradient evaluations: 30
#
#
#  !!!!! evaluating animal W065 !!!!!
#
#
# model : base, sigma: 0.13, tau: 3, size of X: (41343, 7), Y: (41343, 3)
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 29532.714313
#          Iterations: 24
#          Function evaluations: 39
#          Gradient evaluations: 39
# model : violation, sigma: 0.13, tau: 3, size of X: (41343, 8), Y: (41343, 3)
# Optimization terminated successfully.
#          Current function value: 28798.662311
#          Iterations: 25
#          Function evaluations: 36
#          Gradient evaluations: 36
# model : violation_filtered, sigma: 0.13, tau: 3, size of X: (41343, 8), Y: (41343, 3)
# Optimization terminated successfully.
#          Current function value: 28420.546953
#          Iterations: 29
#          Function evaluations: 39
#          Gradient evaluations: 39
# model : base, sigma: 0.25, tau: 3, size of X: (41343, 7), Y: (41343, 3)
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 29490.538020
#          Iterations: 24
#          Function evaluations: 76
#          Gradient evaluations: 64
# model : violation, sigma: 0.25, tau: 3, size of X: (41343, 8), Y: (41343, 3)
# Optimization terminated successfully.
#          Current function value: 28738.668892
#          Iterations: 24
#          Function evaluations: 37
#          Gradient evaluations: 37
# model : violation_filtered, sigma: 0.25, tau: 3, size of X: (41343, 8), Y: (41343, 3)
# Optimization terminated successfully.
#          Current function value: 28284.136457
#          Iterations: 25
#          Function evaluations: 34
#          Gradient evaluations: 34
# model : base, sigma: 0.5, tau: 3, size of X: (41343, 7), Y: (41343, 3)
# Optimization terminated successfully.
#          Current function value: 29478.551441
#          Iterations: 24
#          Function evaluations: 36
#          Gradient evaluations: 36
# model : violation, sigma: 0.5, tau: 3, size of X: (41343, 8), Y: (41343, 3)
# Optimization terminated successfully.
#          Current function value: 28721.570707
#          Iterations: 23
#          Function evaluations: 35
#          Gradient evaluations: 35
# model : violation_filtered, sigma: 0.5, tau: 3, size of X: (41343, 8), Y: (41343, 3)
# Optimization terminated successfully.
#          Current function value: 28242.859213
#          Iterations: 25
#          Function evaluations: 33
#          Gradient evaluations: 33
# model : base, sigma: 1, tau: 3, size of X: (41343, 7), Y: (41343, 3)
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 29475.536349
#          Iterations: 23
#          Function evaluations: 35
#          Gradient evaluations: 35
# model : violation, sigma: 1, tau: 3, size of X: (41343, 8), Y: (41343, 3)
# Optimization terminated successfully.
#          Current function value: 28717.266503
#          Iterations: 24
#          Function evaluations: 35
#          Gradient evaluations: 35
# model : violation_filtered, sigma: 1, tau: 3, size of X: (41343, 8), Y: (41343, 3)
# Optimization terminated successfully.
#          Current function value: 28232.281304
#          Iterations: 25
#          Function evaluations: 33
#          Gradient evaluations: 33
# model : base, sigma: 2, tau: 3, size of X: (41343, 7), Y: (41343, 3)
# Optimization terminated successfully.
#          Current function value: 29474.781413
#          Iterations: 24
#          Function evaluations: 36
#          Gradient evaluations: 36
# model : violation, sigma: 2, tau: 3, size of X: (41343, 8), Y: (41343, 3)
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 28716.188582
#          Iterations: 23
#          Function evaluations: 71
#          Gradient evaluations: 60
# model : violation_filtered, sigma: 2, tau: 3, size of X: (41343, 8), Y: (41343, 3)
# Optimization terminated successfully.
#          Current function value: 28229.620072
#          Iterations: 25
#          Function evaluations: 33
#          Gradient evaluations: 33
# model : base, sigma: 4, tau: 3, size of X: (41343, 7), Y: (41343, 3)
# Optimization terminated successfully.
#          Current function value: 29474.592606
#          Iterations: 24
#          Function evaluations: 36
#          Gradient evaluations: 36
# model : violation, sigma: 4, tau: 3, size of X: (41343, 8), Y: (41343, 3)
# Optimization terminated successfully.
#          Current function value: 28715.918985
#          Iterations: 24
#          Function evaluations: 35
#          Gradient evaluations: 35
# model : violation_filtered, sigma: 4, tau: 3, size of X: (41343, 8), Y: (41343, 3)
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 28228.953707
#          Iterations: 24
#          Function evaluations: 32
#          Gradient evaluations: 32
# model : base, sigma: 8, tau: 3, size of X: (41343, 7), Y: (41343, 3)
# Optimization terminated successfully.
#          Current function value: 29474.545400
#          Iterations: 24
#          Function evaluations: 71
#          Gradient evaluations: 70
# model : violation, sigma: 8, tau: 3, size of X: (41343, 8), Y: (41343, 3)
# Optimization terminated successfully.
#          Current function value: 28715.851578
#          Iterations: 24
#          Function evaluations: 35
#          Gradient evaluations: 35
# model : violation_filtered, sigma: 8, tau: 3, size of X: (41343, 8), Y: (41343, 3)
# Optimization terminated successfully.
#          Current function value: 28228.787049
#          Iterations: 25
#          Function evaluations: 33
#          Gradient evaluations: 33
# model : base, sigma: 16, tau: 3, size of X: (41343, 7), Y: (41343, 3)
# Optimization terminated successfully.
#          Current function value: 29474.533598
#          Iterations: 24
#          Function evaluations: 36
#          Gradient evaluations: 36
# model : violation, sigma: 16, tau: 3, size of X: (41343, 8), Y: (41343, 3)
# Optimization terminated successfully.
#          Current function value: 28715.834726
#          Iterations: 24
#          Function evaluations: 37
#          Gradient evaluations: 37
# model : violation_filtered, sigma: 16, tau: 3, size of X: (41343, 8), Y: (41343, 3)
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 28228.745381
#          Iterations: 24
#          Function evaluations: 82
#          Gradient evaluations: 70
#
#
#  !!!!! evaluating animal W066 !!!!!
#
#
# model : base, sigma: 0.13, tau: 4, size of X: (25116, 7), Y: (25116, 3)
# Optimization terminated successfully.
#          Current function value: 18339.161997
#          Iterations: 23
#          Function evaluations: 37
#          Gradient evaluations: 37
# model : violation, sigma: 0.13, tau: 4, size of X: (25116, 8), Y: (25116, 3)
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 17688.830636
#          Iterations: 28
#          Function evaluations: 40
#          Gradient evaluations: 40
# model : violation_filtered, sigma: 0.13, tau: 4, size of X: (25116, 8), Y: (25116, 3)
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 17241.857831
#          Iterations: 26
#          Function evaluations: 34
#          Gradient evaluations: 34
# model : base, sigma: 0.25, tau: 4, size of X: (25116, 7), Y: (25116, 3)
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 18310.278701
#          Iterations: 23
#          Function evaluations: 37
#          Gradient evaluations: 37
# model : violation, sigma: 0.25, tau: 4, size of X: (25116, 8), Y: (25116, 3)
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 17635.850238
#          Iterations: 27
#          Function evaluations: 37
#          Gradient evaluations: 37
# model : violation_filtered, sigma: 0.25, tau: 4, size of X: (25116, 8), Y: (25116, 3)
# Optimization terminated successfully.
#          Current function value: 17067.260523
#          Iterations: 26
#          Function evaluations: 33
#          Gradient evaluations: 33
# model : base, sigma: 0.5, tau: 4, size of X: (25116, 7), Y: (25116, 3)
# Optimization terminated successfully.
#          Current function value: 18302.012481
#          Iterations: 22
#          Function evaluations: 35
#          Gradient evaluations: 35
# model : violation, sigma: 0.5, tau: 4, size of X: (25116, 8), Y: (25116, 3)
# Optimization terminated successfully.
#          Current function value: 17620.555884
#          Iterations: 26
#          Function evaluations: 35
#          Gradient evaluations: 35
# model : violation_filtered, sigma: 0.5, tau: 4, size of X: (25116, 8), Y: (25116, 3)
# Optimization terminated successfully.
#          Current function value: 17010.101332
#          Iterations: 25
#          Function evaluations: 31
#          Gradient evaluations: 31
# model : base, sigma: 1, tau: 4, size of X: (25116, 7), Y: (25116, 3)
# Optimization terminated successfully.
#          Current function value: 18299.929105
#          Iterations: 22
#          Function evaluations: 35
#          Gradient evaluations: 35
# model : violation, sigma: 1, tau: 4, size of X: (25116, 8), Y: (25116, 3)
# Optimization terminated successfully.
#          Current function value: 17616.691803
#          Iterations: 25
#          Function evaluations: 34
#          Gradient evaluations: 34
# model : violation_filtered, sigma: 1, tau: 4, size of X: (25116, 8), Y: (25116, 3)
# Optimization terminated successfully.
#          Current function value: 16995.065939
#          Iterations: 25
#          Function evaluations: 31
#          Gradient evaluations: 31
# model : base, sigma: 2, tau: 4, size of X: (25116, 7), Y: (25116, 3)
# Optimization terminated successfully.
#          Current function value: 18299.407198
#          Iterations: 22
#          Function evaluations: 35
#          Gradient evaluations: 35
# model : violation, sigma: 2, tau: 4, size of X: (25116, 8), Y: (25116, 3)
# Optimization terminated successfully.
#          Current function value: 17615.723218
#          Iterations: 26
#          Function evaluations: 35
#          Gradient evaluations: 35
# model : violation_filtered, sigma: 2, tau: 4, size of X: (25116, 8), Y: (25116, 3)
# Optimization terminated successfully.
#          Current function value: 16991.256862
#          Iterations: 24
#          Function evaluations: 30
#          Gradient evaluations: 30
# model : base, sigma: 4, tau: 4, size of X: (25116, 7), Y: (25116, 3)
# Optimization terminated successfully.
#          Current function value: 18299.276654
#          Iterations: 22
#          Function evaluations: 35
#          Gradient evaluations: 35
# model : violation, sigma: 4, tau: 4, size of X: (25116, 8), Y: (25116, 3)
# Optimization terminated successfully.
#          Current function value: 17615.480911
#          Iterations: 26
#          Function evaluations: 35
#          Gradient evaluations: 35
# model : violation_filtered, sigma: 4, tau: 4, size of X: (25116, 8), Y: (25116, 3)
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 16990.301391
#          Iterations: 23
#          Function evaluations: 75
#          Gradient evaluations: 63
# model : base, sigma: 8, tau: 4, size of X: (25116, 7), Y: (25116, 3)
# Optimization terminated successfully.
#          Current function value: 18299.244014
#          Iterations: 22
#          Function evaluations: 35
#          Gradient evaluations: 35
# model : violation, sigma: 8, tau: 4, size of X: (25116, 8), Y: (25116, 3)
# Optimization terminated successfully.
#          Current function value: 17615.420324
#          Iterations: 26
#          Function evaluations: 39
#          Gradient evaluations: 39
# model : violation_filtered, sigma: 8, tau: 4, size of X: (25116, 8), Y: (25116, 3)
# Optimization terminated successfully.
#          Current function value: 16990.062322
#          Iterations: 24
#          Function evaluations: 30
#          Gradient evaluations: 30
# model : base, sigma: 16, tau: 4, size of X: (25116, 7), Y: (25116, 3)
# Optimization terminated successfully.
#          Current function value: 18299.235854
#          Iterations: 22
#          Function evaluations: 35
#          Gradient evaluations: 35
# model : violation, sigma: 16, tau: 4, size of X: (25116, 8), Y: (25116, 3)
# Optimization terminated successfully.
#          Current function value: 17615.405176
#          Iterations: 26
#          Function evaluations: 35
#          Gradient evaluations: 35
# model : violation_filtered, sigma: 16, tau: 4, size of X: (25116, 8), Y: (25116, 3)
# Optimization terminated successfully.
#          Current function value: 16990.002542
#          Iterations: 24
#          Function evaluations: 30
#          Gradient evaluations: 30
#
#
#  !!!!! evaluating animal W068 !!!!!
#
#
# model : base, sigma: 0.13, tau: 4, size of X: (32246, 7), Y: (32246, 3)
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 23172.543661
#          Iterations: 22
#          Function evaluations: 74
#          Gradient evaluations: 62
# model : violation, sigma: 0.13, tau: 4, size of X: (32246, 8), Y: (32246, 3)
# Optimization terminated successfully.
#          Current function value: 22363.617054
#          Iterations: 24
#          Function evaluations: 39
#          Gradient evaluations: 39
# model : violation_filtered, sigma: 0.13, tau: 4, size of X: (32246, 8), Y: (32246, 3)
# Optimization terminated successfully.
#          Current function value: 22080.223543
#          Iterations: 24
#          Function evaluations: 34
#          Gradient evaluations: 34
# model : base, sigma: 0.25, tau: 4, size of X: (32246, 7), Y: (32246, 3)
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 23142.486356
#          Iterations: 22
#          Function evaluations: 75
#          Gradient evaluations: 63
# model : violation, sigma: 0.25, tau: 4, size of X: (32246, 8), Y: (32246, 3)
# Optimization terminated successfully.
#          Current function value: 22309.528515
#          Iterations: 25
#          Function evaluations: 37
#          Gradient evaluations: 37
# model : violation_filtered, sigma: 0.25, tau: 4, size of X: (32246, 8), Y: (32246, 3)
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 21925.462941
#          Iterations: 26
#          Function evaluations: 63
#          Gradient evaluations: 51
# model : base, sigma: 0.5, tau: 4, size of X: (32246, 7), Y: (32246, 3)
# Optimization terminated successfully.
#          Current function value: 23133.939873
#          Iterations: 21
#          Function evaluations: 36
#          Gradient evaluations: 36
# model : violation, sigma: 0.5, tau: 4, size of X: (32246, 8), Y: (32246, 3)
# Optimization terminated successfully.
#          Current function value: 22294.030161
#          Iterations: 24
#          Function evaluations: 35
#          Gradient evaluations: 35
# model : violation_filtered, sigma: 0.5, tau: 4, size of X: (32246, 8), Y: (32246, 3)
# Optimization terminated successfully.
#          Current function value: 21876.418338
#          Iterations: 25
#          Function evaluations: 34
#          Gradient evaluations: 34
# model : base, sigma: 1, tau: 4, size of X: (32246, 7), Y: (32246, 3)
# Optimization terminated successfully.
#          Current function value: 23131.789782
#          Iterations: 21
#          Function evaluations: 36
#          Gradient evaluations: 36
# model : violation, sigma: 1, tau: 4, size of X: (32246, 8), Y: (32246, 3)
# Optimization terminated successfully.
#          Current function value: 22290.122732
#          Iterations: 22
#          Function evaluations: 34
#          Gradient evaluations: 34
# model : violation_filtered, sigma: 1, tau: 4, size of X: (32246, 8), Y: (32246, 3)
# Optimization terminated successfully.
#          Current function value: 21863.663725
#          Iterations: 25
#          Function evaluations: 34
#          Gradient evaluations: 34
# model : base, sigma: 2, tau: 4, size of X: (32246, 7), Y: (32246, 3)
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 23131.251410
#          Iterations: 20
#          Function evaluations: 52
#          Gradient evaluations: 41
# model : violation, sigma: 2, tau: 4, size of X: (32246, 8), Y: (32246, 3)
# Optimization terminated successfully.
#          Current function value: 22289.143799
#          Iterations: 23
#          Function evaluations: 35
#          Gradient evaluations: 35
# model : violation_filtered, sigma: 2, tau: 4, size of X: (32246, 8), Y: (32246, 3)
# Optimization terminated successfully.
#          Current function value: 21860.442457
#          Iterations: 25
#          Function evaluations: 34
#          Gradient evaluations: 34
# model : base, sigma: 4, tau: 4, size of X: (32246, 7), Y: (32246, 3)
# Optimization terminated successfully.
#          Current function value: 23131.116763
#          Iterations: 21
#          Function evaluations: 36
#          Gradient evaluations: 36
# model : violation, sigma: 4, tau: 4, size of X: (32246, 8), Y: (32246, 3)
# Optimization terminated successfully.
#          Current function value: 22288.898936
#          Iterations: 23
#          Function evaluations: 35
#          Gradient evaluations: 35
# model : violation_filtered, sigma: 4, tau: 4, size of X: (32246, 8), Y: (32246, 3)
# Optimization terminated successfully.
#          Current function value: 21859.635072
#          Iterations: 25
#          Function evaluations: 34
#          Gradient evaluations: 34
# model : base, sigma: 8, tau: 4, size of X: (32246, 7), Y: (32246, 3)
# Optimization terminated successfully.
#          Current function value: 23131.083098
#          Iterations: 21
#          Function evaluations: 36
#          Gradient evaluations: 36
# model : violation, sigma: 8, tau: 4, size of X: (32246, 8), Y: (32246, 3)
# Optimization terminated successfully.
#          Current function value: 22288.837712
#          Iterations: 23
#          Function evaluations: 35
#          Gradient evaluations: 35
# model : violation_filtered, sigma: 8, tau: 4, size of X: (32246, 8), Y: (32246, 3)
# Optimization terminated successfully.
#          Current function value: 21859.433096
#          Iterations: 25
#          Function evaluations: 34
#          Gradient evaluations: 34
# model : base, sigma: 16, tau: 4, size of X: (32246, 7), Y: (32246, 3)
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 23131.074682
#          Iterations: 20
#          Function evaluations: 81
#          Gradient evaluations: 69
# model : violation, sigma: 16, tau: 4, size of X: (32246, 8), Y: (32246, 3)
# Optimization terminated successfully.
#          Current function value: 22288.822405
#          Iterations: 23
#          Function evaluations: 35
#          Gradient evaluations: 35
# model : violation_filtered, sigma: 16, tau: 4, size of X: (32246, 8), Y: (32246, 3)
# Optimization terminated successfully.
#          Current function value: 21859.382594
#          Iterations: 25
#          Function evaluations: 34
#          Gradient evaluations: 34
#
#
#  !!!!! evaluating animal W072 !!!!!
#
#
# model : base, sigma: 0.13, tau: 2, size of X: (26000, 7), Y: (26000, 3)
# Optimization terminated successfully.
#          Current function value: 19165.081852
#          Iterations: 23
#          Function evaluations: 36
#          Gradient evaluations: 36
# model : violation, sigma: 0.13, tau: 2, size of X: (26000, 8), Y: (26000, 3)
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 18202.921013
#          Iterations: 26
#          Function evaluations: 42
#          Gradient evaluations: 42
# model : violation_filtered, sigma: 0.13, tau: 2, size of X: (26000, 8), Y: (26000, 3)
# Optimization terminated successfully.
#          Current function value: 17858.262766
#          Iterations: 28
#          Function evaluations: 42
#          Gradient evaluations: 42
# model : base, sigma: 0.25, tau: 2, size of X: (26000, 7), Y: (26000, 3)
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 19137.669368
#          Iterations: 25
#          Function evaluations: 38
#          Gradient evaluations: 38
# model : violation, sigma: 0.25, tau: 2, size of X: (26000, 8), Y: (26000, 3)
# Optimization terminated successfully.
#          Current function value: 18143.658615
#          Iterations: 25
#          Function evaluations: 38
#          Gradient evaluations: 38
# model : violation_filtered, sigma: 0.25, tau: 2, size of X: (26000, 8), Y: (26000, 3)
# Optimization terminated successfully.
#          Current function value: 17726.824074
#          Iterations: 27
#          Function evaluations: 37
#          Gradient evaluations: 37
# model : base, sigma: 0.5, tau: 2, size of X: (26000, 7), Y: (26000, 3)
# Optimization terminated successfully.
#          Current function value: 19129.831443
#          Iterations: 23
#          Function evaluations: 33
#          Gradient evaluations: 33
# model : violation, sigma: 0.5, tau: 2, size of X: (26000, 8), Y: (26000, 3)
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 18126.566864
#          Iterations: 24
#          Function evaluations: 78
#          Gradient evaluations: 66
# model : violation_filtered, sigma: 0.5, tau: 2, size of X: (26000, 8), Y: (26000, 3)
# Optimization terminated successfully.
#          Current function value: 17686.638692
#          Iterations: 26
#          Function evaluations: 35
#          Gradient evaluations: 35
# model : base, sigma: 1, tau: 2, size of X: (26000, 7), Y: (26000, 3)
# Optimization terminated successfully.
#          Current function value: 19127.856539
#          Iterations: 23
#          Function evaluations: 33
#          Gradient evaluations: 33
# model : violation, sigma: 1, tau: 2, size of X: (26000, 8), Y: (26000, 3)
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 18122.249845
#          Iterations: 25
#          Function evaluations: 40
#          Gradient evaluations: 40
# model : violation_filtered, sigma: 1, tau: 2, size of X: (26000, 8), Y: (26000, 3)
# Optimization terminated successfully.
#          Current function value: 17676.308659
#          Iterations: 26
#          Function evaluations: 35
#          Gradient evaluations: 35
# model : base, sigma: 2, tau: 2, size of X: (26000, 7), Y: (26000, 3)
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 19127.361839
#          Iterations: 25
#          Function evaluations: 39
#          Gradient evaluations: 39
# model : violation, sigma: 2, tau: 2, size of X: (26000, 8), Y: (26000, 3)
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 18121.167800
#          Iterations: 24
#          Function evaluations: 82
#          Gradient evaluations: 70
# model : violation_filtered, sigma: 2, tau: 2, size of X: (26000, 8), Y: (26000, 3)
# Optimization terminated successfully.
#          Current function value: 17673.707711
#          Iterations: 26
#          Function evaluations: 35
#          Gradient evaluations: 35
# model : base, sigma: 4, tau: 2, size of X: (26000, 7), Y: (26000, 3)
# ...
#          Iterations: 27
#          Function evaluations: 32
#          Gradient evaluations: 32
# model : base, sigma: 2, tau: 4, size of X: (31660, 7), Y: (31660, 3)
# Optimization terminated successfully.
#          Current function value: 22474.678905
#          Iterations: 20
#          Function evaluations: 34
#          Gradient evaluations: 34
# model : violation, sigma: 2, tau: 4, size of X: (31660, 8), Y: (31660, 3)
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 18270.804835
#          Iterations: 25
#          Function evaluations: 109
#          Gradient evaluations: 94
# model : violation_filtered, sigma: 2, tau: 4, size of X: (31660, 8), Y: (31660, 3)
# Optimization terminated successfully.
#          Current function value: 16665.749499
#          Iterations: 28
#          Function evaluations: 33
#          Gradient evaluations: 33
# model : base, sigma: 4, tau: 4, size of X: (31660, 7), Y: (31660, 3)
# Optimization terminated successfully.
#          Current function value: 22474.502153
#          Iterations: 20
#          Function evaluations: 34
#          Gradient evaluations: 34
# model : violation, sigma: 4, tau: 4, size of X: (31660, 8), Y: (31660, 3)
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 18270.158512
#          Iterations: 25
#          Function evaluations: 115
#          Gradient evaluations: 100
# model : violation_filtered, sigma: 4, tau: 4, size of X: (31660, 8), Y: (31660, 3)
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 16663.988751
#          Iterations: 27
#          Function evaluations: 66
#          Gradient evaluations: 55
# model : base, sigma: 8, tau: 4, size of X: (31660, 7), Y: (31660, 3)
# Optimization terminated successfully.
#          Current function value: 22474.457960
#          Iterations: 20
#          Function evaluations: 34
#          Gradient evaluations: 34
# model : violation, sigma: 8, tau: 4, size of X: (31660, 8), Y: (31660, 3)
# Optimization terminated successfully.
#          Current function value: 18269.996903
#          Iterations: 25
#          Function evaluations: 40
#          Gradient evaluations: 40
# model : violation_filtered, sigma: 8, tau: 4, size of X: (31660, 8), Y: (31660, 3)
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 16663.548308
#          Iterations: 26
#          Function evaluations: 69
#          Gradient evaluations: 57
# model : base, sigma: 16, tau: 4, size of X: (31660, 7), Y: (31660, 3)
# Optimization terminated successfully.
#          Current function value: 22474.446911
#          Iterations: 20
#          Function evaluations: 34
#          Gradient evaluations: 34
# model : violation, sigma: 16, tau: 4, size of X: (31660, 8), Y: (31660, 3)
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 18269.956499
#          Iterations: 25
#          Function evaluations: 71
#          Gradient evaluations: 60
# model : violation_filtered, sigma: 16, tau: 4, size of X: (31660, 8), Y: (31660, 3)
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 16663.438181
#          Iterations: 27
#          Function evaluations: 32
#          Gradient evaluations: 32
#
#
#  !!!!! evaluating animal W089 !!!!!
#
#
# model : base, sigma: 0.13, tau: 3, size of X: (42822, 7), Y: (42822, 3)
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 32348.816803
#          Iterations: 22
#          Function evaluations: 91
#          Gradient evaluations: 81
# model : violation, sigma: 0.13, tau: 3, size of X: (42822, 8), Y: (42822, 3)
# Optimization terminated successfully.
#          Current function value: 26929.696370
#          Iterations: 29
#          Function evaluations: 44
#          Gradient evaluations: 44
# model : violation_filtered, sigma: 0.13, tau: 3, size of X: (42822, 8), Y: (42822, 3)
# Optimization terminated successfully.
#          Current function value: 25392.057918
#          Iterations: 28
#          Function evaluations: 40
#          Gradient evaluations: 40
# model : base, sigma: 0.25, tau: 3, size of X: (42822, 7), Y: (42822, 3)
# Optimization terminated successfully.
#          Current function value: 32317.136387
#          Iterations: 24
#          Function evaluations: 40
#          Gradient evaluations: 40
# model : violation, sigma: 0.25, tau: 3, size of X: (42822, 8), Y: (42822, 3)
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 26782.641522
#          Iterations: 26
#          Function evaluations: 40
#          Gradient evaluations: 40
# model : violation_filtered, sigma: 0.25, tau: 3, size of X: (42822, 8), Y: (42822, 3)
# Optimization terminated successfully.
#          Current function value: 25051.978188
#          Iterations: 27
#          Function evaluations: 37
#          Gradient evaluations: 37
# model : base, sigma: 0.5, tau: 3, size of X: (42822, 7), Y: (42822, 3)
# Optimization terminated successfully.
#          Current function value: 32308.166618
#          Iterations: 22
#          Function evaluations: 35
#          Gradient evaluations: 35
# model : violation, sigma: 0.5, tau: 3, size of X: (42822, 8), Y: (42822, 3)
# Optimization terminated successfully.
#          Current function value: 26740.502119
#          Iterations: 26
#          Function evaluations: 37
#          Gradient evaluations: 37
# model : violation_filtered, sigma: 0.5, tau: 3, size of X: (42822, 8), Y: (42822, 3)
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 24949.009927
#          Iterations: 26
#          Function evaluations: 88
#          Gradient evaluations: 76
# model : base, sigma: 1, tau: 3, size of X: (42822, 7), Y: (42822, 3)
# Optimization terminated successfully.
#          Current function value: 32305.912767
#          Iterations: 22
#          Function evaluations: 35
#          Gradient evaluations: 35
# model : violation, sigma: 1, tau: 3, size of X: (42822, 8), Y: (42822, 3)
# Optimization terminated successfully.
#          Current function value: 26729.877576
#          Iterations: 26
#          Function evaluations: 37
#          Gradient evaluations: 37
# model : violation_filtered, sigma: 1, tau: 3, size of X: (42822, 8), Y: (42822, 3)
# Optimization terminated successfully.
#          Current function value: 24922.600129
#          Iterations: 26
#          Function evaluations: 35
#          Gradient evaluations: 35
# model : base, sigma: 2, tau: 3, size of X: (42822, 7), Y: (42822, 3)
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 32305.348586
#          Iterations: 21
#          Function evaluations: 67
#          Gradient evaluations: 57
# model : violation, sigma: 2, tau: 3, size of X: (42822, 8), Y: (42822, 3)
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 26727.215767
#          Iterations: 26
#          Function evaluations: 96
#          Gradient evaluations: 84
# model : violation_filtered, sigma: 2, tau: 3, size of X: (42822, 8), Y: (42822, 3)
# Optimization terminated successfully.
#          Current function value: 24915.953989
#          Iterations: 26
#          Function evaluations: 35
#          Gradient evaluations: 35
# model : base, sigma: 4, tau: 3, size of X: (42822, 7), Y: (42822, 3)
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 32305.207496
#          Iterations: 21
#          Function evaluations: 77
#          Gradient evaluations: 66
# model : violation, sigma: 4, tau: 3, size of X: (42822, 8), Y: (42822, 3)
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 26726.549959
#          Iterations: 26
#          Function evaluations: 85
#          Gradient evaluations: 74
# model : violation_filtered, sigma: 4, tau: 3, size of X: (42822, 8), Y: (42822, 3)
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 24914.289691
#          Iterations: 27
#          Function evaluations: 136
#          Gradient evaluations: 120
# model : base, sigma: 8, tau: 3, size of X: (42822, 7), Y: (42822, 3)
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 32305.172220
#          Iterations: 21
#          Function evaluations: 78
#          Gradient evaluations: 66
# model : violation, sigma: 8, tau: 3, size of X: (42822, 8), Y: (42822, 3)
# Optimization terminated successfully.
#          Current function value: 26726.383485
#          Iterations: 27
#          Function evaluations: 38
#          Gradient evaluations: 38
# model : violation_filtered, sigma: 8, tau: 3, size of X: (42822, 8), Y: (42822, 3)
# Optimization terminated successfully.
#          Current function value: 24913.873443
#          Iterations: 26
#          Function evaluations: 35
#          Gradient evaluations: 35
# model : base, sigma: 16, tau: 3, size of X: (42822, 7), Y: (42822, 3)
# Optimization terminated successfully.
#          Current function value: 32305.163401
#          Iterations: 22
#          Function evaluations: 35
#          Gradient evaluations: 35
# model : violation, sigma: 16, tau: 3, size of X: (42822, 8), Y: (42822, 3)
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 26726.341865
#          Iterations: 26
#          Function evaluations: 37
#          Gradient evaluations: 37
# model : violation_filtered, sigma: 16, tau: 3, size of X: (42822, 8), Y: (42822, 3)
# Optimization terminated successfully.
#          Current function value: 24913.769370
#          Iterations: 26
#          Function evaluations: 35
#          Gradient evaluations: 35
#
#
#  !!!!! evaluating animal W094 !!!!!
#
#
# model : base, sigma: 0.13, tau: 6, size of X: (25879, 7), Y: (25879, 3)
# Optimization terminated successfully.
#          Current function value: 18977.461096
#          Iterations: 23
#          Function evaluations: 38
#          Gradient evaluations: 38
# model : violation, sigma: 0.13, tau: 6, size of X: (25879, 8), Y: (25879, 3)
# Optimization terminated successfully.
#          Current function value: 18535.863572
#          Iterations: 24
#          Function evaluations: 40
#          Gradient evaluations: 40
# model : violation_filtered, sigma: 0.13, tau: 6, size of X: (25879, 8), Y: (25879, 3)
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 18002.787638
#          Iterations: 24
#          Function evaluations: 68
#          Gradient evaluations: 56
# model : base, sigma: 0.25, tau: 6, size of X: (25879, 7), Y: (25879, 3)
# Optimization terminated successfully.
#          Current function value: 18951.853284
#          Iterations: 23
#          Function evaluations: 39
#          Gradient evaluations: 39
# model : violation, sigma: 0.25, tau: 6, size of X: (25879, 8), Y: (25879, 3)
# Optimization terminated successfully.
#          Current function value: 18498.315866
#          Iterations: 24
#          Function evaluations: 39
#          Gradient evaluations: 39
# model : violation_filtered, sigma: 0.25, tau: 6, size of X: (25879, 8), Y: (25879, 3)
# Optimization terminated successfully.
#          Current function value: 17842.366948
#          Iterations: 24
#          Function evaluations: 34
#          Gradient evaluations: 34
# model : base, sigma: 0.5, tau: 6, size of X: (25879, 7), Y: (25879, 3)
# Optimization terminated successfully.
#          Current function value: 18944.547319
#          Iterations: 22
#          Function evaluations: 37
#          Gradient evaluations: 37
# model : violation, sigma: 0.5, tau: 6, size of X: (25879, 8), Y: (25879, 3)
# Optimization terminated successfully.
#          Current function value: 18487.564358
#          Iterations: 23
#          Function evaluations: 37
#          Gradient evaluations: 37
# model : violation_filtered, sigma: 0.5, tau: 6, size of X: (25879, 8), Y: (25879, 3)
# Optimization terminated successfully.
#          Current function value: 17789.539859
#          Iterations: 23
#          Function evaluations: 32
#          Gradient evaluations: 32
# model : base, sigma: 1, tau: 6, size of X: (25879, 7), Y: (25879, 3)
# Optimization terminated successfully.
#          Current function value: 18942.707546
#          Iterations: 22
#          Function evaluations: 37
#          Gradient evaluations: 37
# model : violation, sigma: 1, tau: 6, size of X: (25879, 8), Y: (25879, 3)
# Optimization terminated successfully.
#          Current function value: 18484.854206
#          Iterations: 23
#          Function evaluations: 37
#          Gradient evaluations: 37
# model : violation_filtered, sigma: 1, tau: 6, size of X: (25879, 8), Y: (25879, 3)
# Optimization terminated successfully.
#          Current function value: 17775.622343
#          Iterations: 23
#          Function evaluations: 32
#          Gradient evaluations: 32
# model : base, sigma: 2, tau: 6, size of X: (25879, 7), Y: (25879, 3)
# Optimization terminated successfully.
#          Current function value: 18942.246764
#          Iterations: 22
#          Function evaluations: 37
#          Gradient evaluations: 37
# model : violation, sigma: 2, tau: 6, size of X: (25879, 8), Y: (25879, 3)
# Optimization terminated successfully.
#          Current function value: 18484.175260
#          Iterations: 23
#          Function evaluations: 37
#          Gradient evaluations: 37
# model : violation_filtered, sigma: 2, tau: 6, size of X: (25879, 8), Y: (25879, 3)
# Optimization terminated successfully.
#          Current function value: 17772.095146
#          Iterations: 23
#          Function evaluations: 32
#          Gradient evaluations: 32
# model : base, sigma: 4, tau: 6, size of X: (25879, 7), Y: (25879, 3)
# Optimization terminated successfully.
#          Current function value: 18942.131516
#          Iterations: 22
#          Function evaluations: 37
#          Gradient evaluations: 37
# model : violation, sigma: 4, tau: 6, size of X: (25879, 8), Y: (25879, 3)
# Optimization terminated successfully.
#          Current function value: 18484.005435
#          Iterations: 23
#          Function evaluations: 37
#          Gradient evaluations: 37
# model : violation_filtered, sigma: 4, tau: 6, size of X: (25879, 8), Y: (25879, 3)
# Optimization terminated successfully.
#          Current function value: 17771.210299
#          Iterations: 23
#          Function evaluations: 32
#          Gradient evaluations: 32
# model : base, sigma: 8, tau: 6, size of X: (25879, 7), Y: (25879, 3)
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 18942.102701
#          Iterations: 21
#          Function evaluations: 83
#          Gradient evaluations: 71
# model : violation, sigma: 8, tau: 6, size of X: (25879, 8), Y: (25879, 3)
# Optimization terminated successfully.
#          Current function value: 18483.962973
#          Iterations: 23
#          Function evaluations: 37
#          Gradient evaluations: 37
# model : violation_filtered, sigma: 8, tau: 6, size of X: (25879, 8), Y: (25879, 3)
# Optimization terminated successfully.
#          Current function value: 17770.988897
#          Iterations: 23
#          Function evaluations: 32
#          Gradient evaluations: 32
# model : base, sigma: 16, tau: 6, size of X: (25879, 7), Y: (25879, 3)
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 18942.095497
#          Iterations: 21
#          Function evaluations: 81
#          Gradient evaluations: 69
# model : violation, sigma: 16, tau: 6, size of X: (25879, 8), Y: (25879, 3)
# Optimization terminated successfully.
#          Current function value: 18483.952358
#          Iterations: 23
#          Function evaluations: 37
#          Gradient evaluations: 37
# model : violation_filtered, sigma: 16, tau: 6, size of X: (25879, 8), Y: (25879, 3)
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 17770.933534
#          Iterations: 23
#          Function evaluations: 128
#          Gradient evaluations: 113

# %%
experiment.plot_model_comparison(type="bar")

# %%
fig, ax = plt.subplots(figsize=(7, 5))
experiment.plot_model_comparison(type="point", ax=ax, ylim=(0, None))
sns.despine()
plt.xticks(rotation=25)
# Out:
# (array([0, 1, 2]),
#  [Text(0, 0, 'base'),
#   Text(1, 0, 'violation'),
#   Text(2, 0, 'violation_filtered')])

# %%
x = experiment.compute_bits_per_trial_df().to_csv(
    "compare_prev_viol_psytrack_bits_per_trial.csv", index=False
)

# x.to_csv("compare_prev_viol_psytrack_bits_per_trial.csv", index=False)

# %%
experiment.null_fits["model_name"] = "null"
best_fits = experiment.find_best_fit(
    group=["animal_id", "model_name"]
)  # find best sigma for each animal, model

# concat nll for null and fit models
combined_df = pd.concat(
    [
        experiment.null_fits[["animal_id", "nll", "model_name"]],
        best_fits[["animal_id", "nll", "model_name"]],
    ]
)

# add in number of test trials for each animal
combined_df = pd.merge(
    combined_df,
    experiment.null_fits[["animal_id", "n_test_trials"]],
    on="animal_id",
    how="left",
)

combined_df
# Out:
#    animal_id           nll          model_name  n_test_trials
# 0       W051  14808.888189                null          14534
# 1       W060  10647.188847                null          10436
# 2       W061   8220.928368                null           7497
# 3       W062   6715.445475                null           6120
# 4       W065  11325.328773                null          10487
# ..       ...           ...                 ...            ...
# 71      W089   8763.450722           violation          10567
# 72      W089   8134.469232  violation_filtered          10567
# 73      W094   6671.668852                base           6667
# 74      W094   6542.349859           violation           6667
# 75      W094   6219.756735  violation_filtered           6667
#
# [76 rows x 4 columns]

# %%
fig, ax = plt.subplots(figsize=(7, 5))

experiment.plot_model_comparison(
    type="point", hue="tau", palette="Greys", ax=ax, ylim=(0, None)
)
sns.despine()
plt.xticks(rotation=25)
# Out:
# (array([0, 1, 2]),
#  [Text(0, 0, 'base'),
#   Text(1, 0, 'violation'),
#   Text(2, 0, 'violation_filtered')])

# %%
fig, ax = plt.subplots(figsize=(7, 5))

experiment.plot_model_comparison(
    type="point", hue="animal_id", palette="Blues", ax=ax, ylim=(0, None)
)
sns.despine()
plt.xticks(rotation=25)
# Out:
# (array([0, 1, 2]),
#  [Text(0, 0, 'base'),
#   Text(1, 0, 'violation'),
#   Text(2, 0, 'violation_filtered')])

# %%
experiment.plot_nll_over_sigmas_by_animal()

# %%
experiment.find_best_fit?
# Out:
# Signature: experiment.find_best_fit(group='model_name')
# Docstring: <no docstring>
# File:      /var/folders/__/8jn6qz211155h1xb451s5zcr0000gn/T/ipykernel_62757/1499397920.py
# Type:      method

# %%
best_fits = experiment.find_best_fit()
best_fits
# Out:
#    animal_id          model_name  sigma  tau           nll
# 0       W051                base  16.00    6  13860.100598
# 1       W051           violation  16.00    6  13627.588535
# 2       W051  violation_filtered  16.00    6  13377.834257
# 3       W060                base   0.13    4   9673.801121
# 4       W060           violation  16.00    4   9268.344014
# 5       W060  violation_filtered  16.00    4   9026.235886
# 6       W061                base   0.13    3   7860.662413
# 7       W061           violation  16.00    3   7532.658282
# 8       W061  violation_filtered  16.00    3   7335.090216
# 9       W062                base  16.00    3   6329.217132
# 10      W062           violation  16.00    3   6047.869025
# 11      W062  violation_filtered  16.00    3   5864.827789
# 12      W065                base  16.00    3   9873.549921
# 13      W065           violation  16.00    3   9555.465648
# 14      W065  violation_filtered  16.00    3   9357.395909
# 15      W066                base   0.13    4   6174.132152
# 16      W066           violation   0.13    4   5953.992279
# 17      W066  violation_filtered   0.25    4   5755.830700
# 18      W068                base   0.25    4   7646.110908
# 19      W068           violation  16.00    4   7305.399198
# 20      W068  violation_filtered  16.00    4   7113.950009
# 21      W072                base  16.00    2   6504.750979
# 22      W072           violation  16.00    2   6149.854699
# 23      W072  violation_filtered  16.00    2   6001.669140
# 24      W073                base  16.00    2   7172.421716
# 25      W073           violation  16.00    2   6410.078037
# 26      W073  violation_filtered  16.00    2   6166.914478
# 27      W074                base  16.00    4   8829.594393
# 28      W074           violation  16.00    4   8380.761250
# 29      W074  violation_filtered  16.00    4   8134.925294
# 30      W075                base   0.13    6  12902.671817
# 31      W075           violation  16.00    6  12774.504997
# 32      W075  violation_filtered  16.00    6  12592.745033
# 33      W078                base   0.13    2   9704.240321
# 34      W078           violation   0.13    2   9459.519906
# 35      W078  violation_filtered   0.25    2   9384.928276
# 36      W080                base   0.13    3  10797.706592
# 37      W080           violation   0.13    3   9274.861639
# 38      W080  violation_filtered   0.25    3   8572.829279
# 39      W081                base   0.13    4   6847.559425
# 40      W081           violation  16.00    4   5744.284829
# 41      W081  violation_filtered   0.50    4   5237.401471
# 42      W082                base  16.00    6  15343.218503
# 43      W082           violation  16.00    6  14986.578135
# 44      W082  violation_filtered  16.00    6  14185.919188
# 45      W083                base   0.13    2  12494.224047
# 46      W083           violation  16.00    2  10675.214941
# 47      W083  violation_filtered  16.00    2  10071.502915
# 48      W088                base   0.25    4   8015.060887
# 49      W088           violation   0.25    4   6582.502677
# 50      W088  violation_filtered  16.00    4   5875.573154
# 51      W089                base   0.13    3  10749.949146
# 52      W089           violation  16.00    3   8763.450722
# 53      W089  violation_filtered  16.00    3   8134.469232
# 54      W094                base   0.13    6   6671.668852
# 55      W094           violation   0.13    6   6542.349859
# 56      W094  violation_filtered   0.50    6   6219.756735

# %%
base_best = best_fits.query("model_name == 'base'")
# Out:
#    animal_id model_name  sigma  tau           nll
# 0       W051       base  16.00    6  13860.100598
# 3       W060       base   0.13    4   9673.801121
# 6       W061       base   0.13    3   7860.662413
# 9       W062       base  16.00    3   6329.217132
# 12      W065       base  16.00    3   9873.549921
# 15      W066       base   0.13    4   6174.132152
# 18      W068       base   0.25    4   7646.110908
# 21      W072       base  16.00    2   6504.750979
# 24      W073       base  16.00    2   7172.421716
# 27      W074       base  16.00    4   8829.594393
# 30      W075       base   0.13    6  12902.671817
# 33      W078       base   0.13    2   9704.240321
# 36      W080       base   0.13    3  10797.706592
# 39      W081       base   0.13    4   6847.559425
# 42      W082       base  16.00    6  15343.218503
# 45      W083       base   0.13    2  12494.224047
# 48      W088       base   0.25    4   8015.060887
# 51      W089       base   0.13    3  10749.949146
# 54      W094       base   0.13    6   6671.668852

# %%
experiment.plot_class_weights(animal_id="W094", model_name="base")

# %%
sns.set_context("poster")


class PlotModelWeights:
    def __init__(self, main_dataframe):
        self.main_dataframe = main_dataframe  # Assuming you store main data here

    def plot_all_class_weights(self):
        """
        Function to plot class weights for all animals and models.
        """
        # Prepare an empty DataFrame to collect data
        all_weight_data = pd.DataFrame(
            columns=["Weight", "Feature", "Class", "Animal_ID", "Model_Name"]
        )

        # Loop through all rows in the main DataFrame
        for index, row in self.main_dataframe.iterrows():
            animal_id = row["animal_id"]
            model_name = row[
                "model_name"
            ]  # Assuming MultiIndex (model_name, animal_id)
            feature_names = row["features"]
            W_fit = np.array(row["weights"])

            weight_data = self._plot_class_weights(
                feature_names, W_fit, animal_id, model_name
            )
            all_weight_data = pd.concat([all_weight_data, weight_data])

        # Plotting
        fig, ax = plt.subplots(figsize=(20, 8))
        ax.axhline(y=0, color="black")
        sns.barplot(
            x="Feature",
            y="Weight",
            hue="Class",
            palette=["#e03412", "#1d85c2", "purple"],
            data=all_weight_data,
        )
        plt.xticks(rotation=45)
        plt.legend(loc="upper left")
        plt.show()

    def _plot_class_weights(self, feature_names, W_fit, animal_id, model_name):
        """
        Internal function to prepare the DataFrame for plotting weights.
        """
        D, C = W_fit.shape
        classes = ["L", "R", "V"]

        weight_data = [
            {
                "Weight": W_fit[d, c],
                "Feature": feature_names[d],
                "Class": classes[c],
                "Animal_ID": animal_id,
                "Model_Name": model_name,
            }
            for c in range(C)
            for d in range(D)
        ]
        return pd.DataFrame(weight_data)


base = PlotModelWeights(model_fits.query("model_name == 'base'"))
base.plot_all_class_weights()

# %%
base = PlotModelWeights(model_fits.query("model_name == 'violation'"))
base.plot_all_class_weights()

# %%
base = PlotModelWeights(model_fits.query("model_name == 'violation_filtered'"))
base.plot_all_class_weights()

# %%
test = model_fits.query("model_name == 'violation_filtered'").copy()

# %%
def preprocess_features(df_w_filter):
    """
    Internal method to preprocess the 'features' column.
    Replaces 'prev_violation_exp_X' with 'prev_violation_filtered'.
    """

    def replace_prev_violation(exp_list):
        return [
            "prev_violation_filtered" if "prev_violation_exp_" in feature else feature
            for feature in exp_list
        ]

    df_w_filter["features"] = df_w_filter["features"].apply(replace_prev_violation)


test = model_fits.query("model_name == 'violation_filtered'").copy()
preprocess_features(test)

# %%
test
# Out:
#     animal_id          model_name           nll  sigma  tau
# 2        W051  violation_filtered  13409.430411   0.13    6  \
# 5        W051  violation_filtered  13384.226415   0.25    6
# 8        W051  violation_filtered  13379.172834   0.50    6
# 11       W051  violation_filtered  13378.148982   1.00    6
# 14       W051  violation_filtered  13377.910793   2.00    6
# ..        ...                 ...           ...    ...  ...
# 443      W094  violation_filtered   6219.936728   1.00    6
# 446      W094  violation_filtered   6220.001368   2.00    6
# 449      W094  violation_filtered   6220.018803   4.00    6
# 452      W094  violation_filtered   6220.023242   8.00    6
# 455      W094  violation_filtered   6220.024357  16.00    6
#
#                                               features
# 2    [bias, prev_violation_filtered, s_a, s_b, prev...  \
# 5    [bias, prev_violation_filtered, s_a, s_b, prev...
# 8    [bias, prev_violation_filtered, s_a, s_b, prev...
# 11   [bias, prev_violation_filtered, s_a, s_b, prev...
# 14   [bias, prev_violation_filtered, s_a, s_b, prev...
# ..                                                 ...
# 443  [bias, prev_violation_filtered, s_a, s_b, prev...
# 446  [bias, prev_violation_filtered, s_a, s_b, prev...
# 449  [bias, prev_violation_filtered, s_a, s_b, prev...
# 452  [bias, prev_violation_filtered, s_a, s_b, prev...
# 455  [bias, prev_violation_filtered, s_a, s_b, prev...
#
#                                                weights
# 2    [[0.46047260007475954, 0.5069155371605573, -0....
# 5    [[0.4888916634457322, 0.5465248475440213, -1.0...
# 8    [[0.4990614287761923, 0.5608173739442295, -1.0...
# 11   [[0.5018139452684494, 0.5646965612355106, -1.0...
# 14   [[0.5025165469118063, 0.5656874879666433, -1.0...
# ..                                                 ...
# 443  [[0.38599032125657545, 0.2865669938181222, -0....
# 446  [[0.38735894129524423, 0.28763594208972604, -0...
# 449  [[0.3877029110294061, 0.2879045197339588, -0.6...
# 452  [[0.38778901765697005, 0.2879717484558841, -0....
# 455  [[0.3878105607649002, 0.28798856195963773, -0....
#
# [152 rows x 7 columns]

# %%
filtviol = PlotModelWeights(test)
filtviol.plot_all_class_weights()

# %%
def count_sessions(session_list):
    return len(session_list)


# Apply the function to each row in the 'test_sessions' column
null_fits["num_test_sessions"] = null_fits["test_sessions"].apply(count_sessions)

# %%
fig, ax = plt.subplots(figsize=(10, 5))
null_fits.groupby("animal_id")["num_test_sessions"].min().plot(kind="bar", ax=ax)

plt.title("Number of test sessions per animal")
# Out:
# Text(0.5, 1.0, 'Number of test sessions per animal')

# %%
fig, ax = plt.subplots(figsize=(10, 5))
null_fits.groupby("animal_id")["n_test_trials"].min().plot(kind="bar", ax=ax)

plt.title("Number of test trials per animal")
# Out:
# Text(0.5, 1.0, 'Number of test trials per animal')

# %%
experiment.null_fits.groupby("animal_id")["test_sessions"]
