# %% [markdown]
# # Experiment: Fit N Prev Trial Not Starteded
#
# **Goal**: Determine if knowing the number of previous trials not started (i.e. more than binary encoding) predicts L/R/V trials. This feature is not scaled and is just the raw trial value.
#
# **Summary**: This seems to be more sensible then the scaled version, but a comparative analysis is needed to see if this performs better than just the binary encoding.
#
#
# Related notebooks:
#
# * `2024_02_20_dev_trial_not_started.ipynb`
# * `2024_02_20_EXP_fit_prev_trial_not_started.ipynb`
# * `2024_02_20_EXP_fit_prev_trial_not_started_scaled.ipynb`

# %% [markdown]
# ## Imports

# %%
import seaborn as sns
import matplotlib.pyplot as plt


from multiglm.experiments.experiment import load_experiment
from multiglm.experiments.experiment_sigma_sweep import ExperimentSigmaSweep
from multiglm.models.multiclass_logistic_regression import MultiClassLogisticRegression
from multiglm.visualizations.model_visualizer import ModelVisualizer
from multiglm.features.design_matrix_generator import DesignMatrixGeneratorFilteredHistory
from multiglm.data import ANIMAL_IDS

sns.set_context("talk")
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# ## Model Configs

# %%
model_config = {
    "prev_trial_not_started": {
        "model_class": MultiClassLogisticRegression,
        "model_type": "multi",
        "design_matrix_generator": DesignMatrixGeneratorFilteredHistory,
        "filter_implementation": {
            "prev_violation": 1
        },  # filter column with animals tau,
        "design_matrix_generator_args": {
            "trial_not_started": "n_prev",
        },
    }
}

params = {
    "animals": ANIMAL_IDS,
    "data_type": "new_trained",
    "sigmas": [0.07, 0.13, 0.25, 0.5, 1, 2, 4, 8, 16],
    "random_state": 47,
    "null_mode": "multi",
    "eval_train": True,
    "tau_columns": ["prev_violation"],
    "model_config": model_config,
}

save_name = "2024_02_20_fit_n_prev_trial_not_started.pkl"

# %% [markdown]
# ## Run

# %%
experiment = ExperimentSigmaSweep(params)
experiment.run()
experiment.save(save_name)
# Out:
# Loading dataset type : new_trained
# Loading data for animal ids:  ['W051', 'W060', 'W065', 'W066', 'W068', 'W072', 'W073', 'W074', 'W075', 'W078', 'W080', 'W081', 'W082', 'W083', 'W088', 'W089', 'W094']
#
#  >>>> evaluating animal W051 <<<<
# Evaluating trial_not_started n_prev
#
#  ***** evaluating model prev_trial_not_started w/ sigma 0.07 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 64723.979692
#          Iterations: 30
#          Function evaluations: 70
#          Gradient evaluations: 58
#
#  ***** evaluating model prev_trial_not_started w/ sigma 0.13 *****
# Optimization terminated successfully.
#          Current function value: 64411.307666
#          Iterations: 32
#          Function evaluations: 42
#          Gradient evaluations: 42
#
#  ***** evaluating model prev_trial_not_started w/ sigma 0.25 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 64299.062848
#          Iterations: 31
#          Function evaluations: 89
#          Gradient evaluations: 77
#
#  ***** evaluating model prev_trial_not_started w/ sigma 0.5 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 64262.487301
#          Iterations: 33
#          Function evaluations: 75
#          Gradient evaluations: 63
#
#  ***** evaluating model prev_trial_not_started w/ sigma 1 *****
# Optimization terminated successfully.
#          Current function value: 64252.401245
#          Iterations: 33
#          Function evaluations: 41
#          Gradient evaluations: 41
#
#  ***** evaluating model prev_trial_not_started w/ sigma 2 *****
# Optimization terminated successfully.
#          Current function value: 64249.782334
#          Iterations: 33
#          Function evaluations: 41
#          Gradient evaluations: 41
#
#  ***** evaluating model prev_trial_not_started w/ sigma 4 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 64249.120298
#          Iterations: 32
#          Function evaluations: 90
#          Gradient evaluations: 79
#
#  ***** evaluating model prev_trial_not_started w/ sigma 8 *****
# Optimization terminated successfully.
#          Current function value: 64248.954308
#          Iterations: 33
#          Function evaluations: 41
#          Gradient evaluations: 41
#
#  ***** evaluating model prev_trial_not_started w/ sigma 16 *****
# Optimization terminated successfully.
#          Current function value: 64248.912780
#          Iterations: 33
#          Function evaluations: 41
#          Gradient evaluations: 41
#
#  >>>> evaluating animal W060 <<<<
# Evaluating trial_not_started n_prev
#
#  ***** evaluating model prev_trial_not_started w/ sigma 0.07 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 51758.668223
#          Iterations: 33
#          Function evaluations: 130
#          Gradient evaluations: 117
#
#  ***** evaluating model prev_trial_not_started w/ sigma 0.13 *****
# Optimization terminated successfully.
#          Current function value: 51396.170776
#          Iterations: 31
#          Function evaluations: 44
#          Gradient evaluations: 44
#
#  ***** evaluating model prev_trial_not_started w/ sigma 0.25 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 51277.025375
#          Iterations: 29
#          Function evaluations: 42
#          Gradient evaluations: 42
#
#  ***** evaluating model prev_trial_not_started w/ sigma 0.5 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 51242.752024
#          Iterations: 28
#          Function evaluations: 75
#          Gradient evaluations: 63
#
#  ***** evaluating model prev_trial_not_started w/ sigma 1 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 51234.098625
#          Iterations: 29
#          Function evaluations: 127
#          Gradient evaluations: 115
#
#  ***** evaluating model prev_trial_not_started w/ sigma 2 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 51231.929838
#          Iterations: 28
#          Function evaluations: 79
#          Gradient evaluations: 67
#
#  ***** evaluating model prev_trial_not_started w/ sigma 4 *****
# Optimization terminated successfully.
#          Current function value: 51231.387299
#          Iterations: 29
#          Function evaluations: 40
#          Gradient evaluations: 40
#
#  ***** evaluating model prev_trial_not_started w/ sigma 8 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 51231.251643
#          Iterations: 28
#          Function evaluations: 39
#          Gradient evaluations: 39
#
#  ***** evaluating model prev_trial_not_started w/ sigma 16 *****
# Optimization terminated successfully.
#          Current function value: 51231.217728
#          Iterations: 29
#          Function evaluations: 40
#          Gradient evaluations: 40
#
#  >>>> evaluating animal W065 <<<<
# Evaluating trial_not_started n_prev
#
#  ***** evaluating model prev_trial_not_started w/ sigma 0.07 *****
# Optimization terminated successfully.
#          Current function value: 56921.351811
#          Iterations: 29
#          Function evaluations: 39
#          Gradient evaluations: 39
#
#  ***** evaluating model prev_trial_not_started w/ sigma 0.13 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 56501.463514
#          Iterations: 28
#          Function evaluations: 38
#          Gradient evaluations: 38
#
#  ***** evaluating model prev_trial_not_started w/ sigma 0.25 *****
# Optimization terminated successfully.
#          Current function value: 56343.745392
#          Iterations: 29
#          Function evaluations: 39
#          Gradient evaluations: 39
#
#  ***** evaluating model prev_trial_not_started w/ sigma 0.5 *****
# Optimization terminated successfully.
#          Current function value: 56292.451606
#          Iterations: 31
#          Function evaluations: 68
#          Gradient evaluations: 67
#
#  ***** evaluating model prev_trial_not_started w/ sigma 1 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 56278.609716
#          Iterations: 29
#          Function evaluations: 97
#          Gradient evaluations: 85
#
#  ***** evaluating model prev_trial_not_started w/ sigma 2 *****
# Optimization terminated successfully.
#          Current function value: 56275.059388
#          Iterations: 29
#          Function evaluations: 38
#          Gradient evaluations: 38
#
#  ***** evaluating model prev_trial_not_started w/ sigma 4 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 56274.165484
#          Iterations: 28
#          Function evaluations: 90
#          Gradient evaluations: 79
#
#  ***** evaluating model prev_trial_not_started w/ sigma 8 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 56273.941600
#          Iterations: 30
#          Function evaluations: 150
#          Gradient evaluations: 132
#
#  ***** evaluating model prev_trial_not_started w/ sigma 16 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 56273.885603
#          Iterations: 28
#          Function evaluations: 83
#          Gradient evaluations: 71
#
#  >>>> evaluating animal W066 <<<<
# Evaluating trial_not_started n_prev
#
#  ***** evaluating model prev_trial_not_started w/ sigma 0.07 *****
# Optimization terminated successfully.
#          Current function value: 85391.157623
#          Iterations: 30
#          Function evaluations: 46
#          Gradient evaluations: 46
#
#  ***** evaluating model prev_trial_not_started w/ sigma 0.13 *****
# Optimization terminated successfully.
#          Current function value: 84983.573883
#          Iterations: 31
#          Function evaluations: 42
#          Gradient evaluations: 42
#
#  ***** evaluating model prev_trial_not_started w/ sigma 0.25 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 84835.258894
#          Iterations: 30
#          Function evaluations: 96
#          Gradient evaluations: 82
#
#  ***** evaluating model prev_trial_not_started w/ sigma 0.5 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 84785.419592
#          Iterations: 31
#          Function evaluations: 120
#          Gradient evaluations: 107
#
#  ***** evaluating model prev_trial_not_started w/ sigma 1 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 84770.537691
#          Iterations: 31
#          Function evaluations: 98
#          Gradient evaluations: 87
#
#  ***** evaluating model prev_trial_not_started w/ sigma 2 *****
# Optimization terminated successfully.
#          Current function value: 84766.353226
#          Iterations: 32
#          Function evaluations: 41
#          Gradient evaluations: 41
#
#  ***** evaluating model prev_trial_not_started w/ sigma 4 *****
# Optimization terminated successfully.
#          Current function value: 84765.253308
#          Iterations: 32
#          Function evaluations: 41
#          Gradient evaluations: 41
#
#  ***** evaluating model prev_trial_not_started w/ sigma 8 *****
# Optimization terminated successfully.
#          Current function value: 84764.974047
#          Iterations: 32
#          Function evaluations: 41
#          Gradient evaluations: 41
#
#  ***** evaluating model prev_trial_not_started w/ sigma 16 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 84764.903944
#          Iterations: 31
#          Function evaluations: 88
#          Gradient evaluations: 76
#
#  >>>> evaluating animal W068 <<<<
# Evaluating trial_not_started n_prev
#
#  ***** evaluating model prev_trial_not_started w/ sigma 0.07 *****
# Optimization terminated successfully.
#          Current function value: 77732.072479
#          Iterations: 29
#          Function evaluations: 44
#          Gradient evaluations: 44
#
#  ***** evaluating model prev_trial_not_started w/ sigma 0.13 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 77442.562186
#          Iterations: 28
#          Function evaluations: 45
#          Gradient evaluations: 45
#
#  ***** evaluating model prev_trial_not_started w/ sigma 0.25 *****
# Optimization terminated successfully.
#          Current function value: 77347.306157
#          Iterations: 29
#          Function evaluations: 41
#          Gradient evaluations: 41
#
#  ***** evaluating model prev_trial_not_started w/ sigma 0.5 *****
# Optimization terminated successfully.
#          Current function value: 77319.802508
#          Iterations: 29
#          Function evaluations: 41
#          Gradient evaluations: 41
#
#  ***** evaluating model prev_trial_not_started w/ sigma 1 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 77312.848228
#          Iterations: 27
#          Function evaluations: 104
#          Gradient evaluations: 92
#
#  ***** evaluating model prev_trial_not_started w/ sigma 2 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 77311.104594
#          Iterations: 27
#          Function evaluations: 70
#          Gradient evaluations: 59
#
#  ***** evaluating model prev_trial_not_started w/ sigma 4 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 77310.668366
#          Iterations: 28
#          Function evaluations: 133
#          Gradient evaluations: 119
#
#  ***** evaluating model prev_trial_not_started w/ sigma 8 *****
# Optimization terminated successfully.
#          Current function value: 77310.559289
#          Iterations: 28
#          Function evaluations: 39
#          Gradient evaluations: 39
#
#  ***** evaluating model prev_trial_not_started w/ sigma 16 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 77310.532018
#          Iterations: 28
#          Function evaluations: 41
#          Gradient evaluations: 41
#
#  >>>> evaluating animal W072 <<<<
# Evaluating trial_not_started n_prev
#
#  ***** evaluating model prev_trial_not_started w/ sigma 0.07 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 59751.636423
#          Iterations: 27
#          Function evaluations: 43
#          Gradient evaluations: 43
#
#  ***** evaluating model prev_trial_not_started w/ sigma 0.13 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 59351.932233
#          Iterations: 26
#          Function evaluations: 54
#          Gradient evaluations: 48
#
#  ***** evaluating model prev_trial_not_started w/ sigma 0.25 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 59219.998162
#          Iterations: 26
#          Function evaluations: 94
#          Gradient evaluations: 82
#
#  ***** evaluating model prev_trial_not_started w/ sigma 0.5 *****
# Optimization terminated successfully.
#          Current function value: 59181.764884
#          Iterations: 26
#          Function evaluations: 38
#          Gradient evaluations: 38
#
#  ***** evaluating model prev_trial_not_started w/ sigma 1 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 59172.077811
#          Iterations: 25
#          Function evaluations: 80
#          Gradient evaluations: 68
#
#  ***** evaluating model prev_trial_not_started w/ sigma 2 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 59169.647447
#          Iterations: 25
#          Function evaluations: 79
#          Gradient evaluations: 68
#
#  ***** evaluating model prev_trial_not_started w/ sigma 4 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 59169.039309
#          Iterations: 26
#          Function evaluations: 98
#          Gradient evaluations: 87
#
#  ***** evaluating model prev_trial_not_started w/ sigma 8 *****
# Optimization terminated successfully.
#          Current function value: 59168.887240
#          Iterations: 27
#          Function evaluations: 68
#          Gradient evaluations: 67
#
#  ***** evaluating model prev_trial_not_started w/ sigma 16 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 59168.849221
#          Iterations: 25
#          Function evaluations: 68
#          Gradient evaluations: 57
#
#  >>>> evaluating animal W073 <<<<
# Evaluating trial_not_started n_prev
#
#  ***** evaluating model prev_trial_not_started w/ sigma 0.07 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 73237.502622
#          Iterations: 33
#          Function evaluations: 52
#          Gradient evaluations: 52
#
#  ***** evaluating model prev_trial_not_started w/ sigma 0.13 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 72744.127386
#          Iterations: 32
#          Function evaluations: 129
#          Gradient evaluations: 115
#
#  ***** evaluating model prev_trial_not_started w/ sigma 0.25 *****
# Optimization terminated successfully.
#          Current function value: 72582.824948
#          Iterations: 33
#          Function evaluations: 46
#          Gradient evaluations: 46
#
#  ***** evaluating model prev_trial_not_started w/ sigma 0.5 *****
# Optimization terminated successfully.
#          Current function value: 72536.392723
#          Iterations: 33
#          Function evaluations: 72
#          Gradient evaluations: 70
#
#  ***** evaluating model prev_trial_not_started w/ sigma 1 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 72524.661260
#          Iterations: 30
#          Function evaluations: 62
#          Gradient evaluations: 51
#
#  ***** evaluating model prev_trial_not_started w/ sigma 2 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 72521.720359
#          Iterations: 31
#          Function evaluations: 83
#          Gradient evaluations: 73
#
#  ***** evaluating model prev_trial_not_started w/ sigma 4 *****
# Optimization terminated successfully.
#          Current function value: 72520.984627
#          Iterations: 32
#          Function evaluations: 43
#          Gradient evaluations: 43
#
#  ***** evaluating model prev_trial_not_started w/ sigma 8 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 72520.800662
#          Iterations: 30
#          Function evaluations: 71
#          Gradient evaluations: 60
#
#  ***** evaluating model prev_trial_not_started w/ sigma 16 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 72520.754668
#          Iterations: 31
#          Function evaluations: 109
#          Gradient evaluations: 96
#
#  >>>> evaluating animal W074 <<<<
# Evaluating trial_not_started n_prev
#
#  ***** evaluating model prev_trial_not_started w/ sigma 0.07 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 112901.751164
#          Iterations: 40
#          Function evaluations: 156
#          Gradient evaluations: 143
#
#  ***** evaluating model prev_trial_not_started w/ sigma 0.13 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 111575.838721
#          Iterations: 36
#          Function evaluations: 93
#          Gradient evaluations: 82
#
#  ***** evaluating model prev_trial_not_started w/ sigma 0.25 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 111116.432544
#          Iterations: 36
#          Function evaluations: 165
#          Gradient evaluations: 151
#
#  ***** evaluating model prev_trial_not_started w/ sigma 0.5 *****
# Optimization terminated successfully.
#          Current function value: 110978.913017
#          Iterations: 34
#          Function evaluations: 44
#          Gradient evaluations: 44
#
#  ***** evaluating model prev_trial_not_started w/ sigma 1 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 110943.481963
#          Iterations: 33
#          Function evaluations: 98
#          Gradient evaluations: 86
#
#  ***** evaluating model prev_trial_not_started w/ sigma 2 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 110934.542967
#          Iterations: 33
#          Function evaluations: 90
#          Gradient evaluations: 78
#
#  ***** evaluating model prev_trial_not_started w/ sigma 4 *****
# Optimization terminated successfully.
#          Current function value: 110932.302790
#          Iterations: 34
#          Function evaluations: 43
#          Gradient evaluations: 43
#
#  ***** evaluating model prev_trial_not_started w/ sigma 8 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 110931.742400
#          Iterations: 34
#          Function evaluations: 112
#          Gradient evaluations: 99
#
#  ***** evaluating model prev_trial_not_started w/ sigma 16 *****
# Optimization terminated successfully.
#          Current function value: 110931.602281
#          Iterations: 34
#          Function evaluations: 45
#          Gradient evaluations: 45
#
#  >>>> evaluating animal W075 <<<<
# Evaluating trial_not_started n_prev
#
#  ***** evaluating model prev_trial_not_started w/ sigma 0.07 *****
# Optimization terminated successfully.
#          Current function value: 129977.288109
#          Iterations: 38
#          Function evaluations: 54
#          Gradient evaluations: 54
#
#  ***** evaluating model prev_trial_not_started w/ sigma 0.13 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 128786.974353
#          Iterations: 33
#          Function evaluations: 103
#          Gradient evaluations: 91
#
#  ***** evaluating model prev_trial_not_started w/ sigma 0.25 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 128361.076011
#          Iterations: 34
#          Function evaluations: 93
#          Gradient evaluations: 83
#
#  ***** evaluating model prev_trial_not_started w/ sigma 0.5 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 128233.237127
#          Iterations: 32
#          Function evaluations: 65
#          Gradient evaluations: 53
#
#  ***** evaluating model prev_trial_not_started w/ sigma 1 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 128200.464889
#          Iterations: 32
#          Function evaluations: 119
#          Gradient evaluations: 108
#
#  ***** evaluating model prev_trial_not_started w/ sigma 2 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 128192.216533
#          Iterations: 33
#          Function evaluations: 127
#          Gradient evaluations: 114
#
#  ***** evaluating model prev_trial_not_started w/ sigma 4 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 128190.150904
#          Iterations: 31
#          Function evaluations: 88
#          Gradient evaluations: 78
#
#  ***** evaluating model prev_trial_not_started w/ sigma 8 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 128189.634274
#          Iterations: 33
#          Function evaluations: 96
#          Gradient evaluations: 84
#
#  ***** evaluating model prev_trial_not_started w/ sigma 16 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 128189.505103
#          Iterations: 34
#          Function evaluations: 117
#          Gradient evaluations: 104
#
#  >>>> evaluating animal W078 <<<<
# Evaluating trial_not_started n_prev
#
#  ***** evaluating model prev_trial_not_started w/ sigma 0.07 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 43910.664270
#          Iterations: 37
#          Function evaluations: 52
#          Gradient evaluations: 52
#
#  ***** evaluating model prev_trial_not_started w/ sigma 0.13 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 43390.087437
#          Iterations: 36
#          Function evaluations: 72
#          Gradient evaluations: 62
#
#  ***** evaluating model prev_trial_not_started w/ sigma 0.25 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 43218.414267
#          Iterations: 34
#          Function evaluations: 112
#          Gradient evaluations: 98
#
#  ***** evaluating model prev_trial_not_started w/ sigma 0.5 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 43168.983277
#          Iterations: 32
#          Function evaluations: 43
#          Gradient evaluations: 43
#
#  ***** evaluating model prev_trial_not_started w/ sigma 1 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 43156.498144
#          Iterations: 30
#          Function evaluations: 77
#          Gradient evaluations: 66
#
#  ***** evaluating model prev_trial_not_started w/ sigma 2 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 43153.368676
#          Iterations: 32
#          Function evaluations: 86
#          Gradient evaluations: 73
#
#  ***** evaluating model prev_trial_not_started w/ sigma 4 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 43152.585793
#          Iterations: 31
#          Function evaluations: 77
#          Gradient evaluations: 66
#
#  ***** evaluating model prev_trial_not_started w/ sigma 8 *****
# Optimization terminated successfully.
#          Current function value: 43152.390041
#          Iterations: 32
#          Function evaluations: 41
#          Gradient evaluations: 41
#
#  ***** evaluating model prev_trial_not_started w/ sigma 16 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 43152.341100
#          Iterations: 30
#          Function evaluations: 97
#          Gradient evaluations: 86
#
#  >>>> evaluating animal W080 <<<<
# Evaluating trial_not_started n_prev
#
#  ***** evaluating model prev_trial_not_started w/ sigma 0.07 *****
# Optimization terminated successfully.
#          Current function value: 29264.136890
#          Iterations: 30
#          Function evaluations: 43
#          Gradient evaluations: 43
#
#  ***** evaluating model prev_trial_not_started w/ sigma 0.13 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 28977.151334
#          Iterations: 27
#          Function evaluations: 59
#          Gradient evaluations: 51
#
#  ***** evaluating model prev_trial_not_started w/ sigma 0.25 *****
# Optimization terminated successfully.
#          Current function value: 28876.113926
#          Iterations: 28
#          Function evaluations: 38
#          Gradient evaluations: 38
#
#  ***** evaluating model prev_trial_not_started w/ sigma 0.5 *****
# Optimization terminated successfully.
#          Current function value: 28846.281365
#          Iterations: 27
#          Function evaluations: 36
#          Gradient evaluations: 36
#
#  ***** evaluating model prev_trial_not_started w/ sigma 1 *****
# Optimization terminated successfully.
#          Current function value: 28838.688669
#          Iterations: 27
#          Function evaluations: 36
#          Gradient evaluations: 36
#
#  ***** evaluating model prev_trial_not_started w/ sigma 2 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 28836.781757
#          Iterations: 26
#          Function evaluations: 75
#          Gradient evaluations: 63
#
#  ***** evaluating model prev_trial_not_started w/ sigma 4 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 28836.304477
#          Iterations: 26
#          Function evaluations: 74
#          Gradient evaluations: 62
#
#  ***** evaluating model prev_trial_not_started w/ sigma 8 *****
# Optimization terminated successfully.
#          Current function value: 28836.185123
#          Iterations: 27
#          Function evaluations: 36
#          Gradient evaluations: 36
#
#  ***** evaluating model prev_trial_not_started w/ sigma 16 *****
# Optimization terminated successfully.
#          Current function value: 28836.155282
#          Iterations: 27
#          Function evaluations: 36
#          Gradient evaluations: 36
#
#  >>>> evaluating animal W081 <<<<
# Evaluating trial_not_started n_prev
#
#  ***** evaluating model prev_trial_not_started w/ sigma 0.07 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 29255.855238
#          Iterations: 24
#          Function evaluations: 77
#          Gradient evaluations: 70
#
#  ***** evaluating model prev_trial_not_started w/ sigma 0.13 *****
# Optimization terminated successfully.
#          Current function value: 29006.213026
#          Iterations: 25
#          Function evaluations: 36
#          Gradient evaluations: 36
#
#  ***** evaluating model prev_trial_not_started w/ sigma 0.25 *****
# Optimization terminated successfully.
#          Current function value: 28915.119069
#          Iterations: 28
#          Function evaluations: 39
#          Gradient evaluations: 39
#
#  ***** evaluating model prev_trial_not_started w/ sigma 0.5 *****
# Optimization terminated successfully.
#          Current function value: 28886.870481
#          Iterations: 28
#          Function evaluations: 38
#          Gradient evaluations: 38
#
#  ***** evaluating model prev_trial_not_started w/ sigma 1 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 28879.428998
#          Iterations: 27
#          Function evaluations: 70
#          Gradient evaluations: 58
#
#  ***** evaluating model prev_trial_not_started w/ sigma 2 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 28877.534447
#          Iterations: 27
#          Function evaluations: 70
#          Gradient evaluations: 58
#
#  ***** evaluating model prev_trial_not_started w/ sigma 4 *****
# Optimization terminated successfully.
#          Current function value: 28877.058371
#          Iterations: 29
#          Function evaluations: 39
#          Gradient evaluations: 39
#
#  ***** evaluating model prev_trial_not_started w/ sigma 8 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 28876.939193
#          Iterations: 28
#          Function evaluations: 38
#          Gradient evaluations: 38
#
#  ***** evaluating model prev_trial_not_started w/ sigma 16 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 28876.909389
#          Iterations: 28
#          Function evaluations: 105
#          Gradient evaluations: 93
#
#  >>>> evaluating animal W082 <<<<
# Evaluating trial_not_started n_prev
#
#  ***** evaluating model prev_trial_not_started w/ sigma 0.07 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 203293.133690
#          Iterations: 32
#          Function evaluations: 135
#          Gradient evaluations: 123
#
#  ***** evaluating model prev_trial_not_started w/ sigma 0.13 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 202769.364727
#          Iterations: 27
#          Function evaluations: 96
#          Gradient evaluations: 83
#
#  ***** evaluating model prev_trial_not_started w/ sigma 0.25 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 202605.198074
#          Iterations: 27
#          Function evaluations: 117
#          Gradient evaluations: 102
#
#  ***** evaluating model prev_trial_not_started w/ sigma 0.5 *****
# Optimization terminated successfully.
#          Current function value: 202558.839237
#          Iterations: 26
#          Function evaluations: 33
#          Gradient evaluations: 33
#
#  ***** evaluating model prev_trial_not_started w/ sigma 1 *****
# Optimization terminated successfully.
#          Current function value: 202547.198674
#          Iterations: 27
#          Function evaluations: 36
#          Gradient evaluations: 36
#
#  ***** evaluating model prev_trial_not_started w/ sigma 2 *****
# Optimization terminated successfully.
#          Current function value: 202544.285329
#          Iterations: 26
#          Function evaluations: 33
#          Gradient evaluations: 33
#
#  ***** evaluating model prev_trial_not_started w/ sigma 4 *****
# Optimization terminated successfully.
#          Current function value: 202543.556793
#          Iterations: 26
#          Function evaluations: 33
#          Gradient evaluations: 33
#
#  ***** evaluating model prev_trial_not_started w/ sigma 8 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 202543.374646
#          Iterations: 25
#          Function evaluations: 69
#          Gradient evaluations: 57
#
#  ***** evaluating model prev_trial_not_started w/ sigma 16 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 202543.329108
#          Iterations: 25
#          Function evaluations: 90
#          Gradient evaluations: 79
#
#  >>>> evaluating animal W083 <<<<
# Evaluating trial_not_started n_prev
#
#  ***** evaluating model prev_trial_not_started w/ sigma 0.07 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 134633.819219
#          Iterations: 38
#          Function evaluations: 80
#          Gradient evaluations: 74
#
#  ***** evaluating model prev_trial_not_started w/ sigma 0.13 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 134055.762230
#          Iterations: 41
#          Function evaluations: 112
#          Gradient evaluations: 100
#
#  ***** evaluating model prev_trial_not_started w/ sigma 0.25 *****
# Optimization terminated successfully.
#          Current function value: 133869.297789
#          Iterations: 37
#          Function evaluations: 52
#          Gradient evaluations: 52
#
#  ***** evaluating model prev_trial_not_started w/ sigma 0.5 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 133816.134090
#          Iterations: 35
#          Function evaluations: 113
#          Gradient evaluations: 100
#
#  ***** evaluating model prev_trial_not_started w/ sigma 1 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 133802.748482
#          Iterations: 34
#          Function evaluations: 69
#          Gradient evaluations: 57
#
#  ***** evaluating model prev_trial_not_started w/ sigma 2 *****
# Optimization terminated successfully.
#          Current function value: 133799.396090
#          Iterations: 36
#          Function evaluations: 49
#          Gradient evaluations: 49
#
#  ***** evaluating model prev_trial_not_started w/ sigma 4 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 133798.557617
#          Iterations: 34
#          Function evaluations: 87
#          Gradient evaluations: 76
#
#  ***** evaluating model prev_trial_not_started w/ sigma 8 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 133798.347975
#          Iterations: 34
#          Function evaluations: 86
#          Gradient evaluations: 74
#
#  ***** evaluating model prev_trial_not_started w/ sigma 16 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 133798.295563
#          Iterations: 34
#          Function evaluations: 90
#          Gradient evaluations: 78
#
#  >>>> evaluating animal W088 <<<<
# Evaluating trial_not_started n_prev
#
#  ***** evaluating model prev_trial_not_started w/ sigma 0.07 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 76330.466483
#          Iterations: 32
#          Function evaluations: 82
#          Gradient evaluations: 70
#
#  ***** evaluating model prev_trial_not_started w/ sigma 0.13 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 75845.277462
#          Iterations: 32
#          Function evaluations: 89
#          Gradient evaluations: 78
#
#  ***** evaluating model prev_trial_not_started w/ sigma 0.25 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 75685.353208
#          Iterations: 32
#          Function evaluations: 127
#          Gradient evaluations: 111
#
#  ***** evaluating model prev_trial_not_started w/ sigma 0.5 *****
# Optimization terminated successfully.
#          Current function value: 75639.398948
#          Iterations: 31
#          Function evaluations: 44
#          Gradient evaluations: 44
#
#  ***** evaluating model prev_trial_not_started w/ sigma 1 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 75627.802263
#          Iterations: 30
#          Function evaluations: 42
#          Gradient evaluations: 42
#
#  ***** evaluating model prev_trial_not_started w/ sigma 2 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 75624.896225
#          Iterations: 30
#          Function evaluations: 81
#          Gradient evaluations: 69
#
#  ***** evaluating model prev_trial_not_started w/ sigma 4 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 75624.169284
#          Iterations: 30
#          Function evaluations: 42
#          Gradient evaluations: 42
#
#  ***** evaluating model prev_trial_not_started w/ sigma 8 *****
# Optimization terminated successfully.
#          Current function value: 75623.987522
#          Iterations: 31
#          Function evaluations: 43
#          Gradient evaluations: 43
#
#  ***** evaluating model prev_trial_not_started w/ sigma 16 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 75623.942080
#          Iterations: 29
#          Function evaluations: 83
#          Gradient evaluations: 72
#
#  >>>> evaluating animal W089 <<<<
# Evaluating trial_not_started n_prev
#
#  ***** evaluating model prev_trial_not_started w/ sigma 0.07 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 92353.076965
#          Iterations: 32
#          Function evaluations: 46
#          Gradient evaluations: 46
#
#  ***** evaluating model prev_trial_not_started w/ sigma 0.13 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 91895.471144
#          Iterations: 32
#          Function evaluations: 89
#          Gradient evaluations: 74
#
#  ***** evaluating model prev_trial_not_started w/ sigma 0.25 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 91745.325849
#          Iterations: 30
#          Function evaluations: 45
#          Gradient evaluations: 45
#
#  ***** evaluating model prev_trial_not_started w/ sigma 0.5 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 91702.249162
#          Iterations: 33
#          Function evaluations: 142
#          Gradient evaluations: 127
#
#  ***** evaluating model prev_trial_not_started w/ sigma 1 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 91691.383604
#          Iterations: 29
#          Function evaluations: 86
#          Gradient evaluations: 75
#
#  ***** evaluating model prev_trial_not_started w/ sigma 2 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 91688.661097
#          Iterations: 31
#          Function evaluations: 129
#          Gradient evaluations: 116
#
#  ***** evaluating model prev_trial_not_started w/ sigma 4 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 91687.980087
#          Iterations: 29
#          Function evaluations: 89
#          Gradient evaluations: 77
#
#  ***** evaluating model prev_trial_not_started w/ sigma 8 *****
# Optimization terminated successfully.
#          Current function value: 91687.809810
#          Iterations: 31
#          Function evaluations: 43
#          Gradient evaluations: 43
#
#  ***** evaluating model prev_trial_not_started w/ sigma 16 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 91687.767240
#          Iterations: 29
#          Function evaluations: 90
#          Gradient evaluations: 78
#
#  >>>> evaluating animal W094 <<<<
# Evaluating trial_not_started n_prev
#
#  ***** evaluating model prev_trial_not_started w/ sigma 0.07 *****
# Optimization terminated successfully.
#          Current function value: 45494.933127
#          Iterations: 28
#          Function evaluations: 43
#          Gradient evaluations: 43
#
#  ***** evaluating model prev_trial_not_started w/ sigma 0.13 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 44990.912536
#          Iterations: 28
#          Function evaluations: 43
#          Gradient evaluations: 43
#
#  ***** evaluating model prev_trial_not_started w/ sigma 0.25 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 44794.864204
#          Iterations: 28
#          Function evaluations: 93
#          Gradient evaluations: 81
#
#  ***** evaluating model prev_trial_not_started w/ sigma 0.5 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 44734.198896
#          Iterations: 27
#          Function evaluations: 38
#          Gradient evaluations: 38
#
#  ***** evaluating model prev_trial_not_started w/ sigma 1 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 44718.522716
#          Iterations: 27
#          Function evaluations: 38
#          Gradient evaluations: 38
#
#  ***** evaluating model prev_trial_not_started w/ sigma 2 *****
# Optimization terminated successfully.
#          Current function value: 44714.569787
#          Iterations: 28
#          Function evaluations: 39
#          Gradient evaluations: 39
#
#  ***** evaluating model prev_trial_not_started w/ sigma 4 *****
# Optimization terminated successfully.
#          Current function value: 44713.579403
#          Iterations: 28
#          Function evaluations: 39
#          Gradient evaluations: 39
#
#  ***** evaluating model prev_trial_not_started w/ sigma 8 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 44713.331672
#          Iterations: 27
#          Function evaluations: 64
#          Gradient evaluations: 53
#
#  ***** evaluating model prev_trial_not_started w/ sigma 16 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 44713.269730
#          Iterations: 27
#          Function evaluations: 38
#          Gradient evaluations: 38

# %% [markdown]
# ## Visualize

# %%
palette = "Set2"
experiment = load_experiment(save_name)
mv = ModelVisualizer(experiment)

# %%
mv.plot_sigma_summary()

# %%
mv.plot_weights_summary(palette=palette)

# %%
mv.plot_nll_over_sigmas_by_animal()

# %%
mv.plot_weights_by_animal(palette=palette)
