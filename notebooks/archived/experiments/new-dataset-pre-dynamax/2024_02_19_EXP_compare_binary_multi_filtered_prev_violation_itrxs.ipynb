# %% [markdown]
# # Experiment: Compare Filtered Binary - Multi Previous Violation w/ Stim Interaction
#
# **Goal**: See if a multi model trained with stim interaction pairs does better than a binary model on L/R test trials
#
#
# Related notebooks:
#
# * `2024_02_15_EXP_fit_prev_violation.ipynb`
# * `2024_02_19_EXP_fit_filtered_prev_violation_stim_intrx.ipynb`
# * `2024_02_19_EXP_compare_binary_multi_filtered_prev_violation_itrxs.ipynb`
#
# > Written by Jess Breda

# %% [markdown]
# ## Imports

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd

from multiglm.experiments.experiment import load_experiment
from multiglm.experiments.experiment_compare_models import ExperimentCompareModels
from multiglm.features.design_matrix_generator import (
     DesignMatrixGeneratorInteractions, DesignMatrixGeneratorFilteredHistory, DesignMatrixGeneratorPsytrack
)
from multiglm.models.multiclass_logistic_regression import MultiClassLogisticRegression
from multiglm.models.binary_logistic_regression import BinaryLogisticRegression
from multiglm.visualizations.model_visualizer import ModelVisualizerCompare
from multiglm.utils.fitting_utils import create_violation_interaction_pairs
from multiglm.data import ANIMAL_IDS

sns.set_context("talk")
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# ## Model Configs

# %%
model_config = {
    "b_psytrack_features": {  # MODEL 0- psytrack binary base
        "model_class": BinaryLogisticRegression,
        "model_type": "binary",
        "design_matrix_generator": DesignMatrixGeneratorPsytrack,
        "filter_implementation": {},  # nothing to filter or drop
    },
    "m_psytrack_features": {  # MODEL 1- pystrack multi base
        "model_class": MultiClassLogisticRegression,
        "model_type": "multi",
        "lr_only_eval": True,
        "design_matrix_generator": DesignMatrixGeneratorFilteredHistory,
        "filter_implementation": {"prev_violation": -1},  # no filter & drop column
    },
    "m_prev_violation": {  # MODEL 2- prev violation bool
        "model_class": MultiClassLogisticRegression,
        "model_type": "multi",
        "lr_only_eval": True,
        "design_matrix_generator": DesignMatrixGeneratorFilteredHistory,
        "filter_implementation": {"prev_violation": 0},  # no filter
    },
    "m_filter_prev_violation": {  # MODEL 3- prev violation filtered
        "model_class": MultiClassLogisticRegression,
        "model_type": "multi",
        "lr_only_eval": True,
        "design_matrix_generator": DesignMatrixGeneratorFilteredHistory,
        "filter_implementation": {
            "prev_violation": 1
        },  # filter column with animals tau
    },
    "m_filter_prev_violation_stim_itrx": {  # MODEL 4- with filt prev violation history and stim interactions
        "model_class": MultiClassLogisticRegression,
        "model_type": "multi",
        "lr_only_eval": True,
        "design_matrix_generator": DesignMatrixGeneratorInteractions,
        "filter_implementation": {
            "prev_violation": 1
        },  # filter column with animals tau,
        "design_matrix_generator_args": {
            "interaction_pairs": create_violation_interaction_pairs(["s_a", "s_b"])
        },
    },
}

params = {
    "animals": ANIMAL_IDS,
    "data_type": "new_trained",
    "sigmas": [0.07, 0.13, 0.25, 0.5, 1, 2, 4, 8, 16],
    "random_state": 47,
    "null_mode": "binary",
    "eval_train": True,
    "tau_columns": ["prev_violation"],
    "model_config": model_config,
}


save_name = "compare_binary_multi_filtered_prev_violation_itrxs.pkl"
ORDER = [
    "b_psytrack_features",
    "m_psytrack_features",
    "m_prev_violation",
    "m_filter_prev_violation",
    "m_filter_prev_violation_stim_itrx",
]

# %% [markdown]
# ## Run

# %%
experiment = ExperimentCompareModels(params)
experiment.run()
experiment.save(save_name)
# Out:
# Loading dataset type : new_trained
# Loading data for animal ids:  ['W051', 'W060', 'W065', 'W066', 'W068', 'W072', 'W073', 'W074', 'W075', 'W078', 'W080', 'W081', 'W082', 'W083', 'W088', 'W089', 'W094']
#
#  >>>> evaluating animal W051 <<<<
#
#  ***** evaluating model b_psytrack_features w/ sigma 0.07 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 32027.207413
#          Iterations: 12
#          Function evaluations: 73
#          Gradient evaluations: 61
#
#  ***** evaluating model b_psytrack_features w/ sigma 0.13 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 32417.262078
#          Iterations: 14
#          Function evaluations: 81
#          Gradient evaluations: 69
#
#  ***** evaluating model b_psytrack_features w/ sigma 0.25 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 32556.842441
#          Iterations: 13
#          Function evaluations: 63
#          Gradient evaluations: 51
#
#  ***** evaluating model b_psytrack_features w/ sigma 0.5 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 32597.848349
#          Iterations: 13
#          Function evaluations: 77
#          Gradient evaluations: 65
#
#  ***** evaluating model b_psytrack_features w/ sigma 1 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 32608.257003
#          Iterations: 13
#          Function evaluations: 66
#          Gradient evaluations: 54
#
#  ***** evaluating model b_psytrack_features w/ sigma 2 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 32610.868894
#          Iterations: 12
#          Function evaluations: 65
#          Gradient evaluations: 53
#
#  ***** evaluating model b_psytrack_features w/ sigma 4 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 32611.522496
#          Iterations: 12
#          Function evaluations: 67
#          Gradient evaluations: 55
#
#  ***** evaluating model b_psytrack_features w/ sigma 8 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 32611.685934
#          Iterations: 13
#          Function evaluations: 74
#          Gradient evaluations: 62
#
#  ***** evaluating model b_psytrack_features w/ sigma 16 *****
# Optimization terminated successfully.
#          Current function value: 32611.726796
#          Iterations: 17
#          Function evaluations: 26
#          Gradient evaluations: 26
#
#  ***** evaluating model m_psytrack_features w/ sigma 0.07 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 64995.381417
#          Iterations: 24
#          Function evaluations: 103
#          Gradient evaluations: 91
#
#  ***** evaluating model m_psytrack_features w/ sigma 0.13 *****
# Optimization terminated successfully.
#          Current function value: 64759.621627
#          Iterations: 25
#          Function evaluations: 38
#          Gradient evaluations: 38
#
#  ***** evaluating model m_psytrack_features w/ sigma 0.25 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 64687.335386
#          Iterations: 24
#          Function evaluations: 103
#          Gradient evaluations: 90
#
#  ***** evaluating model m_psytrack_features w/ sigma 0.5 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 64667.068595
#          Iterations: 23
#          Function evaluations: 68
#          Gradient evaluations: 57
#
#  ***** evaluating model m_psytrack_features w/ sigma 1 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 64661.989920
#          Iterations: 22
#          Function evaluations: 71
#          Gradient evaluations: 59
#
#  ***** evaluating model m_psytrack_features w/ sigma 2 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 64660.719500
#          Iterations: 22
#          Function evaluations: 57
#          Gradient evaluations: 46
#
#  ***** evaluating model m_psytrack_features w/ sigma 4 *****
# Optimization terminated successfully.
#          Current function value: 64660.401848
#          Iterations: 23
#          Function evaluations: 34
#          Gradient evaluations: 34
#
#  ***** evaluating model m_psytrack_features w/ sigma 8 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 64660.322432
#          Iterations: 22
#          Function evaluations: 71
#          Gradient evaluations: 60
#
#  ***** evaluating model m_psytrack_features w/ sigma 16 *****
# Optimization terminated successfully.
#          Current function value: 64660.302577
#          Iterations: 23
#          Function evaluations: 34
#          Gradient evaluations: 34
#
#  ***** evaluating model m_prev_violation w/ sigma 0.07 *****
# Optimization terminated successfully.
#          Current function value: 64817.693634
#          Iterations: 28
#          Function evaluations: 44
#          Gradient evaluations: 44
#
#  ***** evaluating model m_prev_violation w/ sigma 0.13 *****
# Optimization terminated successfully.
#          Current function value: 64568.968515
#          Iterations: 27
#          Function evaluations: 43
#          Gradient evaluations: 43
#
#  ***** evaluating model m_prev_violation w/ sigma 0.25 *****
# Optimization terminated successfully.
#          Current function value: 64492.465901
#          Iterations: 27
#          Function evaluations: 42
#          Gradient evaluations: 42
#
#  ***** evaluating model m_prev_violation w/ sigma 0.5 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 64470.995586
#          Iterations: 23
#          Function evaluations: 105
#          Gradient evaluations: 93
#
#  ***** evaluating model m_prev_violation w/ sigma 1 *****
# Optimization terminated successfully.
#          Current function value: 64465.613827
#          Iterations: 25
#          Function evaluations: 40
#          Gradient evaluations: 40
#
#  ***** evaluating model m_prev_violation w/ sigma 2 *****
# Optimization terminated successfully.
#          Current function value: 64464.267498
#          Iterations: 25
#          Function evaluations: 40
#          Gradient evaluations: 40
#
#  ***** evaluating model m_prev_violation w/ sigma 4 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 64463.930860
#          Iterations: 24
#          Function evaluations: 92
#          Gradient evaluations: 81
#
#  ***** evaluating model m_prev_violation w/ sigma 8 *****
# Optimization terminated successfully.
#          Current function value: 64463.846697
#          Iterations: 25
#          Function evaluations: 40
#          Gradient evaluations: 40
#
#  ***** evaluating model m_prev_violation w/ sigma 16 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 64463.825656
#          Iterations: 24
#          Function evaluations: 40
#          Gradient evaluations: 40
#
#  ***** evaluating model m_filter_prev_violation w/ sigma 0.07 *****
# Optimization terminated successfully.
#          Current function value: 64772.423102
#          Iterations: 26
#          Function evaluations: 39
#          Gradient evaluations: 39
#
#  ***** evaluating model m_filter_prev_violation w/ sigma 0.13 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 64482.383681
#          Iterations: 25
#          Function evaluations: 101
#          Gradient evaluations: 84
#
#  ***** evaluating model m_filter_prev_violation w/ sigma 0.25 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 64388.728414
#          Iterations: 25
#          Function evaluations: 84
#          Gradient evaluations: 72
#
#  ***** evaluating model m_filter_prev_violation w/ sigma 0.5 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 64361.957615
#          Iterations: 24
#          Function evaluations: 115
#          Gradient evaluations: 101
#
#  ***** evaluating model m_filter_prev_violation w/ sigma 1 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 64355.210912
#          Iterations: 23
#          Function evaluations: 79
#          Gradient evaluations: 67
#
#  ***** evaluating model m_filter_prev_violation w/ sigma 2 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 64353.520791
#          Iterations: 22
#          Function evaluations: 49
#          Gradient evaluations: 38
#
#  ***** evaluating model m_filter_prev_violation w/ sigma 4 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 64353.098044
#          Iterations: 25
#          Function evaluations: 153
#          Gradient evaluations: 136
#
#  ***** evaluating model m_filter_prev_violation w/ sigma 8 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 64352.992344
#          Iterations: 23
#          Function evaluations: 154
#          Gradient evaluations: 141
#
#  ***** evaluating model m_filter_prev_violation w/ sigma 16 *****
# Optimization terminated successfully.
#          Current function value: 64352.965918
#          Iterations: 24
#          Function evaluations: 34
#          Gradient evaluations: 34
#
#  ***** evaluating model m_filter_prev_violation_stim_itrx w/ sigma 0.07 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 64737.946312
#          Iterations: 33
#          Function evaluations: 127
#          Gradient evaluations: 109
#
#  ***** evaluating model m_filter_prev_violation_stim_itrx w/ sigma 0.13 *****
# Optimization terminated successfully.
#          Current function value: 64420.545519
#          Iterations: 32
#          Function evaluations: 79
#          Gradient evaluations: 78
#
#  ***** evaluating model m_filter_prev_violation_stim_itrx w/ sigma 0.25 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 64312.632101
#          Iterations: 30
#          Function evaluations: 118
#          Gradient evaluations: 104
#
#  ***** evaluating model m_filter_prev_violation_stim_itrx w/ sigma 0.5 *****
# Optimization terminated successfully.
#          Current function value: 
#          Function evaluations: 32
#          Gradient evaluations: 32
#
#  ***** evaluating model m_prev_violation w/ sigma 0.07 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 85456.021801
#          Iterations: 27
#          Function evaluations: 60
#          Gradient evaluations: 48
#
#  ***** evaluating model m_prev_violation w/ sigma 0.13 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 85138.397476
#          Iterations: 25
#          Function evaluations: 80
#          Gradient evaluations: 68
#
#  ***** evaluating model m_prev_violation w/ sigma 0.25 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 85040.087281
#          Iterations: 26
#          Function evaluations: 38
#          Gradient evaluations: 38
#
#  ***** evaluating model m_prev_violation w/ sigma 0.5 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 85012.443997
#          Iterations: 25
#          Function evaluations: 107
#          Gradient evaluations: 95
#
#  ***** evaluating model m_prev_violation w/ sigma 1 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 85005.511284
#          Iterations: 25
#          Function evaluations: 36
#          Gradient evaluations: 36
#
#  ***** evaluating model m_prev_violation w/ sigma 2 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 85003.776731
#          Iterations: 25
#          Function evaluations: 36
#          Gradient evaluations: 36
#
#  ***** evaluating model m_prev_violation w/ sigma 4 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 85003.343007
#          Iterations: 25
#          Function evaluations: 36
#          Gradient evaluations: 36
#
#  ***** evaluating model m_prev_violation w/ sigma 8 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 85003.234570
#          Iterations: 24
#          Function evaluations: 76
#          Gradient evaluations: 64
#
#  ***** evaluating model m_prev_violation w/ sigma 16 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 85003.207461
#          Iterations: 25
#          Function evaluations: 79
#          Gradient evaluations: 67
#
#  ***** evaluating model m_filter_prev_violation w/ sigma 0.07 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 85414.728926
#          Iterations: 25
#          Function evaluations: 37
#          Gradient evaluations: 37
#
#  ***** evaluating model m_filter_prev_violation w/ sigma 0.13 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 85026.264750
#          Iterations: 25
#          Function evaluations: 92
#          Gradient evaluations: 81
#
#  ***** evaluating model m_filter_prev_violation w/ sigma 0.25 *****
# Optimization terminated successfully.
#          Current function value: 84897.117456
#          Iterations: 26
#          Function evaluations: 38
#          Gradient evaluations: 38
#
#  ***** evaluating model m_filter_prev_violation w/ sigma 0.5 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 84859.736515
#          Iterations: 24
#          Function evaluations: 68
#          Gradient evaluations: 59
#
#  ***** evaluating model m_filter_prev_violation w/ sigma 1 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 84850.279233
#          Iterations: 24
#          Function evaluations: 75
#          Gradient evaluations: 64
#
#  ***** evaluating model m_filter_prev_violation w/ sigma 2 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 84847.907693
#          Iterations: 24
#          Function evaluations: 108
#          Gradient evaluations: 95
#
#  ***** evaluating model m_filter_prev_violation w/ sigma 4 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 84847.314354
#          Iterations: 24
#          Function evaluations: 80
#          Gradient evaluations: 68
#
#  ***** evaluating model m_filter_prev_violation w/ sigma 8 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 84847.165990
#          Iterations: 24
#          Function evaluations: 35
#          Gradient evaluations: 35
#
#  ***** evaluating model m_filter_prev_violation w/ sigma 16 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 84847.128898
#          Iterations: 23
#          Function evaluations: 65
#          Gradient evaluations: 53
#
#  ***** evaluating model m_filter_prev_violation_stim_itrx w/ sigma 0.07 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 85376.096550
#          Iterations: 31
#          Function evaluations: 84
#          Gradient evaluations: 72
#
#  ***** evaluating model m_filter_prev_violation_stim_itrx w/ sigma 0.13 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 84997.085562
#          Iterations: 30
#          Function evaluations: 89
#          Gradient evaluations: 77
#
#  ***** evaluating model m_filter_prev_violation_stim_itrx w/ sigma 0.25 *****
# Optimization terminated successfully.
#          Current function value: 84869.159830
#          Iterations: 31
#          Function evaluations: 40
#          Gradient evaluations: 40
#
#  ***** evaluating model m_filter_prev_violation_stim_itrx w/ sigma 0.5 *****
# Optimization terminated successfully.
#          Current function value: 84831.805622
#          Iterations: 29
#          Function evaluations: 37
#          Gradient evaluations: 37
#
#  ***** evaluating model m_filter_prev_violation_stim_itrx w/ sigma 1 *****
# Optimization terminated successfully.
#          Current function value: 84822.322019
#          Iterations: 29
#          Function evaluations: 37
#          Gradient evaluations: 37
#
#  ***** evaluating model m_filter_prev_violation_stim_itrx w/ sigma 2 *****
# Optimization terminated successfully.
#          Current function value: 84819.941491
#          Iterations: 29
#          Function evaluations: 37
#          Gradient evaluations: 37
#
#  ***** evaluating model m_filter_prev_violation_stim_itrx w/ sigma 4 *****
# Optimization terminated successfully.
#          Current function value: 84819.345747
#          Iterations: 29
#          Function evaluations: 37
#          Gradient evaluations: 37
#
#  ***** evaluating model m_filter_prev_violation_stim_itrx w/ sigma 8 *****
# Optimization terminated successfully.
#          Current function value: 84819.196772
#          Iterations: 29
#          Function evaluations: 37
#          Gradient evaluations: 37
#
#  ***** evaluating model m_filter_prev_violation_stim_itrx w/ sigma 16 *****
# Optimization terminated successfully.
#          Current function value: 84819.159526
#          Iterations: 29
#          Function evaluations: 37
# ...
#          Iterations: 29
#          Function evaluations: 91
#          Gradient evaluations: 79
#
#  ***** evaluating model m_filter_prev_violation w/ sigma 0.5 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 92062.897707
#          Iterations: 29
#          Function evaluations: 68
#          Gradient evaluations: 56
#
#  ***** evaluating model m_filter_prev_violation w/ sigma 1 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 92051.915234
#          Iterations: 28
#          Function evaluations: 86
#          Gradient evaluations: 75
#
#  ***** evaluating model m_filter_prev_violation w/ sigma 2 *****
# Optimization terminated successfully.
#          Current function value: 92049.163418
#          Iterations: 30
#          Function evaluations: 40
#          Gradient evaluations: 40
#
#  ***** evaluating model m_filter_prev_violation w/ sigma 4 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 92048.475076
#          Iterations: 28
#          Function evaluations: 38
#          Gradient evaluations: 38
#
#  ***** evaluating model m_filter_prev_violation w/ sigma 8 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 92048.302966
#          Iterations: 28
#          Function evaluations: 41
#          Gradient evaluations: 41
#
#  ***** evaluating model m_filter_prev_violation w/ sigma 16 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 92048.259937
#          Iterations: 29
#          Function evaluations: 39
#          Gradient evaluations: 39
#
#  ***** evaluating model m_filter_prev_violation_stim_itrx w/ sigma 0.07 *****
# Optimization terminated successfully.
#          Current function value: 92538.854513
#          Iterations: 39
#          Function evaluations: 66
#          Gradient evaluations: 65
#
#  ***** evaluating model m_filter_prev_violation_stim_itrx w/ sigma 0.13 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 92028.888647
#          Iterations: 33
#          Function evaluations: 96
#          Gradient evaluations: 85
#
#  ***** evaluating model m_filter_prev_violation_stim_itrx w/ sigma 0.25 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 91857.024470
#          Iterations: 33
#          Function evaluations: 45
#          Gradient evaluations: 45
#
#  ***** evaluating model m_filter_prev_violation_stim_itrx w/ sigma 0.5 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 91807.114572
#          Iterations: 35
#          Function evaluations: 169
#          Gradient evaluations: 153
#
#  ***** evaluating model m_filter_prev_violation_stim_itrx w/ sigma 1 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 91794.476720
#          Iterations: 32
#          Function evaluations: 68
#          Gradient evaluations: 57
#
#  ***** evaluating model m_filter_prev_violation_stim_itrx w/ sigma 2 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 91791.306940
#          Iterations: 32
#          Function evaluations: 42
#          Gradient evaluations: 42
#
#  ***** evaluating model m_filter_prev_violation_stim_itrx w/ sigma 4 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 91790.513846
#          Iterations: 33
#          Function evaluations: 86
#          Gradient evaluations: 75
#
#  ***** evaluating model m_filter_prev_violation_stim_itrx w/ sigma 8 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 91790.315532
#          Iterations: 33
#          Function evaluations: 43
#          Gradient evaluations: 43
#
#  ***** evaluating model m_filter_prev_violation_stim_itrx w/ sigma 16 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 91790.265951
#          Iterations: 33
#          Function evaluations: 97
#          Gradient evaluations: 83
#
#  >>>> evaluating animal W094 <<<<
#
#  ***** evaluating model b_psytrack_features w/ sigma 0.07 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 18808.262850
#          Iterations: 16
#          Function evaluations: 94
#          Gradient evaluations: 83
#
#  ***** evaluating model b_psytrack_features w/ sigma 0.13 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 19178.667695
#          Iterations: 12
#          Function evaluations: 69
#          Gradient evaluations: 57
#
#  ***** evaluating model b_psytrack_features w/ sigma 0.25 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 19333.193779
#          Iterations: 13
#          Function evaluations: 74
#          Gradient evaluations: 62
#
#  ***** evaluating model b_psytrack_features w/ sigma 0.5 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 19380.896047
#          Iterations: 13
#          Function evaluations: 83
#          Gradient evaluations: 71
#
#  ***** evaluating model b_psytrack_features w/ sigma 1 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 19393.174675
#          Iterations: 12
#          Function evaluations: 59
#          Gradient evaluations: 47
#
#  ***** evaluating model b_psytrack_features w/ sigma 2 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 19396.267744
#          Iterations: 13
#          Function evaluations: 63
#          Gradient evaluations: 51
#
#  ***** evaluating model b_psytrack_features w/ sigma 4 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 19397.042276
#          Iterations: 13
#          Function evaluations: 73
#          Gradient evaluations: 61
#
#  ***** evaluating model b_psytrack_features w/ sigma 8 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 19397.235998
#          Iterations: 13
#          Function evaluations: 71
#          Gradient evaluations: 59
#
#  ***** evaluating model b_psytrack_features w/ sigma 16 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 19397.284434
#          Iterations: 14
#          Function evaluations: 69
#          Gradient evaluations: 57
#
#  ***** evaluating model m_psytrack_features w/ sigma 0.07 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 46181.052893
#          Iterations: 21
#          Function evaluations: 61
#          Gradient evaluations: 49
#
#  ***** evaluating model m_psytrack_features w/ sigma 0.13 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 45920.160201
#          Iterations: 21
#          Function evaluations: 67
#          Gradient evaluations: 55
#
#  ***** evaluating model m_psytrack_features w/ sigma 0.25 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 45838.411439
#          Iterations: 21
#          Function evaluations: 74
#          Gradient evaluations: 62
#
#  ***** evaluating model m_psytrack_features w/ sigma 0.5 *****
# Optimization terminated successfully.
#          Current function value: 45815.334405
#          Iterations: 21
#          Function evaluations: 33
#          Gradient evaluations: 33
#
#  ***** evaluating model m_psytrack_features w/ sigma 1 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 45809.540510
#          Iterations: 20
#          Function evaluations: 79
#          Gradient evaluations: 68
#
#  ***** evaluating model m_psytrack_features w/ sigma 2 *****
# Optimization terminated successfully.
#          Current function value: 45808.090487
#          Iterations: 21
#          Function evaluations: 33
#          Gradient evaluations: 33
#
#  ***** evaluating model m_psytrack_features w/ sigma 4 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 45807.727884
#          Iterations: 21
#          Function evaluations: 71
#          Gradient evaluations: 60
#
#  ***** evaluating model m_psytrack_features w/ sigma 8 *****
# Optimization terminated successfully.
#          Current function value: 45807.637227
#          Iterations: 21
#          Function evaluations: 33
#          Gradient evaluations: 33
#
#  ***** evaluating model m_psytrack_features w/ sigma 16 *****
# Optimization terminated successfully.
#          Current function value: 45807.614562
#          Iterations: 21
#          Function evaluations: 33
#          Gradient evaluations: 33
#
#  ***** evaluating model m_prev_violation w/ sigma 0.07 *****
# Optimization terminated successfully.
#          Current function value: 45736.379940
#          Iterations: 25
#          Function evaluations: 42
#          Gradient evaluations: 42
#
#  ***** evaluating model m_prev_violation w/ sigma 0.13 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 45445.112363
#          Iterations: 25
#          Function evaluations: 62
#          Gradient evaluations: 59
#
#  ***** evaluating model m_prev_violation w/ sigma 0.25 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 45353.497493
#          Iterations: 23
#          Function evaluations: 73
#          Gradient evaluations: 61
#
#  ***** evaluating model m_prev_violation w/ sigma 0.5 *****
# Optimization terminated successfully.
#          Current function value: 45327.604699
#          Iterations: 23
#          Function evaluations: 35
#          Gradient evaluations: 35
#
#  ***** evaluating model m_prev_violation w/ sigma 1 *****
# Optimization terminated successfully.
#          Current function value: 45321.101728
#          Iterations: 23
#          Function evaluations: 35
#          Gradient evaluations: 35
#
#  ***** evaluating model m_prev_violation w/ sigma 2 *****
# Optimization terminated successfully.
#          Current function value: 45319.474112
#          Iterations: 23
#          Function evaluations: 35
#          Gradient evaluations: 35
#
#  ***** evaluating model m_prev_violation w/ sigma 4 *****
# Optimization terminated successfully.
#          Current function value: 45319.067091
#          Iterations: 23
#          Function evaluations: 35
#          Gradient evaluations: 35
#
#  ***** evaluating model m_prev_violation w/ sigma 8 *****
# Optimization terminated successfully.
#          Current function value: 45318.965328
#          Iterations: 23
#          Function evaluations: 35
#          Gradient evaluations: 35
#
#  ***** evaluating model m_prev_violation w/ sigma 16 *****
# Optimization terminated successfully.
#          Current function value: 45318.939887
#          Iterations: 23
#          Function evaluations: 35
#          Gradient evaluations: 35
#
#  ***** evaluating model m_filter_prev_violation w/ sigma 0.07 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 45603.676258
#          Iterations: 24
#          Function evaluations: 38
#          Gradient evaluations: 38
#
#  ***** evaluating model m_filter_prev_violation w/ sigma 0.13 *****
# Optimization terminated successfully.
#          Current function value: 45111.695525
#          Iterations: 25
#          Function evaluations: 37
#          Gradient evaluations: 37
#
#  ***** evaluating model m_filter_prev_violation w/ sigma 0.25 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 44921.391554
#          Iterations: 25
#          Function evaluations: 85
#          Gradient evaluations: 74
#
#  ***** evaluating model m_filter_prev_violation w/ sigma 0.5 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 44862.795603
#          Iterations: 25
#          Function evaluations: 37
#          Gradient evaluations: 37
#
#  ***** evaluating model m_filter_prev_violation w/ sigma 1 *****
# Optimization terminated successfully.
#          Current function value: 44847.687522
#          Iterations: 26
#          Function evaluations: 77
#          Gradient evaluations: 74
#
#  ***** evaluating model m_filter_prev_violation w/ sigma 2 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 44843.880337
#          Iterations: 24
#          Function evaluations: 64
#          Gradient evaluations: 52
#
#  ***** evaluating model m_filter_prev_violation w/ sigma 4 *****
# Optimization terminated successfully.
#          Current function value: 44842.926631
#          Iterations: 25
#          Function evaluations: 36
#          Gradient evaluations: 36
#
#  ***** evaluating model m_filter_prev_violation w/ sigma 8 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 44842.688085
#          Iterations: 23
#          Function evaluations: 73
#          Gradient evaluations: 61
#
#  ***** evaluating model m_filter_prev_violation w/ sigma 16 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 44842.628441
#          Iterations: 24
#          Function evaluations: 35
#          Gradient evaluations: 35
#
#  ***** evaluating model m_filter_prev_violation_stim_itrx w/ sigma 0.07 *****
# Optimization terminated successfully.
#          Current function value: 45582.510569
#          Iterations: 31
#          Function evaluations: 47
#          Gradient evaluations: 47
#
#  ***** evaluating model m_filter_prev_violation_stim_itrx w/ sigma 0.13 *****
# Optimization terminated successfully.
#          Current function value: 45057.061490
#          Iterations: 31
#          Function evaluations: 40
#          Gradient evaluations: 40
#
#  ***** evaluating model m_filter_prev_violation_stim_itrx w/ sigma 0.25 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 44842.079913
#          Iterations: 28
#          Function evaluations: 75
#          Gradient evaluations: 64
#
#  ***** evaluating model m_filter_prev_violation_stim_itrx w/ sigma 0.5 *****
# Optimization terminated successfully.
#          Current function value: 44772.599851
#          Iterations: 28
#          Function evaluations: 37
#          Gradient evaluations: 37
#
#  ***** evaluating model m_filter_prev_violation_stim_itrx w/ sigma 1 *****
# Optimization terminated successfully.
#          Current function value: 44754.278119
#          Iterations: 28
#          Function evaluations: 37
#          Gradient evaluations: 37
#
#  ***** evaluating model m_filter_prev_violation_stim_itrx w/ sigma 2 *****
# Optimization terminated successfully.
#          Current function value: 44749.629789
#          Iterations: 28
#          Function evaluations: 37
#          Gradient evaluations: 37
#
#  ***** evaluating model m_filter_prev_violation_stim_itrx w/ sigma 4 *****
# Optimization terminated successfully.
#          Current function value: 44748.463304
#          Iterations: 28
#          Function evaluations: 37
#          Gradient evaluations: 37
#
#  ***** evaluating model m_filter_prev_violation_stim_itrx w/ sigma 8 *****
# Optimization terminated successfully.
#          Current function value: 44748.171405
#          Iterations: 28
#          Function evaluations: 37
#          Gradient evaluations: 37
#
#  ***** evaluating model m_filter_prev_violation_stim_itrx w/ sigma 16 *****
# Optimization terminated successfully.
#          Current function value: 44748.098413
#          Iterations: 28
#          Function evaluations: 37
#          Gradient evaluations: 37

# %% [markdown]
# ## Visualize

# %%
experiment = load_experiment(save_name)
mvc = ModelVisualizerCompare(experiment)

df = mvc.find_best_fit(group="model_name")
df["model_name"] = pd.Categorical(df["model_name"], categories=ORDER, ordered=True)
for model_name, model_df in df.groupby("model_name"):
    mvc.plot_sigma_summary(model_df, title=f"{model_name} fit sigma summary")

# %%
fig, ax = plt.subplots(
    len(ORDER), 1, figsize=(10, len(ORDER) * 6), constrained_layout=True, sharey=True
)

best_fit_by_model = mvc.find_best_fit(group=["animal_id", "model_name"])
best_fit_by_model["model_name"] = pd.Categorical(
    best_fit_by_model["model_name"], categories=ORDER, ordered=True
)

for ii, (model_name, model_df) in enumerate(best_fit_by_model.groupby("model_name")):
    if model_name == ORDER[0]:
        continue
    unpacked = mvc.unpack_features_and_weights(model_df)

    mvc.plot_weights_summary(
        df=unpacked,
        ax=ax[ii],
        palette="Set2",
        title=f"{model_name} weights summary",
    )

# %%
fig, ax = plt.subplots(1, 1, figsize=(8, 5))
mvc.plot_model_comparison(
    hue=None,
    ax=ax,
    order=ORDER,
    errorbar=None,
)

# %%
fig, ax = plt.subplots(1, 1, figsize=(8, 5))
mvc.plot_model_comparison(
    hue=None,
    ax=ax,
    order=ORDER[3:],
    errorbar=None,
)

# %%
fig, ax = plt.subplots(1, 1, figsize=(8, 5))
mvc.plot_model_comparison(
    hue=None,
    ax=ax,
    order=[ORDER[0], ORDER[-1]],
    errorbar=None,
)

# %%
mvc.plot_train_and_test_ll(
    order=ORDER,
    errorbar=None,
)

# %%
mvc.plot_ll_delta_by_animal(
    base_model_name=ORDER[0],
    new_model_name=ORDER[4],
    type="test",
)
# Out:
# <Axes: title={'center': 'Model Improvement- mu: 10.94 std: 43.41 \n b_psytrack_features -> m_filter_prev_violation_stim_itrx'}, xlabel='animal_id', ylabel='Delta test LL (new - base)'>

# %%
mvc.plot_ll_delta_by_animal(
    base_model_name=ORDER[2],
    new_model_name=ORDER[4],
    type="test",
)
# Out:
# <Axes: title={'center': 'Model Improvement- mu: 19.09 std: 24.36 \n m_prev_violation -> m_filter_prev_violation_stim_itrx'}, xlabel='animal_id', ylabel='Delta test LL (new - base)'>

# %%
for i in range(len(ORDER)):
    for j in range(i + 1, len(ORDER)):
        mvc.plot_delta_ll_by_violation_rate(ORDER[i], ORDER[j])

# %%
for i in range(len(ORDER)):
    for j in range(i + 1, len(ORDER)):
        mvc.plot_delta_ll_by_train_test_size(ORDER[i], ORDER[j])

# %%
# TODO- bits per trial vs violation rate?

# %%
# TODO- bits per trial vs violation rate?
