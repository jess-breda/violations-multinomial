# %% [markdown]
# # Experiment: Compare Previous Disengaged
#
# **Goal**: Compare models with various disengaged regressors- combined, on their own or alone.
#
# Additional Notes
#
# Related notebooks:
#
# * `2024_03_20_tau_sweep_prev_disengaged_combo.ipynb`
# * `2024_03_20_tau_sweep_prev_disengaged_binary_combo.ipynb`
#
# > Written by Jess Breda
#
# Models being compared:
#
# 1. Base model (psytrack features)
# 2. Only prev violation
# 3. Only prev tns
# 4. Only filt prev violation
# 5. Only filt prev tns
# 6. Prev viol abd prev tns
# 7. Filt prev viol and filt prev tns
# 8. prev tns + prev viol then filt combo
# 9. n prev tns + prev viol then filt combo (maybe)

# %% [markdown]
# ## Imports

# %%
import seaborn as sns
import matplotlib.pyplot as plt

from multiglm.experiments.experiment import load_experiment

from multiglm.experiments.experiment_compare_models import ExperimentCompareModels

from multiglm.features.design_matrix_generator import *
from multiglm.features.design_matrix_generator_PWM import *

from multiglm.models.multiclass_logistic_regression import MultiClassLogisticRegression

from multiglm.visualizations.model_visualizer import ModelVisualizerCompare

from multiglm.data import ANIMAL_IDS
from multiglm.experiments import STANDARD_SIGMAS


sns.set_context("talk")
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# ## Model Configs

# %% [markdown]
# ### Compare

# %%
# design matrix columns shared between all models being fit
shared_cols = {
    "session": lambda df: (copy(df.session)),
    "bias": lambda df: (add_bias_column(df)),
    "s_a": lambda df: (standardize(df.s_a)),
    "s_b": lambda df: (standardize(df.s_b)),
    "prev_avg_stim": lambda df: (prev_avg_stim(df, mask_prev_violation=True)),
    "prev_correct": lambda df: (prev_correct_side(df)),
    "prev_choice": lambda df: (prev_choice(df)),
    "labels": {"column_name": "choice"},
}

models_config = {
    "prev_tns_only": {
        "model_class": MultiClassLogisticRegression,
        "dmg_config": {
            **shared_cols,
            "prev_tns": lambda df: (prev_trial_not_started(df)),
        },
    },
    "base": {
        "model_class": MultiClassLogisticRegression,
        "dmg_config": {
            **shared_cols,
        },
    },
    "prev_viol_only": {
        "model_class": MultiClassLogisticRegression,
        "dmg_config": {
            **shared_cols,
            "prev_viol": lambda df: (prev_violation(df)),
        },
    },
    "filt_prev_viol_only": {
        "model_class": MultiClassLogisticRegression,
        "dmg_config": {
            **shared_cols,
            "filt_prev_viol": lambda df: (
                filtered_prev_viol(df, get_animals_tau(df, var_name="prev_violation"))
            ),
        },
    },
    "binary_prev_tns_and_viol": {
        "model_class": MultiClassLogisticRegression,
        "dmg_config": {
            **shared_cols,
            "prev_viol": lambda df: (prev_violation(df)),
            "prev_tns": lambda df: (prev_trial_not_started(df)),
        },
    },
    "binary_prev_tns_viol_added": {
        "model_class": MultiClassLogisticRegression,
        "dmg_config": {
            **shared_cols,
            "prev_viol_tns": lambda df: combine_two_cols(
                prev_violation(df),
                prev_trial_not_started(df),
                operator.add,
            ),
        },
    },
}
# "filt_prev_tns_only": {
#     "model_class": MultiClassLogisticRegression,
#     "dmg_config": {
#         **shared_cols,
#         "filt_prev_tns": lambda df: exp_filter_column(
#             prev_trial_not_started(df),
#             df.session,
#             get_animals_tau(df, var_name="prev_trial_not_started")
#         ),
#     },
# },

# }

params = {
    "animals": ANIMAL_IDS,
    "data_type": "new_trained",
    "sigmas": STANDARD_SIGMAS,
    "random_state": 47,
    "eval_train": True,
    "null_mode": "multi",
    "model_config": models_config,
}

save_name = "2024_03_20_compare_prev_disengaged_no_filt.pkl"

ORDER = [
    "base",
    "prev_viol_only",
    "filt_prev_viol_only",
    "prev_tns_only",
    "binary_prev_tns_and_viol",
    "binary_prev_tns_viol_added",
]

# %% [markdown]
# ## Run

# %%
experiment = ExperimentCompareModels(params)
experiment.run()
experiment.save(save_name)
# Out:
# Loading dataset type : new_trained
# Loading data for animal ids:  ['W051', 'W060', 'W065', 'W066', 'W068', 'W072', 'W073', 'W074', 'W075', 'W078', 'W080', 'W081', 'W082', 'W083', 'W088', 'W089', 'W094']
#
#  >>>> evaluating animal W051 <<<<
#
#  ***** evaluating model prev_tns_only w/ sigma 0.07 *****
# Optimization terminated successfully.
#          Current function value: 64969.072609
#          Iterations: 27
#          Function evaluations: 45
#          Gradient evaluations: 45
#
#  ***** evaluating model prev_tns_only w/ sigma 0.13 *****
# Optimization terminated successfully.
#          Current function value: 64694.617404
#          Iterations: 28
#          Function evaluations: 47
#          Gradient evaluations: 47
#
#  ***** evaluating model prev_tns_only w/ sigma 0.25 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 64578.136529
#          Iterations: 26
#          Function evaluations: 76
#          Gradient evaluations: 65
#
#  ***** evaluating model prev_tns_only w/ sigma 0.5 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 64533.225780
#          Iterations: 24
#          Function evaluations: 89
#          Gradient evaluations: 77
#
#  ***** evaluating model prev_tns_only w/ sigma 1 *****
# Optimization terminated successfully.
#          Current function value: 64519.839481
#          Iterations: 27
#          Function evaluations: 40
#          Gradient evaluations: 40
#
#  ***** evaluating model prev_tns_only w/ sigma 2 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 64516.266685
#          Iterations: 27
#          Function evaluations: 124
#          Gradient evaluations: 109
#
#  ***** evaluating model prev_tns_only w/ sigma 4 *****
# Optimization terminated successfully.
#          Current function value: 64515.356030
#          Iterations: 28
#          Function evaluations: 69
#          Gradient evaluations: 68
#
#  ***** evaluating model prev_tns_only w/ sigma 8 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 64515.127202
#          Iterations: 27
#          Function evaluations: 70
#          Gradient evaluations: 58
#
#  ***** evaluating model prev_tns_only w/ sigma 16 *****
# Optimization terminated successfully.
#          Current function value: 64515.069921
#          Iterations: 27
#          Function evaluations: 40
#          Gradient evaluations: 40
#
#  ***** evaluating model base w/ sigma 0.07 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 64995.381251
#          Iterations: 25
#          Function evaluations: 116
#          Gradient evaluations: 103
#
#  ***** evaluating model base w/ sigma 0.13 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 64759.621472
#          Iterations: 25
#          Function evaluations: 107
#          Gradient evaluations: 94
#
#  ***** evaluating model base w/ sigma 0.25 *****
# Optimization terminated successfully.
#          Current function value: 64687.335235
#          Iterations: 24
#          Function evaluations: 36
#          Gradient evaluations: 36
#
#  ***** evaluating model base w/ sigma 0.5 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 64667.068445
#          Iterations: 22
#          Function evaluations: 44
#          Gradient evaluations: 39
#
#  ***** evaluating model base w/ sigma 1 *****
# Optimization terminated successfully.
#          Current function value: 64661.989770
#          Iterations: 24
#          Function evaluations: 62
#          Gradient evaluations: 61
#
#  ***** evaluating model base w/ sigma 2 *****
# Optimization terminated successfully.
#          Current function value: 64660.719350
#          Iterations: 23
#          Function evaluations: 34
#          Gradient evaluations: 34
#
#  ***** evaluating model base w/ sigma 4 *****
# Optimization terminated successfully.
#          Current function value: 64660.401698
#          Iterations: 23
#          Function evaluations: 34
#          Gradient evaluations: 34
#
#  ***** evaluating model base w/ sigma 8 *****
# Optimization terminated successfully.
#          Current function value: 64660.322282
#          Iterations: 23
#          Function evaluations: 34
#          Gradient evaluations: 34
#
#  ***** evaluating model base w/ sigma 16 *****
# Optimization terminated successfully.
#          Current function value: 64660.302428
#          Iterations: 23
#          Function evaluations: 34
#          Gradient evaluations: 34
#
#  ***** evaluating model prev_viol_only w/ sigma 0.07 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 64817.693586
#          Iterations: 27
#          Function evaluations: 56
#          Gradient evaluations: 51
#
#  ***** evaluating model prev_viol_only w/ sigma 0.13 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 64568.968491
#          Iterations: 26
#          Function evaluations: 91
#          Gradient evaluations: 79
#
#  ***** evaluating model prev_viol_only w/ sigma 0.25 *****
# Optimization terminated successfully.
#          Current function value: 64492.465884
#          Iterations: 27
#          Function evaluations: 42
#          Gradient evaluations: 42
#
#  ***** evaluating model prev_viol_only w/ sigma 0.5 *****
# Optimization terminated successfully.
#          Current function value: 64470.995571
#          Iterations: 25
#          Function evaluations: 41
#          Gradient evaluations: 41
#
#  ***** evaluating model prev_viol_only w/ sigma 1 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 64465.613813
#          Iterations: 25
#          Function evaluations: 138
#          Gradient evaluations: 123
#
#  ***** evaluating model prev_viol_only w/ sigma 2 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 64464.267484
#          Iterations: 24
#          Function evaluations: 94
#          Gradient evaluations: 83
#
#  ***** evaluating model prev_viol_only w/ sigma 4 *****
# Optimization terminated successfully.
#          Current function value: 64463.930846
#          Iterations: 25
#          Function evaluations: 42
#          Gradient evaluations: 42
#
#  ***** evaluating model prev_viol_only w/ sigma 8 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 64463.846683
#          Iterations: 24
#          Function evaluations: 40
#          Gradient evaluations: 40
#
#  ***** evaluating model prev_viol_only w/ sigma 16 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 64463.825642
#          Iterations: 23
#          Function evaluations: 86
#          Gradient evaluations: 75
#
#  ***** evaluating model filt_prev_viol_only w/ sigma 0.07 *****
# Optimization terminated successfully.
#          Current function value: 64772.423027
#          Iterations: 26
#          Function evaluations: 38
#          Gradient evaluations: 38
#
#  ***** evaluating model filt_prev_viol_only w/ sigma 0.13 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 64482.383639
#          Iterations: 25
#          Function evaluations: 37
#          Gradient evaluations: 37
#
#  ***** evaluating model filt_prev_viol_only w/ sigma 0.25 *****
# Optimization terminated successfully.
#          Current function value: 64388.728385
#          Iterations: 25
#          Function evaluations: 36
#          Gradient evaluations: 36
#
#  ***** evaluating model filt_prev_viol_only w/ sigma 0.5 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 64361.957590
#          Iterations: 23
#          Function evaluations: 70
#          Gradient evaluations: 67
#
#  ***** evaluating model filt_prev_viol_only w/ sigma 1 *****
# Optimization terminated successfully.
#          Current function value: 64355.210888
#          Iterations: 24
#          Function evaluations: 34
#          Gradient evaluations: 34
#
#  ***** evaluating model filt_prev_viol_only w/ sigma 2 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 64353.520767
#          Iterations: 22
#          Function evaluations: 87
#          Gradient evaluations: 75
#
#  ***** evaluating model filt_prev_viol_only w/ sigma 4 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 64353.098020
#          Iterations: 22
#          Function evaluations: 94
#          Gradient evaluations: 83
#
#  ***** evaluating model filt_prev_viol_only w/ sigma 8 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 64352.992320
#          Iterations: 22
#          Function evaluations: 81
#          Gradient evaluations: 69
#
#  ***** evaluating model filt_prev_viol_only w/ sigma 16 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 64352.965894
#          Iterations: 23
#          Function evaluations: 33
#          Gradient evaluations: 33
#
#  ***** evaluating model binary_prev_tns_and_viol w/ sigma 0.07 *****
# Optimization terminated successfully.
#          Current function value: 64793.385595
#          Iterations: 29
#          Function evaluations: 46
#          Gradient evaluations: 46
#
#  ***** evaluating model binary_prev_tns_and_viol w/ sigma 0.13 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 64509.945051
#          Iterations: 28
#          Function evaluations: 44
#          Gradient evaluations: 44
#
#  ***** evaluating model binary_prev_tns_and_viol w/ sigma 0.25 *****
# Optimization terminated successfully.
#          Current function value: 64393.852353
#          Iterations: 28
#          Function evaluations: 41
#          Gradient evaluations: 41
#
#  ***** evaluating model binary_prev_tns_and_viol w/ sigma 0.5 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 64350.069180
#          Iterations: 28
#          Function evaluations: 81
#          Gradient evaluations: 69
#
#  ***** evaluating model binary_prev_tns_and_viol w/ sigma 1 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 64337.117796
#          Iterations: 28
#          Function evaluations: 40
#          Gradient evaluations: 40
#
#  ***** evaluating model binary_prev_tns_and_viol w/ sigma 2 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 64333.669432
#          Iterations: 27
#          Function evaluations: 80
#          Gradient evaluations: 68
#
#  ***** evaluating model binary_prev_tns_and_viol w/ sigma 4 *****
# Optimization terminated successfully.
#          Current function value: 64332.791114
#          Iterations: 29
#          Function evaluations: 41
#          Gradient evaluations: 41
#
#  ***** evaluating model binary_prev_tns_and_viol w/ sigma 8 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 64332.570453
#          Iterations: 27
#          Function evaluations: 86
#          Gradient evaluations: 74
#
#  ***** evaluating model binary_prev_tns_and_viol w/ sigma 16 *****
# Optimization terminated successfully.
#          Current function value: 64332.515219
#          Iterations: 29
#          Function evaluations: 41
#          Gradient evaluations: 41
#
#  ***** evaluating model binary_prev_tns_viol_added w/ sigma 0.07 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 
#          Iterations: 30
#          Function evaluations: 39
#          Gradient evaluations: 39
#
#  ***** evaluating model binary_prev_tns_and_viol w/ sigma 16 *****
# Optimization terminated successfully.
#          Current function value: 56732.529457
#          Iterations: 30
#          Function evaluations: 39
#          Gradient evaluations: 39
#
#  ***** evaluating model binary_prev_tns_viol_added w/ sigma 0.07 *****
# Optimization terminated successfully.
#          Current function value: 57513.213449
#          Iterations: 28
#          Function evaluations: 42
#          Gradient evaluations: 42
#
#  ***** evaluating model binary_prev_tns_viol_added w/ sigma 0.13 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 57251.646796
#          Iterations: 26
#          Function evaluations: 43
#          Gradient evaluations: 43
#
#  ***** evaluating model binary_prev_tns_viol_added w/ sigma 0.25 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 57170.037150
#          Iterations: 26
#          Function evaluations: 71
#          Gradient evaluations: 59
#
#  ***** evaluating model binary_prev_tns_viol_added w/ sigma 0.5 *****
# Optimization terminated successfully.
#          Current function value: 57147.031165
#          Iterations: 27
#          Function evaluations: 43
#          Gradient evaluations: 43
#
#  ***** evaluating model binary_prev_tns_viol_added w/ sigma 1 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 57141.257339
#          Iterations: 25
#          Function evaluations: 93
#          Gradient evaluations: 81
#
#  ***** evaluating model binary_prev_tns_viol_added w/ sigma 2 *****
# Optimization terminated successfully.
#          Current function value: 57139.812479
#          Iterations: 26
#          Function evaluations: 39
#          Gradient evaluations: 39
#
#  ***** evaluating model binary_prev_tns_viol_added w/ sigma 4 *****
# Optimization terminated successfully.
#          Current function value: 57139.451176
#          Iterations: 26
#          Function evaluations: 39
#          Gradient evaluations: 39
#
#  ***** evaluating model binary_prev_tns_viol_added w/ sigma 8 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 57139.360845
#          Iterations: 25
#          Function evaluations: 87
#          Gradient evaluations: 75
#
#  ***** evaluating model binary_prev_tns_viol_added w/ sigma 16 *****
# Optimization terminated successfully.
#          Current function value: 57139.338262
#          Iterations: 26
#          Function evaluations: 39
#          Gradient evaluations: 39
#
#  >>>> evaluating animal W066 <<<<
#
#  ***** evaluating model prev_tns_only w/ sigma 0.07 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 85647.970892
#          Iterations: 28
#          Function evaluations: 91
#          Gradient evaluations: 79
#
#  ***** evaluating model prev_tns_only w/ sigma 0.13 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 85306.415866
#          Iterations: 25
#          Function evaluations: 38
#          Gradient evaluations: 38
#
#  ***** evaluating model prev_tns_only w/ sigma 0.25 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 85172.884158
#          Iterations: 26
#          Function evaluations: 78
#          Gradient evaluations: 67
#
#  ***** evaluating model prev_tns_only w/ sigma 0.5 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 85120.997900
#          Iterations: 26
#          Function evaluations: 38
#          Gradient evaluations: 38
#
#  ***** evaluating model prev_tns_only w/ sigma 1 *****
# Optimization terminated successfully.
#          Current function value: 85104.153817
#          Iterations: 28
#          Function evaluations: 39
#          Gradient evaluations: 39
#
#  ***** evaluating model prev_tns_only w/ sigma 2 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 85099.321194
#          Iterations: 28
#          Function evaluations: 42
#          Gradient evaluations: 42
#
#  ***** evaluating model prev_tns_only w/ sigma 4 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 85098.047351
#          Iterations: 28
#          Function evaluations: 144
#          Gradient evaluations: 131
#
#  ***** evaluating model prev_tns_only w/ sigma 8 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 85097.723784
#          Iterations: 28
#          Function evaluations: 84
#          Gradient evaluations: 72
#
#  ***** evaluating model prev_tns_only w/ sigma 16 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 85097.642550
#          Iterations: 28
#          Function evaluations: 77
#          Gradient evaluations: 65
#
#  ***** evaluating model base w/ sigma 0.07 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 85668.959699
#          Iterations: 26
#          Function evaluations: 37
#          Gradient evaluations: 37
#
#  ***** evaluating model base w/ sigma 0.13 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 85357.449002
#          Iterations: 24
#          Function evaluations: 81
#          Gradient evaluations: 71
#
#  ***** evaluating model base w/ sigma 0.25 *****
# Optimization terminated successfully.
#          Current function value: 85261.035000
#          Iterations: 23
#          Function evaluations: 32
#          Gradient evaluations: 32
#
#  ***** evaluating model base w/ sigma 0.5 *****
# Optimization terminated successfully.
#          Current function value: 85233.925205
#          Iterations: 23
#          Function evaluations: 33
#          Gradient evaluations: 33
#
#  ***** evaluating model base w/ sigma 1 *****
# Optimization terminated successfully.
#          Current function value: 85227.126307
#          Iterations: 23
#          Function evaluations: 31
#          Gradient evaluations: 31
#
#  ***** evaluating model base w/ sigma 2 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 85225.425236
#          Iterations: 22
#          Function evaluations: 30
#          Gradient evaluations: 30
#
#  ***** evaluating model base w/ sigma 4 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 85224.999884
#          Iterations: 21
#          Function evaluations: 71
#          Gradient evaluations: 59
#
#  ***** evaluating model base w/ sigma 8 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 85224.893541
#          Iterations: 22
#          Function evaluations: 55
#          Gradient evaluations: 44
#
#  ***** evaluating model base w/ sigma 16 *****
# Optimization terminated successfully.
#          Current function value: 85224.866954
#          Iterations: 23
#          Function evaluations: 33
#          Gradient evaluations: 33
#
#  ***** evaluating model prev_viol_only w/ sigma 0.07 *****
# Optimization terminated successfully.
#          Current function value: 85456.021884
#          Iterations: 27
#          Function evaluations: 41
#          Gradient evaluations: 41
#
#  ***** evaluating model prev_viol_only w/ sigma 0.13 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 85138.397518
#          Iterations: 25
#          Function evaluations: 84
#          Gradient evaluations: 72
#
#  ***** evaluating model prev_viol_only w/ sigma 0.25 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 85040.087310
#          Iterations: 26
#          Function evaluations: 38
#          Gradient evaluations: 38
#
#  ***** evaluating model prev_viol_only w/ sigma 0.5 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 85012.444022
#          Iterations: 24
#          Function evaluations: 89
#          Gradient evaluations: 77
#
#  ***** evaluating model prev_viol_only w/ sigma 1 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 85005.511308
#          Iterations: 25
#          Function evaluations: 36
#          Gradient evaluations: 36
#
#  ***** evaluating model prev_viol_only w/ sigma 2 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 85003.776755
#          Iterations: 26
#          Function evaluations: 43
#          Gradient evaluations: 43
#
# ...
#          Current function value: 92132.753994
#          Iterations: 31
#          Function evaluations: 98
#          Gradient evaluations: 87
#
#  ***** evaluating model binary_prev_tns_viol_added w/ sigma 0.25 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 92033.078841
#          Iterations: 28
#          Function evaluations: 42
#          Gradient evaluations: 42
#
#  ***** evaluating model binary_prev_tns_viol_added w/ sigma 0.5 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 92005.152461
#          Iterations: 29
#          Function evaluations: 109
#          Gradient evaluations: 97
#
#  ***** evaluating model binary_prev_tns_viol_added w/ sigma 1 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 91998.155699
#          Iterations: 27
#          Function evaluations: 84
#          Gradient evaluations: 72
#
#  ***** evaluating model binary_prev_tns_viol_added w/ sigma 2 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 91996.405557
#          Iterations: 29
#          Function evaluations: 135
#          Gradient evaluations: 122
#
#  ***** evaluating model binary_prev_tns_viol_added w/ sigma 4 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 91995.967962
#          Iterations: 28
#          Function evaluations: 86
#          Gradient evaluations: 74
#
#  ***** evaluating model binary_prev_tns_viol_added w/ sigma 8 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 91995.858560
#          Iterations: 26
#          Function evaluations: 91
#          Gradient evaluations: 80
#
#  ***** evaluating model binary_prev_tns_viol_added w/ sigma 16 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 91995.831209
#          Iterations: 29
#          Function evaluations: 65
#          Gradient evaluations: 64
#
#  >>>> evaluating animal W094 <<<<
#
#  ***** evaluating model prev_tns_only w/ sigma 0.07 *****
# Optimization terminated successfully.
#          Current function value: 46092.737729
#          Iterations: 27
#          Function evaluations: 39
#          Gradient evaluations: 39
#
#  ***** evaluating model prev_tns_only w/ sigma 0.13 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 45753.790791
#          Iterations: 25
#          Function evaluations: 54
#          Gradient evaluations: 47
#
#  ***** evaluating model prev_tns_only w/ sigma 0.25 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 45614.310341
#          Iterations: 25
#          Function evaluations: 88
#          Gradient evaluations: 76
#
#  ***** evaluating model prev_tns_only w/ sigma 0.5 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 45566.488516
#          Iterations: 25
#          Function evaluations: 92
#          Gradient evaluations: 79
#
#  ***** evaluating model prev_tns_only w/ sigma 1 *****
# Optimization terminated successfully.
#          Current function value: 45553.421850
#          Iterations: 25
#          Function evaluations: 36
#          Gradient evaluations: 36
#
#  ***** evaluating model prev_tns_only w/ sigma 2 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 45550.066412
#          Iterations: 25
#          Function evaluations: 36
#          Gradient evaluations: 36
#
#  ***** evaluating model prev_tns_only w/ sigma 4 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 45549.221573
#          Iterations: 25
#          Function evaluations: 79
#          Gradient evaluations: 67
#
#  ***** evaluating model prev_tns_only w/ sigma 8 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 45549.009982
#          Iterations: 25
#          Function evaluations: 36
#          Gradient evaluations: 36
#
#  ***** evaluating model prev_tns_only w/ sigma 16 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 45548.957061
#          Iterations: 24
#          Function evaluations: 75
#          Gradient evaluations: 65
#
#  ***** evaluating model base w/ sigma 0.07 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 46181.052794
#          Iterations: 22
#          Function evaluations: 36
#          Gradient evaluations: 36
#
#  ***** evaluating model base w/ sigma 0.13 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 45920.160099
#          Iterations: 21
#          Function evaluations: 84
#          Gradient evaluations: 73
#
#  ***** evaluating model base w/ sigma 0.25 *****
# Optimization terminated successfully.
#          Current function value: 45838.411336
#          Iterations: 22
#          Function evaluations: 35
#          Gradient evaluations: 35
#
#  ***** evaluating model base w/ sigma 0.5 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 45815.334302
#          Iterations: 20
#          Function evaluations: 72
#          Gradient evaluations: 60
#
#  ***** evaluating model base w/ sigma 1 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 45809.540407
#          Iterations: 20
#          Function evaluations: 62
#          Gradient evaluations: 50
#
#  ***** evaluating model base w/ sigma 2 *****
# Optimization terminated successfully.
#          Current function value: 45808.090384
#          Iterations: 22
#          Function evaluations: 58
#          Gradient evaluations: 57
#
#  ***** evaluating model base w/ sigma 4 *****
# Optimization terminated successfully.
#          Current function value: 45807.727781
#          Iterations: 21
#          Function evaluations: 33
#          Gradient evaluations: 33
#
#  ***** evaluating model base w/ sigma 8 *****
# Optimization terminated successfully.
#          Current function value: 45807.637124
#          Iterations: 21
#          Function evaluations: 33
#          Gradient evaluations: 33
#
#  ***** evaluating model base w/ sigma 16 *****
# Optimization terminated successfully.
#          Current function value: 45807.614460
#          Iterations: 21
#          Function evaluations: 33
#          Gradient evaluations: 33
#
#  ***** evaluating model prev_viol_only w/ sigma 0.07 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 45736.379875
#          Iterations: 22
#          Function evaluations: 80
#          Gradient evaluations: 69
#
#  ***** evaluating model prev_viol_only w/ sigma 0.13 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 45445.112294
#          Iterations: 24
#          Function evaluations: 80
#          Gradient evaluations: 68
#
#  ***** evaluating model prev_viol_only w/ sigma 0.25 *****
# Optimization terminated successfully.
#          Current function value: 45353.497421
#          Iterations: 24
#          Function evaluations: 37
#          Gradient evaluations: 37
#
#  ***** evaluating model prev_viol_only w/ sigma 0.5 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 45327.604627
#          Iterations: 23
#          Function evaluations: 90
#          Gradient evaluations: 77
#
#  ***** evaluating model prev_viol_only w/ sigma 1 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 45321.101656
#          Iterations: 23
#          Function evaluations: 79
#          Gradient evaluations: 68
#
#  ***** evaluating model prev_viol_only w/ sigma 2 *****
# Optimization terminated successfully.
#          Current function value: 45319.474040
#          Iterations: 23
#          Function evaluations: 35
#          Gradient evaluations: 35
#
#  ***** evaluating model prev_viol_only w/ sigma 4 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 45319.067019
#          Iterations: 23
#          Function evaluations: 101
#          Gradient evaluations: 87
#
#  ***** evaluating model prev_viol_only w/ sigma 8 *****
# Optimization terminated successfully.
#          Current function value: 45318.965256
#          Iterations: 23
#          Function evaluations: 35
#          Gradient evaluations: 35
#
#  ***** evaluating model prev_viol_only w/ sigma 16 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 45318.939815
#          Iterations: 21
#          Function evaluations: 67
#          Gradient evaluations: 55
#
#  ***** evaluating model filt_prev_viol_only w/ sigma 0.07 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 45603.676263
#          Iterations: 25
#          Function evaluations: 77
#          Gradient evaluations: 73
#
#  ***** evaluating model filt_prev_viol_only w/ sigma 0.13 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 45111.695605
#          Iterations: 25
#          Function evaluations: 117
#          Gradient evaluations: 104
#
#  ***** evaluating model filt_prev_viol_only w/ sigma 0.25 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 44921.391673
#          Iterations: 25
#          Function evaluations: 98
#          Gradient evaluations: 86
#
#  ***** evaluating model filt_prev_viol_only w/ sigma 0.5 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 44862.795736
#          Iterations: 24
#          Function evaluations: 35
#          Gradient evaluations: 35
#
#  ***** evaluating model filt_prev_viol_only w/ sigma 1 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 44847.687658
#          Iterations: 25
#          Function evaluations: 116
#          Gradient evaluations: 102
#
#  ***** evaluating model filt_prev_viol_only w/ sigma 2 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 44843.880474
#          Iterations: 24
#          Function evaluations: 35
#          Gradient evaluations: 35
#
#  ***** evaluating model filt_prev_viol_only w/ sigma 4 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 44842.926768
#          Iterations: 24
#          Function evaluations: 63
#          Gradient evaluations: 51
#
#  ***** evaluating model filt_prev_viol_only w/ sigma 8 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 44842.688222
#          Iterations: 24
#          Function evaluations: 35
#          Gradient evaluations: 35
#
#  ***** evaluating model filt_prev_viol_only w/ sigma 16 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 44842.628578
#          Iterations: 24
#          Function evaluations: 35
#          Gradient evaluations: 35
#
#  ***** evaluating model binary_prev_tns_and_viol w/ sigma 0.07 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 45657.797886
#          Iterations: 24
#          Function evaluations: 78
#          Gradient evaluations: 66
#
#  ***** evaluating model binary_prev_tns_and_viol w/ sigma 0.13 *****
# Optimization terminated successfully.
#          Current function value: 45297.926549
#          Iterations: 26
#          Function evaluations: 37
#          Gradient evaluations: 37
#
#  ***** evaluating model binary_prev_tns_and_viol w/ sigma 0.25 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 45154.443830
#          Iterations: 26
#          Function evaluations: 100
#          Gradient evaluations: 89
#
#  ***** evaluating model binary_prev_tns_and_viol w/ sigma 0.5 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 45105.974998
#          Iterations: 27
#          Function evaluations: 87
#          Gradient evaluations: 75
#
#  ***** evaluating model binary_prev_tns_and_viol w/ sigma 1 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 45092.797501
#          Iterations: 27
#          Function evaluations: 81
#          Gradient evaluations: 70
#
#  ***** evaluating model binary_prev_tns_and_viol w/ sigma 2 *****
# Optimization terminated successfully.
#          Current function value: 45089.418238
#          Iterations: 28
#          Function evaluations: 38
#          Gradient evaluations: 38
#
#  ***** evaluating model binary_prev_tns_and_viol w/ sigma 4 *****
# Optimization terminated successfully.
#          Current function value: 45088.567701
#          Iterations: 28
#          Function evaluations: 38
#          Gradient evaluations: 38
#
#  ***** evaluating model binary_prev_tns_and_viol w/ sigma 8 *****
# Optimization terminated successfully.
#          Current function value: 45088.354701
#          Iterations: 28
#          Function evaluations: 38
#          Gradient evaluations: 38
#
#  ***** evaluating model binary_prev_tns_and_viol w/ sigma 16 *****
# Optimization terminated successfully.
#          Current function value: 45088.301428
#          Iterations: 28
#          Function evaluations: 38
#          Gradient evaluations: 38
#
#  ***** evaluating model binary_prev_tns_viol_added w/ sigma 0.07 *****
# Optimization terminated successfully.
#          Current function value: 45622.505132
#          Iterations: 25
#          Function evaluations: 40
#          Gradient evaluations: 40
#
#  ***** evaluating model binary_prev_tns_viol_added w/ sigma 0.13 *****
# Optimization terminated successfully.
#          Current function value: 45326.155467
#          Iterations: 24
#          Function evaluations: 37
#          Gradient evaluations: 37
#
#  ***** evaluating model binary_prev_tns_viol_added w/ sigma 0.25 *****
# Optimization terminated successfully.
#          Current function value: 45232.954985
#          Iterations: 24
#          Function evaluations: 37
#          Gradient evaluations: 37
#
#  ***** evaluating model binary_prev_tns_viol_added w/ sigma 0.5 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 45206.615445
#          Iterations: 23
#          Function evaluations: 83
#          Gradient evaluations: 69
#
#  ***** evaluating model binary_prev_tns_viol_added w/ sigma 1 *****
# Optimization terminated successfully.
#          Current function value: 45200.000375
#          Iterations: 23
#          Function evaluations: 35
#          Gradient evaluations: 35
#
#  ***** evaluating model binary_prev_tns_viol_added w/ sigma 2 *****
# Optimization terminated successfully.
#          Current function value: 45198.344709
#          Iterations: 23
#          Function evaluations: 35
#          Gradient evaluations: 35
#
#  ***** evaluating model binary_prev_tns_viol_added w/ sigma 4 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 45197.930673
#          Iterations: 23
#          Function evaluations: 104
#          Gradient evaluations: 91
#
#  ***** evaluating model binary_prev_tns_viol_added w/ sigma 8 *****
# Optimization terminated successfully.
#          Current function value: 45197.827157
#          Iterations: 23
#          Function evaluations: 35
#          Gradient evaluations: 35
#
#  ***** evaluating model binary_prev_tns_viol_added w/ sigma 16 *****
# Optimization terminated successfully.
#          Current function value: 45197.801277
#          Iterations: 23
#          Function evaluations: 35
#          Gradient evaluations: 35

# %% [markdown]
# ## Visualize

# %%
experiment = load_experiment(save_name)
mvc = ModelVisualizerCompare(experiment)

# %%
df = mvc.find_best_fit(group="model_name")
df["model_name"] = pd.Categorical(df["model_name"], categories=ORDER, ordered=True)
for model_name, model_df in df.groupby("model_name"):
    mvc.plot_sigma_summary(model_df, title=f"{model_name} fit sigma summary")
# Out:
# /var/folders/__/8jn6qz211155h1xb451s5zcr0000gn/T/ipykernel_31486/2431235986.py:3: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   for model_name, model_df in df.groupby("model_name"):
# /Users/jessbreda/anaconda3/envs/an_lrn/lib/python3.10/site-packages/seaborn/categorical.py:641: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   grouped_vals = vals.groupby(grouper)
# /Users/jessbreda/anaconda3/envs/an_lrn/lib/python3.10/site-packages/seaborn/categorical.py:641: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   grouped_vals = vals.groupby(grouper)
# /Users/jessbreda/anaconda3/envs/an_lrn/lib/python3.10/site-packages/seaborn/categorical.py:641: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   grouped_vals = vals.groupby(grouper)
# /Users/jessbreda/anaconda3/envs/an_lrn/lib/python3.10/site-packages/seaborn/categorical.py:641: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   grouped_vals = vals.groupby(grouper)
# /Users/jessbreda/anaconda3/envs/an_lrn/lib/python3.10/site-packages/seaborn/categorical.py:641: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   grouped_vals = vals.groupby(grouper)
# /Users/jessbreda/anaconda3/envs/an_lrn/lib/python3.10/site-packages/seaborn/categorical.py:641: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   grouped_vals = vals.groupby(grouper)

# %%
fig, ax = plt.subplots(
    len(ORDER), 1, figsize=(10, len(ORDER) * 6), constrained_layout=True, sharey=False
)

best_fit_by_model = mvc.find_best_fit(group=["animal_id", "model_name"])
best_fit_by_model["model_name"] = pd.Categorical(
    best_fit_by_model["model_name"], categories=ORDER, ordered=True
)

for ii, (model_name, model_df) in enumerate(best_fit_by_model.groupby("model_name")):
    unpacked = mvc.unpack_features_and_weights(model_df)

    mvc.plot_weights_summary(
        df=unpacked,
        ax=ax[ii],
        palette="Set2",
        title=f"{model_name} weights summary",
    )
# Out:
# /var/folders/__/8jn6qz211155h1xb451s5zcr0000gn/T/ipykernel_31486/2667047998.py:10: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   for ii, (model_name, model_df) in enumerate(best_fit_by_model.groupby("model_name")):

# %%
fig, ax = plt.subplots(1, 1, figsize=(8, 5))
mvc.plot_model_comparison(
    hue=None,
    ax=ax,
    order=ORDER,
    errorbar=None,
)

# %%
mvc.plot_train_and_test_ll(
    order=ORDER,
    errorbar=None,
)
# Out:
# /Users/jessbreda/anaconda3/envs/an_lrn/lib/python3.10/site-packages/seaborn/categorical.py:641: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   grouped_vals = vals.groupby(grouper)
# /Users/jessbreda/anaconda3/envs/an_lrn/lib/python3.10/site-packages/seaborn/categorical.py:641: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   grouped_vals = vals.groupby(grouper)

# %%
mvc.plot_ll_delta_by_animal(
    base_model_name=ORDER[0],
    new_model_name=ORDER[1],
    type="test",
)
# Out:
# <Axes: title={'center': 'Model Improvement- mu: 185.02 std: 153.69 \n base -> prev_viol_only'}, xlabel='animal_id', ylabel='Delta test LL (new - base)'>
