# %% [markdown]
# # Experiment: Compare Binary Model Disengaged Features
#
# **Goal**: assess the impact of adding the combined regressor as a disengaged feature to the binary model
#
# Related notebooks:
# * `2024_03_26_EXP_compare_binary_base_features.ipynb`
# * `2024_03_26_EXP_compare_binary_disengaged_features.ipynb`
#
#
# > Written by Jess Breda

# %% [markdown]
# ## Imports

# %%
import seaborn as sns
import matplotlib.pyplot as plt

from multiglm.experiments.experiment import load_experiment

from multiglm.experiments.experiment_compare_models import ExperimentCompareModels

from multiglm.features.design_matrix_generator import *
from multiglm.features.design_matrix_generator_PWM import *

from multiglm.models.binary_logistic_regression import BinaryLogisticRegression
from multiglm.models.multiclass_logistic_regression import MultiClassLogisticRegression

from multiglm.visualizations.model_visualizer import *

from multiglm.data import ANIMAL_IDS
from multiglm.experiments import STANDARD_SIGMAS


sns.set_context("talk")
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# ## Model Configs

# %% [markdown]
# ### Compare

# %%
# design matrix columns shared between all models being fit
shared_cols = {
    "session": lambda df: (copy(df.session)),
    "bias": lambda df: (add_bias_column(df)),
    "s_a": lambda df: (standardize(df.s_a)),
    "s_b": lambda df: (standardize(df.s_b)),
    "prev_avg_stim": lambda df: prev_avg_stim(df, mask_prev_violation=True),
    "prev_correct": lambda df: (prev_correct_side(df)),
    "prev_choice": lambda df: (prev_choice(df)),
    "labels": binary_choice_labels(),
}

models_config = {
    "base": {
        "model_class": BinaryLogisticRegression,
        "dmg_config": {
            **shared_cols,
        },
    },
    "prev_violation_filt": {
        "model_class": BinaryLogisticRegression,
        "dmg_config": {
            **shared_cols,
            "prev_violation_filt": lambda df: (
                filtered_prev_viol(df, get_animals_tau(df, "prev_violation"))
            ),
        },
    },
    "prev_tns": {
        "model_class": BinaryLogisticRegression,
        "dmg_config": {
            **shared_cols,
            "prev_violation_filt": lambda df: (
                filtered_prev_viol(df, get_animals_tau(df, "prev_violation"))
            ),
            "prev_tns": lambda df: (prev_trial_not_started(df)),
        },
    },
    "prev_disengaged_filt_summed": {
        "model_class": BinaryLogisticRegression,
        "dmg_config": {
            **shared_cols,
            "prev_disengaged_filt": lambda df: (
                filtered_prev_disengaged(
                    df,
                    get_animals_tau(df, "prev_tns_viol_combo"),
                    binarize_pre_filt=False,
                )
            ),
        },
    },
    "prev_viol_stim_intrxs": {
        "model_class": BinaryLogisticRegression,
        "dmg_config": {
            **shared_cols,
            "prev_violation_filt": lambda df: (
                filtered_prev_viol(df, get_animals_tau(df, "prev_violation"))
            ),
            "prev_tns": lambda df: (prev_trial_not_started(df)),
            "s_a_x_filt_prev_viol": lambda df: (
                stim_filt_viol_intrx(df, "s_a", get_animals_tau(df, "prev_violation"))
            ),
            "s_b_x_filt_prev_viol": lambda df: (
                stim_filt_viol_intrx(df, "s_b", get_animals_tau(df, "prev_violation"))
            ),
        },
    },
    "prev_tns_stim_intrxs": {
        "model_class": BinaryLogisticRegression,
        "dmg_config": {
            **shared_cols,
            "prev_violation_filt": lambda df: (
                filtered_prev_viol(df, get_animals_tau(df, "prev_violation"))
            ),
            "prev_tns": lambda df: (prev_trial_not_started(df)),
            "s_a_x_filt_prev_viol": lambda df: (
                stim_filt_viol_intrx(df, "s_a", get_animals_tau(df, "prev_violation"))
            ),
            "s_b_x_filt_prev_viol": lambda df: (
                stim_filt_viol_intrx(df, "s_b", get_animals_tau(df, "prev_violation"))
            ),
            "sa_x_prev_tns": lambda df: combine_two_cols(
                standardize(df.s_a), prev_trial_not_started(df), operator.mul
            ),
            "sb_x_prev_tns": lambda df: combine_two_cols(
                standardize(df.s_b), prev_trial_not_started(df), operator.mul
            ),
        },
    },
    "prev_disengaged_stim_intrxs": {
        "model_class": BinaryLogisticRegression,
        "dmg_config": {
            **shared_cols,
            "sa_x_filt_prev_disengaged": lambda df: combine_two_cols(
                standardize(df.s_a),
                filtered_prev_disengaged(
                    df,
                    get_animals_tau(df, "prev_tns_viol_combo"),
                    binarize_pre_filt=False,
                ),
                operator.mul,
            ),
            "sb_x_filt_prev_disengaged": lambda df: combine_two_cols(
                standardize(df.s_b),
                filtered_prev_disengaged(
                    df,
                    get_animals_tau(df, "prev_tns_viol_combo"),
                    binarize_pre_filt=False,
                ),
                operator.mul,
            ),
        },
    },
}
params = {
    "animals": ANIMAL_IDS,
    "data_type": "new_trained",
    "sigmas": STANDARD_SIGMAS,
    "random_state": 47,
    "eval_train": True,
    "null_mode": "binary",
    "model_config": models_config,
}

save_name = "2024_03_28_compare_binary_combined_disengaged_features.pkl"

ORDER = [
    "base",
    "prev_violation_filt",
    "prev_tns",
    "prev_disengaged_filt_summed",
    "prev_disengaged_stim_intrxs",
    "prev_viol_stim_intrxs",
    "prev_tns_stim_intrxs",
]

# %% [markdown]
# ## Run

# %%
experiment = ExperimentCompareModels(params)
experiment.run()
experiment.save(save_name)
# Out:
# Loading dataset type : new_trained
# Loading data for animal ids:  ['W051', 'W060', 'W065', 'W066', 'W068', 'W072', 'W073', 'W074', 'W075', 'W078', 'W080', 'W081', 'W082', 'W083', 'W088', 'W089', 'W094']
#
#  >>>> evaluating animal W051 <<<<
#
#  ***** evaluating model base w/ sigma 0.07 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 32027.241052
#          Iterations: 13
#          Function evaluations: 69
#          Gradient evaluations: 57
#
#  ***** evaluating model base w/ sigma 0.13 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 32417.261695
#          Iterations: 13
#          Function evaluations: 94
#          Gradient evaluations: 82
#
#  ***** evaluating model base w/ sigma 0.25 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 32556.844191
#          Iterations: 13
#          Function evaluations: 70
#          Gradient evaluations: 58
#
#  ***** evaluating model base w/ sigma 0.5 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 32597.848920
#          Iterations: 13
#          Function evaluations: 73
#          Gradient evaluations: 61
#
#  ***** evaluating model base w/ sigma 1 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 32608.256919
#          Iterations: 13
#          Function evaluations: 63
#          Gradient evaluations: 51
#
#  ***** evaluating model base w/ sigma 2 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 32610.868822
#          Iterations: 13
#          Function evaluations: 72
#          Gradient evaluations: 60
#
#  ***** evaluating model base w/ sigma 4 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 32611.522414
#          Iterations: 13
#          Function evaluations: 75
#          Gradient evaluations: 64
#
#  ***** evaluating model base w/ sigma 8 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 32611.685858
#          Iterations: 13
#          Function evaluations: 64
#          Gradient evaluations: 53
#
#  ***** evaluating model base w/ sigma 16 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 32611.726720
#          Iterations: 14
#          Function evaluations: 58
#          Gradient evaluations: 47
#
#  ***** evaluating model prev_violation_filt w/ sigma 0.07 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 32025.262677
#          Iterations: 14
#          Function evaluations: 67
#          Gradient evaluations: 55
#
#  ***** evaluating model prev_violation_filt w/ sigma 0.13 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 32415.274996
#          Iterations: 14
#          Function evaluations: 85
#          Gradient evaluations: 73
#
#  ***** evaluating model prev_violation_filt w/ sigma 0.25 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 32554.994522
#          Iterations: 13
#          Function evaluations: 61
#          Gradient evaluations: 49
#
#  ***** evaluating model prev_violation_filt w/ sigma 0.5 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 32596.064184
#          Iterations: 13
#          Function evaluations: 82
#          Gradient evaluations: 70
#
#  ***** evaluating model prev_violation_filt w/ sigma 1 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 32606.491303
#          Iterations: 13
#          Function evaluations: 65
#          Gradient evaluations: 53
#
#  ***** evaluating model prev_violation_filt w/ sigma 2 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 32609.108067
#          Iterations: 14
#          Function evaluations: 63
#          Gradient evaluations: 51
#
#  ***** evaluating model prev_violation_filt w/ sigma 4 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 32609.762913
#          Iterations: 14
#          Function evaluations: 70
#          Gradient evaluations: 58
#
#  ***** evaluating model prev_violation_filt w/ sigma 8 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 32609.926659
#          Iterations: 16
#          Function evaluations: 81
#          Gradient evaluations: 70
#
#  ***** evaluating model prev_violation_filt w/ sigma 16 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 32609.967599
#          Iterations: 14
#          Function evaluations: 73
#          Gradient evaluations: 61
#
#  ***** evaluating model prev_tns w/ sigma 0.07 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 32025.065624
#          Iterations: 14
#          Function evaluations: 57
#          Gradient evaluations: 45
#
#  ***** evaluating model prev_tns w/ sigma 0.13 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 32234.243661
#          Iterations: 9
#          Function evaluations: 78
#          Gradient evaluations: 66
#
#  ***** evaluating model prev_tns w/ sigma 0.25 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 32553.685819
#          Iterations: 14
#          Function evaluations: 73
#          Gradient evaluations: 61
#
#  ***** evaluating model prev_tns w/ sigma 0.5 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 32593.929547
#          Iterations: 14
#          Function evaluations: 74
#          Gradient evaluations: 62
#
#  ***** evaluating model prev_tns w/ sigma 1 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 32604.211929
#          Iterations: 16
#          Function evaluations: 88
#          Gradient evaluations: 76
#
#  ***** evaluating model prev_tns w/ sigma 2 *****
# Optimization terminated successfully.
#          Current function value: 32607.040918
#          Iterations: 20
#          Function evaluations: 29
#          Gradient evaluations: 29
#
#  ***** evaluating model prev_tns w/ sigma 4 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 32607.750911
#          Iterations: 18
#          Function evaluations: 76
#          Gradient evaluations: 64
#
#  ***** evaluating model prev_tns w/ sigma 8 *****
# Optimization terminated successfully.
#          Current function value: 32607.930331
#          Iterations: 22
#          Function evaluations: 30
#          Gradient evaluations: 30
#
#  ***** evaluating model prev_tns w/ sigma 16 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 32607.975314
#          Iterations: 14
#          Function evaluations: 74
#          Gradient evaluations: 62
#
#  ***** evaluating model prev_disengaged_filt_summed w/ sigma 0.07 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 32025.238738
#          Iterations: 13
#          Function evaluations: 68
#          Gradient evaluations: 56
#
#  ***** evaluating model prev_disengaged_filt_summed w/ sigma 0.13 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 32414.651417
#          Iterations: 14
#          Function evaluations: 83
#          Gradient evaluations: 71
#
#  ***** evaluating model prev_disengaged_filt_summed w/ sigma 0.25 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 32554.294682
#          Iterations: 13
#          Function evaluations: 68
#          Gradient evaluations: 56
#
#  ***** evaluating model prev_disengaged_filt_summed w/ sigma 0.5 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 32595.449894
#          Iterations: 13
#          Function evaluations: 65
#          Gradient evaluations: 53
#
#  ***** evaluating model prev_disengaged_filt_summed w/ sigma 1 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 32605.912847
#          Iterations: 14
#          Function evaluations: 60
#          Gradient evaluations: 48
#
#  ***** evaluating model prev_disengaged_filt_summed w/ sigma 2 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 32608.539794
#          Iterations: 14
#          Function evaluations: 65
#          Gradient evaluations: 53
#
#  ***** evaluating model prev_disengaged_filt_summed w/ sigma 4 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 32609.197230
#          Iterations: 14
#          Function evaluations: 53
#          Gradient evaluations: 41
#
#  ***** evaluating model prev_disengaged_filt_summed w/ sigma 8 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 32609.361634
#          Iterations: 15
#          Function evaluations: 81
#          Gradient evaluations: 70
#
#  ***** evaluating model prev_disengaged_filt_summed w/ sigma 16 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 32609.402738
#          Iterations: 16
#          Function evaluations: 69
#          Gradient evaluations: 57
#
#  ***** evaluating model prev_viol_stim_intrxs w/ sigma 0.07 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 31979.987907
#          Iterations: 15
#          Function evaluations: 77
#          Gradient evaluations: 65
#
#  ***** evaluating model prev_viol_stim_intrxs w/ sigma 0.13 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 32347.114567
#          Iterations: 11
#          Function evaluations: 81
#          Gradient evaluations: 69
#
#  ***** evaluating model prev_viol_stim_intrxs w/ sigma 0.25 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 32475.548962
#          Iterations: 15
#          Function evaluations: 61
#          Gradient evaluations: 49
#
#  ***** evaluating model prev_viol_stim_intrxs w/ sigma 0.5 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 32523.683734
#          Iterations: 15
#          Function evaluations: 74
#          Gradient evaluations: 63
#
#  ***** evaluating model prev_viol_stim_intrxs w/ sigma 1 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 32536.812157
#          Iterations: 15
#          Function evaluations: 78
#          Gradient evaluations: 66
#
#  ***** evaluating model prev_viol_stim_intrxs w/ sigma 2 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 32540.314482
#          Iterations: 18
#          Function evaluations: 70
#          Gradient evaluations: 58
#
#  ***** evaluating model prev_viol_stim_intrxs w/ sigma 4 *****
# Optimization terminated successfully.
#          Current function value: 32541.217042
#          Iterations: 22
#          Function evaluations: 28
#          Gradient evaluations: 28
#
#  ***** evaluating model prev_viol_stim_intrxs w/ sigma 8 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 32541.444621
#          Iterations: 17
#          Function evaluations: 51
#          Gradient evaluations: 41
#
#  ***** evaluating model prev_viol_stim_intrxs w/ sigma 16 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 32541.501649
#          Iterations: 18
#          Function evaluations: 80
#          Gradient evaluations: 69
#
#  ***** evaluating model prev_tns_stim_intrxs w/ sigma 0.07 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 31995.175372
#          Iterations: 19
#          Function evaluations: 93
#          Gradient evaluations: 81
#
#  ***** evaluating model prev_tns_stim_intrxs w/ sigma 0.13 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 32339.373070
#          Iterations: 20
#          Function evaluations: 93
#          Gradient evaluations: 81
#
#  ***** evaluating model prev_tns_stim_intrxs w/ sigma 0.25 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 32522.761160
#          Iterations: 13
#          Function evaluations: 47
#          Gradient evaluations: 36
#
#  ***** evaluating model prev_tns_stim_intrxs w/ sigma 0.5 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 32513.067749
#          Iterations: 14
#          Function evaluations: 85
#          Gradient evaluations: 73
#
#  ***** evaluating model prev_tns_stim_intrxs w/ sigma 1 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 32530.042556
#          Iterations: 20
#          Function evaluations: 90
#          Gradient evaluations: 78
#
#  ***** evaluating model prev_tns_stim_intrxs w/ sigma 2 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 32533.904128
#          Iterations: 19
#          Function evaluations: 95
#          Gradient evaluations: 83
#
#  ***** evaluating model prev_tns_stim_intrxs w/ sigma 4 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 32534.999170
#          Iterations: 22
#          Function evaluations: 86
#          Gradient evaluations: 74
#
#  ***** evaluating model prev_tns_stim_intrxs w/ sigma 8 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 32535.278998
#          Iterations: 21
#          Function evaluations: 87
#          Gradient evaluations: 75
#
#  ***** evaluating model prev_tns_stim_intrxs w/ sigma 16 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 32535.349425
#          Iterations: 24
#          Function evaluations: 74
#          Gradient evaluations: 62
#
#  ***** evaluating model prev_disengaged_stim_intrxs w/ sigma 0.07 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 32010.989426
#          Iterations: 15
#          Function evaluations: 66
#          Gradient evaluations: 54
#
#  ***** evaluating model prev_disengaged_stim_intrxs w/ sigma 0.13 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 32360.736241
#          Iterations: 14
#          Function evaluations: 74
#          Gradient evaluations: 62
#
#  ***** evaluating model prev_disengaged_stim_intrxs w/ sigma 0.25 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 32476.960799
#          Iterations: 14
#          Function evaluations: 87
#          Gradient evaluations: 75
#
#  ***** evaluating model prev_disengaged_stim_intrxs w/ sigma 0.5 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 32521.568461
#          Iterations: 15
#          Function evaluations: 71
#          Gradient evaluations: 59
#
#  ***** evaluating model prev_disengaged_stim_intrxs w/ sigma 1 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 32536.450745
#          Iterations: 15
#          Function evaluations: 72
#          Gradient evaluations: 60
#
#  ***** evaluating model prev_disengaged_stim_intrxs w/ sigma 2 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 32540.586809
#          Iterations: 15
#          Function evaluations: 79
#          Gradient evaluations: 67
#
#  ***** evaluating model prev_disengaged_stim_intrxs w/ sigma 4 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 32541.648271
#          Iterations: 17
#          Function evaluations: 70
#          Gradient evaluations: 58
#
#  ***** evaluating model prev_disengaged_stim_intrxs w/ sigma 8 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 32541.915393
#          Iterations: 17
#          Function evaluations: 74
#          Gradient evaluations: 62
#
#  ***** evaluating model prev_disengaged_stim_intrxs w/ sigma 16 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 32541.982295
#          Iterations: 15
#          Function evaluations: 72
#          Gradient evaluations: 60
#
#  >>>> evaluating animal W060 <<<<
#
#  ***** evaluating model base w/ sigma 0.07 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 24623.350579
#          Iterations: 13
#          Function evaluations: 77
#          Gradient evaluations: 65
#
#  ***** evaluating model base w/ sigma 0.13 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 25058.741992
#          Iterations: 11
#          Function evaluations: 65
#          Gradient evaluations: 53
#
#  ***** evaluating model base w/ sigma 0.25 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 25224.037948
#          Iterations: 17
#          Function evaluations: 62
#          Gradient evaluations: 50
#
#  ***** evaluating model base w/ sigma 0.5 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 25273.514227
#          Iterations: 12
#          Function evaluations: 70
#          Gradient evaluations: 58
#
#  ***** evaluating model base w/ sigma 1 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 25286.139071
#          Iterations: 13
#          Function evaluations: 76
#          Gradient evaluations: 64
#
#  ***** evaluating model base w/ sigma 2 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 25289.312590
#          Iterations: 13
#          Function evaluations: 78
#          Gradient evaluations: 66
#
#  ***** evaluating model base w/ sigma 4 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 25290.106804
#          Iterations: 12
#          Function evaluations: 56
#          Gradient evaluations: 44
#
#  ***** evaluating model base w/ sigma 8 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 25290.305415
#          Iterations: 18
#          Function evaluations: 70
#          Gradient evaluations: 58
#
#  ***** evaluating model base w/ sigma 16 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 25290.355071
#          Iterations: 19
#          Function evaluations: 75
#          Gradient evaluations: 60
#
#  ***** evaluating model prev_violation_filt w/ sigma 0.07 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 24621.605490
#          Iterations: 13
#          Function evaluations: 66
#          Gradient evaluations: 54
#
#  ***** evaluating model prev_violation_filt w/ sigma 0.13 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 25056.835139
#          Iterations: 13
#          Function evaluations: 74
#          Gradient evaluations: 62
#
#  ***** evaluating model prev_violation_filt w/ sigma 0.25 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 25222.168011
#          Iterations: 14
#          Function evaluations: 72
#          Gradient evaluations: 60
#
#  ***** evaluating model prev_violation_filt w/ sigma 0.5 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 25271.737054
#          Iterations: 14
#          Function evaluations: 85
#          Gradient evaluations: 73
#
#  ***** evaluating model prev_violation_filt w/ sigma 1 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 25284.379267
#          Iterations: 15
#          Function evaluations: 74
#          Gradient evaluations: 62
#
#  ***** evaluating model prev_violation_filt w/ sigma 2 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 25287.559823
#          Iterations: 18
#          Function evaluations: 58
#          Gradient evaluations: 46
#
#  ***** evaluating model prev_violation_filt w/ sigma 4 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 25288.355280
#          Iterations: 19
#          Function evaluations: 70
#          Gradient evaluations: 58
#
#  ***** evaluating model prev_violation_filt w/ sigma 8 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 25288.554209
#          Iterations: 19
#          Function evaluations: 72
#          Gradient evaluations: 60
#
#  ***** evaluating model prev_violation_filt w/ sigma 16 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 25288.603946
#          Iterations: 19
#          Function evaluations: 79
#          Gradient evaluations: 68
#
#  ***** evaluating model prev_tns w/ sigma 0.07 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 24620.962651
#          Iterations: 16
#          Function evaluations: 58
#          Gradient evaluations: 46
#
#  ***** evaluating model prev_tns w/ sigma 0.13 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 25055.544644
#          Iterations: 13
#          Function evaluations: 88
#          Gradient evaluations: 76
#
#  ***** evaluating model prev_tns w/ sigma 0.25 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 25220.636939
#          Iterations: 15
#          Function evaluations: 72
#          Gradient evaluations: 60
#
#  ***** evaluating model prev_tns w/ sigma 0.5 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 25270.332271
#          Iterations: 15
#          Function evaluations: 67
#          Gradient evaluations: 55
#
#  ***** evaluating model prev_tns w/ sigma 1 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 25283.037595
#          Iterations: 14
#          Function evaluations: 64
#          Gradient evaluations: 53
#
#  ***** evaluating model prev_tns w/ sigma 2 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 25286.234834
#          Iterations: 15
#          Function evaluations: 73
#          Gradient evaluations: 62
#
#  ***** evaluating model prev_tns w/ sigma 4 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 25287.035660
#          Iterations: 15
#          Function evaluations: 70
#          Gradient evaluations: 58
#
#  ***** evaluating model prev_tns w/ sigma 8 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 25287.235920
#          Iterations: 19
#          Function evaluations: 71
#          Gradient evaluations: 59
#
#  ***** evaluating model prev_tns w/ sigma 16 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 25287.285991
#          Iterations: 21
#          Function evaluations: 67
#          Gradient evaluations: 56
#
#  ***** evaluating model prev_disengaged_filt_summed w/ sigma 0.07 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 24621.077361
#          Iterations: 13
#          Function evaluations: 73
#          Gradient evaluations: 61
#
#  ***** evaluating model prev_disengaged_filt_summed w/ sigma 0.13 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 25055.170912
#          Iterations: 12
#          Function evaluations: 63
#          Gradient evaluations: 51
#
#  ***** evaluating model prev_disengaged_filt_summed w/ sigma 0.25 *****
# Optimization terminated successfully.
#          Current function value: 25220.374256
#          Iterations: 16
#          Function evaluations: 22
#          Gradient evaluations: 22
#
#  ***** evaluating model prev_disengaged_filt_summed w/ sigma 0.5 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 25270.066014
#          Iterations: 15
#          Function evaluations: 72
#          Gradient evaluations: 60
#
#  ***** evaluating model prev_disengaged_filt_summed w/ sigma 1 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 25282.787512
#          Iterations: 14
#          Function evaluations: 70
#          Gradient evaluations: 58
#
#  ***** evaluating model prev_disengaged_filt_summed w/ sigma 2 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 25285.990353
#          Iterations: 14
#          Function evaluations: 79
#          Gradient evaluations: 67
#
#  ***** evaluating model prev_disengaged_filt_summed w/ sigma 4 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 25286.791875
#          Iterations: 14
#          Function evaluations: 79
#          Gradient evaluations: 67
#
#  ***** evaluating model prev_disengaged_filt_summed w/ sigma 8 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 25286.992343
#          Iterations: 19
#          Function evaluations: 81
#          Gradient evaluations: 70
#
#  ***** evaluating model prev_disengaged_filt_summed w/ sigma 16 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 25287.042461
#          Iterations: 19
#          Function evaluations: 68
#          Gradient evaluations: 56
#
#  ***** evaluating model prev_viol_stim_intrxs w/ sigma 0.07 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 24591.678793
#          Iterations: 17
#          Function evaluations: 83
#          Gradient evaluations: 71
#
#  ***** evaluating model prev_viol_stim_intrxs w/ sigma 0.13 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 24979.277076
#          Iterations: 17
#          Function evaluations: 90
#          Gradient evaluations: 78
#
#  ***** evaluating model prev_viol_stim_intrxs w/ sigma 0.25 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 25135.165968
#          Iterations: 18
#          Function evaluations: 96
#          Gradient evaluations: 84
#
#  ***** evaluating model prev_viol_stim_intrxs w/ sigma 0.5 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 25191.377841
#          Iterations: 18
#          Function evaluations: 62
#          Gradient evaluations: 50
#
#  ***** evaluating model prev_viol_stim_intrxs w/ sigma 1 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 25207.385216
#          Iterations: 18
#          Function evaluations: 81
#          Gradient evaluations: 69
#
#  ***** evaluating model prev_viol_stim_intrxs w/ sigma 2 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 25211.549861
#          Iterations: 17
#          Function evaluations: 72
#          Gradient evaluations: 60
#
#  ***** evaluating model prev_viol_stim_intrxs w/ sigma 4 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 25212.601705
#          Iterations: 17
#          Function evaluations: 66
#          Gradient evaluations: 54
#
#  ***** evaluating model prev_viol_stim_intrxs w/ sigma 8 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 25212.865353
#          Iterations: 21
#          Function evaluations: 83
#          Gradient evaluations: 71
#
#  ***** evaluating model prev_viol_stim_intrxs w/ sigma 16 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 25212.931307
#          Iterations: 22
#          Function evaluations: 78
#          Gradient evaluations: 67
#
#  ***** evaluating model prev_tns_stim_intrxs w/ sigma 0.07 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 24583.123214
#          Iterations: 23
#          Function evaluations: 65
#          Gradient evaluations: 53
#
#  ***** evaluating model prev_tns_stim_intrxs w/ sigma 0.13 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 24963.551073
#          Iterations: 25
#          Function evaluations: 94
#          Gradient evaluations: 82
#
#  ***** evaluating model prev_tns_stim_intrxs w/ sigma 0.25 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 25115.711946
#          Iterations: 20
#          Function evaluations: 81
#          Gradient evaluations: 69
#
#  ***** evaluating model prev_tns_stim_intrxs w/ sigma 0.5 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 25171.474293
#          Iterations: 19
#          Function evaluations: 82
#          Gradient evaluations: 70
#
#  ***** evaluating model prev_tns_stim_intrxs w/ sigma 1 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 25188.827845
#          Iterations: 20
#          Function evaluations: 88
#          Gradient evaluations: 76
#
#  ***** evaluating model prev_tns_stim_intrxs w/ sigma 2 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 25193.357085
#          Iterations: 22
#          Function evaluations: 90
#          Gradient evaluations: 78
#
#  ***** evaluating model prev_tns_stim_intrxs w/ sigma 4 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 25194.515616
#          Iterations: 20
#          Function evaluations: 80
#          Gradient evaluations: 68
#
#  ***** evaluating model prev_tns_stim_intrxs w/ sigma 8 *****
# Optimization terminated successfully.
#          Current function value: 25194.806385
#          Iterations: 28
#          Function evaluations: 33
#          Gradient evaluations: 33
#
#  ***** evaluating model prev_tns_stim_intrxs w/ sigma 16 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 25194.879174
#          Iterations: 25
#          Function evaluations: 86
#          Gradient evaluations: 75
#
#  ***** evaluating model prev_disengaged_stim_intrxs w/ sigma 0.07 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 24600.472819
#          Iterations: 16
#          Function evaluations: 65
#          Gradient evaluations: 53
#
#  ***** evaluating model prev_disengaged_stim_intrxs w/ sigma 0.13 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 24993.809789
#          Iterations: 15
#          Function evaluations: 79
#          Gradient evaluations: 67
#
#  ***** evaluating model prev_disengaged_stim_intrxs w/ sigma 0.25 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 25126.219391
#          Iterations: 15
#          Function evaluations: 61
#          Gradient evaluations: 49
#
#  ***** evaluating model prev_disengaged_stim_intrxs w/ sigma 0.5 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 25175.785968
#          Iterations: 20
#          Function evaluations: 79
#          Gradient evaluations: 67
#
#  ***** evaluating model prev_disengaged_stim_intrxs w/ sigma 1 *****
# Optimization terminated successfully.
#          Current function value: 25194.271666
#          Iterations: 24
#          Function evaluations: 30
#          Gradient evaluations: 30
#
#  ***** evaluating model prev_disengaged_stim_intrxs w/ sigma 2 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 25199.710290
#          Iterations: 19
#          Function evaluations: 74
#          Gradient evaluations: 62
#
#  ***** evaluating model prev_disengaged_stim_intrxs w/ sigma 4 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 25201.133442
#          Iterations: 17
#          Function evaluations: 60
#          Gradient evaluations: 48
#
#  ***** evaluating model prev_disengaged_stim_intrxs w/ sigma 8 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 25201.493483
#          Iterations: 19
#          Function evaluations: 63
#          Gradient evaluations: 51
#
#  ***** evaluating model prev_disengaged_stim_intrxs w/ sigma 16 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 25201.583749
#          Iterations: 22
#          Function evaluations: 54
#          Gradient evaluations: 43
#
#  >>>> evaluating animal W065 <<<<
#
#  ***** evaluating model base w/ sigma 0.07 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 21046.638662
#          Iterations: 12
#          Function evaluations: 72
#          Gradient evaluations: 60
#
#  ***** evaluating model base w/ sigma 0.13 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 21420.504993
#          Iterations: 13
#          Function evaluations: 63
#          Gradient evaluations: 51
#
#  ***** evaluating model base w/ sigma 0.25 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 21577.425411
#          Iterations: 12
#          Function evaluations: 85
#          Gradient evaluations: 73
#
#  ***** evaluating model base w/ sigma 0.5 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 21625.965484
#          Iterations: 13
#          Function evaluations: 61
#          Gradient evaluations: 49
#
#  ***** evaluating model base w/ sigma 1 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 21638.467208
#          Iterations: 12
#          Function evaluations: 94
#          Gradient evaluations: 82
#
#  ***** evaluating model base w/ sigma 2 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 21641.616211
#          Iterations: 13
#          Function evaluations: 85
#          Gradient evaluations: 73
#
#  ***** evaluating model base w/ sigma 4 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 21642.404945
#          Iterations: 13
#          Function evaluations: 60
#          Gradient evaluations: 48
#
#  ***** evaluating model base w/ sigma 8 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 21642.602221
#          Iterations: 13
#          Function evaluations: 60
#          Gradient evaluations: 48
#
#  ***** evaluating model base w/ sigma 16 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 21642.651546
#          Iterations: 14
#          Function evaluations: 58
#          Gradient evaluations: 46
#
#  ***** evaluating model prev_violation_filt w/ sigma 0.07 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 21010.691398
#          Iterations: 13
#          Function evaluations: 92
#          Gradient evaluations: 80
#
#  ***** evaluating model prev_violation_filt w/ sigma 0.13 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 21383.144916
#          Iterations: 13
#          Function evaluations: 65
#          Gradient evaluations: 53
#
#  ***** evaluating model prev_violation_filt w/ sigma 0.25 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 21541.989722
#          Iterations: 13
#          Function evaluations: 70
#          Gradient evaluations: 58
#
#  ***** evaluating model prev_violation_filt w/ sigma 0.5 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 21591.538969
#          Iterations: 14
#          Function evaluations: 56
#          Gradient evaluations: 44
#
#  ***** evaluating model prev_violation_filt w/ sigma 1 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 21604.336523
#          Iterations: 13
#          Function evaluations: 58
#          Gradient evaluations: 46
#
#  ***** evaluating model prev_violation_filt w/ sigma 2 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 21607.562298
#          Iterations: 12
#          Function evaluations: 80
#          Gradient evaluations: 69
#
#  ***** evaluating model prev_violation_filt w/ sigma 4 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 21608.370411
#          Iterations: 14
#          Function evaluations: 75
#          Gradient evaluations: 63
#
#  ***** evaluating model prev_violation_filt w/ sigma 8 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 21608.572550
#          Iterations: 14
#          Function evaluations: 69
#          Gradient evaluations: 58
#
#  ***** evaluating model prev_violation_filt w/ sigma 16 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 21608.623091
#          Iterations: 14
#          Function evaluations: 68
#          Gradient evaluations: 56
#
#  ***** evaluating model prev_tns w/ sigma 0.07 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 21010.685594
#          Iterations: 14
#          Function evaluations: 75
#          Gradient evaluations: 63
#
#  ***** evaluating model prev_tns w/ sigma 0.13 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 21383.112394
#          Iterations: 14
#          Function evaluations: 71
#          Gradient evaluations: 59
#
#  ***** evaluating model prev_tns w/ sigma 0.25 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 21541.941345
#          Iterations: 15
#          Function evaluations: 87
#          Gradient evaluations: 75
#
#  ***** evaluating model prev_tns w/ sigma 0.5 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 21591.461126
#          Iterations: 14
#          Function evaluations: 63
#          Gradient evaluations: 51
#
#  ***** evaluating model prev_tns w/ sigma 1 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 21604.259265
#          Iterations: 17
#          Function evaluations: 76
#          Gradient evaluations: 64
#
#  ***** evaluating model prev_tns w/ sigma 2 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 21607.489532
#          Iterations: 14
#          Function evaluations: 57
#          Gradient evaluations: 45
#
#  ***** evaluating model prev_tns w/ sigma 4 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 21608.299265
#          Iterations: 16
#          Function evaluations: 80
#          Gradient evaluations: 68
#
#  ***** evaluating model prev_tns w/ sigma 8 *****
# Optimization terminated successfully.
#          Current function value: 21608.501845
#          Iterations: 17
#          Function evaluations: 23
#          Gradient evaluations: 23
#
#  ***** evaluating model prev_tns w/ sigma 16 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 21608.552499
#          Iterations: 17
#          Function evaluations: 71
#          Gradient evaluations: 60
#
#  ***** evaluating model prev_disengaged_filt_summed w/ sigma 0.07 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 21022.082266
#          Iterations: 13
#          Function evaluations: 61
#          Gradient evaluations: 49
#
#  ***** evaluating model prev_disengaged_filt_summed w/ sigma 0.13 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 21384.167023
#          Iterations: 13
#          Function evaluations: 75
#          Gradient evaluations: 63
#
#  ***** evaluating model prev_disengaged_filt_summed w/ sigma 0.25 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 21540.315833
#          Iterations: 12
#          Function evaluations: 81
#          Gradient evaluations: 69
#
#  ***** evaluating model prev_disengaged_filt_summed w/ sigma 0.5 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 21591.015672
#          Iterations: 12
#          Function evaluations: 66
#          Gradient evaluations: 54
#
#  ***** evaluating model prev_disengaged_filt_summed w/ sigma 1 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 21604.427192
#          Iterations: 12
#          Function evaluations: 64
#          Gradient evaluations: 52
#
#  ***** evaluating model prev_disengaged_filt_summed w/ sigma 2 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 21607.833741
#          Iterations: 14
#          Function evaluations: 83
#          Gradient evaluations: 71
#
#  ***** evaluating model prev_disengaged_filt_summed w/ sigma 4 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 21608.688877
#          Iterations: 15
#          Function evaluations: 78
#          Gradient evaluations: 67
#
#  ***** evaluating model prev_disengaged_filt_summed w/ sigma 8 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 21608.902875
#          Iterations: 16
#          Function evaluations: 62
#          Gradient evaluations: 51
#
#  ***** evaluating model prev_disengaged_filt_summed w/ sigma 16 *****
# Optimization terminated successfully.
#          Current function value: 21608.956388
#          Iterations: 15
#          Function evaluations: 20
#          Gradient evaluations: 20
#
#  ***** evaluating model prev_viol_stim_intrxs w/ sigma 0.07 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 21020.048171
#          Iterations: 13
#          Function evaluations: 84
#          Gradient evaluations: 72
#
#  ***** evaluating model prev_viol_stim_intrxs w/ sigma 0.13 *****
# Optimization terminated successfully.
#          Current function value: 21363.582296
#          Iterations: 21
#          Function evaluations: 27
#          Gradient evaluations: 27
#
#  ***** evaluating model prev_viol_stim_intrxs w/ sigma 0.25 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 21512.562193
#          Iterations: 19
#          Function evaluations: 77
#          Gradient evaluations: 65
#
#  ***** evaluating model prev_viol_stim_intrxs w/ sigma 0.5 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 21564.305565
#          Iterations: 16
#          Function evaluations: 78
#          Gradient evaluations: 66
#
#  ***** evaluating model prev_viol_stim_intrxs w/ sigma 1 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 21578.577626
#          Iterations: 21
#          Function evaluations: 85
#          Gradient evaluations: 73
#
#  ***** evaluating model prev_viol_stim_intrxs w/ sigma 2 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 21582.251830
#          Iterations: 18
#          Function evaluations: 64
#          Gradient evaluations: 52
#
#  ***** evaluating model prev_viol_stim_intrxs w/ sigma 4 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 21583.177685
#          Iterations: 20
#          Function evaluations: 79
#          Gradient evaluations: 67
#
#  ***** evaluating model prev_viol_stim_intrxs w/ sigma 8 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 21583.409614
#          Iterations: 18
#          Function evaluations: 75
#          Gradient evaluations: 63
#
#  ***** evaluating model prev_viol_stim_intrxs w/ sigma 16 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 21583.467631
#          Iterations: 18
#          Function evaluations: 81
#          Gradient evaluations: 70
#
#  ***** evaluating model prev_tns_stim_intrxs w/ sigma 0.07 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 20998.189269
#          Iterations: 12
#          Function evaluations: 81
#          Gradient evaluations: 69
#
#  ***** evaluating model prev_tns_stim_intrxs w/ sigma 0.13 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 21363.233773
#          Iterations: 22
#          Function evaluations: 76
#          Gradient evaluations: 64
#
#  ***** evaluating model prev_tns_stim_intrxs w/ sigma 0.25 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 21512.898557
#          Iterations: 12
#          Function evaluations: 87
#          Gradient evaluations: 75
#
#  ***** evaluating model prev_tns_stim_intrxs w/ sigma 0.5 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 21565.765478
#          Iterations: 13
#          Function evaluations: 79
#          Gradient evaluations: 67
#
#  ***** evaluating model prev_tns_stim_intrxs w/ sigma 1 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 21574.280904
#          Iterations: 15
#          Function evaluations: 86
#          Gradient evaluations: 74
#
#  ***** evaluating model prev_tns_stim_intrxs w/ sigma 2 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 21578.967593
#          Iterations: 17
#          Function evaluations: 86
#          Gradient evaluations: 74
#
# ...
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 19393.176283
#          Iterations: 13
#          Function evaluations: 63
#          Gradient evaluations: 51
#
#  ***** evaluating model base w/ sigma 2 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 19396.268871
#          Iterations: 13
#          Function evaluations: 65
#          Gradient evaluations: 53
#
#  ***** evaluating model base w/ sigma 4 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 19397.043401
#          Iterations: 13
#          Function evaluations: 63
#          Gradient evaluations: 51
#
#  ***** evaluating model base w/ sigma 8 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 19397.237125
#          Iterations: 13
#          Function evaluations: 65
#          Gradient evaluations: 53
#
#  ***** evaluating model base w/ sigma 16 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 19397.285561
#          Iterations: 13
#          Function evaluations: 59
#          Gradient evaluations: 48
#
#  ***** evaluating model prev_violation_filt w/ sigma 0.07 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 18795.541251
#          Iterations: 14
#          Function evaluations: 74
#          Gradient evaluations: 62
#
#  ***** evaluating model prev_violation_filt w/ sigma 0.13 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 19159.238216
#          Iterations: 13
#          Function evaluations: 69
#          Gradient evaluations: 57
#
#  ***** evaluating model prev_violation_filt w/ sigma 0.25 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 19313.541493
#          Iterations: 14
#          Function evaluations: 63
#          Gradient evaluations: 51
#
#  ***** evaluating model prev_violation_filt w/ sigma 0.5 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 19362.343518
#          Iterations: 13
#          Function evaluations: 72
#          Gradient evaluations: 60
#
#  ***** evaluating model prev_violation_filt w/ sigma 1 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 19375.066803
#          Iterations: 14
#          Function evaluations: 66
#          Gradient evaluations: 54
#
#  ***** evaluating model prev_violation_filt w/ sigma 2 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 19378.283695
#          Iterations: 14
#          Function evaluations: 68
#          Gradient evaluations: 56
#
#  ***** evaluating model prev_violation_filt w/ sigma 4 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 19379.090237
#          Iterations: 14
#          Function evaluations: 72
#          Gradient evaluations: 60
#
#  ***** evaluating model prev_violation_filt w/ sigma 8 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 19379.292018
#          Iterations: 15
#          Function evaluations: 69
#          Gradient evaluations: 57
#
#  ***** evaluating model prev_violation_filt w/ sigma 16 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 19379.342472
#          Iterations: 15
#          Function evaluations: 61
#          Gradient evaluations: 50
#
#  ***** evaluating model prev_tns w/ sigma 0.07 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 18884.629170
#          Iterations: 10
#          Function evaluations: 69
#          Gradient evaluations: 57
#
#  ***** evaluating model prev_tns w/ sigma 0.13 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 19159.141595
#          Iterations: 15
#          Function evaluations: 83
#          Gradient evaluations: 71
#
#  ***** evaluating model prev_tns w/ sigma 0.25 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 19313.352288
#          Iterations: 15
#          Function evaluations: 81
#          Gradient evaluations: 69
#
#  ***** evaluating model prev_tns w/ sigma 0.5 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 19362.101773
#          Iterations: 14
#          Function evaluations: 61
#          Gradient evaluations: 49
#
#  ***** evaluating model prev_tns w/ sigma 1 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 19374.834739
#          Iterations: 15
#          Function evaluations: 78
#          Gradient evaluations: 66
#
#  ***** evaluating model prev_tns w/ sigma 2 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 19378.062278
#          Iterations: 16
#          Function evaluations: 62
#          Gradient evaluations: 51
#
#  ***** evaluating model prev_tns w/ sigma 4 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 19378.872363
#          Iterations: 15
#          Function evaluations: 72
#          Gradient evaluations: 60
#
#  ***** evaluating model prev_tns w/ sigma 8 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 19379.075083
#          Iterations: 15
#          Function evaluations: 69
#          Gradient evaluations: 57
#
#  ***** evaluating model prev_tns w/ sigma 16 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 19379.125775
#          Iterations: 17
#          Function evaluations: 86
#          Gradient evaluations: 75
#
#  ***** evaluating model prev_disengaged_filt_summed w/ sigma 0.07 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 18799.114094
#          Iterations: 14
#          Function evaluations: 63
#          Gradient evaluations: 51
#
#  ***** evaluating model prev_disengaged_filt_summed w/ sigma 0.13 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 19161.775878
#          Iterations: 14
#          Function evaluations: 87
#          Gradient evaluations: 75
#
#  ***** evaluating model prev_disengaged_filt_summed w/ sigma 0.25 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 19314.536990
#          Iterations: 13
#          Function evaluations: 72
#          Gradient evaluations: 60
#
#  ***** evaluating model prev_disengaged_filt_summed w/ sigma 0.5 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 19363.345366
#          Iterations: 13
#          Function evaluations: 64
#          Gradient evaluations: 52
#
#  ***** evaluating model prev_disengaged_filt_summed w/ sigma 1 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 19376.221732
#          Iterations: 14
#          Function evaluations: 64
#          Gradient evaluations: 52
#
#  ***** evaluating model prev_disengaged_filt_summed w/ sigma 2 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 19379.491607
#          Iterations: 13
#          Function evaluations: 76
#          Gradient evaluations: 65
#
#  ***** evaluating model prev_disengaged_filt_summed w/ sigma 4 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 19380.312507
#          Iterations: 14
#          Function evaluations: 64
#          Gradient evaluations: 52
#
#  ***** evaluating model prev_disengaged_filt_summed w/ sigma 8 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 19380.517942
#          Iterations: 13
#          Function evaluations: 53
#          Gradient evaluations: 41
#
#  ***** evaluating model prev_disengaged_filt_summed w/ sigma 16 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 19380.569314
#          Iterations: 14
#          Function evaluations: 75
#          Gradient evaluations: 64
#
#  ***** evaluating model prev_viol_stim_intrxs w/ sigma 0.07 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 18794.934411
#          Iterations: 18
#          Function evaluations: 91
#          Gradient evaluations: 79
#
#  ***** evaluating model prev_viol_stim_intrxs w/ sigma 0.13 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 19099.481479
#          Iterations: 17
#          Function evaluations: 61
#          Gradient evaluations: 49
#
#  ***** evaluating model prev_viol_stim_intrxs w/ sigma 0.25 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 19210.571754
#          Iterations: 15
#          Function evaluations: 74
#          Gradient evaluations: 62
#
#  ***** evaluating model prev_viol_stim_intrxs w/ sigma 0.5 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 19313.024328
#          Iterations: 11
#          Function evaluations: 47
#          Gradient evaluations: 36
#
#  ***** evaluating model prev_viol_stim_intrxs w/ sigma 1 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 19279.920273
#          Iterations: 21
#          Function evaluations: 64
#          Gradient evaluations: 52
#
#  ***** evaluating model prev_viol_stim_intrxs w/ sigma 2 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 19285.709754
#          Iterations: 17
#          Function evaluations: 63
#          Gradient evaluations: 51
#
#  ***** evaluating model prev_viol_stim_intrxs w/ sigma 4 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 19287.225221
#          Iterations: 18
#          Function evaluations: 62
#          Gradient evaluations: 50
#
#  ***** evaluating model prev_viol_stim_intrxs w/ sigma 8 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 19287.608657
#          Iterations: 18
#          Function evaluations: 67
#          Gradient evaluations: 55
#
#  ***** evaluating model prev_viol_stim_intrxs w/ sigma 16 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 19287.704780
#          Iterations: 18
#          Function evaluations: 78
#          Gradient evaluations: 66
#
#  ***** evaluating model prev_tns_stim_intrxs w/ sigma 0.07 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 18794.799645
#          Iterations: 26
#          Function evaluations: 79
#          Gradient evaluations: 67
#
#  ***** evaluating model prev_tns_stim_intrxs w/ sigma 0.13 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 18939.026630
#          Iterations: 12
#          Function evaluations: 85
#          Gradient evaluations: 73
#
#  ***** evaluating model prev_tns_stim_intrxs w/ sigma 0.25 *****
# Optimization terminated successfully.
#          Current function value: 19210.199849
#          Iterations: 25
#          Function evaluations: 34
#          Gradient evaluations: 34
#
#  ***** evaluating model prev_tns_stim_intrxs w/ sigma 0.5 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 19064.163170
#          Iterations: 12
#          Function evaluations: 79
#          Gradient evaluations: 67
#
#  ***** evaluating model prev_tns_stim_intrxs w/ sigma 1 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 19277.382599
#          Iterations: 18
#          Function evaluations: 99
#          Gradient evaluations: 87
#
#  ***** evaluating model prev_tns_stim_intrxs w/ sigma 2 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 19283.677510
#          Iterations: 20
#          Function evaluations: 81
#          Gradient evaluations: 69
#
#  ***** evaluating model prev_tns_stim_intrxs w/ sigma 4 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 19285.272504
#          Iterations: 21
#          Function evaluations: 97
#          Gradient evaluations: 85
#
#  ***** evaluating model prev_tns_stim_intrxs w/ sigma 8 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 19285.678047
#          Iterations: 21
#          Function evaluations: 90
#          Gradient evaluations: 78
#
#  ***** evaluating model prev_tns_stim_intrxs w/ sigma 16 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 19285.779997
#          Iterations: 23
#          Function evaluations: 80
#          Gradient evaluations: 68
#
#  ***** evaluating model prev_disengaged_stim_intrxs w/ sigma 0.07 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 18801.085449
#          Iterations: 23
#          Function evaluations: 97
#          Gradient evaluations: 85
#
#  ***** evaluating model prev_disengaged_stim_intrxs w/ sigma 0.13 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 19117.345283
#          Iterations: 14
#          Function evaluations: 56
#          Gradient evaluations: 44
#
#  ***** evaluating model prev_disengaged_stim_intrxs w/ sigma 0.25 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 19215.888450
#          Iterations: 12
#          Function evaluations: 65
#          Gradient evaluations: 53
#
#  ***** evaluating model prev_disengaged_stim_intrxs w/ sigma 0.5 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 19255.307596
#          Iterations: 12
#          Function evaluations: 77
#          Gradient evaluations: 65
#
#  ***** evaluating model prev_disengaged_stim_intrxs w/ sigma 1 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 19276.058312
#          Iterations: 14
#          Function evaluations: 77
#          Gradient evaluations: 65
#
#  ***** evaluating model prev_disengaged_stim_intrxs w/ sigma 2 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 19283.082923
#          Iterations: 16
#          Function evaluations: 66
#          Gradient evaluations: 54
#
#  ***** evaluating model prev_disengaged_stim_intrxs w/ sigma 4 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 19284.986864
#          Iterations: 15
#          Function evaluations: 66
#          Gradient evaluations: 54
#
#  ***** evaluating model prev_disengaged_stim_intrxs w/ sigma 8 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 19285.472890
#          Iterations: 16
#          Function evaluations: 66
#          Gradient evaluations: 54
#
#  ***** evaluating model prev_disengaged_stim_intrxs w/ sigma 16 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 19285.595008
#          Iterations: 15
#          Function evaluations: 69
#          Gradient evaluations: 57

# %% [markdown]
# ## Visualize

# %%
experiment = load_experiment(save_name)
mvc = ModelVisualizerCompare(experiment)

# %%
df = mvc.find_best_fit(group="model_name")
df["model_name"] = pd.Categorical(df["model_name"], categories=ORDER, ordered=True)
for model_name, model_df in df.groupby("model_name"):
    mvc.plot_sigma_summary(model_df, title=f"{model_name} fit sigma summary")
# Out:
# /var/folders/__/8jn6qz211155h1xb451s5zcr0000gn/T/ipykernel_4635/2431235986.py:3: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   for model_name, model_df in df.groupby("model_name"):
# /Users/jessbreda/anaconda3/envs/an_lrn/lib/python3.10/site-packages/seaborn/categorical.py:641: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   grouped_vals = vals.groupby(grouper)
# /Users/jessbreda/anaconda3/envs/an_lrn/lib/python3.10/site-packages/seaborn/categorical.py:641: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   grouped_vals = vals.groupby(grouper)
# /Users/jessbreda/anaconda3/envs/an_lrn/lib/python3.10/site-packages/seaborn/categorical.py:641: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   grouped_vals = vals.groupby(grouper)
# /Users/jessbreda/anaconda3/envs/an_lrn/lib/python3.10/site-packages/seaborn/categorical.py:641: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   grouped_vals = vals.groupby(grouper)
# /Users/jessbreda/anaconda3/envs/an_lrn/lib/python3.10/site-packages/seaborn/categorical.py:641: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   grouped_vals = vals.groupby(grouper)
# /Users/jessbreda/anaconda3/envs/an_lrn/lib/python3.10/site-packages/seaborn/categorical.py:641: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   grouped_vals = vals.groupby(grouper)
# /Users/jessbreda/anaconda3/envs/an_lrn/lib/python3.10/site-packages/seaborn/categorical.py:641: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   grouped_vals = vals.groupby(grouper)

# %%
fig, ax = plt.subplots(
    len(ORDER), 1, figsize=(10, len(ORDER) * 6), constrained_layout=True, sharey=False
)

best_fit_by_model = mvc.find_best_fit(group=["animal_id", "model_name"])
best_fit_by_model["model_name"] = pd.Categorical(
    best_fit_by_model["model_name"], categories=ORDER, ordered=True
)

for ii, (model_name, model_df) in enumerate(best_fit_by_model.groupby("model_name")):
    unpacked = mvc.unpack_features_and_weights(model_df)

    mvc.plot_weights_summary(
        df=unpacked,
        ax=ax[ii],
        palette="Set2",
        title=f"{model_name} weights summary",
    )
# Out:
# /var/folders/__/8jn6qz211155h1xb451s5zcr0000gn/T/ipykernel_4635/2667047998.py:10: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   for ii, (model_name, model_df) in enumerate(best_fit_by_model.groupby("model_name")):

# %%
fig, ax = plt.subplots(1, 1, figsize=(8, 5))
mvc.plot_model_comparison(
    hue=None,
    ax=ax,
    order=ORDER,
    errorbar=None,
)

# %%
mvc.plot_train_and_test_ll(
    order=ORDER,
    errorbar=None,
)
# Out:
# /Users/jessbreda/anaconda3/envs/an_lrn/lib/python3.10/site-packages/seaborn/categorical.py:641: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   grouped_vals = vals.groupby(grouper)
# /Users/jessbreda/anaconda3/envs/an_lrn/lib/python3.10/site-packages/seaborn/categorical.py:641: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   grouped_vals = vals.groupby(grouper)

# %%
mvc.plot_ll_delta_by_animal(
    base_model_name=ORDER[0],
    new_model_name=ORDER[1],
    type="test",
)
# Out:
# <Axes: title={'center': 'Model Improvement- mu: 7.51 std: 29.14 \n base -> prev_violation_filt'}, xlabel='animal_id', ylabel='Delta test LL (new - base)'>

# %%
mvc.plot_ll_delta_by_animal(
    base_model_name=ORDER[0],
    new_model_name=ORDER[-4],
    type="test",
)
# Out:
# <Axes: title={'center': 'Model Improvement- mu: 9.24 std: 31.81 \n base -> prev_disengaged_filt_summed'}, xlabel='animal_id', ylabel='Delta test LL (new - base)'>
