# %% [markdown]
# # Experiment: Compare Binary Model Base Features
#
# **Goal**: assess the impact of adding base features, serially to the binary model
#
#
# > Written by Jess Breda

# %% [markdown]
# ## Imports

# %%
import seaborn as sns
import matplotlib.pyplot as plt

from multiglm.experiments.experiment import load_experiment

from multiglm.experiments.experiment_compare_models import ExperimentCompareModels

from multiglm.features.design_matrix_generator import *
from multiglm.features.design_matrix_generator_PWM import *

from multiglm.models.binary_logistic_regression import BinaryLogisticRegression
from multiglm.models.multiclass_logistic_regression import MultiClassLogisticRegression

from multiglm.visualizations.model_visualizer import *

from multiglm.data import ANIMAL_IDS
from multiglm.experiments import STANDARD_SIGMAS


sns.set_context("talk")
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# ## Model Configs

# %% [markdown]
# ### Compare

# %%
# design matrix columns shared between all models being fit
shared_cols = {
    "session": lambda df: (copy(df.session)),
    "bias": lambda df: (add_bias_column(df)),
    "labels": binary_choice_labels(),
}

models_config = {
    "stimuli": {
        "model_class": BinaryLogisticRegression,
        "dmg_config": {
            **shared_cols,
            "s_a": lambda df: (standardize(df.s_a)),
            "s_b": lambda df: (standardize(df.s_b)),
        },
    },
    "prev_stim_viol_mask": {
        "model_class": BinaryLogisticRegression,
        "dmg_config": {
            **shared_cols,
            "s_a": lambda df: (standardize(df.s_a)),
            "s_b": lambda df: (standardize(df.s_b)),
            "prev_avg_stim": lambda df: prev_avg_stim(df, mask_prev_violation=True),
        },
    },
    "prev_stim_no_viol_mask": {
        "model_class": BinaryLogisticRegression,
        "dmg_config": {
            **shared_cols,
            "s_a": lambda df: (standardize(df.s_a)),
            "s_b": lambda df: (standardize(df.s_b)),
            "prev_avg_stim": lambda df: prev_avg_stim(df, mask_prev_violation=True),
        },
    },
    "prev_correct": {
        "model_class": BinaryLogisticRegression,
        "dmg_config": {
            **shared_cols,
            "s_a": lambda df: (standardize(df.s_a)),
            "s_b": lambda df: (standardize(df.s_b)),
            "prev_avg_stim": lambda df: prev_avg_stim(df, mask_prev_violation=True),
            "prev_correct": lambda df: (prev_correct_side(df)),
        },
    },
    "prev_choice": {
        "model_class": BinaryLogisticRegression,
        "dmg_config": {
            **shared_cols,
            "s_a": lambda df: (standardize(df.s_a)),
            "s_b": lambda df: (standardize(df.s_b)),
            "prev_avg_stim": lambda df: prev_avg_stim(df, mask_prev_violation=True),
            "prev_correct": lambda df: (prev_correct_side(df)),
            "prev_choice": lambda df: (prev_choice(df)),
        },
    },
}

params = {
    "animals": ANIMAL_IDS,
    "data_type": "new_trained",
    "sigmas": STANDARD_SIGMAS,
    "random_state": 47,
    "eval_train": True,
    "null_mode": "binary",
    "model_config": models_config,
}

save_name = "2024_03_26_compare_binary_base_features.pkl"

ORDER = [
    "stimuli",
    "prev_stim_viol_mask",
    "prev_stim_no_viol_mask",
    "prev_correct",
    "prev_choice",
]

# %% [markdown]
# ## Run

# %%
experiment = ExperimentCompareModels(params)
experiment.run()
experiment.save(save_name)
# Out:
# Loading dataset type : new_trained
# Loading data for animal ids:  ['W051', 'W060', 'W065', 'W066', 'W068', 'W072', 'W073', 'W074', 'W075', 'W078', 'W080', 'W081', 'W082', 'W083', 'W088', 'W089', 'W094']
#
#  >>>> evaluating animal W051 <<<<
#
#  ***** evaluating model stimuli w/ sigma 0.07 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 32572.577018
#          Iterations: 8
#          Function evaluations: 62
#          Gradient evaluations: 50
#
#  ***** evaluating model stimuli w/ sigma 0.13 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 32947.251082
#          Iterations: 11
#          Function evaluations: 87
#          Gradient evaluations: 75
#
#  ***** evaluating model stimuli w/ sigma 0.25 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 33080.066363
#          Iterations: 10
#          Function evaluations: 92
#          Gradient evaluations: 80
#
#  ***** evaluating model stimuli w/ sigma 0.5 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 33118.961727
#          Iterations: 10
#          Function evaluations: 60
#          Gradient evaluations: 48
#
#  ***** evaluating model stimuli w/ sigma 1 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 33128.825723
#          Iterations: 9
#          Function evaluations: 59
#          Gradient evaluations: 47
#
#  ***** evaluating model stimuli w/ sigma 2 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 33131.300584
#          Iterations: 10
#          Function evaluations: 49
#          Gradient evaluations: 37
#
#  ***** evaluating model stimuli w/ sigma 4 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 33131.919855
#          Iterations: 11
#          Function evaluations: 55
#          Gradient evaluations: 44
#
#  ***** evaluating model stimuli w/ sigma 8 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 33132.074707
#          Iterations: 10
#          Function evaluations: 67
#          Gradient evaluations: 55
#
#  ***** evaluating model stimuli w/ sigma 16 *****
# Optimization terminated successfully.
#          Current function value: 33132.113422
#          Iterations: 10
#          Function evaluations: 14
#          Gradient evaluations: 14
#
#  ***** evaluating model prev_stim_viol_mask w/ sigma 0.07 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 32261.161724
#          Iterations: 12
#          Function evaluations: 66
#          Gradient evaluations: 54
#
#  ***** evaluating model prev_stim_viol_mask w/ sigma 0.13 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 32644.403254
#          Iterations: 12
#          Function evaluations: 59
#          Gradient evaluations: 47
#
#  ***** evaluating model prev_stim_viol_mask w/ sigma 0.25 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 32780.935244
#          Iterations: 11
#          Function evaluations: 66
#          Gradient evaluations: 54
#
#  ***** evaluating model prev_stim_viol_mask w/ sigma 0.5 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 32820.988737
#          Iterations: 11
#          Function evaluations: 56
#          Gradient evaluations: 44
#
#  ***** evaluating model prev_stim_viol_mask w/ sigma 1 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 32831.150439
#          Iterations: 11
#          Function evaluations: 72
#          Gradient evaluations: 60
#
#  ***** evaluating model prev_stim_viol_mask w/ sigma 2 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 32833.700234
#          Iterations: 10
#          Function evaluations: 63
#          Gradient evaluations: 51
#
#  ***** evaluating model prev_stim_viol_mask w/ sigma 4 *****
# Optimization terminated successfully.
#          Current function value: 32834.338306
#          Iterations: 17
#          Function evaluations: 25
#          Gradient evaluations: 25
#
#  ***** evaluating model prev_stim_viol_mask w/ sigma 8 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 32834.497855
#          Iterations: 16
#          Function evaluations: 29
#          Gradient evaluations: 29
#
#  ***** evaluating model prev_stim_viol_mask w/ sigma 16 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 32834.537744
#          Iterations: 12
#          Function evaluations: 63
#          Gradient evaluations: 51
#
#  ***** evaluating model prev_stim_no_viol_mask w/ sigma 0.07 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 32261.181514
#          Iterations: 10
#          Function evaluations: 52
#          Gradient evaluations: 40
#
#  ***** evaluating model prev_stim_no_viol_mask w/ sigma 0.13 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 32644.400857
#          Iterations: 10
#          Function evaluations: 77
#          Gradient evaluations: 65
#
#  ***** evaluating model prev_stim_no_viol_mask w/ sigma 0.25 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 32780.938102
#          Iterations: 10
#          Function evaluations: 57
#          Gradient evaluations: 45
#
#  ***** evaluating model prev_stim_no_viol_mask w/ sigma 0.5 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 32820.988717
#          Iterations: 11
#          Function evaluations: 50
#          Gradient evaluations: 38
#
#  ***** evaluating model prev_stim_no_viol_mask w/ sigma 1 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 32831.150330
#          Iterations: 11
#          Function evaluations: 69
#          Gradient evaluations: 57
#
#  ***** evaluating model prev_stim_no_viol_mask w/ sigma 2 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 32833.700212
#          Iterations: 11
#          Function evaluations: 61
#          Gradient evaluations: 49
#
#  ***** evaluating model prev_stim_no_viol_mask w/ sigma 4 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 32834.338306
#          Iterations: 10
#          Function evaluations: 64
#          Gradient evaluations: 52
#
#  ***** evaluating model prev_stim_no_viol_mask w/ sigma 8 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 32834.497854
#          Iterations: 11
#          Function evaluations: 56
#          Gradient evaluations: 44
#
#  ***** evaluating model prev_stim_no_viol_mask w/ sigma 16 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 32834.537744
#          Iterations: 11
#          Function evaluations: 58
#          Gradient evaluations: 46
#
#  ***** evaluating model prev_correct w/ sigma 0.07 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 32055.688592
#          Iterations: 11
#          Function evaluations: 65
#          Gradient evaluations: 53
#
#  ***** evaluating model prev_correct w/ sigma 0.13 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 32444.259128
#          Iterations: 12
#          Function evaluations: 83
#          Gradient evaluations: 71
#
#  ***** evaluating model prev_correct w/ sigma 0.25 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 32583.144626
#          Iterations: 11
#          Function evaluations: 67
#          Gradient evaluations: 55
#
#  ***** evaluating model prev_correct w/ sigma 0.5 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 32623.927338
#          Iterations: 13
#          Function evaluations: 64
#          Gradient evaluations: 52
#
#  ***** evaluating model prev_correct w/ sigma 1 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 32634.278483
#          Iterations: 11
#          Function evaluations: 70
#          Gradient evaluations: 58
#
#  ***** evaluating model prev_correct w/ sigma 2 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 32636.875904
#          Iterations: 12
#          Function evaluations: 65
#          Gradient evaluations: 53
#
#  ***** evaluating model prev_correct w/ sigma 4 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 32637.525873
#          Iterations: 11
#          Function evaluations: 48
#          Gradient evaluations: 36
#
#  ***** evaluating model prev_correct w/ sigma 8 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 32637.688403
#          Iterations: 13
#          Function evaluations: 48
#          Gradient evaluations: 37
#
#  ***** evaluating model prev_correct w/ sigma 16 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 32637.729038
#          Iterations: 11
#          Function evaluations: 65
#          Gradient evaluations: 53
#
#  ***** evaluating model prev_choice w/ sigma 0.07 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 32027.237175
#          Iterations: 13
#          Function evaluations: 84
#          Gradient evaluations: 72
#
#  ***** evaluating model prev_choice w/ sigma 0.13 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 32417.262141
#          Iterations: 13
#          Function evaluations: 84
#          Gradient evaluations: 72
#
#  ***** evaluating model prev_choice w/ sigma 0.25 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 32556.844894
#          Iterations: 13
#          Function evaluations: 69
#          Gradient evaluations: 57
#
#  ***** evaluating model prev_choice w/ sigma 0.5 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 32597.849034
#          Iterations: 12
#          Function evaluations: 57
#          Gradient evaluations: 45
#
#  ***** evaluating model prev_choice w/ sigma 1 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 32608.256916
#          Iterations: 13
#          Function evaluations: 64
#          Gradient evaluations: 52
#
#  ***** evaluating model prev_choice w/ sigma 2 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 32610.868824
#          Iterations: 13
#          Function evaluations: 68
#          Gradient evaluations: 56
#
#  ***** evaluating model prev_choice w/ sigma 4 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 32611.522419
#          Iterations: 12
#          Function evaluations: 77
#          Gradient evaluations: 65
#
#  ***** evaluating model prev_choice w/ sigma 8 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 32611.685858
#          Iterations: 13
#          Function evaluations: 54
#          Gradient evaluations: 43
#
#  ***** evaluating model prev_choice w/ sigma 16 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 32611.726720
#          Iterations: 15
#          Function evaluations: 78
#          Gradient evaluations: 63
#
#  >>>> evaluating animal W060 <<<<
#
#  ***** evaluating model stimuli w/ sigma 0.07 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 24983.073549
#          Iterations: 9
#          Function evaluations: 44
#          Gradient evaluations: 32
#
#  ***** evaluating model stimuli w/ sigma 0.13 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 25406.208539
#          Iterations: 10
#          Function evaluations: 73
#          Gradient evaluations: 61
#
#  ***** evaluating model stimuli w/ sigma 0.25 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 25564.812248
#          Iterations: 10
#          Function evaluations: 59
#          Gradient evaluations: 47
#
#  ***** evaluating model stimuli w/ sigma 0.5 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 25612.119215
#          Iterations: 11
#          Function evaluations: 69
#          Gradient evaluations: 57
#
#  ***** evaluating model stimuli w/ sigma 1 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 25624.170279
#          Iterations: 10
#          Function evaluations: 67
#          Gradient evaluations: 55
#
#  ***** evaluating model stimuli w/ sigma 2 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 25627.198490
#          Iterations: 11
#          Function evaluations: 74
#          Gradient evaluations: 62
#
#  ***** evaluating model stimuli w/ sigma 4 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 25627.956399
#          Iterations: 15
#          Function evaluations: 60
#          Gradient evaluations: 49
#
#  ***** evaluating model stimuli w/ sigma 8 *****
# Optimization terminated successfully.
#          Current function value: 25628.145913
#          Iterations: 15
#          Function evaluations: 21
#          Gradient evaluations: 21
#
#  ***** evaluating model stimuli w/ sigma 16 *****
# Optimization terminated successfully.
#          Current function value: 25628.193293
#          Iterations: 16
#          Function evaluations: 22
#          Gradient evaluations: 22
#
#  ***** evaluating model prev_stim_viol_mask w/ sigma 0.07 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 24691.575062
#          Iterations: 11
#          Function evaluations: 84
#          Gradient evaluations: 72
#
#  ***** evaluating model prev_stim_viol_mask w/ sigma 0.13 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 25125.154240
#          Iterations: 16
#          Function evaluations: 52
#          Gradient evaluations: 40
#
#  ***** evaluating model prev_stim_viol_mask w/ sigma 0.25 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 25289.342660
#          Iterations: 10
#          Function evaluations: 65
#          Gradient evaluations: 53
#
#  ***** evaluating model prev_stim_viol_mask w/ sigma 0.5 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 25338.519439
#          Iterations: 11
#          Function evaluations: 74
#          Gradient evaluations: 62
#
#  ***** evaluating model prev_stim_viol_mask w/ sigma 1 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 25351.062815
#          Iterations: 12
#          Function evaluations: 71
#          Gradient evaluations: 59
#
#  ***** evaluating model prev_stim_viol_mask w/ sigma 2 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 25354.213866
#          Iterations: 15
#          Function evaluations: 54
#          Gradient evaluations: 42
#
#  ***** evaluating model prev_stim_viol_mask w/ sigma 4 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 25355.002373
#          Iterations: 16
#          Function evaluations: 61
#          Gradient evaluations: 49
#
#  ***** evaluating model prev_stim_viol_mask w/ sigma 8 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 25355.199563
#          Iterations: 16
#          Function evaluations: 70
#          Gradient evaluations: 58
#
#  ***** evaluating model prev_stim_viol_mask w/ sigma 16 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 25355.248864
#          Iterations: 15
#          Function evaluations: 69
#          Gradient evaluations: 57
#
#  ***** evaluating model prev_stim_no_viol_mask w/ sigma 0.07 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 24691.597363
#          Iterations: 11
#          Function evaluations: 64
#          Gradient evaluations: 52
#
#  ***** evaluating model prev_stim_no_viol_mask w/ sigma 0.13 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 25125.149002
#          Iterations: 10
#          Function evaluations: 70
#          Gradient evaluations: 58
#
#  ***** evaluating model prev_stim_no_viol_mask w/ sigma 0.25 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 25289.369816
#          Iterations: 11
#          Function evaluations: 67
#          Gradient evaluations: 55
#
#  ***** evaluating model prev_stim_no_viol_mask w/ sigma 0.5 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 25338.514831
#          Iterations: 10
#          Function evaluations: 69
#          Gradient evaluations: 57
#
#  ***** evaluating model prev_stim_no_viol_mask w/ sigma 1 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 25351.062411
#          Iterations: 11
#          Function evaluations: 78
#          Gradient evaluations: 66
#
#  ***** evaluating model prev_stim_no_viol_mask w/ sigma 2 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 25354.213860
#          Iterations: 17
#          Function evaluations: 77
#          Gradient evaluations: 65
#
#  ***** evaluating model prev_stim_no_viol_mask w/ sigma 4 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 25355.002362
#          Iterations: 11
#          Function evaluations: 61
#          Gradient evaluations: 49
#
#  ***** evaluating model prev_stim_no_viol_mask w/ sigma 8 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 25355.199562
#          Iterations: 12
#          Function evaluations: 53
#          Gradient evaluations: 42
#
#  ***** evaluating model prev_stim_no_viol_mask w/ sigma 16 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 25355.248864
#          Iterations: 17
#          Function evaluations: 78
#          Gradient evaluations: 67
#
#  ***** evaluating model prev_correct w/ sigma 0.07 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 24626.339509
#          Iterations: 12
#          Function evaluations: 75
#          Gradient evaluations: 63
#
#  ***** evaluating model prev_correct w/ sigma 0.13 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 25061.555903
#          Iterations: 12
#          Function evaluations: 72
#          Gradient evaluations: 60
#
#  ***** evaluating model prev_correct w/ sigma 0.25 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 25226.692688
#          Iterations: 11
#          Function evaluations: 50
#          Gradient evaluations: 38
#
#  ***** evaluating model prev_correct w/ sigma 0.5 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 25276.127626
#          Iterations: 12
#          Function evaluations: 68
#          Gradient evaluations: 56
#
#  ***** evaluating model prev_correct w/ sigma 1 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 25288.737647
#          Iterations: 12
#          Function evaluations: 71
#          Gradient evaluations: 59
#
#  ***** evaluating model prev_correct w/ sigma 2 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 25291.909108
#          Iterations: 19
#          Function evaluations: 66
#          Gradient evaluations: 54
#
#  ***** evaluating model prev_correct w/ sigma 4 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 25292.702452
#          Iterations: 16
#          Function evaluations: 79
#          Gradient evaluations: 67
#
#  ***** evaluating model prev_correct w/ sigma 8 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 25292.900851
#          Iterations: 14
#          Function evaluations: 66
#          Gradient evaluations: 55
#
#  ***** evaluating model prev_correct w/ sigma 16 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 25292.950456
#          Iterations: 18
#          Function evaluations: 82
#          Gradient evaluations: 70
#
#  ***** evaluating model prev_choice w/ sigma 0.07 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 24622.965090
#          Iterations: 11
#          Function evaluations: 74
#          Gradient evaluations: 62
#
#  ***** evaluating model prev_choice w/ sigma 0.13 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 25058.596782
#          Iterations: 12
#          Function evaluations: 79
#          Gradient evaluations: 67
#
#  ***** evaluating model prev_choice w/ sigma 0.25 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 25224.036423
#          Iterations: 13
#          Function evaluations: 68
#          Gradient evaluations: 56
#
#  ***** evaluating model prev_choice w/ sigma 0.5 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 25273.514548
#          Iterations: 18
#          Function evaluations: 62
#          Gradient evaluations: 50
#
#  ***** evaluating model prev_choice w/ sigma 1 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 25286.139508
#          Iterations: 13
#          Function evaluations: 73
#          Gradient evaluations: 61
#
#  ***** evaluating model prev_choice w/ sigma 2 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 25289.312299
#          Iterations: 13
#          Function evaluations: 73
#          Gradient evaluations: 61
#
#  ***** evaluating model prev_choice w/ sigma 4 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 25290.106795
#          Iterations: 13
#          Function evaluations: 73
#          Gradient evaluations: 62
#
#  ***** evaluating model prev_choice w/ sigma 8 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 25290.305415
#          Iterations: 17
#          Function evaluations: 62
#          Gradient evaluations: 50
#
#  ***** evaluating model prev_choice w/ sigma 16 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 25290.355071
#          Iterations: 14
#          Function evaluations: 58
#          Gradient evaluations: 46
#
#  >>>> evaluating animal W065 <<<<
#
#  ***** evaluating model stimuli w/ sigma 0.07 *****
# Optimization terminated successfully.
#          Current function value: 21484.319912
#          Iterations: 10
#          Function evaluations: 12
#          Gradient evaluations: 12
#
#  ***** evaluating model stimuli w/ sigma 0.13 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 21843.475523
#          Iterations: 9
#          Function evaluations: 77
#          Gradient evaluations: 65
#
#  ***** evaluating model stimuli w/ sigma 0.25 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 21991.620910
#          Iterations: 8
#          Function evaluations: 61
#          Gradient evaluations: 49
#
#  ***** evaluating model stimuli w/ sigma 0.5 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 22037.174175
#          Iterations: 9
#          Function evaluations: 54
#          Gradient evaluations: 42
#
#  ***** evaluating model stimuli w/ sigma 1 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 22048.886601
#          Iterations: 10
#          Function evaluations: 63
#          Gradient evaluations: 51
#
#  ***** evaluating model stimuli w/ sigma 2 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 22051.835465
#          Iterations: 9
#          Function evaluations: 62
#          Gradient evaluations: 50
#
#  ***** evaluating model stimuli w/ sigma 4 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 22052.574010
#          Iterations: 9
#          Function evaluations: 61
#          Gradient evaluations: 49
#
#  ***** evaluating model stimuli w/ sigma 8 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 22052.758724
#          Iterations: 10
#          Function evaluations: 59
#          Gradient evaluations: 47
#
#  ***** evaluating model stimuli w/ sigma 16 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 22052.804908
#          Iterations: 10
#          Function evaluations: 54
#          Gradient evaluations: 43
#
#  ***** evaluating model prev_stim_viol_mask w/ sigma 0.07 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 21117.967265
#          Iterations: 12
#          Function evaluations: 64
#          Gradient evaluations: 52
#
#  ***** evaluating model prev_stim_viol_mask w/ sigma 0.13 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 21489.543380
#          Iterations: 11
#          Function evaluations: 87
#          Gradient evaluations: 75
#
#  ***** evaluating model prev_stim_viol_mask w/ sigma 0.25 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 21644.944252
#          Iterations: 10
#          Function evaluations: 71
#          Gradient evaluations: 59
#
#  ***** evaluating model prev_stim_viol_mask w/ sigma 0.5 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 21692.957735
#          Iterations: 11
#          Function evaluations: 66
#          Gradient evaluations: 54
#
#  ***** evaluating model prev_stim_viol_mask w/ sigma 1 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 21705.319906
#          Iterations: 11
#          Function evaluations: 59
#          Gradient evaluations: 47
#
#  ***** evaluating model prev_stim_viol_mask w/ sigma 2 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 21708.433607
#          Iterations: 10
#          Function evaluations: 61
#          Gradient evaluations: 49
#
#  ***** evaluating model prev_stim_viol_mask w/ sigma 4 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 21709.213504
#          Iterations: 11
#          Function evaluations: 70
#          Gradient evaluations: 58
#
#  ***** evaluating model prev_stim_viol_mask w/ sigma 8 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 21709.408557
#          Iterations: 10
#          Function evaluations: 69
#          Gradient evaluations: 58
#
#  ***** evaluating model prev_stim_viol_mask w/ sigma 16 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 21709.457327
#          Iterations: 12
#          Function evaluations: 50
#          Gradient evaluations: 39
#
#  ***** evaluating model prev_stim_no_viol_mask w/ sigma 0.07 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 21117.890188
#          Iterations: 11
#          Function evaluations: 71
#          Gradient evaluations: 59
#
#  ***** evaluating model prev_stim_no_viol_mask w/ sigma 0.13 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 21489.543401
#          Iterations: 11
#          Function evaluations: 58
#          Gradient evaluations: 46
#
#  ***** evaluating model prev_stim_no_viol_mask w/ sigma 0.25 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 21644.944533
#          Iterations: 10
#          Function evaluations: 58
#          Gradient evaluations: 46
#
#  ***** evaluating model prev_stim_no_viol_mask w/ sigma 0.5 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 21692.956322
#          Iterations: 11
#          Function evaluations: 58
#          Gradient evaluations: 46
#
#  ***** evaluating model prev_stim_no_viol_mask w/ sigma 1 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 21705.319959
#          Iterations: 11
#          Function evaluations: 73
#          Gradient evaluations: 61
#
#  ***** evaluating model prev_stim_no_viol_mask w/ sigma 2 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 21708.433654
#          Iterations: 11
#          Function evaluations: 68
#          Gradient evaluations: 56
#
#  ***** evaluating model prev_stim_no_viol_mask w/ sigma 4 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 21709.213504
#          Iterations: 11
#          Function evaluations: 64
#          Gradient evaluations: 52
#
#  ***** evaluating model prev_stim_no_viol_mask w/ sigma 8 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 21709.408558
#          Iterations: 11
#          Function evaluations: 68
#          Gradient evaluations: 56
#
#  ***** evaluating model prev_stim_no_viol_mask w/ sigma 16 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 21709.457326
#          Iterations: 11
#          Function evaluations: 59
#          Gradient evaluations: 48
#
#  ***** evaluating model prev_correct w/ sigma 0.07 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 21066.547611
#          Iterations: 11
#          Function evaluations: 55
#          Gradient evaluations: 43
#
#  ***** evaluating model prev_correct w/ sigma 0.13 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 21439.491753
#          Iterations: 11
#          Function evaluations: 75
#          Gradient evaluations: 63
#
#  ***** evaluating model prev_correct w/ sigma 0.25 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 21595.639762
#          Iterations: 11
#          Function evaluations: 68
#          Gradient evaluations: 56
#
#  ***** evaluating model prev_correct w/ sigma 0.5 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 21643.908456
#          Iterations: 11
#          Function evaluations: 54
#          Gradient evaluations: 42
#
#  ***** evaluating model prev_correct w/ sigma 1 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 21656.337369
#          Iterations: 11
#          Function evaluations: 59
#          Gradient evaluations: 47
#
#  ***** evaluating model prev_correct w/ sigma 2 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 21659.467847
#          Iterations: 12
#          Function evaluations: 61
#          Gradient evaluations: 49
#
#  ***** evaluating model prev_correct w/ sigma 4 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 21660.251929
#          Iterations: 11
#          Function evaluations: 71
#          Gradient evaluations: 59
#
#  ***** evaluating model prev_correct w/ sigma 8 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 21660.448042
#          Iterations: 11
#          Function evaluations: 70
#          Gradient evaluations: 58
#
#  ***** evaluating model prev_correct w/ sigma 16 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 21660.497076
#          Iterations: 13
#          Function evaluations: 68
#          Gradient evaluations: 56
#
#  ***** evaluating model prev_choice w/ sigma 0.07 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 21046.642836
#          Iterations: 13
#          Function evaluations: 112
#          Gradient evaluations: 100
#
#  ***** evaluating model prev_choice w/ sigma 0.13 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 21420.516589
#          Iterations: 13
#          Function evaluations: 67
#          Gradient evaluations: 55
#
#  ***** evaluating model prev_choice w/ sigma 0.25 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 21577.427898
#          Iterations: 13
#          Function evaluations: 61
#          Gradient evaluations: 49
#
#  ***** evaluating model prev_choice w/ sigma 0.5 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 21625.965268
#          Iterations: 12
#          Function evaluations: 65
#          Gradient evaluations: 53
#
#  ***** evaluating model prev_choice w/ sigma 1 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 21638.467080
#          Iterations: 12
#          Function evaluations: 90
#          Gradient evaluations: 78
#
#  ***** evaluating model prev_choice w/ sigma 2 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 21641.616211
#          Iterations: 12
#          Function evaluations: 61
#          Gradient evaluations: 49
#
#  ***** evaluating model prev_choice w/ sigma 4 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 21642.404944
#          Iterations: 12
#          Function evaluations: 78
#          Gradient evaluations: 66
#
#  ***** evaluating model prev_choice w/ sigma 8 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 21642.602222
#          Iterations: 14
#          Function evaluations: 69
#          Gradient evaluations: 57
#
#  ***** evaluating model prev_choice w/ sigma 16 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 21642.651546
#          Iterations: 13
#          Function evaluations: 68
#          Gradient evaluations: 56
#
#  >>>> evaluating animal W066 <<<<
#
#  ***** evaluating model stimuli w/ sigma 0.07 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 33069.403667
#          Iterations: 10
#          Function evaluations: 58
#          Gradient evaluations: 46
#
#  ***** evaluating model stimuli w/ sigma 0.13 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 33536.272520
#          Iterations: 9
#          Function evaluations: 62
#          Gradient evaluations: 50
#
#  ***** evaluating model stimuli w/ sigma 0.25 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 33713.412822
#          Iterations: 8
#          Function evaluations: 58
#          Gradient evaluations: 46
#
#  ***** evaluating model stimuli w/ sigma 0.5 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 33766.407304
#          Iterations: 8
#          Function evaluations: 69
#          Gradient evaluations: 57
#
#  ***** evaluating model stimuli w/ sigma 1 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 33779.918102
#          Iterations: 8
#          Function evaluations: 77
#          Gradient evaluations: 65
#
#  ***** evaluating model stimuli w/ sigma 2 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 33783.316448
#          Iterations: 9
#          Function evaluations: 65
#          Gradient evaluations: 53
#
#  ***** evaluating model stimuli w/ sigma 4 *****
# Optimization terminated successfully.
#          Current function value: 33784.166398
#          Iterations: 15
#          Function evaluations: 20
#          Gradient evaluations: 20
#
#  ***** evaluating model stimuli w/ sigma 8 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 33784.378951
#          Iterations: 13
#          Function evaluations: 60
#          Gradient evaluations: 49
#
#  ***** evaluating model stimuli w/ sigma 16 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 33784.432095
#          Iterations: 11
#          Function evaluations: 48
#          Gradient evaluations: 36
#
#  ***** evaluating model prev_stim_viol_mask w/ sigma 0.07 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 32596.274277
#          Iterations: 10
#          Function evaluations: 62
#          Gradient evaluations: 50
#
#  ***** evaluating model prev_stim_viol_mask w/ sigma 0.13 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 33076.179652
#          Iterations: 8
#          Function evaluations: 69
#          Gradient evaluations: 57
#
#  ***** evaluating model prev_stim_viol_mask w/ sigma 0.25 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 33260.180541
#          Iterations: 9
#          Function evaluations: 58
#          Gradient evaluations: 46
#
#  ***** evaluating model prev_stim_viol_mask w/ sigma 0.5 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 33315.308822
#          Iterations: 10
#          Function evaluations: 77
#          Gradient evaluations: 65
#
#  ***** evaluating model prev_stim_viol_mask w/ sigma 1 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 33329.380009
#          Iterations: 10
#          Function evaluations: 66
#          Gradient evaluations: 54
#
#  ***** evaluating model prev_stim_viol_mask w/ sigma 2 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 33332.917926
#          Iterations: 11
#          Function evaluations: 78
#          Gradient evaluations: 66
#
#  ***** evaluating model prev_stim_viol_mask w/ sigma 4 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 33333.803241
#          Iterations: 11
#          Function evaluations: 56
#          Gradient evaluations: 44
#
#  ***** evaluating model prev_stim_viol_mask w/ sigma 8 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 33334.024642
#          Iterations: 11
#          Function evaluations: 72
#          Gradient evaluations: 60
#
#  ***** evaluating model prev_stim_viol_mask w/ sigma 16 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 33334.079997
#          Iterations: 15
#          Function evaluations: 74
#          Gradient evaluations: 63
#
#  ***** evaluating model prev_stim_no_viol_mask w/ sigma 0.07 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 32596.270599
#          Iterations: 10
#          Function evaluations: 60
#          Gradient evaluations: 48
#
#  ***** evaluating model prev_stim_no_viol_mask w/ sigma 0.13 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 33076.406496
#          Iterations: 10
#          Function evaluations: 67
#          Gradient evaluations: 55
#
#  ***** evaluating model prev_stim_no_viol_mask w/ sigma 0.25 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 33260.188450
#          Iterations: 11
#          Function evaluations: 61
#          Gradient evaluations: 49
#
#  ***** evaluating model prev_stim_no_viol_mask w/ sigma 0.5 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 33315.302861
#          Iterations: 9
#          Function evaluations: 65
#          Gradient evaluations: 53
#
#  ***** evaluating model prev_stim_no_viol_mask w/ sigma 1 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 33329.381338
#          Iterations: 11
#          Function evaluations: 83
#          Gradient evaluations: 71
#
#  ***** evaluating model prev_stim_no_viol_mask w/ sigma 2 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 33332.917927
#          Iterations: 11
#          Function evaluations: 68
#          Gradient evaluations: 56
#
#  ***** evaluating model prev_stim_no_viol_mask w/ sigma 4 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 33333.803241
#          Iterations: 11
#          Function evaluations: 72
#          Gradient evaluations: 60
#
#  ***** evaluating model prev_stim_no_viol_mask w/ sigma 8 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 33334.024642
#          Iterations: 12
#          Function evaluations: 63
#          Gradient evaluations: 51
#
#  ***** evaluating model prev_stim_no_viol_mask w/ sigma 16 *****
# Optimization terminated successfully.
#          Current function value: 33334.079997
#          Iterations: 16
#          Function evaluations: 23
#          Gradient evaluations: 23
#
#  ***** evaluating model prev_correct w/ sigma 0.07 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 32071.349592
#          Iterations: 12
#          Function evaluations: 68
#          Gradient evaluations: 56
#
#  ***** evaluating model prev_correct w/ sigma 0.13 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 32566.308755
#          Iterations: 11
#          Function evaluations: 59
#          Gradient evaluations: 47
#
#  ***** evaluating model prev_correct w/ sigma 0.25 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 32757.718828
#          Iterations: 12
#          Function evaluations: 68
#          Gradient evaluations: 56
#
#  ***** evaluating model prev_correct w/ sigma 0.5 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 32815.311736
#          Iterations: 11
#          Function evaluations: 72
#          Gradient evaluations: 60
#
#  ***** evaluating model prev_correct w/ sigma 1 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 32830.038468
#          Iterations: 12
#          Function evaluations: 68
#          Gradient evaluations: 56
#
#  ***** evaluating model prev_correct w/ sigma 2 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 32833.738557
#          Iterations: 12
#          Function evaluations: 73
#          Gradient evaluations: 61
#
#  ***** evaluating model prev_correct w/ sigma 4 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 32834.664981
#          Iterations: 12
#          Function evaluations: 72
#          Gradient evaluations: 60
#
#  ***** evaluating model prev_correct w/ sigma 8 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 32834.896642
#          Iterations: 12
#          Function evaluations: 50
#          Gradient evaluations: 38
#
#  ***** evaluating model prev_correct w/ sigma 16 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 32834.954562
#          Iterations: 13
#          Function evaluations: 78
#          Gradient evaluations: 66
#
#  ***** evaluating model prev_choice w/ sigma 0.07 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 31962.632440
#          Iterations: 13
#          Function evaluations: 61
#          Gradient evaluations: 49
#
#  ***** evaluating model prev_choice w/ sigma 0.13 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 32462.089593
#          Iterations: 13
#          Function evaluations: 88
#          Gradient evaluations: 76
#
#  ***** evaluating model prev_choice w/ sigma 0.25 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 32655.952178
#          Iterations: 12
#          Function evaluations: 69
#          Gradient evaluations: 57
#
#  ***** evaluating model prev_choice w/ sigma 0.5 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 32714.376380
#          Iterations: 13
#          Function evaluations: 79
#          Gradient evaluations: 67
#
#  ***** evaluating model prev_choice w/ sigma 1 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 32729.310684
#          Iterations: 12
#          Function evaluations: 68
#          Gradient evaluations: 56
#
#  ***** evaluating model prev_choice w/ sigma 2 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 32733.067211
#          Iterations: 13
#          Function evaluations: 63
#          Gradient evaluations: 51
#
#  ***** evaluating model prev_choice w/ sigma 4 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 32734.007176
#          Iterations: 13
#          Function evaluations: 75
#          Gradient evaluations: 63
#
#  ***** evaluating model prev_choice w/ sigma 8 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 32734.242258
#          Iterations: 13
#          Function evaluations: 68
#          Gradient evaluations: 57
#
# ...
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 50120.673543
#          Iterations: 12
#          Function evaluations: 71
#          Gradient evaluations: 59
#
#  ***** evaluating model prev_correct w/ sigma 1 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 50132.170606
#          Iterations: 12
#          Function evaluations: 50
#          Gradient evaluations: 38
#
#  ***** evaluating model prev_correct w/ sigma 2 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 50135.052509
#          Iterations: 12
#          Function evaluations: 75
#          Gradient evaluations: 63
#
#  ***** evaluating model prev_correct w/ sigma 4 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 50135.773478
#          Iterations: 12
#          Function evaluations: 65
#          Gradient evaluations: 53
#
#  ***** evaluating model prev_correct w/ sigma 8 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 50135.953749
#          Iterations: 13
#          Function evaluations: 72
#          Gradient evaluations: 60
#
#  ***** evaluating model prev_correct w/ sigma 16 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 50135.998818
#          Iterations: 18
#          Function evaluations: 27
#          Gradient evaluations: 27
#
#  ***** evaluating model prev_choice w/ sigma 0.07 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 49402.668957
#          Iterations: 13
#          Function evaluations: 73
#          Gradient evaluations: 61
#
#  ***** evaluating model prev_choice w/ sigma 0.13 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 49870.357111
#          Iterations: 13
#          Function evaluations: 92
#          Gradient evaluations: 80
#
#  ***** evaluating model prev_choice w/ sigma 0.25 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 50029.132789
#          Iterations: 12
#          Function evaluations: 67
#          Gradient evaluations: 55
#
#  ***** evaluating model prev_choice w/ sigma 0.5 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 50075.030969
#          Iterations: 12
#          Function evaluations: 78
#          Gradient evaluations: 66
#
#  ***** evaluating model prev_choice w/ sigma 1 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 50086.631659
#          Iterations: 12
#          Function evaluations: 72
#          Gradient evaluations: 60
#
#  ***** evaluating model prev_choice w/ sigma 2 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 50089.539174
#          Iterations: 12
#          Function evaluations: 66
#          Gradient evaluations: 54
#
#  ***** evaluating model prev_choice w/ sigma 4 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 50090.266600
#          Iterations: 12
#          Function evaluations: 54
#          Gradient evaluations: 42
#
#  ***** evaluating model prev_choice w/ sigma 8 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 50090.448479
#          Iterations: 12
#          Function evaluations: 63
#          Gradient evaluations: 52
#
#  ***** evaluating model prev_choice w/ sigma 16 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 50090.493950
#          Iterations: 13
#          Function evaluations: 54
#          Gradient evaluations: 43
#
#  >>>> evaluating animal W094 <<<<
#
#  ***** evaluating model stimuli w/ sigma 0.07 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 19596.994684
#          Iterations: 10
#          Function evaluations: 78
#          Gradient evaluations: 66
#
#  ***** evaluating model stimuli w/ sigma 0.13 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 19944.029511
#          Iterations: 10
#          Function evaluations: 55
#          Gradient evaluations: 43
#
#  ***** evaluating model stimuli w/ sigma 0.25 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 20084.518285
#          Iterations: 9
#          Function evaluations: 67
#          Gradient evaluations: 55
#
#  ***** evaluating model stimuli w/ sigma 0.5 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 20127.420222
#          Iterations: 10
#          Function evaluations: 65
#          Gradient evaluations: 53
#
#  ***** evaluating model stimuli w/ sigma 1 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 20138.428793
#          Iterations: 9
#          Function evaluations: 63
#          Gradient evaluations: 51
#
#  ***** evaluating model stimuli w/ sigma 2 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 20141.199035
#          Iterations: 10
#          Function evaluations: 78
#          Gradient evaluations: 66
#
#  ***** evaluating model stimuli w/ sigma 4 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 20141.892730
#          Iterations: 9
#          Function evaluations: 71
#          Gradient evaluations: 59
#
#  ***** evaluating model stimuli w/ sigma 8 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 20142.066229
#          Iterations: 10
#          Function evaluations: 62
#          Gradient evaluations: 50
#
#  ***** evaluating model stimuli w/ sigma 16 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 20142.109607
#          Iterations: 10
#          Function evaluations: 64
#          Gradient evaluations: 52
#
#  ***** evaluating model prev_stim_viol_mask w/ sigma 0.07 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 19524.923867
#          Iterations: 10
#          Function evaluations: 61
#          Gradient evaluations: 49
#
#  ***** evaluating model prev_stim_viol_mask w/ sigma 0.13 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 19874.078589
#          Iterations: 10
#          Function evaluations: 65
#          Gradient evaluations: 53
#
#  ***** evaluating model prev_stim_viol_mask w/ sigma 0.25 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 20015.802911
#          Iterations: 11
#          Function evaluations: 61
#          Gradient evaluations: 49
#
#  ***** evaluating model prev_stim_viol_mask w/ sigma 0.5 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 20059.120586
#          Iterations: 10
#          Function evaluations: 55
#          Gradient evaluations: 43
#
#  ***** evaluating model prev_stim_viol_mask w/ sigma 1 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 20070.239430
#          Iterations: 10
#          Function evaluations: 65
#          Gradient evaluations: 53
#
#  ***** evaluating model prev_stim_viol_mask w/ sigma 2 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 20073.037503
#          Iterations: 10
#          Function evaluations: 77
#          Gradient evaluations: 66
#
#  ***** evaluating model prev_stim_viol_mask w/ sigma 4 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 20073.738176
#          Iterations: 11
#          Function evaluations: 60
#          Gradient evaluations: 48
#
#  ***** evaluating model prev_stim_viol_mask w/ sigma 8 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 20073.913416
#          Iterations: 12
#          Function evaluations: 60
#          Gradient evaluations: 48
#
#  ***** evaluating model prev_stim_viol_mask w/ sigma 16 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 20073.957231
#          Iterations: 11
#          Function evaluations: 61
#          Gradient evaluations: 49
#
#  ***** evaluating model prev_stim_no_viol_mask w/ sigma 0.07 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 19524.925222
#          Iterations: 11
#          Function evaluations: 57
#          Gradient evaluations: 45
#
#  ***** evaluating model prev_stim_no_viol_mask w/ sigma 0.13 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 19874.079521
#          Iterations: 10
#          Function evaluations: 73
#          Gradient evaluations: 61
#
#  ***** evaluating model prev_stim_no_viol_mask w/ sigma 0.25 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 20015.802925
#          Iterations: 11
#          Function evaluations: 56
#          Gradient evaluations: 44
#
#  ***** evaluating model prev_stim_no_viol_mask w/ sigma 0.5 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 20059.121113
#          Iterations: 10
#          Function evaluations: 57
#          Gradient evaluations: 45
#
#  ***** evaluating model prev_stim_no_viol_mask w/ sigma 1 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 20070.239452
#          Iterations: 11
#          Function evaluations: 59
#          Gradient evaluations: 47
#
#  ***** evaluating model prev_stim_no_viol_mask w/ sigma 2 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 20073.037485
#          Iterations: 10
#          Function evaluations: 61
#          Gradient evaluations: 49
#
#  ***** evaluating model prev_stim_no_viol_mask w/ sigma 4 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 20073.738176
#          Iterations: 12
#          Function evaluations: 70
#          Gradient evaluations: 58
#
#  ***** evaluating model prev_stim_no_viol_mask w/ sigma 8 *****
# Optimization terminated successfully.
#          Current function value: 20073.913417
#          Iterations: 15
#          Function evaluations: 23
#          Gradient evaluations: 23
#
#  ***** evaluating model prev_stim_no_viol_mask w/ sigma 16 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 20073.957231
#          Iterations: 12
#          Function evaluations: 76
#          Gradient evaluations: 65
#
#  ***** evaluating model prev_correct w/ sigma 0.07 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 18929.008916
#          Iterations: 16
#          Function evaluations: 59
#          Gradient evaluations: 47
#
#  ***** evaluating model prev_correct w/ sigma 0.13 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 19295.887633
#          Iterations: 13
#          Function evaluations: 74
#          Gradient evaluations: 62
#
#  ***** evaluating model prev_correct w/ sigma 0.25 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 19448.253196
#          Iterations: 12
#          Function evaluations: 69
#          Gradient evaluations: 57
#
#  ***** evaluating model prev_correct w/ sigma 0.5 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 19495.195332
#          Iterations: 11
#          Function evaluations: 61
#          Gradient evaluations: 49
#
#  ***** evaluating model prev_correct w/ sigma 1 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 19507.274667
#          Iterations: 12
#          Function evaluations: 56
#          Gradient evaluations: 44
#
#  ***** evaluating model prev_correct w/ sigma 2 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 19510.316033
#          Iterations: 12
#          Function evaluations: 73
#          Gradient evaluations: 61
#
#  ***** evaluating model prev_correct w/ sigma 4 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 19511.077690
#          Iterations: 12
#          Function evaluations: 58
#          Gradient evaluations: 46
#
#  ***** evaluating model prev_correct w/ sigma 8 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 19511.268190
#          Iterations: 13
#          Function evaluations: 56
#          Gradient evaluations: 44
#
#  ***** evaluating model prev_correct w/ sigma 16 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 19511.315821
#          Iterations: 13
#          Function evaluations: 62
#          Gradient evaluations: 50
#
#  ***** evaluating model prev_choice w/ sigma 0.07 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 18808.832948
#          Iterations: 13
#          Function evaluations: 97
#          Gradient evaluations: 85
#
#  ***** evaluating model prev_choice w/ sigma 0.13 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 19178.652903
#          Iterations: 13
#          Function evaluations: 59
#          Gradient evaluations: 47
#
#  ***** evaluating model prev_choice w/ sigma 0.25 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 19333.196170
#          Iterations: 12
#          Function evaluations: 94
#          Gradient evaluations: 82
#
#  ***** evaluating model prev_choice w/ sigma 0.5 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 19380.897342
#          Iterations: 12
#          Function evaluations: 48
#          Gradient evaluations: 36
#
#  ***** evaluating model prev_choice w/ sigma 1 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 19393.176453
#          Iterations: 13
#          Function evaluations: 68
#          Gradient evaluations: 56
#
#  ***** evaluating model prev_choice w/ sigma 2 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 19396.268855
#          Iterations: 13
#          Function evaluations: 72
#          Gradient evaluations: 60
#
#  ***** evaluating model prev_choice w/ sigma 4 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 19397.043403
#          Iterations: 13
#          Function evaluations: 71
#          Gradient evaluations: 59
#
#  ***** evaluating model prev_choice w/ sigma 8 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 19397.237125
#          Iterations: 13
#          Function evaluations: 85
#          Gradient evaluations: 73
#
#  ***** evaluating model prev_choice w/ sigma 16 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 19397.285561
#          Iterations: 13
#          Function evaluations: 72
#          Gradient evaluations: 60

# %% [markdown]
# ## Visualize

# %%
experiment = load_experiment(save_name)
mvc = ModelVisualizerCompare(experiment)

# %%
df = mvc.find_best_fit(group="model_name")
df["model_name"] = pd.Categorical(df["model_name"], categories=ORDER, ordered=True)
for model_name, model_df in df.groupby("model_name"):
    mvc.plot_sigma_summary(model_df, title=f"{model_name} fit sigma summary")
# Out:
# /var/folders/__/8jn6qz211155h1xb451s5zcr0000gn/T/ipykernel_64133/2431235986.py:3: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   for model_name, model_df in df.groupby("model_name"):
# /Users/jessbreda/anaconda3/envs/an_lrn/lib/python3.10/site-packages/seaborn/categorical.py:641: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   grouped_vals = vals.groupby(grouper)
# /Users/jessbreda/anaconda3/envs/an_lrn/lib/python3.10/site-packages/seaborn/categorical.py:641: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   grouped_vals = vals.groupby(grouper)
# /Users/jessbreda/anaconda3/envs/an_lrn/lib/python3.10/site-packages/seaborn/categorical.py:641: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   grouped_vals = vals.groupby(grouper)
# /Users/jessbreda/anaconda3/envs/an_lrn/lib/python3.10/site-packages/seaborn/categorical.py:641: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   grouped_vals = vals.groupby(grouper)
# /Users/jessbreda/anaconda3/envs/an_lrn/lib/python3.10/site-packages/seaborn/categorical.py:641: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   grouped_vals = vals.groupby(grouper)

# %%
fig, ax = plt.subplots(
    len(ORDER), 1, figsize=(10, len(ORDER) * 6), constrained_layout=True, sharey=False
)

best_fit_by_model = mvc.find_best_fit(group=["animal_id", "model_name"])
best_fit_by_model["model_name"] = pd.Categorical(
    best_fit_by_model["model_name"], categories=ORDER, ordered=True
)

for ii, (model_name, model_df) in enumerate(best_fit_by_model.groupby("model_name")):
    unpacked = mvc.unpack_features_and_weights(model_df)

    mvc.plot_weights_summary(
        df=unpacked,
        ax=ax[ii],
        palette="Set2",
        title=f"{model_name} weights summary",
    )
# Out:
# /var/folders/__/8jn6qz211155h1xb451s5zcr0000gn/T/ipykernel_64133/2667047998.py:10: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   for ii, (model_name, model_df) in enumerate(best_fit_by_model.groupby("model_name")):

# %%
fig, ax = plt.subplots(1, 1, figsize=(8, 5))
mvc.plot_model_comparison(
    hue=None,
    ax=ax,
    order=ORDER,
    errorbar=None,
)

# %%
mvc.plot_train_and_test_ll(
    order=ORDER,
    errorbar=None,
)
# Out:
# /Users/jessbreda/anaconda3/envs/an_lrn/lib/python3.10/site-packages/seaborn/categorical.py:641: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   grouped_vals = vals.groupby(grouper)
# /Users/jessbreda/anaconda3/envs/an_lrn/lib/python3.10/site-packages/seaborn/categorical.py:641: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   grouped_vals = vals.groupby(grouper)

# %%
mvc.plot_ll_delta_by_animal(
    base_model_name=ORDER[0],
    new_model_name=ORDER[1],
    type="test",
)
# Out:
# <Axes: title={'center': 'Model Improvement- mu: 77.51 std: 37.0 \n stimuli -> prev_stim_viol_mask'}, xlabel='animal_id', ylabel='Delta test LL (new - base)'>

# %%
mvc.plot_ll_delta_by_animal(
    base_model_name=ORDER[-3],
    new_model_name=ORDER[-2],
    type="test",
)
# Out:
# <Axes: title={'center': 'Model Improvement- mu: 103.93 std: 130.02 \n prev_stim_no_viol_mask -> prev_correct'}, xlabel='animal_id', ylabel='Delta test LL (new - base)'>

# %%
mvc.plot_ll_delta_by_animal(
    base_model_name=ORDER[-2],
    new_model_name=ORDER[-1],
    type="test",
)
# Out:
# <Axes: title={'center': 'Model Improvement- mu: 17.81 std: 19.66 \n prev_correct -> prev_choice'}, xlabel='animal_id', ylabel='Delta test LL (new - base)'>
