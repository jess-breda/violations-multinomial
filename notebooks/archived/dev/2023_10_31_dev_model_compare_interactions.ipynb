# %% [markdown]
# # Dev Model Compare Interactions
#
# Written on Oct 31 2023 by Jess Breda.
#
# The goal of this notebook is to write some new child classes for a model comparison experiment that can then be re-used for any model comparison experiment.
#
# The specific comparison here is a model with violation history only and a model with violation history + viol history sa/sb interactions.
#
# There are three main classes to write.
#
#
# 1. design matrix generator for violation history (most of this code comes form the base dmg class)
# 2. a model comparison experiment class
#     - this will need to build off of the sigma sweep class to account for iterating over models and fitting a null model
# 3. a model vizualizer comparison class
#     - this will re-format code that has been previously to allow for computing and plotting of bits/trial

# %%
import pandas as pd
import numpy as np

import pathlib
import sys
import seaborn as sns
from matplotlib import pyplot as plt

[
    sys.path.append(str(folder))
    for folder in pathlib.Path("../src/").iterdir()
    if folder.is_dir()
]

from design_matrix_generator import *
from get_rat_data import *
from fitting_utils import create_violation_interaction_pairs

sns.set_context("talk")
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# ### Design Matrix Generator Violation History

# %%
animal_ids = ["W078"]

df = get_rat_viol_data(animal_ids)
# Out:
# returning viol data for ['W078']

# %%
X, y = DesignMatrixGeneratorViolationHistory("multi").generate_design_matrix(df, tau=7)

# %%
X2, y2 = DesignMatrixGeneratorInteractions("multi").generate_design_matrix(
    df,
    tau=7,
    filter_column="prev_violation",
    interaction_pairs=create_violation_interaction_pairs(["s_a", "s_b"]),
)

# %%
X.equals(X2.drop(columns=["prev_violation_exp_x_s_a", "prev_violation_exp_x_s_b"]))
# Out:
# True

# %% [markdown]
# Okay great- Now there is a class DesignMatrixGeneratorViolationHistory and given the same animal df and tau, the columns and labels generated are the same as DesignMatrixGeneratorInteractions when excluding interaction terms. This is due to both functions using the parent class to generate the base matrix and exp filter

# %% [markdown]
# ### Model Compare Experiment Class

# %%
from experiment import Experiment
from multiclass_logistic_regression import MultiClassLogisticRegression
from binary_logistic_regression import BinaryLogisticRegression
from null_model import NullModel

# %%
params = {
    "animals": ["W078"],
    "sigmas": [0.07, 0.13],
    "random_state": 47,
    "null_model": "multi"
    "model_config": {
        "model_class": MultiClassLogisticRegression,
        "model_type": "multi",
        "design_matrix_generator": DesignMatrixGeneratorInteractions,
        "design_matrix_generator_args": {
            "filter_column": "prev_violation",
            "interaction_pairs": create_violation_interaction_pairs(["s_a", "s_b"]),
        },
    },
}

test = Experiment(params)
# Out:
# returning viol data for ['W078']

# %%
test.df
# Out:
#       animal_id  session  trial   s_a   s_b  choice  correct_side  hit  delay
# 0          W078        1      1   NaN   NaN     1.0             0  0.0    1.0  \
# 1          W078        1      2   NaN   NaN     0.0             0  1.0    1.0
# 2          W078        1      3   NaN   NaN     0.0             0  1.0    1.0
# 3          W078        1      4   NaN   NaN     0.0             0  1.0    1.0
# 4          W078        1      5   NaN   NaN     1.0             1  1.0    1.0
# ...         ...      ...    ...   ...   ...     ...           ...  ...    ...
# 53294      W078      200    269  92.0  84.0     0.0             1  0.0    3.1
# 53295      W078      200    270  68.0  76.0     0.0             0  1.0    2.1
# 53296      W078      200    271  68.0  60.0     NaN             1  NaN    3.1
# 53297      W078      200    272  60.0  68.0     NaN             0  NaN    2.1
# 53298      W078      200    273  92.0  84.0     NaN             1  NaN    3.1
#
#        training_stage  violation  n_trial  training_stage_cat
# 0                   1      False  1511189                   1
# 1                   1      False  1511190                   1
# 2                   1      False  1511191                   1
# 3                   1      False  1511192                   1
# 4                   1      False  1511193                   1
# ...               ...        ...      ...                 ...
# 53294               4      False  1564483                   4
# 53295               4      False  1564484                   4
# 53296               4       True  1564485                   4
# 53297               4       True  1564486                   4
# 53298               4       True  1564487                   4
#
# [53299 rows x 13 columns]

# %%
X3, y3 = test.generate_design_matrix_for_animal(
    test.df,
    tau=7,
)

# %%
X2.equals(X3), np.all(y2 == y3)
# Out:
# (True, True)

# %%
params = {
    "animals": ["W078"],
    "sigmas": [0.07, 0.13],
    "random_state": 47,
    "model_config": {
        "model_class": MultiClassLogisticRegression,
        "model_type": "multi",
        "design_matrix_generator": DesignMatrixGeneratorViolationHistory,
    },
}


test2 = Experiment(params)

X4, y4 = test2.generate_design_matrix_for_animal(
    test2.df,
    tau=7,
)

X4.equals(X), np.all(y == y4)
# Out:
# returning viol data for ['W078']
# (True, True)

# %% [markdown]
# Next step: work on writing out the run_single_animal function for comparison experiment using the new parent class functions. Will need to write in a null model class into the part. Will need to take into account where/when train test splitting is happening.

# %%
from multiclass_logistic_regression import MultiClassLogisticRegression
from binary_logistic_regression import BinaryLogisticRegression
from design_matrix_generator import (
    DesignMatrixGeneratorViolationHistory,
    DesignMatrixGeneratorInteractions,
)

model_config = {
    "violation_history": {
        "model_class": MultiClassLogisticRegression,
        "model_type": "multi",
        "design_matrix_generator": DesignMatrixGeneratorViolationHistory,
    },
    "violation_stim_intrx": {
        "model_class": MultiClassLogisticRegression,
        "model_type": "mutli",
        "design_matrix_generator": DesignMatrixGeneratorInteractions,
        "design_matrix_generator_args": {
            "filter_column": "prev_violation",
            "interaction_pairs": create_violation_interaction_pairs(["s_a", "s_b"]),
        },
    },
}
params = {
    "animals": ["W078", "W075"],
    "sigmas": [0.07, 0.13, 13],
    "random_state": 47,
    "null_mode": "multi",
    "model_config": model_config,
}

# %%
from experiment_compare_models import ExperimentCompareModels

exp = ExperimentCompareModels(params)

exp.run()
# Out:
# returning viol data for ['W078', 'W075']
#
#  >>>> evaluating animal W078 <<<<
#
#  ***** evaluating model violation_history w/ sigma 0.07 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 27335.333531
#          Iterations: 22
#          Function evaluations: 37
#          Gradient evaluations: 37
#
#  ***** evaluating model violation_history w/ sigma 0.13 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 26938.678805
#          Iterations: 23
#          Function evaluations: 87
#          Gradient evaluations: 75
#
#  ***** evaluating model violation_history w/ sigma 13 *****
# Optimization terminated successfully.
#          Current function value: 26722.662774
#          Iterations: 22
#          Function evaluations: 34
#          Gradient evaluations: 34
#
#  ***** evaluating model violation_stim_intrx w/ sigma 0.07 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 27304.057314
#          Iterations: 30
#          Function evaluations: 105
#          Gradient evaluations: 93
#
#  ***** evaluating model violation_stim_intrx w/ sigma 0.13 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 26887.726239
#          Iterations: 28
#          Function evaluations: 52
#          Gradient evaluations: 45
#
#  ***** evaluating model violation_stim_intrx w/ sigma 13 *****
# Optimization terminated successfully.
#          Current function value: 26655.863442
#          Iterations: 29
#          Function evaluations: 37
#          Gradient evaluations: 37
#
#  >>>> evaluating animal W075 <<<<
#
#  ***** evaluating model violation_history w/ sigma 0.07 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 42705.984294
#          Iterations: 23
#          Function evaluations: 81
#          Gradient evaluations: 69
#
#  ***** evaluating model violation_history w/ sigma 0.13 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 42392.856967
#          Iterations: 24
#          Function evaluations: 77
#          Gradient evaluations: 65
#
#  ***** evaluating model violation_history w/ sigma 13 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 42210.248759
#          Iterations: 23
#          Function evaluations: 33
#          Gradient evaluations: 33
#
#  ***** evaluating model violation_stim_intrx w/ sigma 0.07 *****
# Optimization terminated successfully.
#          Current function value: 42700.136097
#          Iterations: 31
#          Function evaluations: 46
#          Gradient evaluations: 46
#
#  ***** evaluating model violation_stim_intrx w/ sigma 0.13 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 42377.406665
#          Iterations: 29
#          Function evaluations: 42
#          Gradient evaluations: 42
#
#  ***** evaluating model violation_stim_intrx w/ sigma 13 *****
# Optimization terminated successfully.
#          Current function value: 42186.077645
#          Iterations: 28
#          Function evaluations: 40
#          Gradient evaluations: 40

# %%
exp.fit_models
# Out:
#    animal_id            model_name model_type           nll sigma tau
# 0       W078     violation_history      multi   7548.797155  0.07   2  \
# 1       W078     violation_history      multi   7537.452885  0.13   2
# 2       W078     violation_history      multi   7542.453844    13   2
# 3       W078  violation_stim_intrx      mutli   7526.359831  0.07   2
# 4       W078  violation_stim_intrx      mutli   7503.648327  0.13   2
# 5       W078  violation_stim_intrx      mutli   7499.068803    13   2
# 6       W075     violation_history      multi  10106.856706  0.07   6
# 7       W075     violation_history      multi  10072.359885  0.13   6
# 8       W075     violation_history      multi   10061.47737    13   6
# 9       W075  violation_stim_intrx      mutli  10100.340021  0.07   6
# 10      W075  violation_stim_intrx      mutli  10060.031652  0.13   6
# 11      W075  violation_stim_intrx      mutli  10044.662347    13   6
#
#                                              features
# 0   [bias, s_a, s_b, prev_sound_avg, prev_correct,...  \
# 1   [bias, s_a, s_b, prev_sound_avg, prev_correct,...
# 2   [bias, s_a, s_b, prev_sound_avg, prev_correct,...
# 3   [bias, s_a, s_b, prev_sound_avg, prev_correct,...
# 4   [bias, s_a, s_b, prev_sound_avg, prev_correct,...
# 5   [bias, s_a, s_b, prev_sound_avg, prev_correct,...
# 6   [bias, s_a, s_b, prev_sound_avg, prev_correct,...
# 7   [bias, s_a, s_b, prev_sound_avg, prev_correct,...
# 8   [bias, s_a, s_b, prev_sound_avg, prev_correct,...
# 9   [bias, s_a, s_b, prev_sound_avg, prev_correct,...
# 10  [bias, s_a, s_b, prev_sound_avg, prev_correct,...
# 11  [bias, s_a, s_b, prev_sound_avg, prev_correct,...
#
#                                               weights n_train_trials
# 0   [[0.36764294740206527, 0.36348350802655865, -0...          31403  \
# 1   [[0.3968193098436286, 0.4118227295445373, -0.8...          31403
# 2   [[0.41510302455577597, 0.4456860494159835, -0....          31403
# 3   [[0.3656597605097624, 0.3617417966782676, -0.7...          31403
# 4   [[0.39188986116352603, 0.4056021671930218, -0....          31403
# 5   [[0.4075222596744689, 0.43320663998078235, -0....          31403
# 6   [[0.31101901635185636, 0.2704928878705004, -0....          45703
# 7   [[0.36978768596990524, 0.30851559862993844, -0...          45703
# 8   [[0.41196504909903636, 0.335382790455736, -0.7...          45703
# 9   [[0.31091194135707795, 0.2694342230683333, -0....          45703
# 10  [[0.3690373019747338, 0.30448235453469646, -0....          45703
# 11  [[0.41056371097206024, 0.326906301554999, -0.7...          45703
#
#    n_test_trials
# 0           8461
# 1           8461
# 2           8461
# 3           8461
# 4           8461
# 5           8461
# 6          10832
# 7          10832
# 8          10832
# 9          10832
# 10         10832
# 11         10832

# %%
exp.null_models
# Out:
#   animal_id model_name model_type           nll  n_test_trials
# 0      W078       null      multi   8727.677461           8461  \
# 1      W075       null      multi  11412.302219          10832
#
#    n_train_trials       p_L   n_L       p_R   n_R       p_V   n_V
# 0           31403  0.437419  3701  0.390734  3306  0.171847  1454
# 1           45703  0.397434  4305  0.404450  4381  0.198117  2146

# %% [markdown]
# Okay great- a new experiment has been made and put into it's own .py file. The output looks as expected for both the fitted & null models. Now, lets build a new ModelVisualizer class specifically for comparing. This class will need to:
#
# 1. compute the bits per trial df
#     - merging the fit & null model dfs
# 2. plot model comparison

# %%
from model_visualizer import ModelVisualizerCompare

mvc = ModelVisualizerCompare(exp)

# %%
# Out:
#   animal_id            model_name model_type           nll  sigma  tau
# 0      W075     violation_history      multi  10061.477370  13.00  6.0  \
# 1      W075  violation_stim_intrx      mutli  10044.662347  13.00  6.0
# 2      W078     violation_history      multi   7537.452885   0.13  2.0
# 3      W078  violation_stim_intrx      mutli   7499.068803  13.00  2.0
#
#                                             features
# 0  [bias, s_a, s_b, prev_sound_avg, prev_correct,...  \
# 1  [bias, s_a, s_b, prev_sound_avg, prev_correct,...
# 2  [bias, s_a, s_b, prev_sound_avg, prev_correct,...
# 3  [bias, s_a, s_b, prev_sound_avg, prev_correct,...
#
#                                              weights  n_train_trials
# 0  [[0.41196504909903636, 0.335382790455736, -0.7...           45703  \
# 1  [[0.41056371097206024, 0.326906301554999, -0.7...           45703
# 2  [[0.3968193098436286, 0.4118227295445373, -0.8...           31403
# 3  [[0.4075222596744689, 0.43320663998078235, -0....           31403
#
#    n_test_trials
# 0          10832
# 1          10832
# 2           8461
# 3           8461

# %%
for model_name, model_df in df.groupby("model_name"):
    # TODO- would be nice to clean this up so it's just one plot with a hue as model_name.
    # TODO might need to re-write in MVC or add more flexibility in parent
    mvc.plot_sigma_summary(model_df, title=f"{model_name} fit sigma summary")

# %%
mvc = ModelVisualizerCompare(exp)
mvc.plot_model_comparison(hue="animal_id")

# %%
mvc.plot_nll_over_sigmas_by_animal_by_model()

# %%
df = mvc.find_best_fit(group="model_name")

# %%
for model_name, model_df in df.groupby("model_name"):
    print(model_name)
    mvc.plot_sigma_summary(model_df, title=f"{model_name} fit sigma summary")
# Out:
# violation_history
# violation_stim_intrx
