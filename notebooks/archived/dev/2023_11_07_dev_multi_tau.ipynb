# %% [markdown]
# # Dev Multi Tau
#
# Written on Nov 7 2023 by Jess Breda
#
# The goal of this notebook is to write a new child cases of experiment and design matrix generator that allows for more than previous violation columns to have a tau regressor. This will start by focusing on just prev_choice.
#
# Writing this will be a balance between moving quickly to see if it's worth having the prev_choice_exp regressor and being thoughtful about if I want any other exp regressors in the future.

# %%
import pandas as pd
import numpy as np

import pathlib
import sys
import seaborn as sns
from matplotlib import pyplot as plt

[
    sys.path.append(str(folder))
    for folder in pathlib.Path("../src/").iterdir()
    if folder.is_dir()
]

from design_matrix_generator import *
from get_rat_data import *
from fitting_utils import create_violation_interaction_pairs

sns.set_context("talk")
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# ## Design Matrix Generator with History
#
# Here I am going to work to build a design matrix that makes a bse and then given a history_params dict, adds exp filter for each. Interactions pairs are optional and I will move this function into the parent class to allow for use of it.

# %%
animal_ids = ["W078"]

df = get_rat_viol_data(animal_ids)

filter_params = {
    "prev_violation": 2,  # column to filter, tau of filter
    "prev_choice": 7,
}
# Out:
# returning viol data for ['W078']

# %%
dmgh = DesignMatrixGeneratorFilteredHistory("multi")

X, y = dmgh.generate_design_matrix(
    df, filter_params
)  # NOTE- commeneted! out the drop on line 92 of design_matrix_generator.py to make this

X
# Out:
#        bias  session  prev_violation       s_a       s_b  prev_sound_avg
# 0         1        1               0  0.000000  0.000000        0.000000  \
# 1         1        1               0  0.000000  0.000000        0.000000
# 2         1        1               0  0.000000  0.000000        0.000000
# 3         1        1               0  0.000000  0.000000        0.000000
# 4         1        1               0  0.000000  0.000000        0.000000
# ...     ...      ...             ...       ...       ...             ...
# 53294     1      200               0  1.579978  0.869187       -1.336899
# 53295     1      200               0 -0.860656  0.050722        1.340593
# 53296     1      200               0 -0.860656 -1.586208       -0.444402
# 53297     1      200               1 -1.674200 -0.767743       -0.000000
# 53298     1      200               1  1.579978  0.869187       -0.000000
#
#        prev_correct  prev_choice  prev_violation_exp  prev_choice_exp
# 0               0.0          0.0            0.000000         0.000000
# 1              -1.0          1.0            0.000000         0.149671
# 2              -1.0         -1.0            0.000000        -0.019924
# 3              -1.0         -1.0            0.000000        -0.166943
# 4              -1.0         -1.0            0.000000        -0.294390
# ...             ...          ...                 ...              ...
# 53294           1.0          1.0            0.000000         0.341044
# 53295           1.0         -1.0            0.000000         0.144964
# 53296          -1.0         -1.0            0.000000        -0.025013
# 53297           0.0          0.0            0.396139        -0.022692
# 53298          -0.0          0.0            0.636409        -0.018663
#
# [53299 rows x 10 columns]

# %%
sub_data = X[X["session"] == 50][25:55]

fig, ax = plt.subplots(figsize=(14, 4))
ax.scatter(
    x=range(len(sub_data["prev_choice"])),
    y=sub_data["prev_choice"].values,
    color="red",
    label="prev_choice",
)

ax.plot(
    # x=range(len(sub_data["prev_choice"])),
    sub_data["prev_choice_exp"].values,
    color="gray",
    label="prev_choice_filtered",
    marker="o",
)

ax.axhline(y=0, color="black", zorder=0)

ax.set(
    xlabel="trial",
    ylabel="L < --- V --- > R",
)

ax.legend()

# %% [markdown]
# Okay great- things are looking pretty good. Lets add the option for interaction terms

# %%
dmgh = DesignMatrixGeneratorFilteredHistory("multi")

X, y = dmgh.generate_design_matrix(
    df,
    filter_params,
    interaction_pairs=create_violation_interaction_pairs(["s_a", "s_b"]),
)

X
# Out:
#        bias  session       s_a       s_b  prev_sound_avg  prev_correct
# 0         1        1  0.000000  0.000000        0.000000           0.0  \
# 1         1        1  0.000000  0.000000        0.000000          -1.0
# 2         1        1  0.000000  0.000000        0.000000          -1.0
# 3         1        1  0.000000  0.000000        0.000000          -1.0
# 4         1        1  0.000000  0.000000        0.000000          -1.0
# ...     ...      ...       ...       ...             ...           ...
# 53294     1      200  1.579978  0.869187       -1.336899           1.0
# 53295     1      200 -0.860656  0.050722        1.340593           1.0
# 53296     1      200 -0.860656 -1.586208       -0.444402          -1.0
# 53297     1      200 -1.674200 -0.767743       -0.000000           0.0
# 53298     1      200  1.579978  0.869187       -0.000000          -0.0
#
#        prev_violation_exp  prev_choice_exp  prev_violation_exp_x_s_a
# 0                0.000000         0.000000                  0.000000  \
# 1                0.000000         0.149671                  0.000000
# 2                0.000000        -0.019924                  0.000000
# 3                0.000000        -0.166943                  0.000000
# 4                0.000000        -0.294390                  0.000000
# ...                   ...              ...                       ...
# 53294            0.000000         0.341044                  0.000000
# 53295            0.000000         0.144964                 -0.000000
# 53296            0.000000        -0.025013                 -0.000000
# 53297            0.396139        -0.022692                 -0.663215
# 53298            0.636409        -0.018663                  1.005512
#
#        prev_violation_exp_x_s_b
# 0                      0.000000
# 1                      0.000000
# 2                      0.000000
# 3                      0.000000
# 4                      0.000000
# ...                         ...
# 53294                  0.000000
# 53295                  0.000000
# 53296                 -0.000000
# 53297                 -0.304133
# 53298                  0.553158
#
# [53299 rows x 10 columns]

# %% [markdown]
# Okay- the design matrix is all set up. Now it's time to make te experiment class.

# %% [markdown]
# ## Experiment Tau Sweep

# %%
from multiclass_logistic_regression import MultiClassLogisticRegression

params = {
    "animals": ["W075", "W078"],
    "sigmas": [0.07, 0.13],
    "taus": [1, 2, 3],
    "random_state": 47,
    "tau_sweep": {
        "prev_violation": False,
        "prev_choice": True,
    },
    "model_config": {
        "tau_sweep_prev_choice": {
            "model_class": MultiClassLogisticRegression,
            "model_type": "multi",
            "design_matrix_generator": DesignMatrixGeneratorFilteredHistory,
            "design_matrix_generator_args": {"interaction_pairs": None},
        }
    },
}

# %%
from experiment_tau_sweep import ExperimentTauSweep

test = ExperimentTauSweep(params)
test.run()
# Out:
# returning viol data for ['W075', 'W078']
#
#  >>>> evaluating animal W075 sweeping taus of prev_choice <<<<
#
#  ***** evaluating tau 1, sigma 0.07 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 42579.609896
#          Iterations: 24
#          Function evaluations: 140
#          Gradient evaluations: 121
#
#  ***** evaluating tau 1, sigma 0.13 *****
# Optimization terminated successfully.
#          Current function value: 42258.808420
#          Iterations: 27
#          Function evaluations: 37
#          Gradient evaluations: 37
#
#  ***** evaluating tau 2, sigma 0.07 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 42545.420557
#          Iterations: 24
#          Function evaluations: 32
#          Gradient evaluations: 32
#
#  ***** evaluating tau 2, sigma 0.13 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 42214.705345
#          Iterations: 25
#          Function evaluations: 34
#          Gradient evaluations: 34
#
#  ***** evaluating tau 3, sigma 0.07 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 42557.504167
#          Iterations: 26
#          Function evaluations: 115
#          Gradient evaluations: 99
#
#  ***** evaluating tau 3, sigma 0.13 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 42219.527714
#          Iterations: 25
#          Function evaluations: 35
#          Gradient evaluations: 35
#
#  >>>> evaluating animal W078 sweeping taus of prev_choice <<<<
#
#  ***** evaluating tau 1, sigma 0.07 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 27291.312840
#          Iterations: 23
#          Function evaluations: 74
#          Gradient evaluations: 62
#
#  ***** evaluating tau 1, sigma 0.13 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 26889.097253
#          Iterations: 26
#          Function evaluations: 84
#          Gradient evaluations: 64
#
#  ***** evaluating tau 2, sigma 0.07 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 27289.164459
#          Iterations: 25
#          Function evaluations: 31
#          Gradient evaluations: 31
#
#  ***** evaluating tau 2, sigma 0.13 *****
# Optimization terminated successfully.
#          Current function value: 26881.801756
#          Iterations: 28
#          Function evaluations: 38
#          Gradient evaluations: 38
#
#  ***** evaluating tau 3, sigma 0.07 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 27298.768533
#          Iterations: 28
#          Function evaluations: 121
#          Gradient evaluations: 107
#
#  ***** evaluating tau 3, sigma 0.13 *****
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 26887.890308
#          Iterations: 24
#          Function evaluations: 74
#          Gradient evaluations: 62

# %%
test.fit_models
# Out:
#    animal_id             model_name model_type           nll  sigma
# 0       W075  tau_sweep_prev_choice      multi  10082.037830   0.07  \
# 1       W075  tau_sweep_prev_choice      multi  10048.082946   0.13
# 2       W075  tau_sweep_prev_choice      multi  10064.828507   0.07
# 3       W075  tau_sweep_prev_choice      multi  10031.000967   0.13
# 4       W075  tau_sweep_prev_choice      multi  10057.958412   0.07
# 5       W075  tau_sweep_prev_choice      multi  10023.812468   0.13
# 6       W078  tau_sweep_prev_choice      multi   7518.798072   0.07
# 7       W078  tau_sweep_prev_choice      multi   7505.162613   0.13
# 8       W078  tau_sweep_prev_choice      multi   7507.736863   0.07
# 9       W078  tau_sweep_prev_choice      multi   7491.375541   0.13
# 10      W078  tau_sweep_prev_choice      multi   7504.833585   0.07
# 11      W078  tau_sweep_prev_choice      multi   7485.832720   0.13
#
#                                              features
# 0   [bias, s_a, s_b, prev_sound_avg, prev_correct,...  \
# 1   [bias, s_a, s_b, prev_sound_avg, prev_correct,...
# 2   [bias, s_a, s_b, prev_sound_avg, prev_correct,...
# 3   [bias, s_a, s_b, prev_sound_avg, prev_correct,...
# 4   [bias, s_a, s_b, prev_sound_avg, prev_correct,...
# 5   [bias, s_a, s_b, prev_sound_avg, prev_correct,...
# 6   [bias, s_a, s_b, prev_sound_avg, prev_correct,...
# 7   [bias, s_a, s_b, prev_sound_avg, prev_correct,...
# 8   [bias, s_a, s_b, prev_sound_avg, prev_correct,...
# 9   [bias, s_a, s_b, prev_sound_avg, prev_correct,...
# 10  [bias, s_a, s_b, prev_sound_avg, prev_correct,...
# 11  [bias, s_a, s_b, prev_sound_avg, prev_correct,...
#
#                                               weights  n_train_trials
# 0   [[0.3092295413066796, 0.2690407116971256, -0.5...           45703  \
# 1   [[0.36724045238195324, 0.30728819146358766, -0...           45703
# 2   [[0.3100498831083352, 0.26783346312218376, -0....           45703
# 3   [[0.36770741914844673, 0.3061164164374315, -0....           45703
# 4   [[0.31133995636953266, 0.26725607698090287, -0...           45703
# 5   [[0.3689593356743234, 0.3054138613239409, -0.6...           45703
# 6   [[0.3678358142683213, 0.3620618637468263, -0.7...           31403
# 7   [[0.3968373799132351, 0.4100977283748035, -0.8...           31403
# 8   [[0.36929436723099857, 0.3603325626725628, -0....           31403
# 9   [[0.398138879851586, 0.4081127776898913, -0.80...           31403
# 10  [[0.3701141588693667, 0.359724212769001, -0.72...           31403
# 11  [[0.3987805922042791, 0.40745369635691936, -0....           31403
#
#     n_test_trials  prev_violation_tau  prev_choice_tau
# 0           10832                 6.0              1.0
# 1           10832                 6.0              1.0
# 2           10832                 6.0              2.0
# 3           10832                 6.0              2.0
# 4           10832                 6.0              3.0
# 5           10832                 6.0              3.0
# 6            8461                 2.0              1.0
# 7            8461                 2.0              1.0
# 8            8461                 2.0              2.0
# 9            8461                 2.0              2.0
# 10           8461                 2.0              3.0
# 11           8461                 2.0              3.0

# %% [markdown]
# ## Model Visualizer Tau Sweep

# %%
from model_visualizer import ModelVisualizerTauSweep

mct = ModelVisualizerTauSweep(test)

# %%
mct.plot_tau_summary()

# %%
mct.plot_nll_over_taus_by_animal(group="tau", color="gray")

# %%
mct.plot_best_tau_counts()

# %%
mct.tau_columns
# Out:
# ['prev_violation_tau', 'prev_choice_tau']

# %%
mct.plot_sigma_summary()

# %%
mct.plot_nll_over_sigmas_by_animal(color="gray")

# %%
mct.plot_weights_summary(palette="Set2")

# %%
mct.plot_weights_by_animal(palette="Set2")
