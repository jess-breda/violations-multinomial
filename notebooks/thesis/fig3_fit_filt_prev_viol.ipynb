# %% [markdown]
# # Fig Experiment: Fit Filtered Prev Violation
#
# Fit model with filtered violation hisotry

# %%
import seaborn as sns
import matplotlib.pyplot as plt

from violmulti.experiments.experiment import load_experiment
from violmulti.experiments.experiment_sigma_sweep import ExperimentSigmaSweep
from violmulti.models.multiclass_logistic_regression import MultiClassLogisticRegression
from violmulti.visualizations.model_visualizer import ModelVisualizer
from violmulti.features.design_matrix_generator_PWM import *

from violmulti.visualizations.model_visualizer import *

from violmulti.data import ANIMAL_IDS
from violmulti.experiments import STANDARD_SIGMAS
import config as c

sns.set_context("talk")
# %load_ext autoreload
# %autoreload 2

# %%
dmg_config = {
    "session": lambda df: (copy(df.session)),
    "bias": lambda df: (add_bias_column(df)),
    "s_a": lambda df: (standardize(df.s_a)),
    "s_b": lambda df: (standardize(df.s_b)),
    "filt_prev_violation": lambda df: (
                filtered_prev_viol(df, get_animals_tau(df, "prev_violation"))
            ),
    "prev_stim_avg": lambda df: (prev_avg_stim(df, mask_prev_violation=False)),
    "prev_correct": lambda df: (prev_correct_side(df)),
    "prev_choice": lambda df: (prev_choice(df)),
    "labels": multi_choice_labels(),
}

model_config = {
    "prev_violation": {
        "model_class": MultiClassLogisticRegression,
        "dmg_config": dmg_config,
    }
}


params = {
    "animals": ANIMAL_IDS,
    "data_type": "new_trained",
    "sigmas": STANDARD_SIGMAS,
    "random_state": 47,
    "eval_train": True,
    "null_mode": "multi",
    "model_config": model_config,
}
save_name = "2025_04_09_fig3_fit_filt_prev_violation_rs47.pkl"

# %%
experiment = ExperimentSigmaSweep(params)
experiment.run()
experiment.save(save_name)
# Out:
# Loading dataset type : new_trained
# DataLoader: Loading data for animal ids:  ['W051', 'W060', 'W065', 'W066', 'W068', 'W072', 'W073', 'W074', 'W075', 'W078', 'W080', 'W081', 'W083', 'W088', 'W089', 'W094']
#
#  >>>> evaluating animal W051 <<<<
#
#  ***** evaluating model prev_violation w/ sigma 0.07 *****
# Optimization terminated successfully.
#          Current function value: 64765.082775
#          Iterations: 27
#          Function evaluations: 41
#          Gradient evaluations: 41
#
#  ***** evaluating model prev_violation w/ sigma 0.13 *****
# /Users/jessbreda/anaconda3/envs/viol-multi/lib/python3.10/site-packages/scipy/optimize/_minimize.py:708: OptimizeWarning: Desired error not necessarily achieved due to precision loss.
#   res = _minimize_bfgs(fun, x0, args, jac, callback, **options)
#          Current function value: 64474.828635
#          Iterations: 26
#          Function evaluations: 88
#          Gradient evaluations: 76
#
#  ***** evaluating model prev_violation w/ sigma 0.25 *****
# Optimization terminated successfully.
#          Current function value: 64381.074612
#          Iterations: 26
#          Function evaluations: 39
#          Gradient evaluations: 39
#
#  ***** evaluating model prev_violation w/ sigma 0.5 *****
# /Users/jessbreda/anaconda3/envs/viol-multi/lib/python3.10/site-packages/scipy/optimize/_minimize.py:708: OptimizeWarning: Desired error not necessarily achieved due to precision loss.
#   res = _minimize_bfgs(fun, x0, args, jac, callback, **options)
#          Current function value: 64354.272453
#          Iterations: 25
#          Function evaluations: 88
#          Gradient evaluations: 77
#
#  ***** evaluating model prev_violation w/ sigma 1 *****
# /Users/jessbreda/anaconda3/envs/viol-multi/lib/python3.10/site-packages/scipy/optimize/_minimize.py:708: OptimizeWarning: Desired error not necessarily achieved due to precision loss.
#   res = _minimize_bfgs(fun, x0, args, jac, callback, **options)
#          Current function value: 64347.517616
#          Iterations: 25
#          Function evaluations: 85
#          Gradient evaluations: 73
#
#  ***** evaluating model prev_violation w/ sigma 2 *****
# /Users/jessbreda/anaconda3/envs/viol-multi/lib/python3.10/site-packages/scipy/optimize/_minimize.py:708: OptimizeWarning: Desired error not necessarily achieved due to precision loss.
#   res = _minimize_bfgs(fun, x0, args, jac, callback, **options)
#          Current function value: 64345.825442
#          Iterations: 25
#          Function evaluations: 37
#          Gradient evaluations: 37
#
#  ***** evaluating model prev_violation w/ sigma 4 *****
# Optimization terminated successfully.
#          Current function value: 64345.402181
#          Iterations: 26
#          Function evaluations: 41
#          Gradient evaluations: 41
#
#  ***** evaluating model prev_violation w/ sigma 8 *****
# /Users/jessbreda/anaconda3/envs/viol-multi/lib/python3.10/site-packages/scipy/optimize/_minimize.py:708: OptimizeWarning: Desired error not necessarily achieved due to precision loss.
#   res = _minimize_bfgs(fun, x0, args, jac, callback, **options)
#          Current function value: 64345.296352
#          Iterations: 25
#          Function evaluations: 79
#          Gradient evaluations: 68
#
#  ***** evaluating model prev_violation w/ sigma 16 *****
# Optimization terminated successfully.
#          Current function value: 64345.269894
#          Iterations: 26
#          Function evaluations: 38
#          Gradient evaluations: 38
#
#  >>>> evaluating animal W060 <<<<
#
#  ***** evaluating model prev_violation w/ sigma 0.07 *****
# /Users/jessbreda/anaconda3/envs/viol-multi/lib/python3.10/site-packages/scipy/optimize/_minimize.py:708: OptimizeWarning: Desired error not necessarily achieved due to precision loss.
#   res = _minimize_bfgs(fun, x0, args, jac, callback, **options)
#          Current function value: 51859.573086
#          Iterations: 31
#          Function evaluations: 97
#          Gradient evaluations: 86
#
#  ***** evaluating model prev_violation w/ sigma 0.13 *****
# Optimization terminated successfully.
#          Current function value: 51494.347199
#          Iterations: 30
#          Function evaluations: 43
#          Gradient evaluations: 43
#
#  ***** evaluating model prev_violation w/ sigma 0.25 *****
# Optimization terminated successfully.
#          Current function value: 51373.903698
#          Iterations: 30
#          Function evaluations: 42
#          Gradient evaluations: 42
#
#  ***** evaluating model prev_violation w/ sigma 0.5 *****
# /Users/jessbreda/anaconda3/envs/viol-multi/lib/python3.10/site-packages/scipy/optimize/_minimize.py:708: OptimizeWarning: Desired error not necessarily achieved due to precision loss.
#   res = _minimize_bfgs(fun, x0, args, jac, callback, **options)
#          Current function value: 51339.218947
#          Iterations: 28
#          Function evaluations: 92
#          Gradient evaluations: 80
#
#  ***** evaluating model prev_violation w/ sigma 1 *****
# /Users/jessbreda/anaconda3/envs/viol-multi/lib/python3.10/site-packages/scipy/optimize/_minimize.py:708: OptimizeWarning: Desired error not necessarily achieved due to precision loss.
#   res = _minimize_bfgs(fun, x0, args, jac, callback, **options)
#          Current function value: 51330.458994
#          Iterations: 28
#          Function evaluations: 184
#          Gradient evaluations: 167
#
#  ***** evaluating model prev_violation w/ sigma 2 *****
# /Users/jessbreda/anaconda3/envs/viol-multi/lib/python3.10/site-packages/scipy/optimize/_minimize.py:708: OptimizeWarning: Desired error not necessarily achieved due to precision loss.
#   res = _minimize_bfgs(fun, x0, args, jac, callback, **options)
#          Current function value: 51328.263332
#          Iterations: 27
#          Function evaluations: 76
#          Gradient evaluations: 67
#
#  ***** evaluating model prev_violation w/ sigma 4 *****
# /Users/jessbreda/anaconda3/envs/viol-multi/lib/python3.10/site-packages/scipy/optimize/_minimize.py:708: OptimizeWarning: Desired error not necessarily achieved due to precision loss.
#   res = _minimize_bfgs(fun, x0, args, jac, callback, **options)
#          Current function value: 51327.714059
#          Iterations: 25
#          Function evaluations: 85
#          Gradient evaluations: 74
#
#  ***** evaluating model prev_violation w/ sigma 8 *****
# Optimization terminated successfully.
#          Current function value: 51327.576719
#          Iterations: 26
#          Function evaluations: 37
#          Gradient evaluations: 37
#
#  ***** evaluating model prev_violation w/ sigma 16 *****
# Optimization terminated successfully.
#          Current function value: 51327.542383
#          Iterations: 26
#          Function evaluations: 37
#          Gradient evaluations: 37
#
#  >>>> evaluating animal W065 <<<<
#
#  ***** evaluating model prev_violation w/ sigma 0.07 *****
# /Users/jessbreda/anaconda3/envs/viol-multi/lib/python3.10/site-packages/scipy/optimize/_minimize.py:708: OptimizeWarning: Desired error not necessarily achieved due to precision loss.
#   res = _minimize_bfgs(fun, x0, args, jac, callback, **options)
#          Current function value: 57306.326602
#          Iterations: 26
#          Function evaluations: 61
#          Gradient evaluations: 50
#
#  ***** evaluating model prev_violation w/ sigma 0.13 *****
# /Users/jessbreda/anaconda3/envs/viol-multi/lib/python3.10/site-packages/scipy/optimize/_minimize.py:708: OptimizeWarning: Desired error not necessarily achieved due to precision loss.
#   res = _minimize_bfgs(fun, x0, args, jac, callback, **options)
#          Current function value: 56962.111674
#          Iterations: 24
#          Function evaluations: 68
#          Gradient evaluations: 57
#
#  ***** evaluating model prev_violation w/ sigma 0.25 *****
# /Users/jessbreda/anaconda3/envs/viol-multi/lib/python3.10/site-packages/scipy/optimize/_minimize.py:708: OptimizeWarning: Desired error not necessarily achieved due to precision loss.
#   res = _minimize_bfgs(fun, x0, args, jac, callback, **options)
#          Current function value: 56850.850903
#          Iterations: 24
#          Function evaluations: 92
#          Gradient evaluations: 80
#
#  ***** evaluating model prev_violation w/ sigma 0.5 *****
# Optimization terminated successfully.
#          Current function value: 56819.113003
#          Iterations: 24
#          Function evaluations: 34
#          Gradient evaluations: 34
#
#  ***** evaluating model prev_violation w/ sigma 1 *****
# Optimization terminated successfully.
#          Current function value: 56811.120989
#          Iterations: 24
#          Function evaluations: 34
#          Gradient evaluations: 34
#
#  ***** evaluating model prev_violation w/ sigma 2 *****
# /Users/jessbreda/anaconda3/envs/viol-multi/lib/python3.10/site-packages/scipy/optimize/_minimize.py:708: OptimizeWarning: Desired error not necessarily achieved due to precision loss.
#   res = _minimize_bfgs(fun, x0, args, jac, callback, **options)
#          Current function value: 56809.119347
#          Iterations: 23
#          Function evaluations: 92
#          Gradient evaluations: 80
#
#  ***** evaluating model prev_violation w/ sigma 4 *****
# Optimization terminated successfully.
#          Current function value: 56808.618709
#          Iterations: 24
#          Function evaluations: 36
#          Gradient evaluations: 36
#
#  ***** evaluating model prev_violation w/ sigma 8 *****
# /Users/jessbreda/anaconda3/envs/viol-multi/lib/python3.10/site-packages/scipy/optimize/_minimize.py:708: OptimizeWarning: Desired error not necessarily achieved due to precision loss.
#   res = _minimize_bfgs(fun, x0, args, jac, callback, **options)
#          Current function value: 56808.493535
#          Iterations: 23
#          Function evaluations: 83
#          Gradient evaluations: 72
#
#  ***** evaluating model prev_violation w/ sigma 16 *****
# Optimization terminated successfully.
#          Current function value: 56808.462241
#          Iterations: 24
#          Function evaluations: 34
#          Gradient evaluations: 34
#
#  >>>> evaluating animal W066 <<<<
#
#  ***** evaluating model prev_violation w/ sigma 0.07 *****
# Optimization terminated successfully.
#          Current function value: 85353.480033
#          Iterations: 27
#          Function evaluations: 42
#          Gradient evaluations: 42
#
#  ***** evaluating model prev_violation w/ sigma 0.13 *****
# /Users/jessbreda/anaconda3/envs/viol-multi/lib/python3.10/site-packages/scipy/optimize/_minimize.py:708: OptimizeWarning: Desired error not necessarily achieved due to precision loss.
#   res = _minimize_bfgs(fun, x0, args, jac, callback, **options)
#          Current function value: 84964.195241
#          Iterations: 26
#          Function evaluations: 36
#          Gradient evaluations: 36
#
#  ***** evaluating model prev_violation w/ sigma 0.25 *****
# /Users/jessbreda/anaconda3/envs/viol-multi/lib/python3.10/site-packages/scipy/optimize/_minimize.py:708: OptimizeWarning: Desired error not necessarily achieved due to precision loss.
#   res = _minimize_bfgs(fun, x0, args, jac, callback, **options)
#          Current function value: 84834.724321
#          Iterations: 24
#          Function evaluations: 62
#          Gradient evaluations: 51
#
#  ***** evaluating model prev_violation w/ sigma 0.5 *****
# /Users/jessbreda/anaconda3/envs/viol-multi/lib/python3.10/site-packages/scipy/optimize/_minimize.py:708: OptimizeWarning: Desired error not necessarily achieved due to precision loss.
#   res = _minimize_bfgs(fun, x0, args, jac, callback, **options)
#          Current function value: 84797.244171
#          Iterations: 25
#          Function evaluations: 91
#          Gradient evaluations: 79
#
#  ***** evaluating model prev_violation w/ sigma 1 *****
# Optimization terminated successfully.
#          Current function value: 84787.761377
#          Iterations: 25
#          Function evaluations: 33
#          Gradient evaluations: 33
#
#  ***** evaluating model prev_violation w/ sigma 2 *****
# /Users/jessbreda/anaconda3/envs/viol-multi/lib/python3.10/site-packages/scipy/optimize/_minimize.py:708: OptimizeWarning: Desired error not necessarily achieved due to precision loss.
#   res = _minimize_bfgs(fun, x0, args, jac, callback, **options)
#          Current function value: 84785.383414
#          Iterations: 24
#          Function evaluations: 32
#          Gradient evaluations: 32
#
#  ***** evaluating model prev_violation w/ sigma 4 *****
# /Users/jessbreda/anaconda3/envs/viol-multi/lib/python3.10/site-packages/scipy/optimize/_minimize.py:708: OptimizeWarning: Desired error not necessarily achieved due to precision loss.
#   res = _minimize_bfgs(fun, x0, args, jac, callback, **options)
#          Current function value: 84784.788465
#          Iterations: 24
#          Function evaluations: 32
#          Gradient evaluations: 32
#
#  ***** evaluating model prev_violation w/ sigma 8 *****
# /Users/jessbreda/anaconda3/envs/viol-multi/lib/python3.10/site-packages/scipy/optimize/_minimize.py:708: OptimizeWarning: Desired error not necessarily achieved due to precision loss.
#   res = _minimize_bfgs(fun, x0, args, jac, callback, **options)
#          Current function value: 84784.639699
#          Iterations: 24
#          Function evaluations: 33
#          Gradient evaluations: 33
#
#  ***** evaluating model prev_violation w/ sigma 16 *****
# /Users/jessbreda/anaconda3/envs/viol-multi/lib/python3.10/site-packages/scipy/optimize/_minimize.py:708: OptimizeWarning: Desired error not necessarily achieved due to precision loss.
#   res = _minimize_bfgs(fun, x0, args, jac, callback, **options)
#          Current function value: 84784.602506
#          Iterations: 25
#          Function evaluations: 78
#          Gradient evaluations: 66
#
#  >>>> evaluating animal W068 <<<<
#
#  ***** evaluating model prev_violation w/ sigma 0.07 *****
# /Users/jessbreda/anaconda3/envs/viol-multi/lib/python3.10/site-packages/scipy/optimize/_minimize.py:708: OptimizeWarning: Desired error not necessarily achieved due to precision loss.
#   res = _minimize_bfgs(fun, x0, args, jac, callback, **options)
#          Current function value: 77986.113929
#          Iterations: 24
#          Function evaluations: 108
#          Gradient evaluations: 96
#
#  ***** evaluating model prev_violation w/ sigma 0.13 *****
# Optimization terminated successfully.
#          Current function value: 77702.736306
#          Iterations: 24
#          Function evaluations: 39
#          Gradient evaluations: 39
#
#  ***** evaluating model prev_violation w/ sigma 0.25 *****
# /Users/jessbreda/anaconda3/envs/viol-multi/lib/python3.10/site-packages/scipy/optimize/_minimize.py:708: OptimizeWarning: Desired error not necessarily achieved due to precision loss.
#   res = _minimize_bfgs(fun, x0, args, jac, callback, **options)
#          Current function value: 77609.415389
#          Iterations: 25
#          Function evaluations: 80
#          Gradient evaluations: 66
#
#  ***** evaluating model prev_violation w/ sigma 0.5 *****
# /Users/jessbreda/anaconda3/envs/viol-multi/lib/python3.10/site-packages/scipy/optimize/_minimize.py:708: OptimizeWarning: Desired error not necessarily achieved due to precision loss.
#   res = _minimize_bfgs(fun, x0, args, jac, callback, **options)
#          Current function value: 77582.460325
#          Iterations: 23
#          Function evaluations: 73
#          Gradient evaluations: 61
#
#  ***** evaluating model prev_violation w/ sigma 1 *****
# Optimization terminated successfully.
#          Current function value: 77575.643988
#          Iterations: 24
#          Function evaluations: 37
#          Gradient evaluations: 37
#
#  ***** evaluating model prev_violation w/ sigma 2 *****
# Optimization terminated successfully.
#          Current function value: 77573.934890
#          Iterations: 24
#          Function evaluations: 38
#          Gradient evaluations: 38
#
#  ***** evaluating model prev_violation w/ sigma 4 *****
# /Users/jessbreda/anaconda3/envs/viol-multi/lib/python3.10/site-packages/scipy/optimize/_minimize.py:708: OptimizeWarning: Desired error not necessarily achieved due to precision loss.
#   res = _minimize_bfgs(fun, x0, args, jac, callback, **options)
#          Current function value: 77573.507300
#          Iterations: 23
#          Function evaluations: 90
#          Gradient evaluations: 78
#
#  ***** evaluating model prev_violation w/ sigma 8 *****
# Optimization terminated successfully.
#          Current function value: 77573.400382
#          Iterations: 24
#          Function evaluations: 37
#          Gradient evaluations: 37
#
#  ***** evaluating model prev_violation w/ sigma 16 *****
# Optimization terminated successfully.
#          Current function value: 77573.373651
#          Iterations: 24
#          Function evaluations: 37
#          Gradient evaluations: 37
#
#  >>>> evaluating animal W072 <<<<
#
#  ***** evaluating model prev_violation w/ sigma 0.07 *****
# Optimization terminated successfully.
#          Current function value: 60290.564679
#          Iterations: 26
#          Function evaluations: 39
#          Gradient evaluations: 39
#
#  ***** evaluating model prev_violation w/ sigma 0.13 *****
# Optimization terminated successfully.
#          Current function value: 59930.558207
#          Iterations: 24
#          Function evaluations: 36
#          Gradient evaluations: 36
#
#  ***** evaluating model prev_violation w/ sigma 0.25 *****
# Optimization terminated successfully.
#          Current function value: 59815.853849
#          Iterations: 25
#          Function evaluations: 36
#          Gradient evaluations: 36
#
#  ***** evaluating model prev_violation w/ sigma 0.5 *****
# /Users/jessbreda/anaconda3/envs/viol-multi/lib/python3.10/site-packages/scipy/optimize/_minimize.py:708: OptimizeWarning: Desired error not necessarily achieved due to precision loss.
#   res = _minimize_bfgs(fun, x0, args, jac, callback, **options)
#          Current function value: 59783.294157
#          Iterations: 23
#          Function evaluations: 52
#          Gradient evaluations: 40
#
#  ***** evaluating model prev_violation w/ sigma 1 *****
# /Users/jessbreda/anaconda3/envs/viol-multi/lib/python3.10/site-packages/scipy/optimize/_minimize.py:708: OptimizeWarning: Desired error not necessarily achieved due to precision loss.
#   res = _minimize_bfgs(fun, x0, args, jac, callback, **options)
#          Current function value: 59775.106710
#          Iterations: 23
#          Function evaluations: 95
#          Gradient evaluations: 83
#
#  ***** evaluating model prev_violation w/ sigma 2 *****
# Optimization terminated successfully.
#          Current function value: 59773.056851
#          Iterations: 25
#          Function evaluations: 48
#          Gradient evaluations: 46
#
#  ***** evaluating model prev_violation w/ sigma 4 *****
# Optimization terminated successfully.
#          Current function value: 59772.544198
#          Iterations: 24
#          Function evaluations: 34
#          Gradient evaluations: 34
#
#  ***** evaluating model prev_violation w/ sigma 8 *****
# Optimization terminated successfully.
#          Current function value: 59772.416023
#          Iterations: 25
#          Function evaluations: 38
#          Gradient evaluations: 38
#
#  ***** evaluating model prev_violation w/ sigma 16 *****
# Optimization terminated successfully.
#          Current function value: 59772.383979
#          Iterations: 25
#          Function evaluations: 50
#          Gradient evaluations: 49
#
#  >>>> evaluating animal W073 <<<<
#
#  ***** evaluating model prev_violation w/ sigma 0.07 *****
# /Users/jessbreda/anaconda3/envs/viol-multi/lib/python3.10/site-packages/scipy/optimize/_minimize.py:708: OptimizeWarning: Desired error not necessarily achieved due to precision loss.
#   res = _minimize_bfgs(fun, x0, args, jac, callback, **options)
#          Current function value: 73500.098548
#          Iterations: 29
#          Function evaluations: 78
#          Gradient evaluations: 67
#
#  ***** evaluating model prev_violation w/ sigma 0.13 *****
# /Users/jessbreda/anaconda3/envs/viol-multi/lib/python3.10/site-packages/scipy/optimize/_minimize.py:708: OptimizeWarning: Desired error not necessarily achieved due to precision loss.
#   res = _minimize_bfgs(fun, x0, args, jac, callback, **options)
#          Current function value: 73045.364076
#          Iterations: 26
#          Function evaluations: 69
#          Gradient evaluations: 57
#
#  ***** evaluating model prev_violation w/ sigma 0.25 *****
# /Users/jessbreda/anaconda3/envs/viol-multi/lib/python3.10/site-packages/scipy/optimize/_minimize.py:708: OptimizeWarning: Desired error not necessarily achieved due to precision loss.
#   res = _minimize_bfgs(fun, x0, args, jac, callback, **options)
#          Current function value: 72900.166766
#          Iterations: 27
#          Function evaluations: 77
#          Gradient evaluations: 65
#
#  ***** evaluating model prev_violation w/ sigma 0.5 *****
# /Users/jessbreda/anaconda3/envs/viol-multi/lib/python3.10/site-packages/scipy/optimize/_minimize.py:708: OptimizeWarning: Desired error not necessarily achieved due to precision loss.
#   res = _minimize_bfgs(fun, x0, args, jac, callback, **options)
#          Current function value: 72858.861584
#          Iterations: 26
#          Function evaluations: 92
#          Gradient evaluations: 80
#
#  ***** evaluating model prev_violation w/ sigma 1 *****
# /Users/jessbreda/anaconda3/envs/viol-multi/lib/python3.10/site-packages/scipy/optimize/_minimize.py:708: OptimizeWarning: Desired error not necessarily achieved due to precision loss.
#   res = _minimize_bfgs(fun, x0, args, jac, callback, **options)
#          Current function value: 72848.467208
#          Iterations: 26
#          Function evaluations: 83
#          Gradient evaluations: 71
#
#  ***** evaluating model prev_violation w/ sigma 2 *****
# /Users/jessbreda/anaconda3/envs/viol-multi/lib/python3.10/site-packages/scipy/optimize/_minimize.py:708: OptimizeWarning: Desired error not necessarily achieved due to precision loss.
#   res = _minimize_bfgs(fun, x0, args, jac, callback, **options)
#          Current function value: 72845.864290
#          Iterations: 26
#          Function evaluations: 97
#          Gradient evaluations: 86
#
#  ***** evaluating model prev_violation w/ sigma 4 *****
# /Users/jessbreda/anaconda3/envs/viol-multi/lib/python3.10/site-packages/scipy/optimize/_minimize.py:708: OptimizeWarning: Desired error not necessarily achieved due to precision loss.
#   res = _minimize_bfgs(fun, x0, args, jac, callback, **options)
#          Current function value: 72845.213289
#          Iterations: 28
#          Function evaluations: 131
#          Gradient evaluations: 117
#
#  ***** evaluating model prev_violation w/ sigma 8 *****
# /Users/jessbreda/anaconda3/envs/viol-multi/lib/python3.10/site-packages/scipy/optimize/_minimize.py:708: OptimizeWarning: Desired error not necessarily achieved due to precision loss.
#   res = _minimize_bfgs(fun, x0, args, jac, callback, **options)
#          Current function value: 72845.050522
#          Iterations: 27
#          Function evaluations: 113
#          Gradient evaluations: 100
#
#  ***** evaluating model prev_violation w/ sigma 16 *****
# /Users/jessbreda/anaconda3/envs/viol-multi/lib/python3.10/site-packages/scipy/optimize/_minimize.py:708: OptimizeWarning: Desired error not necessarily achieved due to precision loss.
#   res = _minimize_bfgs(fun, x0, args, jac, callback, **options)
#          Current function value: 72845.009829
#          Iterations: 25
#          Function evaluations: 88
#          Gradient evaluations: 76
#
#  >>>> evaluating animal W074 <<<<
#
#  ***** evaluating model prev_violation w/ sigma 0.07 *****
# /Users/jessbreda/anaconda3/envs/viol-multi/lib/python3.10/site-packages/scipy/optimize/_minimize.py:708: OptimizeWarning: Desired error not necessarily achieved due to precision loss.
#   res = _minimize_bfgs(fun, x0, args, jac, callback, **options)
#          Current function value: 113201.592929
#          Iterations: 36
#          Function evaluations: 176
#          Gradient evaluations: 162
#
#  ***** evaluating model prev_violation w/ sigma 0.13 *****
# Optimization terminated successfully.
#          Current function value: 111946.306680
#          Iterations: 35
#          Function evaluations: 87
#          Gradient evaluations: 84
#
#  ***** evaluating model prev_violation w/ sigma 0.25 *****
# /Users/jessbreda/anaconda3/envs/viol-multi/lib/python3.10/site-packages/scipy/optimize/_minimize.py:708: OptimizeWarning: Desired error not necessarily achieved due to precision loss.
#   res = _minimize_bfgs(fun, x0, args, jac, callback, **options)
#          Current function value: 111529.247462
#          Iterations: 30
#          Function evaluations: 64
#          Gradient evaluations: 52
#
#  ***** evaluating model prev_violation w/ sigma 0.5 *****
# /Users/jessbreda/anaconda3/envs/viol-multi/lib/python3.10/site-packages/scipy/optimize/_minimize.py:708: OptimizeWarning: Desired error not necessarily achieved due to precision loss.
#   res = _minimize_bfgs(fun, x0, args, jac, callback, **options)
#          Current function value: 111409.057447
#          Iterations: 30
#          Function evaluations: 40
#          Gradient evaluations: 40
#
#  ***** evaluating model prev_violation w/ sigma 1 *****
# /Users/jessbreda/anaconda3/envs/viol-multi/lib/python3.10/site-packages/scipy/optimize/_minimize.py:708: OptimizeWarning: Desired error not necessarily achieved due to precision loss.
#   res = _minimize_bfgs(fun, x0, args, jac, callback, **options)
#          Current function value: 111378.701179
#          Iterations: 30
#          Function evaluations: 146
#          Gradient evaluations: 130
#
#  ***** evaluating model prev_violation w/ sigma 2 *****
# /Users/jessbreda/anaconda3/envs/viol-multi/lib/python3.10/site-packages/scipy/optimize/_minimize.py:708: OptimizeWarning: Desired error not necessarily achieved due to precision loss.
#   res = _minimize_bfgs(fun, x0, args, jac, callback, **options)
#          Current function value: 111371.092467
#          Iterations: 28
#          Function evaluations: 70
#          Gradient evaluations: 59
#
#  ***** evaluating model prev_violation w/ sigma 4 *****
# /Users/jessbreda/anaconda3/envs/viol-multi/lib/python3.10/site-packages/scipy/optimize/_minimize.py:708: OptimizeWarning: Desired error not necessarily achieved due to precision loss.
#   res = _minimize_bfgs(fun, x0, args, jac, callback, **options)
#          Current function value: 111369.189055
#          Iterations: 29
#          Function evaluations: 79
#          Gradient evaluations: 67
#
#  ***** evaluating model prev_violation w/ sigma 8 *****
# /Users/jessbreda/anaconda3/envs/viol-multi/lib/python3.10/site-packages/scipy/optimize/_minimize.py:708: OptimizeWarning: Desired error not necessarily achieved due to precision loss.
#   res = _minimize_bfgs(fun, x0, args, jac, callback, **options)
#          Current function value: 111368.713125
#          Iterations: 29
#          Function evaluations: 80
#          Gradient evaluations: 70
#
#  ***** evaluating model prev_violation w/ sigma 16 *****
# /Users/jessbreda/anaconda3/envs/viol-multi/lib/python3.10/site-packages/scipy/optimize/_minimize.py:708: OptimizeWarning: Desired error not necessarily achieved due to precision loss.
#   res = _minimize_bfgs(fun, x0, args, jac, callback, **options)
#          Current function value: 111368.594138
#          Iterations: 28
#          Function evaluations: 93
#          Gradient evaluations: 82
#
#  >>>> evaluating animal W075 <<<<
#
#  ***** evaluating model prev_violation w/ sigma 0.07 *****
# /Users/jessbreda/anaconda3/envs/viol-multi/lib/python3.10/site-packages/scipy/optimize/_minimize.py:708: OptimizeWarning: Desired error not necessarily achieved due to precision loss.
#   res = _minimize_bfgs(fun, x0, args, jac, callback, **options)
#          Current function value: 130106.254788
#          Iterations: 28
#          Function evaluations: 96
#          Gradient evaluations: 85
#
#  ***** evaluating model prev_violation w/ sigma 0.13 *****
# /Users/jessbreda/anaconda3/envs/viol-multi/lib/python3.10/site-packages/scipy/optimize/_minimize.py:708: OptimizeWarning: Desired error not necessarily achieved due to precision loss.
#   res = _minimize_bfgs(fun, x0, args, jac, callback, **options)
#          Current function value: 128976.004647
#          Iterations: 30
#          Function evaluations: 82
#          Gradient evaluations: 70
#
#  ***** evaluating model prev_violation w/ sigma 0.25 *****
# /Users/jessbreda/anaconda3/envs/viol-multi/lib/python3.10/site-packages/scipy/optimize/_minimize.py:708: OptimizeWarning: Desired error not necessarily achieved due to precision loss.
#   res = _minimize_bfgs(fun, x0, args, jac, callback, **options)
#          Current function value: 128586.224929
#          Iterations: 28
#          Function evaluations: 69
#          Gradient evaluations: 57
#
#  ***** evaluating model prev_violation w/ sigma 0.5 *****
# /Users/jessbreda/anaconda3/envs/viol-multi/lib/python3.10/site-packages/scipy/optimize/_minimize.py:708: OptimizeWarning: Desired error not necessarily achieved due to precision loss.
#   res = _minimize_bfgs(fun, x0, args, jac, callback, **options)
#          Current function value: 128472.126062
#          Iterations: 29
#          Function evaluations: 104
#          Gradient evaluations: 92
#
#  ***** evaluating model prev_violation w/ sigma 1 *****
# /Users/jessbreda/anaconda3/envs/viol-multi/lib/python3.10/site-packages/scipy/optimize/_minimize.py:708: OptimizeWarning: Desired error not necessarily achieved due to precision loss.
#   res = _minimize_bfgs(fun, x0, args, jac, callback, **options)
#          Current function value: 128443.170511
#          Iterations: 29
#          Function evaluations: 114
#          Gradient evaluations: 102
#
#  ***** evaluating model prev_violation w/ sigma 2 *****
# /Users/jessbreda/anaconda3/envs/viol-multi/lib/python3.10/site-packages/scipy/optimize/_minimize.py:708: OptimizeWarning: Desired error not necessarily achieved due to precision loss.
#   res = _minimize_bfgs(fun, x0, args, jac, callback, **options)
#          Current function value: 128435.903944
#          Iterations: 27
#          Function evaluations: 76
#          Gradient evaluations: 65
#
#  ***** evaluating model prev_violation w/ sigma 4 *****
# /Users/jessbreda/anaconda3/envs/viol-multi/lib/python3.10/site-packages/scipy/optimize/_minimize.py:708: OptimizeWarning: Desired error not necessarily achieved due to precision loss.
#   res = _minimize_bfgs(fun, x0, args, jac, callback, **options)
#          Current function value: 128434.085560
#          Iterations: 28
#          Function evaluations: 76
#          Gradient evaluations: 65
#
#  ***** evaluating model prev_violation w/ sigma 8 *****
# /Users/jessbreda/anaconda3/envs/viol-multi/lib/python3.10/site-packages/scipy/optimize/_minimize.py:708: OptimizeWarning: Desired error not necessarily achieved due to precision loss.
#   res = _minimize_bfgs(fun, x0, args, jac, callback, **options)
#          Current function value: 128433.630855
#          Iterations: 29
#          Function evaluations: 107
#          Gradient evaluations: 94
#
#  ***** evaluating model prev_violation w/ sigma 16 *****
# /Users/jessbreda/anaconda3/envs/viol-multi/lib/python3.10/site-packages/scipy/optimize/_minimize.py:708: OptimizeWarning: Desired error not necessarily achieved due to precision loss.
#   res = _minimize_bfgs(fun, x0, args, jac, callback, **options)
#          Current function value: 128433.517172
#          Iterations: 29
#          Function evaluations: 39
#          Gradient evaluations: 39
#
#  >>>> evaluating animal W078 <<<<
#
#  ***** evaluating model prev_violation w/ sigma 0.07 *****
# /Users/jessbreda/anaconda3/envs/viol-multi/lib/python3.10/site-packages/scipy/optimize/_minimize.py:708: OptimizeWarning: Desired error not necessarily achieved due to precision loss.
#   res = _minimize_bfgs(fun, x0, args, jac, callback, **options)
#          Current function value: 43987.020757
#          Iterations: 32
#          Function evaluations: 126
#          Gradient evaluations: 117
#
#  ***** evaluating model prev_violation w/ sigma 0.13 *****
# /Users/jessbreda/anaconda3/envs/viol-multi/lib/python3.10/site-packages/scipy/optimize/_minimize.py:708: OptimizeWarning: Desired error not necessarily achieved due to precision loss.
#   res = _minimize_bfgs(fun, x0, args, jac, callback, **options)
#          Current function value: 43479.682152
#          Iterations: 32
#          Function evaluations: 95
#          Gradient evaluations: 84
#
#  ***** evaluating model prev_violation w/ sigma 0.25 *****
# /Users/jessbreda/anaconda3/envs/viol-multi/lib/python3.10/site-packages/scipy/optimize/_minimize.py:708: OptimizeWarning: Desired error not necessarily achieved due to precision loss.
#   res = _minimize_bfgs(fun, x0, args, jac, callback, **options)
#          Current function value: 43313.632213
#          Iterations: 32
#          Function evaluations: 97
#          Gradient evaluations: 85
#
#  ***** evaluating model prev_violation w/ sigma 0.5 *****
# /Users/jessbreda/anaconda3/envs/viol-multi/lib/python3.10/site-packages/scipy/optimize/_minimize.py:708: OptimizeWarning: Desired error not necessarily achieved due to precision loss.
#   res = _minimize_bfgs(fun, x0, args, jac, callback, **options)
#          Current function value: 43266.023345
#          Iterations: 31
#          Function evaluations: 99
#          Gradient evaluations: 87
#
#  ***** evaluating model prev_violation w/ sigma 1 *****
# /Users/jessbreda/anaconda3/envs/viol-multi/lib/python3.10/site-packages/scipy/optimize/_minimize.py:708: OptimizeWarning: Desired error not necessarily achieved due to precision loss.
#   res = _minimize_bfgs(fun, x0, args, jac, callback, **options)
#          Current function value: 43254.016512
#          Iterations: 29
#          Function evaluations: 91
#          Gradient evaluations: 79
#
#  ***** evaluating model prev_violation w/ sigma 2 *****
# /Users/jessbreda/anaconda3/envs/viol-multi/lib/python3.10/site-packages/scipy/optimize/_minimize.py:708: OptimizeWarning: Desired error not necessarily achieved due to precision loss.
#   res = _minimize_bfgs(fun, x0, args, jac, callback, **options)
#          Current function value: 43251.008159
#          Iterations: 30
#          Function evaluations: 40
#          Gradient evaluations: 40
#
#  ***** evaluating model prev_violation w/ sigma 4 *****
# /Users/jessbreda/anaconda3/envs/viol-multi/lib/python3.10/site-packages/scipy/optimize/_minimize.py:708: OptimizeWarning: Desired error not necessarily achieved due to precision loss.
#   res = _minimize_bfgs(fun, x0, args, jac, callback, **options)
#          Current function value: 43250.255654
#          Iterations: 30
#          Function evaluations: 40
#          Gradient evaluations: 40
#
#  ***** evaluating model prev_violation w/ sigma 8 *****
# /Users/jessbreda/anaconda3/envs/viol-multi/lib/python3.10/site-packages/scipy/optimize/_minimize.py:708: OptimizeWarning: Desired error not necessarily achieved due to precision loss.
#   res = _minimize_bfgs(fun, x0, args, jac, callback, **options)
#          Current function value: 43250.067502
#          Iterations: 31
#          Function evaluations: 95
#          Gradient evaluations: 83
#
#  ***** evaluating model prev_violation w/ sigma 16 *****
# /Users/jessbreda/anaconda3/envs/viol-multi/lib/python3.10/site-packages/scipy/optimize/_minimize.py:708: OptimizeWarning: Desired error not necessarily achieved due to precision loss.
#   res = _minimize_bfgs(fun, x0, args, jac, callback, **options)
#          Current function value: 43250.020462
#          Iterations: 29
#          Function evaluations: 82
#          Gradient evaluations: 72
#
#  >>>> evaluating animal W080 <<<<
#
#  ***** evaluating model prev_violation w/ sigma 0.07 *****
# /Users/jessbreda/anaconda3/envs/viol-multi/lib/python3.10/site-packages/scipy/optimize/_minimize.py:708: OptimizeWarning: Desired error not necessarily achieved due to precision loss.
#   res = _minimize_bfgs(fun, x0, args, jac, callback, **options)
#          Current function value: 29347.283998
#          Iterations: 26
#          Function evaluations: 60
#          Gradient evaluations: 49
#
#  ***** evaluating model prev_violation w/ sigma 0.13 *****
# /Users/jessbreda/anaconda3/envs/viol-multi/lib/python3.10/site-packages/scipy/optimize/_minimize.py:708: OptimizeWarning: Desired error not necessarily achieved due to precision loss.
#   res = _minimize_bfgs(fun, x0, args, jac, callback, **options)
#          Current function value: 29077.501981
#          Iterations: 27
#          Function evaluations: 73
#          Gradient evaluations: 61
#
#  ***** evaluating model prev_violation w/ sigma 0.25 *****
# Optimization terminated successfully.
#          Current function value: 28984.170302
#          Iterations: 26
#          Function evaluations: 34
#          Gradient evaluations: 34
#
#  ***** evaluating model prev_violation w/ sigma 0.5 *****
# Optimization terminated successfully.
#          Current function value: 28956.883330
#          Iterations: 25
#          Function evaluations: 32
#          Gradient evaluations: 32
#
#  ***** evaluating model prev_violation w/ sigma 1 *****
# Optimization terminated successfully.
#          Current function value: 28949.962710
#          Iterations: 25
#          Function evaluations: 32
#          Gradient evaluations: 32
#
#  ***** evaluating model prev_violation w/ sigma 2 *****
# Optimization terminated successfully.
#          Current function value: 28948.226237
#          Iterations: 25
#          Function evaluations: 32
#          Gradient evaluations: 32
#
#  ***** evaluating model prev_violation w/ sigma 4 *****
# Optimization terminated successfully.
#          Current function value: 28947.791721
#          Iterations: 26
#          Function evaluations: 73
#          Gradient evaluations: 72
#
#  ***** evaluating model prev_violation w/ sigma 8 *****
# Optimization terminated successfully.
#          Current function value: 28947.683067
#          Iterations: 25
#          Function evaluations: 32
#          Gradient evaluations: 32
#
#  ***** evaluating model prev_violation w/ sigma 16 *****
# Optimization terminated successfully.
#          Current function value: 28947.655902
#          Iterations: 25
#          Function evaluations: 32
#          Gradient evaluations: 32
#
#  >>>> evaluating animal W081 <<<<
#
#  ***** evaluating model prev_violation w/ sigma 0.07 *****
# Optimization terminated successfully.
#          Current function value: 29262.257764
#          Iterations: 22
#          Function evaluations: 34
#          Gradient evaluations: 34
#
#  ***** evaluating model prev_violation w/ sigma 0.13 *****
# Optimization terminated successfully.
#          Current function value: 29022.751450
#          Iterations: 23
#          Function evaluations: 36
#          Gradient evaluations: 36
#
#  ***** evaluating model prev_violation w/ sigma 0.25 *****
# /Users/jessbreda/anaconda3/envs/viol-multi/lib/python3.10/site-packages/scipy/optimize/_minimize.py:708: OptimizeWarning: Desired error not necessarily achieved due to precision loss.
#   res = _minimize_bfgs(fun, x0, args, jac, callback, **options)
#          Current function value: 28939.040057
#          Iterations: 22
#          Function evaluations: 58
#          Gradient evaluations: 56
#
#  ***** evaluating model prev_violation w/ sigma 0.5 *****
# Optimization terminated successfully.
#          Current function value: 28914.422330
#          Iterations: 21
#          Function evaluations: 33
#          Gradient evaluations: 33
#
#  ***** evaluating model prev_violation w/ sigma 1 *****
# /Users/jessbreda/anaconda3/envs/viol-multi/lib/python3.10/site-packages/scipy/optimize/_minimize.py:708: OptimizeWarning: Desired error not necessarily achieved due to precision loss.
#   res = _minimize_bfgs(fun, x0, args, jac, callback, **options)
#          Current function value: 28908.166616
#          Iterations: 20
#          Function evaluations: 80
#          Gradient evaluations: 68
#
#  ***** evaluating model prev_violation w/ sigma 2 *****
# Optimization terminated successfully.
#          Current function value: 28906.596175
#          Iterations: 21
#          Function evaluations: 33
#          Gradient evaluations: 33
#
#  ***** evaluating model prev_violation w/ sigma 4 *****
# Optimization terminated successfully.
#          Current function value: 28906.203154
#          Iterations: 21
#          Function evaluations: 33
#          Gradient evaluations: 33
#
#  ***** evaluating model prev_violation w/ sigma 8 *****
# Optimization terminated successfully.
#          Current function value: 28906.104874
#          Iterations: 21
#          Function evaluations: 33
#          Gradient evaluations: 33
#
#  ***** evaluating model prev_violation w/ sigma 16 *****
# Optimization terminated successfully.
#          Current function value: 28906.080302
#          Iterations: 21
#          Function evaluations: 33
#          Gradient evaluations: 33
#
#  >>>> evaluating animal W083 <<<<
#
#  ***** evaluating model prev_violation w/ sigma 0.07 *****
# /Users/jessbreda/anaconda3/envs/viol-multi/lib/python3.10/site-packages/scipy/optimize/_minimize.py:708: OptimizeWarning: Desired error not necessarily achieved due to precision loss.
#   res = _minimize_bfgs(fun, x0, args, jac, callback, **options)
#          Current function value: 135550.835590
#          Iterations: 27
#          Function evaluations: 41
#          Gradient evaluations: 41
#
#  ***** evaluating model prev_violation w/ sigma 0.13 *****
# /Users/jessbreda/anaconda3/envs/viol-multi/lib/python3.10/site-packages/scipy/optimize/_minimize.py:708: OptimizeWarning: Desired error not necessarily achieved due to precision loss.
#   res = _minimize_bfgs(fun, x0, args, jac, callback, **options)
#          Current function value: 134992.726715
#          Iterations: 27
#          Function evaluations: 41
#          Gradient evaluations: 41
#
#  ***** evaluating model prev_violation w/ sigma 0.25 *****
# Optimization terminated successfully.
#          Current function value: 134813.004256
#          Iterations: 25
#          Function evaluations: 39
#          Gradient evaluations: 39
#
#  ***** evaluating model prev_violation w/ sigma 0.5 *****
# /Users/jessbreda/anaconda3/envs/viol-multi/lib/python3.10/site-packages/scipy/optimize/_minimize.py:708: OptimizeWarning: Desired error not necessarily achieved due to precision loss.
#   res = _minimize_bfgs(fun, x0, args, jac, callback, **options)
#          Current function value: 134761.794715
#          Iterations: 24
#          Function evaluations: 38
#          Gradient evaluations: 38
#
#  ***** evaluating model prev_violation w/ sigma 1 *****
# Optimization terminated successfully.
#          Current function value: 134748.903472
#          Iterations: 24
#          Function evaluations: 37
#          Gradient evaluations: 37
#
#  ***** evaluating model prev_violation w/ sigma 2 *****
# Optimization terminated successfully.
#          Current function value: 134745.675043
#          Iterations: 24
#          Function evaluations: 37
#          Gradient evaluations: 37
#
#  ***** evaluating model prev_violation w/ sigma 4 *****
# Optimization terminated successfully.
#          Current function value: 134744.867583
#          Iterations: 24
#          Function evaluations: 37
#          Gradient evaluations: 37
#
#  ***** evaluating model prev_violation w/ sigma 8 *****
# Optimization terminated successfully.
#          Current function value: 134744.665696
#          Iterations: 24
#          Function evaluations: 37
#          Gradient evaluations: 37
#
#  ***** evaluating model prev_violation w/ sigma 16 *****
# /Users/jessbreda/anaconda3/envs/viol-multi/lib/python3.10/site-packages/scipy/optimize/_minimize.py:708: OptimizeWarning: Desired error not necessarily achieved due to precision loss.
#   res = _minimize_bfgs(fun, x0, args, jac, callback, **options)
#          Current function value: 134744.615223
#          Iterations: 23
#          Function evaluations: 70
#          Gradient evaluations: 58
#
#  >>>> evaluating animal W088 <<<<
#
#  ***** evaluating model prev_violation w/ sigma 0.07 *****
# /Users/jessbreda/anaconda3/envs/viol-multi/lib/python3.10/site-packages/scipy/optimize/_minimize.py:708: OptimizeWarning: Desired error not necessarily achieved due to precision loss.
#   res = _minimize_bfgs(fun, x0, args, jac, callback, **options)
#          Current function value: 76796.349620
#          Iterations: 25
#          Function evaluations: 91
#          Gradient evaluations: 79
#
#  ***** evaluating model prev_violation w/ sigma 0.13 *****
# /Users/jessbreda/anaconda3/envs/viol-multi/lib/python3.10/site-packages/scipy/optimize/_minimize.py:708: OptimizeWarning: Desired error not necessarily achieved due to precision loss.
#   res = _minimize_bfgs(fun, x0, args, jac, callback, **options)
#          Current function value: 76311.380984
#          Iterations: 24
#          Function evaluations: 82
#          Gradient evaluations: 72
#
#  ***** evaluating model prev_violation w/ sigma 0.25 *****
# /Users/jessbreda/anaconda3/envs/viol-multi/lib/python3.10/site-packages/scipy/optimize/_minimize.py:708: OptimizeWarning: Desired error not necessarily achieved due to precision loss.
#   res = _minimize_bfgs(fun, x0, args, jac, callback, **options)
#          Current function value: 76151.561087
#          Iterations: 24
#          Function evaluations: 85
#          Gradient evaluations: 73
#
#  ***** evaluating model prev_violation w/ sigma 0.5 *****
# /Users/jessbreda/anaconda3/envs/viol-multi/lib/python3.10/site-packages/scipy/optimize/_minimize.py:708: OptimizeWarning: Desired error not necessarily achieved due to precision loss.
#   res = _minimize_bfgs(fun, x0, args, jac, callback, **options)
#          Current function value: 76105.643457
#          Iterations: 23
#          Function evaluations: 44
#          Gradient evaluations: 38
#
#  ***** evaluating model prev_violation w/ sigma 1 *****
# /Users/jessbreda/anaconda3/envs/viol-multi/lib/python3.10/site-packages/scipy/optimize/_minimize.py:708: OptimizeWarning: Desired error not necessarily achieved due to precision loss.
#   res = _minimize_bfgs(fun, x0, args, jac, callback, **options)
#          Current function value: 76094.056575
#          Iterations: 23
#          Function evaluations: 34
#          Gradient evaluations: 34
#
#  ***** evaluating model prev_violation w/ sigma 2 *****
# Optimization terminated successfully.
#          Current function value: 76091.153030
#          Iterations: 24
#          Function evaluations: 34
#          Gradient evaluations: 34
#
#  ***** evaluating model prev_violation w/ sigma 4 *****
# Optimization terminated successfully.
#          Current function value: 76090.426716
#          Iterations: 24
#          Function evaluations: 34
#          Gradient evaluations: 34
#
#  ***** evaluating model prev_violation w/ sigma 8 *****
# Optimization terminated successfully.
#          Current function value: 76090.245111
#          Iterations: 24
#          Function evaluations: 34
#          Gradient evaluations: 34
#
#  ***** evaluating model prev_violation w/ sigma 16 *****
# /Users/jessbreda/anaconda3/envs/viol-multi/lib/python3.10/site-packages/scipy/optimize/_minimize.py:708: OptimizeWarning: Desired error not necessarily achieved due to precision loss.
#   res = _minimize_bfgs(fun, x0, args, jac, callback, **options)
#          Current function value: 76090.199708
#          Iterations: 23
#          Function evaluations: 91
#          Gradient evaluations: 79
#
#  >>>> evaluating animal W089 <<<<
#
#  ***** evaluating model prev_violation w/ sigma 0.07 *****
# /Users/jessbreda/anaconda3/envs/viol-multi/lib/python3.10/site-packages/scipy/optimize/_minimize.py:708: OptimizeWarning: Desired error not necessarily achieved due to precision loss.
#   res = _minimize_bfgs(fun, x0, args, jac, callback, **options)
#          Current function value: 92654.732249
#          Iterations: 32
#          Function evaluations: 80
#          Gradient evaluations: 68
#
#  ***** evaluating model prev_violation w/ sigma 0.13 *****
# Optimization terminated successfully.
#          Current function value: 92191.363776
#          Iterations: 32
#          Function evaluations: 46
#          Gradient evaluations: 46
#
#  ***** evaluating model prev_violation w/ sigma 0.25 *****
# /Users/jessbreda/anaconda3/envs/viol-multi/lib/python3.10/site-packages/scipy/optimize/_minimize.py:708: OptimizeWarning: Desired error not necessarily achieved due to precision loss.
#   res = _minimize_bfgs(fun, x0, args, jac, callback, **options)
#          Current function value: 92039.256445
#          Iterations: 30
#          Function evaluations: 114
#          Gradient evaluations: 101
#
#  ***** evaluating model prev_violation w/ sigma 0.5 *****
# /Users/jessbreda/anaconda3/envs/viol-multi/lib/python3.10/site-packages/scipy/optimize/_minimize.py:708: OptimizeWarning: Desired error not necessarily achieved due to precision loss.
#   res = _minimize_bfgs(fun, x0, args, jac, callback, **options)
#          Current function value: 91995.612778
#          Iterations: 28
#          Function evaluations: 95
#          Gradient evaluations: 84
#
#  ***** evaluating model prev_violation w/ sigma 1 *****
# /Users/jessbreda/anaconda3/envs/viol-multi/lib/python3.10/site-packages/scipy/optimize/_minimize.py:708: OptimizeWarning: Desired error not necessarily achieved due to precision loss.
#   res = _minimize_bfgs(fun, x0, args, jac, callback, **options)
#          Current function value: 91984.603974
#          Iterations: 29
#          Function evaluations: 88
#          Gradient evaluations: 77
#
#  ***** evaluating model prev_violation w/ sigma 2 *****
# /Users/jessbreda/anaconda3/envs/viol-multi/lib/python3.10/site-packages/scipy/optimize/_minimize.py:708: OptimizeWarning: Desired error not necessarily achieved due to precision loss.
#   res = _minimize_bfgs(fun, x0, args, jac, callback, **options)
#          Current function value: 91981.845562
#          Iterations: 29
#          Function evaluations: 116
#          Gradient evaluations: 101
#
#  ***** evaluating model prev_violation w/ sigma 4 *****
# /Users/jessbreda/anaconda3/envs/viol-multi/lib/python3.10/site-packages/scipy/optimize/_minimize.py:708: OptimizeWarning: Desired error not necessarily achieved due to precision loss.
#   res = _minimize_bfgs(fun, x0, args, jac, callback, **options)
#          Current function value: 91981.155569
#          Iterations: 29
#          Function evaluations: 174
#          Gradient evaluations: 159
#
#  ***** evaluating model prev_violation w/ sigma 8 *****
# /Users/jessbreda/anaconda3/envs/viol-multi/lib/python3.10/site-packages/scipy/optimize/_minimize.py:708: OptimizeWarning: Desired error not necessarily achieved due to precision loss.
#   res = _minimize_bfgs(fun, x0, args, jac, callback, **options)
#          Current function value: 91980.983047
#          Iterations: 28
#          Function evaluations: 38
#          Gradient evaluations: 38
#
#  ***** evaluating model prev_violation w/ sigma 16 *****
# /Users/jessbreda/anaconda3/envs/viol-multi/lib/python3.10/site-packages/scipy/optimize/_minimize.py:708: OptimizeWarning: Desired error not necessarily achieved due to precision loss.
#   res = _minimize_bfgs(fun, x0, args, jac, callback, **options)
#          Current function value: 91980.939914
#          Iterations: 27
#          Function evaluations: 84
#          Gradient evaluations: 72
#
#  >>>> evaluating animal W094 <<<<
#
#  ***** evaluating model prev_violation w/ sigma 0.07 *****
# Optimization terminated successfully.
#          Current function value: 45574.307374
#          Iterations: 27
#          Function evaluations: 75
#          Gradient evaluations: 70
#
#  ***** evaluating model prev_violation w/ sigma 0.13 *****
# Optimization terminated successfully.
#          Current function value: 45081.237014
#          Iterations: 25
#          Function evaluations: 35
#          Gradient evaluations: 35
#
#  ***** evaluating model prev_violation w/ sigma 0.25 *****
# Optimization terminated successfully.
#          Current function value: 44890.523301
#          Iterations: 25
#          Function evaluations: 36
#          Gradient evaluations: 36
#
#  ***** evaluating model prev_violation w/ sigma 0.5 *****
# /Users/jessbreda/anaconda3/envs/viol-multi/lib/python3.10/site-packages/scipy/optimize/_minimize.py:708: OptimizeWarning: Desired error not necessarily achieved due to precision loss.
#   res = _minimize_bfgs(fun, x0, args, jac, callback, **options)
#          Current function value: 44831.802838
#          Iterations: 25
#          Function evaluations: 83
#          Gradient evaluations: 71
#
#  ***** evaluating model prev_violation w/ sigma 1 *****
# Optimization terminated successfully.
#          Current function value: 44816.662800
#          Iterations: 25
#          Function evaluations: 35
#          Gradient evaluations: 35
#
#  ***** evaluating model prev_violation w/ sigma 2 *****
# /Users/jessbreda/anaconda3/envs/viol-multi/lib/python3.10/site-packages/scipy/optimize/_minimize.py:708: OptimizeWarning: Desired error not necessarily achieved due to precision loss.
#   res = _minimize_bfgs(fun, x0, args, jac, callback, **options)
#          Current function value: 44812.847571
#          Iterations: 25
#          Function evaluations: 113
#          Gradient evaluations: 99
#
#  ***** evaluating model prev_violation w/ sigma 4 *****
# /Users/jessbreda/anaconda3/envs/viol-multi/lib/python3.10/site-packages/scipy/optimize/_minimize.py:708: OptimizeWarning: Desired error not necessarily achieved due to precision loss.
#   res = _minimize_bfgs(fun, x0, args, jac, callback, **options)
#          Current function value: 44811.891851
#          Iterations: 23
#          Function evaluations: 78
#          Gradient evaluations: 66
#
#  ***** evaluating model prev_violation w/ sigma 8 *****
# /Users/jessbreda/anaconda3/envs/viol-multi/lib/python3.10/site-packages/scipy/optimize/_minimize.py:708: OptimizeWarning: Desired error not necessarily achieved due to precision loss.
#   res = _minimize_bfgs(fun, x0, args, jac, callback, **options)
#          Current function value: 44811.652801
#          Iterations: 24
#          Function evaluations: 85
#          Gradient evaluations: 73
#
#  ***** evaluating model prev_violation w/ sigma 16 *****
#          Current function value: 44811.593031
#          Iterations: 25
#          Function evaluations: 130
#          Gradient evaluations: 116
# /Users/jessbreda/anaconda3/envs/viol-multi/lib/python3.10/site-packages/scipy/optimize/_minimize.py:708: OptimizeWarning: Desired error not necessarily achieved due to precision loss.
#   res = _minimize_bfgs(fun, x0, args, jac, callback, **options)

# %% [markdown]
# ### Visualize

# %%
exp = load_experiment(save_name)
mv = ModelVisualizer(exp)

# %%
mv.plot_sigma_summary()

# %%
mv.plot_weights_summary(palette=c.MULTI_CHOICE_PAL)

# %%
mv.plot_nll_over_sigmas_by_animal()

# %%
mv.plot_weights_by_animal(palette=c.MULTI_CHOICE_PAL)
