# %% [markdown]
# # 2024-01-31 Dataset Alignment
#
# **Goal**: For each animal, align old and new datasets and create summary figure. Additionally, across animals, make a single summary figure of how specified metrics change.
#
# Old is defined as the publicly available dataset from the
# Akrami et al. 2018 paper.
#
# New is defined as the re-make of the old dataset. Specifically,
# the animals are the same, but the data set annotates violations
# for all sessions (old dataset stopped around session 100) and
# also marks timeouts (old dataset marked timeouts as violations).
#
#
# Related notebooks
# - `2024_01_26_dev_dataset_alignment_and_validation.ipynb`
# - `2024_01_22_explore_w078_dataset_remake.ipynb`
#
# *NOTE*: this notebook was initial run with W084- but this is not an animal in the dataset, which is why all values were 0.

# %%
from multiglm.data import ANIMAL_IDS
from multiglm.data.dataset_alignment import (
    align_and_visualize_datasets,
    PostAlignmentVisualizer,
)

import matplotlib.pyplot as plt

# %load_ext autoreload
# %autoreload 2

# %%
print(ANIMAL_IDS)
# Out:
# ['W051', 'W060', 'W061', 'W062', 'W065', 'W066', 'W068', 'W072', 'W073', 'W074', 'W075', 'W078', 'W080', 'W081', 'W082', 'W083', 'W088', 'W089', 'W094']

# %%
align_and_visualize_datasets(ANIMAL_IDS)
# Out:
# ** RUNNING W051 **
# returning full data for W051
# returning truncated viol data for W051
# alignment data already exists for W051
# returning new data for W051
# returning new data with no touts for W051
# alignment summary data across dfs already computed for W051
# figure saved for W051
# ** RUNNING W060 **
# returning full data for W060
# returning truncated viol data for W060
# alignment data already exists for W060
# returning new data for W060
# returning new data with no touts for W060
# alignment summary data across dfs already computed for W060
# figure saved for W060
# ** RUNNING W061 **
# returning full data for W061
# returning truncated viol data for W061
# alignment data already exists for W061
# returning new data for W061
# returning new data with no touts for W061
# alignment summary data across dfs already computed for W061
# figure saved for W061
# ** RUNNING W062 **
# returning full data for W062
# returning truncated viol data for W062
# alignment data already exists for W062
# returning new data for W062
# returning new data with no touts for W062
# alignment summary data across dfs already computed for W062
# figure saved for W062
# ** RUNNING W065 **
# returning full data for W065
# returning truncated viol data for W065
# alignment data already exists for W065
# returning new data for W065
# returning new data with no touts for W065
# alignment summary data across dfs already computed for W065
# figure saved for W065
# ** RUNNING W066 **
# returning full data for W066
# returning truncated viol data for W066
# alignment data already exists for W066
# returning new data for W066
# returning new data with no touts for W066
# alignment summary data across dfs already computed for W066
# figure saved for W066
# ** RUNNING W068 **
# returning full data for W068
# returning truncated viol data for W068
# new to old alignment df created containing W068
# returning new data for W068
# returning new data with no touts for W068
# saved alignment summary data across dfs for W068
# figure saved for W068
# ** RUNNING W072 **
# returning full data for W072
# returning truncated viol data for W072
# new to old alignment df created containing W072
# returning new data for W072
# returning new data with no touts for W072
# saved alignment summary data across dfs for W072
# figure saved for W072
# ** RUNNING W073 **
# returning full data for W073
# returning truncated viol data for W073
# new to old alignment df created containing W073
# returning new data for W073
# returning new data with no touts for W073
# saved alignment summary data across dfs for W073
# figure saved for W073
# ** RUNNING W074 **
# returning full data for W074
# returning truncated viol data for W074
# alignment data already exists for W074
# returning new data for W074
# returning new data with no touts for W074
# alignment summary data across dfs already computed for W074
# figure saved for W074
# ** RUNNING W075 **
# returning full data for W075
# returning truncated viol data for W075
# alignment data already exists for W075
# returning new data for W075
# returning new data with no touts for W075
# alignment summary data across dfs already computed for W075
# figure saved for W075
# ** RUNNING W078 **
# returning full data for W078
# returning truncated viol data for W078
# alignment data already exists for W078
# returning new data for W078
# returning new data with no touts for W078
# alignment summary data across dfs already computed for W078
# figure saved for W078
# ** RUNNING W080 **
# returning full data for W080
# returning truncated viol data for W080
# alignment data already exists for W080
# returning new data for W080
# returning new data with no touts for W080
# alignment summary data across dfs already computed for W080
# figure saved for W080
# ** RUNNING W081 **
# returning full data for W081
# returning truncated viol data for W081
# alignment data already exists for W081
# returning new data for W081
# returning new data with no touts for W081
# alignment summary data across dfs already computed for W081
# figure saved for W081
# ** RUNNING W082 **
# returning full data for W082
# returning truncated viol data for W082
# alignment data already exists for W082
# returning new data for W082
# returning new data with no touts for W082
# alignment summary data across dfs already computed for W082
# figure saved for W082
# ** RUNNING W083 **
# returning full data for W083
# returning truncated viol data for W083
# alignment data already exists for W083
# returning new data for W083
# returning new data with no touts for W083
# alignment summary data across dfs already computed for W083
# figure saved for W083
# ** RUNNING W088 **
# returning full data for W088
# returning truncated viol data for W088
# alignment data already exists for W088
# returning new data for W088
# returning new data with no touts for W088
# alignment summary data across dfs already computed for W088
# figure saved for W088
# ** RUNNING W089 **
# returning full data for W089
# returning truncated viol data for W089
# alignment data already exists for W089
# returning new data for W089
# returning new data with no touts for W089
# alignment summary data across dfs already computed for W089
# figure saved for W089
# ** RUNNING W094 **
# returning full data for W094
# returning truncated viol data for W094
# alignment data already exists for W094
# returning new data for W094
# returning new data with no touts for W094
# alignment summary data across dfs already computed for W094
# figure saved for W094

# %%
summary = PostAlignmentVisualizer(ANIMAL_IDS)

# %%
fig, ax = plt.subplots(figsize=(10, 3))

dd = summary.compute_and_plot_delta(
    "new",
    "old",
    "n_sessions",
    color="black",
    title="$\Delta$ Number of Sessions",
    ax=ax,
)
ax.axhline(dd.delta_n_sessions.mean(), color="black", linestyle="--")

# %%
fig, ax = plt.subplots(figsize=(10, 3))
dd = summary.compute_and_plot_delta(
    "new_no_touts",
    "old",
    "n_trials_per_session",
    color="green",
    title="$\Delta$ Number of Trials per Session",
    ax=ax,
)

ax.axhline(dd.delta_n_trials_per_session.mean(), color="green", linestyle="--")

# %%
fig, ax = plt.subplots(figsize=(10, 3))
dd = summary.compute_and_plot_delta(
    "new_no_touts", "old", "session_avg_violation", color="purple", ax=ax
)

ax.axhline(dd.delta_session_avg_violation.mean(), color="purple", linestyle="--")

# %%
fig, ax = plt.subplots(figsize=(10, 3))
dd = summary.compute_and_plot_delta(
    "new_no_touts",
    "old",
    "session_avg_violation_stage_4",
    ax=ax,
    color="purple",
    title="$\Delta$ Violation/Session Stage 4",
)

ax.axhline(
    dd.delta_session_avg_violation_stage_4.mean(), color="purple", linestyle="--"
)
